# %%
import scanpy as sc
data_dir = '../../dataset/merfish_human_neocortex_SSL.h5ad'
adata = sc.read_h5ad(data_dir)
adata.X = adata.raw.X.copy()
print(adata.X)
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 12532157 stored elements and shape (234125, 300)>
#   Coords	Values
#   (0, 9)	5
#   (0, 16)	2
#   (0, 18)	3
#   (0, 23)	1
#   (0, 24)	1
#   (0, 25)	5
#   (0, 27)	1
#   (0, 28)	1
#   (0, 29)	6
#   (0, 30)	1
#   (0, 31)	1
#   (0, 34)	6
#   (0, 37)	1
#   (0, 45)	21
#   (0, 46)	1
#   (0, 53)	1
#   (0, 58)	1
#   (0, 60)	1
#   (0, 61)	1
#   (0, 67)	2
#   (0, 68)	1
#   (0, 74)	1
#   (0, 81)	1
#   (0, 86)	1
#   (0, 87)	2
#   :	:
#   (234123, 261)	1
#   (234124, 14)	2
#   (234124, 18)	1
#   (234124, 25)	3
#   (234124, 55)	1
#   (234124, 58)	1
#   (234124, 62)	1
#   (234124, 66)	1
#   (234124, 75)	1
#   (234124, 89)	1
#   (234124, 104)	1
#   (234124, 106)	1
#   (234124, 107)	1
#   (234124, 117)	2
#   (234124, 126)	1
#   (234124, 146)	3
#   (234124, 171)	1
#   (234124, 184)	1
#   (234124, 200)	1
#   (234124, 215)	3
#   (234124, 221)	1
#   (234124, 237)	1
#   (234124, 251)	1
#   (234124, 261)	1
#   (234124, 297)	1

# %%
import torch
from torch import nn
import lightning.pytorch as pl
from self_supervision.models.lightning_modules.cellnet_autoencoder import MLPAutoEncoder
from self_supervision.estimator.cellnet import EstimatorAutoEncoder



# 模型参数
units_encoder = [512, 512, 256, 256, 64]
units_decoder = [256, 256, 512, 512]

# 初始化 EstimatorAutoEncoder 实例
estim = EstimatorAutoEncoder(data_path=None)  # 如果没有实际数据路径，可以设置为None

# 加载预训练模型
estim.model = MLPAutoEncoder(
    gene_dim=19331,  # 根据你的数据调整
    batch_size=128,  # 根据你的需要调整
    units_encoder=units_encoder, 
    units_decoder=units_decoder,
    masking_strategy="random",  # 假设模型使用了随机掩码
    masking_rate=0.5,  # 根据需要调整
)

# 使用 GPU 进行评估（如果可用）
estim.trainer = pl.Trainer(accelerator="gpu", devices=1 if torch.cuda.is_available() else None)
estim.model
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/tf.py:52: UserWarning: Tensorflow dtype mappings did not load successfully due to an error: No module named 'tensorflow'
#   warn(f"Tensorflow dtype mappings did not load successfully due to an error: {exc.msg}")
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# MLPAutoEncoder(
#   (train_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=train_
#   )
#   (val_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=val_
#   )
#   (test_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=test_
#   )
#   (encoder): MLP(
#     (0): Linear(in_features=19331, out_features=512, bias=True)
#     (1): SELU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SELU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SELU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): SELU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=True)
#   )
#   (decoder): Sequential(
#     (0): MLP(
#       (0): Linear(in_features=64, out_features=256, bias=True)
#       (1): SELU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SELU()
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=256, out_features=512, bias=True)
#       (7): SELU()
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SELU()
#       (11): Dropout(p=0.1, inplace=False)
#       (12): Linear(in_features=512, out_features=19331, bias=True)
#     )
#     (1): Sigmoid()
#   )
# )

# %%
# 添加分类层 (FC)
n_classes = len(adata.obs['cell_type'].unique())
estim.model.fc = nn.Linear(units_encoder[-1], n_classes)
n_classes
# Out:
# 29

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# features
# TFAP2C          TFAP2C
# HGF                HGF
# NAMPT            NAMPT
# VIM                VIM
# CD38              CD38
#                ...
# LINC01170    LINC01170
# SATB1-AS1    SATB1-AS1
# CFAP54          CFAP54
# RMST              RMST
# NOTCH1          NOTCH1
# Name: gene_name, Length: 300, dtype: object

# %%
import numpy as np
# 初始化一个新的数据矩阵，形状为 (adata.X.shape[0], len(all_genes))，填充为零
new_data = np.zeros((adata.X.shape[0], len(all_genes)), dtype=np.float32)

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# features
# TFAP2C          TFAP2C
# HGF                HGF
# NAMPT            NAMPT
# VIM                VIM
# CD38              CD38
#                ...
# LINC01170    LINC01170
# SATB1-AS1    SATB1-AS1
# CFAP54          CFAP54
# RMST              RMST
# NOTCH1          NOTCH1
# Name: gene_name, Length: 300, dtype: object

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 281
# 匹配的基因列表: {'ablim1', 'prex2', 'pcdh11y', 'cd38', 'mx1', 'kcnh5', 'cdh9', 'lipg', 'nkain2', 'glis3', 'klhl4', 'st18', 'hes6', 'cfap54', 'dll3', 'ebf3', 'calb2', 'pdzrn4', 'diaph3', 'dio2', 'ralyl', 'cdh12', 'angpt1', 'fbxo32', 'epha7', 'pls3', 'sla', 'hopx', 'moxd1', 'prss12', 'eogt', 'rorb', 'arx', 'ca10', 'cd99', 'nefl', 'nr3c2', 'cenpf', 'cck', 'sorcs3', 'lhfpl6', 'runx1t1', 'sfrp1', 'tcerg1l', 'abcb1', 'tnr', 'sp8', 'rrm2', 'sst', 'rbms3', 'tnc', 'lhx1', 'ltbp1', 'aqp4', 'srrm4', 'cped1', 'daam2', 'itga2', 'zbbx', 'cntln', 'dock10', 'pcdh15', 'dock8', 'dlx2', 'sema3c', 'cpne8', 'ifit3', 'kiaa1217', 'dscam', 'lama2', 'apold1', 'etv1', 'sema3e', 'cadps2', 'satb2', 'cldn5', 'col24a1', 'fyb2', 'kcnip4', 'zfp36', 'grm3', 'ptchd4', 'dgkd', 'retreg1', 'cdh18', 'hmga2', 'ascl1', 'klhl14', 'prox1', 'gpr39', 'klhl1', 'opcml', 'egfr', 'sulf2', 'cryab', 'vip', 'lrig1', 'cobll1', 'eva1c', 'pou6f2', 'cd44', 'kcnq5', 'tshz2', 'abca8', 'fam160a1', 'rarb', 'spon1', 'eomes', 'hes1', 'stk32b', 'vegfa', 'map3k1', 'apbb1ip', 'c21orf58', 'tshr', 'brip1', 'adamtsl1', 'spp1', 'smc4', 'nwd2', 'ugt8', 'kitlg', 'aspm', 'rgs6', 'reln', 'gpx3', 'cfap43', 'tac1', 'znf804b', 'dpy19l1', 'mlip', 'ccbe1', 'vav3', 'pbx3', 'alk', 'kit', 'plp1', 'cfap299', 'mab21l1', 'inpp4b', 'grik1', 'pcp4', 'necab1', 'ripor2', 'rit2', 'colec12', 'sorcs1', 'eya2', 'thsd4', 'enpp6', 'gadl1', 'knl1', 'agbl1', 'tac3', 'nell2', 'bmper', 'atp10b', 'lrrc9', 'tfpi', 'spata17', 'notch1', 'col12a1', 'creb5', 'gpr17', 'fezf2', 'sulf1', 'neurod1', 'col4a5', 'col4a1', 'nxph1', 'fbn2', 'fos', 'hs3st4', 'igfbp7', 'gad2', 'pou3f2', 'bnip3', 'itih5', 'ccn1', 'cbln2', 'cntnap4', 'fam107a', 'slc6a1', 'dach1', 'svil', 'gli3', 'st8sia5', 'ebf1', 'cntnap2', 'ebf2', 'dpf3', 'epha3', 'slc35f3', 'vim', 'igfbp5', 'tfrc', 'palmd', 'adarb2', 'ifi6', 'grin3a', 'nampt', 'ifit1', 'nrp1', 'pdgfra', 'bcas1', 'tns3', 'ccser1', 'ccdc175', 'hmgb2', 'itm2a', 'lhfpl3', 'col1a2', 'crh', 'mob3b', 'znf536', 'spock3', 'slco1c1', 'ppp1r16b', 'stat1', 'glul', 'tcf7l2', 'ttr', 'sema5a', 'mdga1', 'nxph2', 'cxcl14', 'olig1', 'zic1', 'pcsk6', 'vwc2l', 'nhlh2', 'olfm3', 'isg15', 'kirrel3', 'cdh20', 'kif11', 'chrdl1', 'flt1', 'carhsp1', 'tfap2c', 'grin2a', 'gja1', 'id3', 'slit3', 'fgfbp3', 'glra3', 'runx1', 'best3', 'camk2a', 'pcbp3', 'slc1a2', 'sv2b', 'cebpd', 'enpp2', 'fn1', 'il1rapl2', 'rbfox3', 'cux2', 'trhde', 'slc9a9', 'tshz1', 'spata6', 'hgf', 'armc3', 'kcns3', 'disc1', 'clmp', 'synpr', 'metap1d', 'hcrtr2', 'top2a', 'znf385d', 'maml2', 'gad1', 'cpne4', 'myt1l', 'rnf220', 'lrmda', 'bcl11b', 'mobp', 'gpc5'}
# {'dlx6-as1',
#  'fam106a',
#  'kcnq1ot1',
#  'lhx1-dt',
#  'linc00609',
#  'linc01170',
#  'linc01619',
#  'linc01965',
#  'linc02147',
#  'linc02487',
#  'lncarod',
#  'neat1',
#  'nfia-as2',
#  'nr2f2-as1',
#  'obi1-as1',
#  'rmst',
#  'satb1-as1',
#  'sgo1-as1',
#  'tctex1d1'}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 19050
# 仅在 all_genes 中存在的基因: {'rcor2', 'dao', 'pitx1', 'krt71', 'prpf6', 'ccdc157', 'sec24c', 'uap1', 'plxdc2', 'rbfox1', 'or2t5', 'znf722p', 'nod2', 'h1-1', 'capn2', 'smpd2', 'selenof', 'stx1a', 'erc2', 'coro1b', 'cnnm3', 'pgp', 'gabrb2', 'mroh2b', 'txnl4b', 'fnip1', 'pcdha9', 'or51l1', 'fbln2', 'cd200r1', 'spock2', 'uvrag', 'wbp2', 'taf11l5', 'or14i1', 'uqcrc2', 'styx', 'chst2', 'cenpb', 'heyl', 'lman2l', 'gimap7', 'dph3', 'fcrl1', 'mxra8', 'or2t1', 'hla-doa', 'sox30', 'znf154', 'srsf12', 'pik3r6', 'tmed5', 'hsbp1l1', 'gsdmc', 'cyp2a13', 'dcst1', 'aida', 'h3c6', 'tmem270', 'gpx2', 'hjurp', 'cir1', 'pax3', 'tulp1', 'hspa1b', 'celsr1', 'ddx1', 'ccdc88a', 'uhrf1', 'mrpl41', 'lrrtm4', 'abhd4', 'h2ac20', 'defb131a', 'bcl2l2-pabpn1', 'pcnt', 'gon4l', 'rrp9', 'pex11g', 'or9i1', 'ppid', 'rab26', 'cntnap3b', 'prpf4', 'krtcap3', 'cald1', 'emc8', 'c22orf39', 'mrps31', 'spata46', 'acot12', 'ccdc54', 'fastkd2', 'tmem171', 'id4', 'tsnax', 'zc3h12d', 'bcar1', 'rpl29', 'abhd13', 'hecw1', 'znf599', 'grpel1', 'exog', 'pcsk4', 'tekt3', 'lmna', 'epdr1', 'gjb4', 'nt5c1b', 'or1a2', 'znf419', 'amer3', 'yipf7', 'fahd2a', 'tsnare1', 'ddx39a', 's100a12', 'cstf1', 'barx1', 'cpt1b', 'enox1', 'zbtb42', 'tsr1', 'rpl14', 's100b', 'cep63', 'pla2g6', 'pnrc2', 'unc93b1', 'nipal4', 'polr2d', 'pxk', 'ccl17', 'pcsk1', 'lmntd1', 'septin10', 'or6p1', 'ct45a8', 'smyd3', 'grhl3', 'rchy1', 'gpn3', 'chm', 'ms4a18', 'creb3l1', 'nudcd3', 'ccdc83', 'hp1bp3', 'tspy9p', 'rxrb', 'znf254', 'cuedc1', 'b4galt6', 'rpl8', 'mboat2', 'trak2', 'adra1d', 'sgcz', 'or2l5', 'or10k1', 'foxp3', 'npipb15', 'rad9b', 'zhx2', 'tomm34', 'ncr1', 'slfn13', 'ubl4a', 'arrb1', 'serpinb13', 'troap', 'rbm19', 'isca2', 'vps25', 'fam72a', 'ninj2', 'tmub2', 'dus1l', 'dusp28', 'notch3', 'maged2', 'wnt9b', 'traf3ip2', 'glyatl3', 'spag8', 'npipb3', 'hrg', 'znf117', 'top1mt', 'armc6', 'grifin', 'snx21', 'pigf', 'tcf3', 'mpc2', 'fmnl3', 'ppp1r8', 'inmt-mindy4', 'usp17l2', 'tmem217', 'psmd14', 'mgmt', 'cacnb4', 'apip', 'alas1', 'krtap10-6', 'kiaa0319', 'h2bc9', 'flnc', 'mylk', 'h4-16', 'cdk3', 'oosp3', 'hmgxb3', 'sh2b1', 'lrif1', 'fcgr3a', 'vnn2', 'zfyve16', 'zc4h2', 'eda', 'ckap5', 'neil2', 'gucd1', 'flot2', 'grik3', 'paqr4', 'mef2d', 'cd84', 'ncbp2as2', 'prrg3', 'ubqln4', 'add2', 'sema6c', 'sprr2b', 'il2', 'slc43a1', 'nrxn3', 'trim64c', 'defb134', 'ankrd24', 'faslg', 'ireb2', 'ptgdr2', 'znf574', 'ube2a', 'cradd', 'kiss1', 'klk10', 'myom2', 'atg4d', 'brap', 'nudt5', 'r3hdm2', 'lrrfip1', 'cptp', 'dusp13', 'kiaa0930', 'aste1', 'asphd2', 'wdr46', 'lrrc8b', 'gpx7', 'h3c13', 'atf7ip', 'spanxn4', 'etfa', 'cd28', 'rbm6', 'nadk2', 'eid2b', 'znf558', 'b3gnt9', 'mif4gd', 'nsmf', 'adamts1', 'acaa1', 'h2ac17', 'ccsap', 'lenep', 'stk39', 'dyrk2', 'slurp2', 'obscn', 'zfand4', 'naa16', 'ly9', 'fam228a', 'hspa1a', 'znf705d', 'sar1a', 'cttn', 'tmpo', 'fthl17', 'osbp2', 'prpf4b', 'uchl5', 'mmp10', 'ltbp3', 'pdxk', 'col6a3', 'rbm45', 'dhx38', 'mybpc2', 'znrf3', 'ttll9', 'nlk', 'znf841', 'glg1', 'pip4k2a', 'pcbd1', 'snx20', 'kdm5a', 'pcdhgb7', 'pianp', 'dcun1d4', 'cbll1', 'rras2', 'tspo2', 'csrp1', 'saa4', 'castor2', 'kcng2', 'or56b2p', 'ifit1b', 'mamstr', 'syne3', 'or56a3', 'triobp', 'rpusd3', 'ppat', 'ltb4r2', 'lgr6', 'gask1a', 'c17orf99', 'or14k1', 'or4f15', 'higd1b', 'pigm', 'ppp4c', 'dhdds', 'cxxc1', 'brd9', 'ell', 'ubqln3', 'lage3', 'kctd2', 'uty', 'simc1', 'foxo4', 'wipf3', 'synj2', 'dnajc1', 'magea10', 'pld2', 'chkb', 'kdm4c', 'gdf9', 'znf93', 'epb42', 'olfml2b', 'rc3h2', 'atg4b', 'zfand2a', 'cdh16', 'klf17', 'tmeff2', 'tcfl5', 'or9q1', 'gjb6', 'trdmt1', 'cd244', 'rnf133', 'gje1', 'plcl1', 'tp53bp1', 'fam72d', 'nek11', 'tnfrsf21', 'nfkb2', 'thoc7', 'corin', 'gabpb1', 'fam189b', 'nudcd2', 'ppm1m', 'dpep2nb', 'c19orf47', 'eps15l1', 'kif5c', 'fdxr', 'lin7c', 'flt3', 'tp53', 'copz2', 'nanogp8', 'znf587', 'mt-nd2', 'lamp1', 'tex51', 'rdh16', 'slc6a2', 'morn1', 'opalin', 'gsdma', 'tubgcp6', 'pabpc1l2a', 'fndc1', 'sp140l', 'rtkn2', 'hmg20b', 'tcf7l1', 'ipo7', 'hmx2', 'tmem175', 'plek2', 'cpne5', 'mob4', 'jkamp', 'ube2z', 'fermt3', ' ...
# 仅在 adata_genes 中存在的基因数量: 19
# 仅在 adata_genes 中存在的基因: {'satb1-as1', 'obi1-as1', 'neat1', 'linc01170', 'lhx1-dt', 'linc02147', 'lncarod', 'rmst', 'nr2f2-as1', 'kcnq1ot1', 'linc01965', 'dlx6-as1', 'linc00609', 'linc02487', 'tctex1d1', 'nfia-as2', 'sgo1-as1', 'fam106a', 'linc01619'}

# %%
dense_adata_X = adata.X.toarray()
for i, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        new_data[:, gene_to_index[gene]] = dense_adata_X[:, i]
    else:
        print(f'Gene {gene} not found in all_genes list')
# Out:
# Gene tctex1d1 not found in all_genes list
# Gene linc02487 not found in all_genes list
# Gene nfia-as2 not found in all_genes list
# Gene lncarod not found in all_genes list
# Gene dlx6-as1 not found in all_genes list
# Gene sgo1-as1 not found in all_genes list
# Gene linc02147 not found in all_genes list
# Gene linc01965 not found in all_genes list
# Gene linc00609 not found in all_genes list
# Gene linc01619 not found in all_genes list
# Gene kcnq1ot1 not found in all_genes list
# Gene obi1-as1 not found in all_genes list
# Gene fam106a not found in all_genes list
# Gene neat1 not found in all_genes list
# Gene nr2f2-as1 not found in all_genes list
# Gene lhx1-dt not found in all_genes list
# Gene linc01170 not found in all_genes list
# Gene satb1-as1 not found in all_genes list
# Gene rmst not found in all_genes list

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)



# 将训练数据转换为张量
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train_tensor = torch.tensor(X_train).float().to(device)
y_train_tensor = torch.tensor(y_train).long().to(device)
X_val_tensor = torch.tensor(X_val).float().to(device)
y_val_tensor = torch.tensor(y_val).long().to(device)
estim.model.to(device)
# Out:
# cuda
# MLPAutoEncoder(
#   (train_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=train_
#   )
#   (val_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=val_
#   )
#   (test_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=test_
#   )
#   (encoder): MLP(
#     (0): Linear(in_features=19331, out_features=512, bias=True)
#     (1): SELU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SELU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SELU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): SELU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=True)
#   )
#   (decoder): Sequential(
#     (0): MLP(
#       (0): Linear(in_features=64, out_features=256, bias=True)
#       (1): SELU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SELU()
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=256, out_features=512, bias=True)
#       (7): SELU()
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SELU()
#       (11): Dropout(p=0.1, inplace=False)
#       (12): Linear(in_features=512, out_features=19331, bias=True)
#     )
#     (1): Sigmoid()
#   )
#   (fc): Linear(in_features=64, out_features=29, bias=True)
# )

# %%
from torch.optim import AdamW
# 定义损失函数和优化器
loss_fn = nn.CrossEntropyLoss()
optimizer = AdamW(filter(lambda p: p.requires_grad, estim.model.parameters()), lr=9e-4, weight_decay=0.05)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.9)

# %%
from torch.utils.data import DataLoader, TensorDataset

# 设置 batch size
batch_size = 128  # 根据实际需求调整 batch size

# 使用 TensorDataset 将训练数据和标签打包
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

# 使用 DataLoader 来创建批次
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

def train_epoch(model, optimizer, loss_fn, train_loader, val_loader):
    model.train()
    total_train_loss = 0
    
    # 训练集批次训练
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        
        # 前向传播
        outputs = model.encoder(X_batch)
        logits = model.fc(outputs)
        
        # 计算损失
        loss = loss_fn(logits, y_batch)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
    
    # 验证集
    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            val_outputs = model.encoder(X_val_batch)
            val_logits = model.fc(val_outputs)
            val_loss = loss_fn(val_logits, y_val_batch)
            total_val_loss += val_loss.item()

    # 返回平均损失
    return total_train_loss / len(train_loader), total_val_loss / len(val_loader)

# %%
import copy  # 用于保存模型的最佳状态

# Early Stopping 参数
patience = 20  # 如果验证损失在 10 个 epoch 中没有改善，停止训练
min_delta = 1e-4  # 最小改善幅度
patience_counter = 0
best_val_loss = float('inf')  # 初始设置为正无穷大
best_model_weights = copy.deepcopy(estim.model.state_dict())  # 保存最佳模型权重
train_losses = []
val_losses = []

# 训练 500 个 epoch
for epoch in range(500):
    train_loss, val_loss = train_epoch(estim.model, optimizer, loss_fn, train_loader, val_loader)
    print(f'Epoch {epoch+1}, Train Loss: {train_loss}, Validation Loss: {val_loss}')
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    # Early Stopping 检查
    if val_loss < best_val_loss - min_delta:
        best_val_loss = val_loss  # 更新最佳验证损失
        patience_counter = 0  # 重置 patience 计数器
        best_model_weights = copy.deepcopy(estim.model.state_dict())  # 保存当前最佳模型
        print(f"Validation loss improved to {best_val_loss}, resetting patience.")
    else:
        patience_counter += 1
        print(f"No improvement in validation loss. Patience counter: {patience_counter}/{patience}")
    
    # 如果 patience_counter 超过设置的 patience，停止训练
    if patience_counter >= patience:
        print(f"Early stopping triggered. Stopping training at epoch {epoch+1}.")
        break

# 恢复到训练中性能最好的模型权重
estim.model.load_state_dict(best_model_weights)
print("Loaded best model weights based on validation loss.")
# Out:
# Epoch 1, Train Loss: 0.6056736193300689, Validation Loss: 0.4903727393800562
# Validation loss improved to 0.4903727393800562, resetting patience.
# Epoch 2, Train Loss: 0.46859800862112055, Validation Loss: 0.4723784817348827
# Validation loss improved to 0.4723784817348827, resetting patience.
# Epoch 3, Train Loss: 0.4363822265936005, Validation Loss: 0.4509821163524281
# Validation loss improved to 0.4509821163524281, resetting patience.
# Epoch 4, Train Loss: 0.4181096373499603, Validation Loss: 0.40955093914812263
# Validation loss improved to 0.40955093914812263, resetting patience.
# Epoch 5, Train Loss: 0.4002041024192993, Validation Loss: 0.40931417671116915
# Validation loss improved to 0.40931417671116915, resetting patience.
# Epoch 6, Train Loss: 0.38765607298490684, Validation Loss: 0.42522743875330143
# No improvement in validation loss. Patience counter: 1/20
# Epoch 7, Train Loss: 0.37742066595072304, Validation Loss: 0.4012585917928002
# Validation loss improved to 0.4012585917928002, resetting patience.
# Epoch 8, Train Loss: 0.36691061310196743, Validation Loss: 0.394025534174659
# Validation loss improved to 0.394025534174659, resetting patience.
# Epoch 9, Train Loss: 0.3564813553146977, Validation Loss: 0.3764261698180979
# Validation loss improved to 0.3764261698180979, resetting patience.
# Epoch 10, Train Loss: 0.3476822715336973, Validation Loss: 0.3930330792340365
# No improvement in validation loss. Patience counter: 1/20
# Epoch 11, Train Loss: 0.34009593675184957, Validation Loss: 0.3849513683535836
# No improvement in validation loss. Patience counter: 2/20
# Epoch 12, Train Loss: 0.3336375251493819, Validation Loss: 0.39279871956868606
# No improvement in validation loss. Patience counter: 3/20
# Epoch 13, Train Loss: 0.32542968836266206, Validation Loss: 0.3817762556401166
# No improvement in validation loss. Patience counter: 4/20
# Epoch 14, Train Loss: 0.31708061098354484, Validation Loss: 0.3693528207323768
# Validation loss improved to 0.3693528207323768, resetting patience.
# Epoch 15, Train Loss: 0.31357916568425553, Validation Loss: 0.36718283263119783
# Validation loss improved to 0.36718283263119783, resetting patience.
# Epoch 16, Train Loss: 0.3078761141947896, Validation Loss: 0.36565520324490286
# Validation loss improved to 0.36565520324490286, resetting patience.
# Epoch 17, Train Loss: 0.3001827518866455, Validation Loss: 0.36542678740891543
# Validation loss improved to 0.36542678740891543, resetting patience.
# Epoch 18, Train Loss: 0.29600407410584606, Validation Loss: 0.3795389351519671
# No improvement in validation loss. Patience counter: 1/20
# Epoch 19, Train Loss: 0.2924146472035117, Validation Loss: 0.37020775973796843
# No improvement in validation loss. Patience counter: 2/20
# Epoch 20, Train Loss: 0.2848780995044366, Validation Loss: 0.3692399030381983
# No improvement in validation loss. Patience counter: 3/20
# Epoch 21, Train Loss: 0.28457476654665065, Validation Loss: 0.3701985896175558
# No improvement in validation loss. Patience counter: 4/20
# Epoch 22, Train Loss: 0.2777879255402842, Validation Loss: 0.3750266471234235
# No improvement in validation loss. Patience counter: 5/20
# Epoch 23, Train Loss: 0.2750103183026708, Validation Loss: 0.3748412383144552
# No improvement in validation loss. Patience counter: 6/20
# Epoch 24, Train Loss: 0.2699967660853213, Validation Loss: 0.36662790222601455
# No improvement in validation loss. Patience counter: 7/20
# Epoch 25, Train Loss: 0.2657119694582472, Validation Loss: 0.3774393620816144
# No improvement in validation loss. Patience counter: 8/20
# Epoch 26, Train Loss: 0.26361436486988676, Validation Loss: 0.35862753797661173
# Validation loss improved to 0.35862753797661173, resetting patience.
# Epoch 27, Train Loss: 0.2595989361207621, Validation Loss: 0.38185865461826324
# No improvement in validation loss. Patience counter: 1/20
# Epoch 28, Train Loss: 0.2557381627489402, Validation Loss: 0.38484160401604395
# No improvement in validation loss. Patience counter: 2/20
# Epoch 29, Train Loss: 0.254896821731892, Validation Loss: 0.3768504173105413
# No improvement in validation loss. Patience counter: 3/20
# Epoch 30, Train Loss: 0.24932200764069606, Validation Loss: 0.38248513156717473
# No improvement in validation loss. Patience counter: 4/20
# Epoch 31, Train Loss: 0.24837492137658793, Validation Loss: 0.3693353428623893
# No improvement in validation loss. Patience counter: 5/20
# Epoch 32, Train Loss: 0.24498694531392717, Validation Loss: 0.37324718058109285
# No improvement in validation loss. Patience counter: 6/20
# Epoch 33, Train Loss: 0.24253354557760054, Validation Loss: 0.3697350285811858
# No improvement in validation loss. Patience counter: 7/20
# Epoch 34, Train Loss: 0.23892024048341615, Validation Loss: 0.386623025373979
# No improvement in validation loss. Patience counter: 8/20
# Epoch 35, Train Loss: 0.23789494123475613, Validation Loss: 0.3827656562761827
# No improvement in validation loss. Patience counter: 9/20
# Epoch 36, Train Loss: 0.23605756717534107, Validation Loss: 0.378068442994898
# No improvement in validation loss. Patience counter: 10/20
# Epoch 37, Train Loss: 0.2335601470416454, Validation Loss: 0.3903048196705905
# No improvement in validation loss. Patience counter: 11/20
# Epoch 38, Train Loss: 0.22999331912288992, Validation Loss: 0.3959651543335481
# No improvement in validation loss. Patience counter: 12/20
# Epoch 39, Train Loss: 0.22986341981474634, Validation Loss: 0.3892971220883456
# No improvement in validation loss. Patience counter: 13/20
# Epoch 40, Train Loss: 0.22841057767633532, Validation Loss: 0.39313118663701146
# No improvement in validation loss. Patience counter: 14/20
# Epoch 41, Train Loss: 0.22471370652701872, Validation Loss: 0.3836208389563994
# No improvement in validation loss. Patience counter: 15/20
# Epoch 42, Train Loss: 0.22291720963310768, Validation Loss: 0.40464843993837185
# No improvement in validation loss. Patience counter: 16/20
# Epoch 43, Train Loss: 0.22086073621048954, Validation Loss: 0.39678642831065436
# No improvement in validation loss. Patience counter: 17/20
# Epoch 44, Train Loss: 0.21759132080065097, Validation Loss: 0.3894727519967339
# No improvement in validation loss. Patience counter: 18/20
# Epoch 45, Train Loss: 0.2171455894442018, Validation Loss: 0.38484088374809783
# No improvement in validation loss. Patience counter: 19/20
# Epoch 46, Train Loss: 0.2184945850819931, Validation Loss: 0.393368296677416
# No improvement in validation loss. Patience counter: 20/20
# Early stopping triggered. Stopping training at epoch 46.
# Loaded best model weights based on validation loss.

# %%
import matplotlib.pyplot as plt  # 导入 matplotlib.pyplot，而不是 matplotlib

plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.savefig('../loss_curve_fig/merfish_human_neocortex_supervised_loss_curve.png', dpi=400)  # 保存图像为png格式，400 dpi
plt.savefig('../loss_curve_fig/merfish_human_neocortex_supervised_loss_curve.eps', format='eps', dpi=400)  # 保存图像为png格式，400 dpi

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# 8. 使用 KNN 替代测试阶段的 FC 分类层
# 使用 encoder 提取训练集和测试集的 embedding
estim.model.eval()
with torch.no_grad():
    train_embeddings = estim.model.encoder(torch.tensor(X_train).float().to(device)).cpu().numpy()
    test_embeddings = estim.model.encoder(torch.tensor(X_test).float().to(device)).cpu().numpy()

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.8747401691392124
# Weighted F1 Score: 0.8746847545957532
# Macro F1 Score: 0.8694632954446665
# Random Guess Accuracy: 0.05408382924188506
#                           precision    recall  f1-score   support
#
#        Astrocyte-Fibrous       0.90      0.92      0.91      2056
#   Astrocyte-Protoplasmic       0.89      0.88      0.89      1958
#           EN-IT-Immature       0.84      0.86      0.85      3827
#               EN-L2_3-IT       0.85      0.87      0.86      2843
#                 EN-L4-IT       0.83      0.83      0.83      2585
#                 EN-L5-ET       0.74      0.80      0.76        98
#                 EN-L5-IT       0.86      0.87      0.87      1670
#               EN-L5_6-NP       0.88      0.87      0.87       344
#                 EN-L6-CT       0.85      0.90      0.87       778
#                 EN-L6-IT       0.91      0.89      0.90      1914
#                   EN-L6b       0.92      0.86      0.89      1218
#               EN-Newborn       0.84      0.79      0.82      1543
#          IN-CGE-Immature       0.82      0.82      0.82      1714
#              IN-CGE-SNCG       0.82      0.84      0.83       570
#               IN-CGE-VIP       0.84      0.86      0.85       658
#          IN-MGE-Immature       0.85      0.85      0.85      1597
#                IN-MGE-PV       0.77      0.80      0.79       516
#               IN-MGE-SST       0.92      0.91      0.92      1558
#             IN-Mix-LAMP5       0.78      0.68      0.73       287
#         IN-dLGE-Immature       0.89      0.85      0.87       509
#                   IPC-EN       0.93      0.95      0.94       128
#                 IPC-Glia       0.87      0.88      0.88       849
#                Microglia       0.98      0.99      0.98       649
#                      OPC       0.95      0.95      0.95      1209
#          Oligodendrocyte       0.95      0.92      0.93       265
# Oligodendrocyte-Immature       0.94      0.94      0.94       359
#                   RG-oRG       0.78      0.75      0.77       645
#                   RG-tRG       0.87      0.86      0.86       431
#                 Vascular       0.99      0.99      0.99      2341
#
#                 accuracy                           0.87     35119
#                macro avg       0.87      0.87      0.87     35119
#             weighted avg       0.87      0.87      0.87     35119

# %%
with torch.no_grad():
    new_data_tensor = torch.tensor(new_data).float().to(device)
    SSL_embeddings = estim.model.encoder(new_data_tensor).detach().cpu().numpy()
new_adata = sc.read_h5ad(data_dir)
new_adata.obsm[f'supervised_{random_seed}'] = SSL_embeddings
new_adata.uns[f'supervised_y_test_{random_seed}'] = y_test
new_adata.uns[f'supervised_predictions_{random_seed}'] = predictions
new_adata.uns[f'supervised_target_names_{random_seed}'] = label_encoder.classes_
new_adata.uns[f'supervised_train_loss_{random_seed}'] = train_losses
new_adata.uns[f'supervised_val_loss_{random_seed}'] = val_losses
new_adata.write_h5ad(data_dir)

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "MERSCOPE_human_neocortex_supervised_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicor_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicor_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['MERSCOPE_human_neocortex'],
    'method': [re.search(r'neocortex_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micor_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# init_train_loss	init_val_loss	converged_epoch	converged_val_loss	macro_f1	weighted_f1	micor_f1
# 0.606	0.490	26	0.359	0.869	0.875	0.875
