# %%
import scanpy as sc
import numpy as np
data_path = '../dataset/Chromium_FFPE_Human_Breast_Cancer_Chromium_FFPE_Human_Breast_Cancer_count_sample_filtered_feature_bc_matrix.h5'
sc_data = sc.read_10x_h5(data_path)
sc_data.X = sc_data.X.toarray()
# Randomly sample 80,000 cells
n_cells = sc_data.shape[0]
sample_size = min(80000, n_cells)  # Ensure we don't try to sample more than available cells
random_indices = np.random.choice(n_cells, size=sample_size, replace=False)

# Create a new AnnData object with the sampled cells
sc_data = sc_data[random_indices, :]

# Print to confirm the shape
print(sc_data)
# Out:
# /home/hanchuangyi/miniconda3/envs/tangram/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/hanchuangyi/miniconda3/envs/tangram/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# View of AnnData object with n_obs × n_vars = 30365 × 18082
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
st_data_path = '../dataset/Xenium_breast_cancer_sample1_replicate1.h5ad'
st_data = sc.read_h5ad(st_data_path)
st_data
# Out:
# AnnData object with n_obs × n_vars = 167780 × 313
#     obs: 'cell_type', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area'
#     var: 'gene_ids', 'feature_types', 'genome'
#     obsm: 'spatial'

# %%
# 检查 sc_data.var_names 是否有重复项
duplicates = sc_data.var_names[sc_data.var_names.duplicated()]
print(f"重复的基因: {duplicates}")
# 删除 sc_data.var_names 中的重复基因
sc_data = sc_data[:, ~sc_data.var_names.duplicated()]
# Out:
# 重复的基因: Index(['TBCE', 'HSPA14', 'TMSB15B'], dtype='object')

# %%
st_data.X = st_data.X.toarray()

# %%
import tangram as tg
tg.pp_adatas(sc_data, st_data, genes=None)
ad_map = tg.map_cells_to_space(sc_data, st_data)
# Out:
# INFO:root:306 training genes are saved in `uns``training_genes` of both single cell and spatial Anndatas.
# INFO:root:306 overlapped genes are saved in `uns``overlap_genes` of both single cell and spatial Anndatas.
# INFO:root:uniform based density prior is calculated and saved in `obs``uniform_density` of the spatial Anndata.
# INFO:root:rna count based density prior is calculated and saved in `obs``rna_count_based_density` of the spatial Anndata.
# INFO:root:Allocate tensors for mapping.
# INFO:root:Begin training with 306 genes and None density_prior in cells mode...
# INFO:root:Printing scores every 100 epochs.
# Score: 0.311
# Score: 0.715
# Score: 0.767
# Score: 0.786
# Score: 0.796
# Score: 0.803
# Score: 0.809
# Score: 0.812

# %%
ad_ge = tg.project_genes(ad_map, sc_data)

# %%
imputed_st_data_path = '../dataset/ad_ge_imputed_Xenium_breast_cancer_sample1_replicate1.h5ad'
imputed_intermediate_st_data_path = '../dataset/ad_map_imputed_Xenium_breast_cancer_sample1_replicate1.h5ad'
ad_ge.write_h5ad(imputed_st_data_path)
ad_map.write_h5ad(imputed_intermediate_st_data_path)

# %%
imputed_st_data_path = '../dataset/ad_ge_imputed_Xenium_breast_cancer_sample1_replicate1.h5ad'
import scanpy as sc
adata = sc.read_h5ad(imputed_st_data_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 167780 × 17693
#     obs: 'cell_type', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'uniform_density', 'rna_count_based_density'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'sparsity', 'is_training'
#     uns: 'overlap_genes', 'training_genes'

# %%
adata.obsm['spatial'] = original_adata.obsm['spatial'].copy()

# %%
adata.write_h5ad(imputed_st_data_path)

# %%
original_adata = sc.read_h5ad('../dataset/Xenium_breast_cancer_sample1_replicate1.h5ad')
original_adata
# Out:
# AnnData object with n_obs × n_vars = 167780 × 313
#     obs: 'cell_type', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area'
#     var: 'gene_ids', 'feature_types', 'genome'
#     obsm: 'spatial'

# %%
# 比较两列是否逐行相同
comparison_result = original_adata.obs['x_centroid'].equals(adata.obs['x_centroid'])

# 输出比较结果
if comparison_result:
    print("两列完全相同")
else:
    print("两列不相同")

# 找出不相同的行
difference = original_adata.obs['x_centroid'] != adata.obs['x_centroid']

# 打印不相同的行
print(original_adata.obs.loc[difference, 'x_centroid'])
print(adata.obs.loc[difference, 'x_centroid'])
# Out:
# 两列完全相同
# Series([], Name: x_centroid, dtype: float64)
# Series([], Name: x_centroid, dtype: float64)

# %%
import pandas as pd
pd.set_option('display.max_rows',None)
adata.var.head(200)
# Out:
#                   gene_ids    feature_types  genome  n_cells  sparsity  \
# samd11     ENSG00000187634  Gene Expression  GRCh38     6500  0.785938
# noc2l      ENSG00000188976  Gene Expression  GRCh38     8285  0.727153
# klhl17     ENSG00000187961  Gene Expression  GRCh38     5265  0.826610
# plekhn1    ENSG00000187583  Gene Expression  GRCh38     5102  0.831978
# perm1      ENSG00000187642  Gene Expression  GRCh38      436  0.985641
# hes4       ENSG00000188290  Gene Expression  GRCh38     9740  0.679236
# isg15      ENSG00000187608  Gene Expression  GRCh38     9458  0.688523
# agrn       ENSG00000188157  Gene Expression  GRCh38    12888  0.575564
# rnf223     ENSG00000237330  Gene Expression  GRCh38      447  0.985279
# c1orf159   ENSG00000131591  Gene Expression  GRCh38     2713  0.910654
# ttll10     ENSG00000162571  Gene Expression  GRCh38      383  0.987387
# tnfrsf18   ENSG00000186891  Gene Expression  GRCh38     1822  0.939997
# tnfrsf4    ENSG00000186827  Gene Expression  GRCh38     1084  0.964301
# sdf4       ENSG00000078808  Gene Expression  GRCh38    10898  0.641100
# b3galt6    ENSG00000176022  Gene Expression  GRCh38     3323  0.890565
# c1qtnf12   ENSG00000184163  Gene Expression  GRCh38      511  0.983171
# ube2j2     ENSG00000160087  Gene Expression  GRCh38     6025  0.801581
# scnn1d     ENSG00000162572  Gene Expression  GRCh38     2195  0.927713
# acap3      ENSG00000131584  Gene Expression  GRCh38    10514  0.653746
# pusl1      ENSG00000169972  Gene Expression  GRCh38     2644  0.912926
# ints11     ENSG00000127054  Gene Expression  GRCh38    13159  0.566639
# cptp       ENSG00000224051  Gene Expression  GRCh38     4291  0.858686
# tas1r3     ENSG00000169962  Gene Expression  GRCh38      650  0.978594
# dvl1       ENSG00000107404  Gene Expression  GRCh38     6496  0.786069
# perm1            False
# hes4             False
# isg15            False
# agrn             False
# rnf223           False
# c1orf159         False
# ttll10           False
# tnfrsf18         False
# tnfrsf4          False
# sdf4             False
# b3galt6          False
# c1qtnf12         False
# ube2j2           False
# scnn1d           False
# acap3            False
# pusl1            False
# ints11           False
# cptp             False
# tas1r3           False
# dvl1             False
# mxra8            False
# aurkaip1         False
# ccnl2            False
# ankrd65          False
# tmem88b          False
# vwa1             False
# atad3c           False
# atad3b           False
# atad3a           False
# tmem240          False
# ssu72            False
# fndc10           False
# mib2             False
# mmp23b           False
# cdk11b           False
# cdk11a           False
# nadk             False
# gnb1             False
# calml6           False
# tmem52           False
# cfap74           False
# gabrd            False
# prkcz            False
# faap20           False
# ski              False
# rer1             False
# pex10            False
# plch2            False
# pank4            False
# hes5             False
# tnfrsf14         False
# prxl2b           False
# mmel1            False
# prdm16           False
# arhgef16         False
# megf6            False
# tprg1l           False
# wrap73           False
# tp73             False
# ccdc27           False
# smim1            False
# lrrc47           False
# cep104           False
# dffb             False
# c1orf174         False
# ajap1            False
# nphp4            False
# kcnab2           False
# chd5             False
# rnf207           False
# icmt             False
# gpr153           False
# acot7            False
# hes2             False
# espn             False
# tnfrsf25         False
# plekhg5          False
# nol9             False
# tas1r1           False
# zbtb48           False
# klhl21           False
# phf13            False
# thap3            False
# dnajc11          False
# camta1           False
# vamp3            False
# per3             False
# uts2             False
# tnfrsf9          False
# errfi1           False
# slc45a1          False
# rere             False
# eno1             False
# ca6              False
# slc2a7           False
# slc2a5           False
# gpr157           False
# h6pd             False
# spsb1            False
# slc25a33         False
# tmem201          False
# pik3cd           False
# clstn1           False
# ctnnbip1         False
# lzic             False
# nmnat1           False
# rbp7             False
# ube4b            False
# kif1b            False
# pgd              False
# cenps            False
# cort             False
# dffa             False
# pex14            False
# casz1            False
# c1orf127         False
# masp2            False
# srm              False
# exosc10          False
# mtor             False
# angptl7          False
# ubiad1           False
# disp3            False
# fbxo2            False
# fbxo44           False
# fbxo6            False
# mad2l2           False
# draxin           False
# agtrap           False
# c1orf167         False
# mthfr            False
# clcn6            False
# nppa             False
# nppb             False
# kiaa2013         False
# plod1            False
# mfn2             False
# miip             False
# tnfrsf8          False
# tnfrsf1b         False
# vps13d           False
# dhrs3            False
# c1orf158         False
# pramef11         False
# pramef2          False
# pramef10         False
# pramef6          False
# pramef15         False
# pramef14         False
# pramef19         False
# lrrc38           False
# pdpn             False
# prdm2            False
# kazn             False
# tmem51           False
# fhad1            False
# efhd2            False
# ctrc             False
# cela2a           False
# cela2b           False
# casp9            False
# dnajc16          False
# agmat            False
# ddi2             False
# plekhm2          False
# slc25a34         False
# tmem82           False
# fblim1            True
# uqcrhl           False
# spen             False
# zbtb17           False
# srarp            False
# hspb7            False
# clcnka           False
# clcnkb           False
# fam131c          False
# epha2            False
# arhgef19         False
# cplane2          False
# fbxo42           False
# szrd1            False
# spata21          False
# necap2           False
# nbpf1            False
# crocc            False
# mfap2            False
# atp13a2          False
# sdhb             False
# padi2            False
# padi1            False
# padi3            False
# padi4            False
# padi6            False
# rcc2             False
# arhgef10l        False
# actl8            False
