# %%
import scanpy as sc
data_dir = '../../dataset/SpaGE_imputed_Xenium_breast_cancer_sample1_replicate1.h5ad'
adata = sc.read_h5ad(data_dir)

# %%
import torch
import lightning.pytorch as pl
from self_supervision.models.lightning_modules.cellnet_autoencoder import MLPAutoEncoder
from self_supervision.estimator.cellnet import EstimatorAutoEncoder

# 设置你的 .ckpt 文件路径
ckpt_path = "../../sc_pretrained/Pretrained Models/RandomMask.ckpt"

# 模型参数
units_encoder = [512, 512, 256, 256, 64]
units_decoder = [256, 256, 512, 512]

# 初始化 EstimatorAutoEncoder 实例
estim = EstimatorAutoEncoder(data_path=None)  # 如果没有实际数据路径，可以设置为None

# 加载预训练模型
estim.model = MLPAutoEncoder.load_from_checkpoint(
    ckpt_path,
    gene_dim=19331,  # 根据你的数据调整
    batch_size=128,  # 根据你的需要调整
    units_encoder=units_encoder, 
    units_decoder=units_decoder,
    masking_strategy="random",  # 假设模型使用了随机掩码
    masking_rate=0.5,  # 根据需要调整
)

# 使用 GPU 进行评估（如果可用）
estim.trainer = pl.Trainer(accelerator="gpu", devices=1 if torch.cuda.is_available() else None)
estim.model
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/tf.py:52: UserWarning: Tensorflow dtype mappings did not load successfully due to an error: No module named 'tensorflow'
#   warn(f"Tensorflow dtype mappings did not load successfully due to an error: {exc.msg}")
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# MLPAutoEncoder(
#   (train_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=train_
#   )
#   (val_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=val_
#   )
#   (test_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=test_
#   )
#   (encoder): MLP(
#     (0): Linear(in_features=19331, out_features=512, bias=True)
#     (1): SELU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SELU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SELU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): SELU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=True)
#   )
#   (decoder): Sequential(
#     (0): MLP(
#       (0): Linear(in_features=64, out_features=256, bias=True)
#       (1): SELU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SELU()
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=256, out_features=512, bias=True)
#       (7): SELU()
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SELU()
#       (11): Dropout(p=0.1, inplace=False)
#       (12): Linear(in_features=512, out_features=19331, bias=True)
#     )
#     (1): Sigmoid()
#   )
# )

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# ABCC11    ABCC11
# ACTA2      ACTA2
# ACTG2      ACTG2
# ADAM9      ADAM9
# ADGRE5    ADGRE5
#            ...
# ZXDC        ZXDC
# ZYG11A    ZYG11A
# ZYG11B    ZYG11B
# ZYX          ZYX
# ZZEF1      ZZEF1
# Name: gene_name, Length: 18085, dtype: object

# %%
import numpy as np
# 初始化一个新的数据矩阵，形状为 (adata.X.shape[0], len(all_genes))，填充为零
new_data = np.zeros((adata.X.shape[0], len(all_genes)), dtype=np.float32)

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# ABCC11    ABCC11
# ACTA2      ACTA2
# ACTG2      ACTG2
# ADAM9      ADAM9
# ADGRE5    ADGRE5
#            ...
# ZXDC        ZXDC
# ZYG11A    ZYG11A
# ZYG11B    ZYG11B
# ZYX          ZYX
# ZZEF1      ZZEF1
# Name: gene_name, Length: 18085, dtype: object

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 17773
# 匹配的基因列表: {'rdh16', 'mapk3', 'srsf11', 'nutm1', 'armc6', 'grip1', 'rffl', 'macc1', 'atrx', 'pars2', 'tmem179b', 'ccdc88b', 'znf239', 'jrkl', 'rbm34', 'hoxb13', 'wdr72', 'osgin2', 'limch1', 'gcna', 'pter', 'msto1', 'sgf29', 'arpc3', 'wwox', 'atg2a', 'nostrin', 'gnpnat1', 'phlpp1', 'ptges3', 'cdadc1', 'znf578', 'bcl2l12', 'unc13b', 'lta4h', 'znf225', 'cdc42ep2', 'rnf10', 'tgfa', 'c12orf60', 'erich2', 'hs2st1', 'mecp2', 'cstf2t', 'actg2', 'sema4f', 'smco2', 'lrrc27', 'naglu', 'stx4', 'actr8', 'etv6', 'mbd3l2b', 'rnf181', 'mnx1', 'ccnyl1', 'hes2', 'irs2', 'ercc8', 'ucn3', 'coro1c', 'retnlb', 'npipb15', 'ggps1', 'ceacam19', 'cbfb', 'gpr18', 'pdgfra', 'znf266', 'spock2', 'sub1', 'gimap8', 'fmo2', 'pced1a', 'adgrb3', 'lingo1', 'vps37b', 'rnf4', 'mybphl', 'abi3bp', 'tmco6', 'adi1', 'b3glct', 'cdh3', 'emc8', 'or10q1', 'tbc1d15', 'pga5', 'pramef13', 'recql', 'tmem212', 'dhx30', 'tlr7', 'znf662', 'polk', 'eed', 'iqcn', 'plaat3', 'cyp1a1', 'npipb2', 'mydgf', 'man1b1', 'rbmxl2', 'slx4', 'nkx6-1', 'tob1', 'prkag1', 'adgrd1', 'ercc1', 'syde1', 'fbxo47', 'gbf1', 'exoc6', 'zap70', 'naa10', 'nom1', 'iqcd', 'egflam', 'col7a1', 'rab26', 'mbd6', 'rnf113a', 'cnrip1', 'ndufa7', 'tpsg1', 'cfap299', 'syt9', 'idh1', 'irx2', 'mcm3', 'ffar1', 'thoc1', 'vps13b', 'ubqlnl', 'fam174b', 'map7d2', 'calml3', 'per2', 'znf324', 'mapk9', 'psg2', 'fahd1', 'c9orf116', 'dnajc28', 'zbtb22', 'adhfe1', 'crnkl1', 'star', 'atf7ip2', 'kcnrg', 'bpgm', 'b4galt2', 'tor1a', 'vwa3a', 'art4', 'krtap20-4', 'adamts5', 'rcbtb1', 'psrc1', 'zdhhc17', 'tprg1', 'atp12a', 'shoc1', 'mesp1', 'wnk3', 'psma3', 'nbpf3', 'polg', 'ambn', 'pitpnm2', 'slc12a8', 'wbp1l', 'ctso', 'fbxo7', 'nab1', 'pgm5', 'tmem223', 'cd5l', 'slc9a4', 'chordc1', 'wwtr1', 'ttc23l', 'dnah8', 'cnpy2', 'cebpb', 'col1a1', 'efcab9', 'or5t3', 'sgtb', 'tcf19', 'dld', 'c4orf33', 'siah2', 'usp38', 'ttc19', 'lgals16', 'snn', 'irx1', 'rnaseh2a', 'sertad3', 'ttc21b', 'virma', 'espl1', 'ntf4', 'flna', 'oip5', 'dcxr', 'gnpda1', 'slc25a14', 'cldn8', 'rprd1b', 'fbh1', 'lefty2', 'mroh6', 'tmem44', 'tpra1', 'dpf1', 'krtap29-1', 'herc3', 'tysnd1', 'tle5', 'fkbp1c', 'ttll1', 'ubl3', 'dhrs13', 'lrfn1', 'kif6', 'pcbp1', 'ppm1k', 'nptx2', 'igf2bp1', 'smpd2', 'bhmt2', 'sfr1', 'cpsf4l', 'ppp1r16b', 'spag8', 'iqca1l', 'pde1c', 'sdhb', 'kiaa1522', 'tlr6', 'cdk11a', 'sema4a', 'tpp2', 'ufsp1', 'ntan1', 'znf667', 'nudt5', 'ezr', 'c7orf31', 'hint2', 'nae1', 'trim26', 'rnf126', 'stag3', 'tubg2', 'scgb1d2', 'atp6v1c2', 'iqcm', 'cdc7', 'cpo', 'incenp', 'themis2', 'tp53bp2', 'asb13', 'kcnk3', 'invs', 'exosc5', 'ap3m2', 'fam193b', 'cebpd', 'scn4a', 'bcar1', 'fnip2', 'sat2', 'dpagt1', 'c11orf52', 'ubox5', 'smim10l1', 'shisa3', 'ctsc', 'wnt3', 'trmt11', 'gtf2h3', 'tnik', 'sae1', 'ttc31', 'mlec', 'scarf1', 'lrit2', 'batf2', 'myh7', 'sall2', 'tifab', 'zscan5c', 'gckr', 'terf2', 'or1c1', 'zdhhc6', 'pigz', 'btn3a3', 'or10d3', 'mgp', 'pfkfb4', 'lipt1', 'ssrp1', 'cfap298', 'tbc1d24', 'orai3', 'rexo5', 'hoxb9', 'golga2', 'ndufab1', 'tm9sf4', 'kcnb2', 'ltb4r2', 'xdh', 'krtap1-3', 'znf286a', 'nup160', 'cer1', 'rrm1', 'kcnj1', 'cntnap5', 'rcvrn', 'smcr8', 'oosp3', 'haus8', 'fam222b', 'lgals3', 'ap3s2', 'mrap2', 'plpp3', 'tgm7', 'qpct', 'rbck1', 'cdx2', 'c21orf91', 'med13', 'asb16', 'nmnat1', 'pcdhgc3', 'gfra3', 'nrsn1', 'ptpdc1', 'tex26', 'serf2', 'plgrkt', 'timm10', 'sorl1', 'dpp10', 'n4bp2l2', 'acox1', 'arhgdig', 'reps2', 'comt', 'znf524', 'sv2c', 'srpk3', 'loxl1', 'c8orf33', 'selenom', 'znf771', 'plin3', 'eif2b3', 'id2', 'tpp1', 'mid1', 'slc22a6', 'dcun1d1', 'dlx4', 'nuak2', 'zdhhc5', 'znf229', 'c6orf132', 'hrct1', 'otp', 'or5b12', 'pex10', 'unc119b', 'znf782', 'rnf165', 'tmem161b', 'phactr2', 'thg1l', 'dpp8', 'e2f8', 'def8', 'nkx3-1', 'hnrnpcl3', 'rsf1', 'qki', 'tmem119', 'lnpk', 'ankrd54', 'tubb8', 'rtn2', 'pgbd2', 'dnal4', 'dhtkd1', 'tmem220', 'gmeb2', 'csnk2b', 'retreg3', 'tfap2b', 'stat2', 'stk39', 'dab2', 'p2ry8', 'lefty1', 'tada3', 'dctn3', 'sstr2', 'odf3', 'znf331', 'ahdc1', 'cst2', 'ccdc15', 'ccdc62', 'gfod1', 'dkk3', 'utp20', 'mansc4', 'taf5l', 'or4k17 ...
# {'aars',
#  'ac004593.3',
#  'ac005551.1',
#  'ac007244.1',
#  'ac007906.2',
#  'ac008397.1',
#  'ac008687.4',
#  'ac010255.3',
#  'ac010325.1',
#  'ac011005.1',
#  'ac011195.2',
#  'ac013470.2',
#  'ac015871.1',
#  'ac021072.1',
#  'ac021097.2',
#  'ac025283.2',
#  'ac025287.4',
#  'ac067752.1',
#  'ac072022.2',
#  'ac073111.4',
#  'ac087498.1',
#  'ac090360.1',
#  'ac091057.6',
#  'ac092835.1',
#  'ac093323.1',
#  'ac099489.1',
#  'ac104389.5',
#  'ac106774.4',
#  'ac113348.1',
#  'ac115220.1',
#  'ac118549.1',
#  'ac119396.1',
#  'ac132217.2',
#  'ac134684.8',
#  'ac135068.1',
#  'ac138647.1',
#  'ac187653.1',
#  'ac233723.1',
#  'ac236972.4',
#  'acpp',
#  'adprhl2',
#  'adss',
#  'adssl1',
#  'al032819.3',
#  'al109810.2',
#  'al121578.2',
#  'al135905.2',
#  'al160269.1',
#  'al162231.1',
#  'al162596.1',
#  'al353572.3',
#  'al354761.1',
#  'al391650.1',
#  'al445238.1',
#  'al451007.3',
#  'al590560.2',
#  'al603764.2',
#  'al772284.2',
#  'al845331.2',
#  'alg1l',
#  'ap000552.4',
#  'ap002495.1',
#  'arih2os',
#  'armc4',
#  'arse',
#  'atp5md',
#  'atp5mpl',
#  'atp6ap1l',
#  'b3gnt10',
#  'bhmg1',
#  'bx255925.3',
#  'bx276092.9',
#  'c10orf142',
#  'c10orf55',
#  'c11orf40',
#  'c11orf74',
#  'c11orf88',
#  'c12orf10',
#  'c12orf49',
#  'c12orf74',
#  'c12orf81',
#  'c14orf177',
#  'c15orf41',
#  'c16orf58',
#  'c17orf53',
#  'c19orf48',
#  'c19orf57',
#  'c1orf61',
#  'c2orf83',
#  'c2orf91',
#  'c3orf67',
#  'c5orf30',
#  'c5orf60',
#  'c5orf67',
#  'c6orf201',
#  'c6orf223',
#  'c7orf77',
#  'c9orf129',
#  'c9orf92',
#  'card16',
#  'card17',
#  'cars',
#  'casc1',
#  'casc4',
#  'castor3',
#  'ccdc114',
#  'ccdc140',
#  'ccdc151',
#  'ccdc155',
#  'ccdc36',
#  'ccdc39',
#  'ccdc84',
#  'cd3eap',
#  'cenpbd1',
#  'cllu1os',
#  'cntd2',
#  'ct62',
#  'cxorf21',
#  'cxorf40a',
#  'cxorf56',
#  'cyb561d2',
#  'dars',
#  'dec1',
#  'defb133',
#  'dirc1',
#  'dock8-as1',
#  'dupd1',
#  'dusp27',
#  'elfn2',
#  'elmsan1',
#  'eloa3',
#  'eprs',
#  'fam122a',
#  'fam122b',
#  'fam122c',
#  'fam169b',
#  'fam192a',
#  'fam218a',
#  'fam30a',
#  'fam49a',
#  'fam49b',
#  'fam92b',
#  'fgfr1op',
#  'fopnl',
#  'fp565260.1',
#  'g6pc',
#  'gars',
#  'gcsaml-as1',
#  'gdf5os',
#  'glra4',
#  'golga8m',
#  'grasp',
#  'h1f0',
#  'h1fnt',
#  'h1foo',
#  'h1fx',
#  'h2afj',
#  'h2afx',
#  'h2afy',
#  'h2afy2',
#  'h2afz',
#  'h2bfm',
#  'h2bfwt',
#  'h3.y',
#  'h3f3a',
#  'h3f3b',
#  'h3f3c',
#  'hars',
#  'hhla3',
#  'hist1h1a',
#  'hist1h1b',
#  'hist1h1c',
#  'hist1h1d',
#  'hist1h1e',
#  'hist1h2aa',
#  'hist1h2ac',
#  'hist1h2ae',
#  'hist1h2ag',
#  'hist1h2ai',
#  'hist1h2ak',
#  'hist1h2ba',
#  'hist1h2bb',
#  'hist1h2bg',
#  'hist1h2bh',
#  'hist1h2bn',
#  'hist1h3e',
#  'hist1h3g',
#  'hist1h3h',
#  'hist1h4b',
#  'hist1h4c',
#  'hist1h4e',
#  'hist1h4g',
#  'hist1h4i',
#  'hist1h4j',
#  'hist2h2be',
#  'hist3h2a',
#  'hist3h2bb',
#  'hist3h3',
#  'hist4h4',
#  'hypm',
#  'iars',
#  'ick',
#  'igha1',
#  'igha2',
#  'ighd',
#  'ighe',
#  'ighg1',
#  'ighg3',
#  'ighm',
#  'igkc',
#  'iglc1',
#  'iglc7',
#  'impad1',
#  'kars',
#  'kiaa0355',
#  'kiaa0556',
#  'kiaa1211',
#  'kiaa1211l',
#  'kiaa1257',
#  'kiaa1324',
#  'kiaa1324l',
#  'kif1bp',
#  'lars',
#  'linc02693',
#  'linc02694',
#  'lor',
#  'lrmp',
#  'lrp5l',
#  'lrrc29',
#  'maats1',
#  'marc1',
#  'marc2',
#  'march1',
#  'march10',
#  'march11',
#  'march2',
#  'march3',
#  'march4',
#  'march5',
#  'march6',
#  'march7',
#  'march8',
#  'march9',
#  'mars',
#  'mir1915hg',
#  'mrvi1',
#  'mycnos',
#  'nars',
#  'nxf5',
#  'or5r1',
#  'palm2-akap2',
#  'pano1',
#  'pde11a',
#  'pih1d3',
#  'pinx1',
#  'polr2j3',
#  'ppp5d1',
#  'prky',
#  'qars',
#  'rars',
#  'rgs5',
#  'sars',
#  'sfta3',
#  'siglec5',
#  'slc26a10',
#  'slc66a1l',
#  'slfn12l',
#  'snhg32',
#  'spata13',
#  'spata8',
#  'spert',
#  'sspo',
#  'st5',
#  'tars',
#  'tarsl2',
#  'tbce',
#  'tcte3',
#  'tctex1d1',
#  'tctex1d2',
#  'tctex1d4',
#  'terc',
#  'tmem155',
#  'tmem173',
#  'tmem189',
#  'tmem246',
#  'tmem8a',
#  'tmem99',
#  'tmsb15b',
#  'trac',
#  'trbc1',
#  'trbc2',
#  'trdc',
#  'trgc1',
#  'trgc2',
#  'trgjp1',
#  'trgjp2',
#  'trim16l',
#  'tsta3',
#  'ttc25',
#  'twistnb',
#  'vars',
#  'wars',
#  'wdr34',
#  'wdr60',
#  'wdr63',
#  'wdr66',
#  'wdr78',
#  'wdyhv1',
#  'yars',
#  'z82206.1',
#  'znf883',
#  'znrd1'}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 1558
# 仅在 all_genes 中存在的基因: {'hsfy2', 'h3c7', 'kcnj12', 'cxorf51b', 'pdcd2', 'bcas1', 'prelid1', 'gfus', 'rpl15', 'borcs7-asmt', 'h1-0', 'prokr2', 'lims4', 'tbc1d3c', 'dusp29', 'mrpl27', 'tdgf1p3', 'ran', 'diablo', 'lce1f', 'usp17l24', 'csag3', 'npm1', 'pcdhga4', 'cbwd5', 'kir3dl1', 'arsl', 'rasa4', 'p2ry4', 'abhd14a-acy1', 'tas2r13', 'h2bs1', 'mrps34', 'rps9', 'supt20hl1', 'mrpl18', 'fam236a', 'ppp1r2b', 'notch2nlc', 'urgcp-mrps24', 'or4f17', 'znf528', 'ocm', 'daz4', 'ssu72p5', 'or2t5', 'tex28', 'hsfx1', 'h2ac16', 'rpl41', 'kir2dl1', 'lyg2', 'ndufc2-kctd14', 'npipa1', 'kcna6', 'scygr5', 'mrpl42', 'h2bc3', 'spata31a3', 'opn1mw', 'fam153a', 'znf616', 'tpi1', 'pip5k1b', 'mrpl4', 'lilrb3', 'ckmt1b', 'odad2', 'maged4b', 'abcc6', 'hars1', 'mbd3l5', 'gucy2d', 'polr1h', 'rps20', 'or11h1', 'mrpl30', 'xage1b', 'srgap2b', 'gpr75', 'potee', 'rgpd1', 'znf593os', 'rpl4', 'ino80b-wbp1', 'pgam4', 'gtf2ird2b', 'bola2', 'rbm14-rbm4', 'usp17l25', 'mrpl15', 'pnpt1', 'znf93', 'htr1b', 'memo1', 'pin4', 'iqcj-schip1', 'npipb8', 'slc35g6', 'hnrnpab', 'pabpn1', 'c5orf63', 'defb104b', 'tug1', 'fam90a16p', 'fam209a', 'rps6', 'h4c15', 'kir3dl2', 'ttc34', 'g3bp1', 'apoc4-apoc2', 'cgb3', 'mrpl47', 'gimap1-gimap5', 'rps19', 'styxl2', 'golga8n', 'defb107a', 'c21orf62', 'ct45a2', 'h3y2', 'znf705e', 'dpy19l2', 'coro7-pam16', 'rpl10', 'hbg2', 'pabpc1', 'pld5p1', 'rpl35a', 'amy1a', 'mtrnr2l10', 'ppial4c', 'krtap4-7', 'bub1b-pak6', 'gtf2h2', 'rimbp3c', 'foxo3b', 'sftpa2', 'or1j4', 'mrps25', 'aopep', 'rbak-rbakdn', 'hnrnpa1p48', 'washc2a', 'yars1', 'bcl2l2-pabpn1', 'npipa2', 'hnrnpa1', 'tuba8', 'spdye11', 'tas2r3', 'ak3', 'krtap4-8', 'rps28', 'kcnk9', 'sdhd', 'flywch1', 'hla-doa', 'znf726', 'gpx1', 'mrps27', 'slc39a4', 'spaca5', 'potei', 'eif2s3b', 'jakmip1', 'hnrnpul2-bscl2', 'ppfia1', 'ctage9', 'zcchc10', 'jmjd7', 'rab43', 'slc35g4', 'ervh48-1', 'gatd3a', 'unkl', 'fam156a', 'plglb1', 'eif5al1', 'cenps-cort', 'rpsa', 'defb4b', 'hmgb1', 'marchf2', 'tvp23c-cdrt4', 'or4m2b', 'casp1', 'opn1mw3', 'mrpl1', 'or1r1p', 'mrps6', 'mrpl44', 'dnah2', 'il6st', 'nap1l1', 'npipb11', 'usp17l5', 'spin2a', 'h3c10', 'mrps16', 'setd2', 'mars1', 'mrpl40', 'steep1', 'rpl29', 'ct47a12', 'ct47a3', 'rps17', 'or51b4', 'fkbp4', 'fam156b', 'cxorf49', 'tdgf1', 'ppial4e', 'ano7', 'stx18', 'mroh7-ttc4', 'or4f5', 'h3c14', 'eif3c', 'rbms2', 'marchf8', 'vars1', 'ntn5', 'timm23b-agap6', 'hspb2-c11orf52', 'necab1', 'tbc1d3g', 'clp1', 'abitram', 'spdye13', 'rps27', 'ccdc25', 'marchf5', 'mrpl22', 'h2aj', 'aknad1', 'specc1l-adora2a', 'h2az1', 'rpl35', 'golga8a', 'cracdl', 'cfap92', 'maged4', 'pcdhgb3', 'tp53tg3e', 'eef1d', 'or8b3', 'dmrtc1b', 'rps11', 'fam246a', 'pabir2', 'h4c3', 'golga6d', 'krtap10-12', 'cep20', 'acer2', 'cxorf49b', 'palm2akap2', 'cd59', 'trim6-trim34', 'ct47a6', 'tas2r43', 'rpl9', 'serf1a', 'ankrd20a4p', 'ct47a9', 'matn4', 'rps12', 'spdye17', 'psg8', 'or1e2', 'mrpl17', 'h2ac21', 'h3c6', 'h2bc7', 'igf2', 'hla-dob', 'ten1-cdk3', 'fam90a19p', 'krtap9-2', 'or10g9', 'rnf222', 'rpl7a', 'mrpl39', 'myo7a', 'ankhd1-eif4ebp3', 'irag2', 'asdurf', 'tcaf2', 'ighmbp2', 'fam243a', 'dapl1', 'dync2i1', 'ccdc169-sohlh2', 'bpy2c', 'mbd3l4', 'mrpl21', 'mrpl14', 'cdy1', 'rbmy1d', 'rpl37', 'spata25', 'or51i1', 'mrps17', 'hsfy1', 'nrip2', 'atf7-npff', 'rex1bd', 'ylpm1', 'dnajc25-gng10', 'nedd8-mdp1', 'pigy', 'adprs', 'pdcd6-ahrr', 'lynx1-slurp2', 'cfhr1', 'psme3ip1', 'qars1', 'katnip', 'ugt1a6', 'rps25', 'scygr7', 'psg1', 'or2t3', 'acr', 'golga6l9', 'rps16', 'spdye8', 'scygr1', 'rab6d', 'tspy8', 'c1qtnf9b', 'rnf123', 'gpr52', 'hnrnpcl4', 'igbp1p2', 'aqp12b', 'dynlt5', 'h2bc5', 'c8orf44-sgk3', 'h2ac6', 'cklf-cmtm1', 'naip', 'utp14c', 'bpy2', 'dgcr6l', 'decr2', 'h3-5', 'c17orf114', 'catsper1', 'h1-7', 'hnrnph1', 'h3c2', 'ssx4', 'dnajc17', 'golga8f', 'bloc1s5-txndc5', 'fam86b2', 'h2ac13', 'ctag1a', 'rbmy1b', 'or51b2', 'ssx4b', 'daz3', 'c16orf82', 'ctbp1', 'dennd2b', 'mrps7', 'or14l1p', 'cct5', 'csh1', 'fam25g', 'pry2', 'znf814', 'loricrin', 'h2bc4', 'hsd17b7', 'rnf225', 'tas2r19', 'rpl36a', 'c20orf203', 'npipb6', ' ...
# 仅在 adata_genes 中存在的基因数量: 312
# 仅在 adata_genes 中存在的基因: {'h3.y', 'hist1h3h', 'cntd2', 'trbc2', 'ac134684.8', 'eprs', 'hist1h4g', 'cenpbd1', 'tars', 'ac015871.1', 'march9', 'kiaa1211', 'marc1', 'acpp', 'march5', 'hist1h2bh', 'or5r1', 'c5orf60', 'ac099489.1', 'igha1', 'ac087498.1', 'b3gnt10', 'prky', 'eloa3', 'ac113348.1', 'hist1h3g', 'h1foo', 'wdyhv1', 'impad1', 'fam192a', 'ac106774.4', 'h2afx', 'hist1h1c', 'hist4h4', 'arse', 'lars', 'fam49b', 'ighe', 'hist1h4j', 'h2bfm', 'al032819.3', 'fam169b', 'ac005551.1', 'armc4', 'c14orf177', 'march4', 'c10orf55', 'tsta3', 'defb133', 'trgc1', 'c2orf83', 'snhg32', 'ac021072.1', 'hist1h2ba', 'dec1', 'trac', 'c19orf57', 'hist1h4i', 'ac008687.4', 'qars', 'ick', 'wdr63', 'fam122a', 'al135905.2', 'ccdc114', 'tbce', 'pinx1', 'z82206.1', 'igha2', 'ac007244.1', 'adss', 'atp5mpl', 'znrd1', 'hist1h1a', 'trbc1', 'c15orf41', 'h2bfwt', 'aars', 'palm2-akap2', 'ccdc39', 'h2afy', 'kiaa1211l', 'tcte3', 'linc02694', 'ac011005.1', 'adssl1', 'gars', 'c11orf88', 'tctex1d1', 'ac236972.4', 'iglc7', 'c11orf40', 'slc66a1l', 'al451007.3', 'ac187653.1', 'al603764.2', 'hist1h4c', 'hist1h2ae', 'h3f3b', 'slc26a10', 'tmem189', 'tmem8a', 'sspo', 'ac004593.3', 'fopnl', 'hist1h1d', 'cxorf21', 'hhla3', 'lrrc29', 'ac093323.1', 'bx276092.9', 'al162596.1', 'al772284.2', 'atp6ap1l', 'fam122c', 'h3f3a', 'arih2os', 'ac011195.2', 'wars', 'c9orf129', 'wdr66', 'cxorf56', 'cxorf40a', 'h1fnt', 'casc4', 'kiaa0355', 'hist2h2be', 'slfn12l', 'h2afz', 'c12orf10', 'ac021097.2', 'fgfr1op', 'fam218a', 'ac233723.1', 'h1f0', 'lrmp', 'march11', 'ap000552.4', 'ighm', 'h1fx', 'march10', 'c16orf58', 'ac067752.1', 'hist1h2bb', 'ct62', 'dusp27', 'trgc2', 'c3orf67', 'c2orf91', 'elfn2', 'ccdc155', 'al354761.1', 'glra4', 'dock8-as1', 'alg1l', 'hars', 'terc', 'kiaa0556', 'dupd1', 'mir1915hg', 'cyb561d2', 'h2afj', 'march1', 'igkc', 'siglec5', 'lor', 'card16', 'ttc25', 'ac007906.2', 'iglc1', 'march2', 'kif1bp', 'fp565260.1', 'cllu1os', 'marc2', 'kars', 'ac073111.4', 'march6', 'g6pc', 'fam92b', 'tmem155', 'ac010325.1', 'al162231.1', 'hist1h1b', 'c6orf223', 'al845331.2', 'al391650.1', 'fam30a', 'rars', 'kiaa1324l', 'hist3h2bb', 'casc1', 'c12orf49', 'c1orf61', 'iars', 'c12orf81', 'ac025283.2', 'ac119396.1', 'ac090360.1', 'spata8', 'gdf5os', 'grasp', 'kiaa1324', 'ac118549.1', 'mrvi1', 'sfta3', 'hist1h2ak', 'nars', 'ccdc84', 'wdr34', 'mars', 'al121578.2', 'hist1h2ag', 'hist3h3', 'ac132217.2', 'tmsb15b', 'c11orf74', 'elmsan1', 'c6orf201', 'card17', 'ac013470.2', 'ac138647.1', 'al109810.2', 'dars', 'gcsaml-as1', 'st5', 'trgjp1', 'hist1h4b', 'h3f3c', 'c5orf30', 'al590560.2', 'h2afy2', 'atp5md', 'ccdc151', 'ac135068.1', 'trgjp2', 'trim16l', 'c5orf67', 'al160269.1', 'spert', 'ppp5d1', 'ighd', 'c7orf77', 'hist1h2bn', 'kiaa1257', 'c10orf142', 'polr2j3', 'hist1h4e', 'znf883', 'tctex1d2', 'hist1h2aa', 'spata13', 'bx255925.3', 'vars', 'ccdc140', 'al353572.3', 'march8', 'tmem99', 'fam49a', 'sars', 'rgs5', 'ac115220.1', 'ac008397.1', 'ap002495.1', 'ac010255.3', 'hist3h2a', 'wdr78', 'c19orf48', 'tarsl2', 'trdc', 'march7', 'ighg3', 'golga8m', 'pano1', 'nxf5', 'wdr60', 'linc02693', 'pih1d3', 'hist1h2ac', 'ac072022.2', 'ac092835.1', 'cars', 'ac091057.6', 'march3', 'lrp5l', 'fam122b', 'hist1h2ai', 'cd3eap', 'hist1h1e', 'mycnos', 'hist1h2bg', 'hypm', 'dirc1', 'adprhl2', 'c12orf74', 'twistnb', 'yars', 'al445238.1', 'ac025287.4', 'ighg1', 'tmem173', 'castor3', 'c9orf92', 'tctex1d4', 'maats1', 'pde11a', 'c17orf53', 'ccdc36', 'hist1h3e', 'tmem246', 'bhmg1', 'ac104389.5'}

# %%
dense_adata_X = adata.X
for i, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        new_data[:, gene_to_index[gene]] = dense_adata_X[:, i]
    else:
        print(f'Gene {gene} not found in all_genes list')
# Out:
# Gene fam49a not found in all_genes list
# Gene kars not found in all_genes list
# Gene lars not found in all_genes list
# Gene nars not found in all_genes list
# Gene polr2j3 not found in all_genes list
# Gene qars not found in all_genes list
# Gene trac not found in all_genes list
# Gene wars not found in all_genes list
# Gene aars not found in all_genes list
# Gene ac004593.3 not found in all_genes list
# Gene ac005551.1 not found in all_genes list
# Gene ac007244.1 not found in all_genes list
# Gene ac007906.2 not found in all_genes list
# Gene ac008397.1 not found in all_genes list
# Gene ac008687.4 not found in all_genes list
# Gene ac010255.3 not found in all_genes list
# Gene ac010325.1 not found in all_genes list
# Gene ac011005.1 not found in all_genes list
# Gene ac011195.2 not found in all_genes list
# Gene ac013470.2 not found in all_genes list
# Gene ac015871.1 not found in all_genes list
# Gene ac021072.1 not found in all_genes list
# Gene ac021097.2 not found in all_genes list
# Gene ac025283.2 not found in all_genes list
# Gene ac025287.4 not found in all_genes list
# Gene ac067752.1 not found in all_genes list
# Gene ac072022.2 not found in all_genes list
# Gene ac073111.4 not found in all_genes list
# Gene ac087498.1 not found in all_genes list
# Gene ac090360.1 not found in all_genes list
# Gene ac091057.6 not found in all_genes list
# Gene ac092835.1 not found in all_genes list
# Gene ac093323.1 not found in all_genes list
# Gene ac099489.1 not found in all_genes list
# Gene ac104389.5 not found in all_genes list
# Gene ac106774.4 not found in all_genes list
# Gene ac113348.1 not found in all_genes list
# Gene ac115220.1 not found in all_genes list
# Gene ac118549.1 not found in all_genes list
# Gene ac119396.1 not found in all_genes list
# Gene ac132217.2 not found in all_genes list
# Gene ac134684.8 not found in all_genes list
# Gene ac135068.1 not found in all_genes list
# Gene ac138647.1 not found in all_genes list
# Gene ac187653.1 not found in all_genes list
# Gene ac233723.1 not found in all_genes list
# Gene ac236972.4 not found in all_genes list
# Gene acpp not found in all_genes list
# Gene adprhl2 not found in all_genes list
# Gene adss not found in all_genes list
# Gene adssl1 not found in all_genes list
# Gene al032819.3 not found in all_genes list
# Gene al109810.2 not found in all_genes list
# Gene al121578.2 not found in all_genes list
# Gene al135905.2 not found in all_genes list
# Gene al160269.1 not found in all_genes list
# Gene al162231.1 not found in all_genes list
# Gene al162596.1 not found in all_genes list
# Gene al353572.3 not found in all_genes list
# Gene al354761.1 not found in all_genes list
# Gene al391650.1 not found in all_genes list
# Gene al445238.1 not found in all_genes list
# Gene al451007.3 not found in all_genes list
# Gene al590560.2 not found in all_genes list
# Gene al603764.2 not found in all_genes list
# Gene al772284.2 not found in all_genes list
# Gene al845331.2 not found in all_genes list
# Gene alg1l not found in all_genes list
# Gene ap000552.4 not found in all_genes list
# Gene ap002495.1 not found in all_genes list
# Gene arih2os not found in all_genes list
# Gene armc4 not found in all_genes list
# Gene arse not found in all_genes list
# Gene atp5md not found in all_genes list
# Gene atp5mpl not found in all_genes list
# Gene atp6ap1l not found in all_genes list
# Gene b3gnt10 not found in all_genes list
# Gene bhmg1 not found in all_genes list
# Gene bx255925.3 not found in all_genes list
# Gene bx276092.9 not found in all_genes list
# Gene c10orf142 not found in all_genes list
# Gene c10orf55 not found in all_genes list
# Gene c11orf40 not found in all_genes list
# Gene c11orf74 not found in all_genes list
# Gene c11orf88 not found in all_genes list
# Gene c12orf10 not found in all_genes list
# Gene c12orf49 not found in all_genes list
# Gene c12orf74 not found in all_genes list
# Gene c12orf81 not found in all_genes list
# Gene c14orf177 not found in all_genes list
# Gene c15orf41 not found in all_genes list
# Gene c16orf58 not found in all_genes list
# Gene c17orf53 not found in all_genes list
# Gene c19orf48 not found in all_genes list
# Gene c19orf57 not found in all_genes list
# Gene c1orf61 not found in all_genes list
# Gene c2orf83 not found in all_genes list
# Gene c2orf91 not found in all_genes list
# Gene c3orf67 not found in all_genes list
# Gene c5orf30 not found in all_genes list
# Gene c5orf60 not found in all_genes list
# Gene c5orf67 not found in all_genes list
# Gene c6orf201 not found in all_genes list
# Gene c6orf223 not found in all_genes list
# Gene c7orf77 not found in all_genes list
# Gene c9orf129 not found in all_genes list
# Gene c9orf92 not found in all_genes list
# Gene card16 not found in all_genes list
# Gene card17 not found in all_genes list
# Gene cars not found in all_genes list
# Gene casc1 not found in all_genes list
# Gene casc4 not found in all_genes list
# Gene castor3 not found in all_genes list
# Gene ccdc114 not found in all_genes list
# Gene ccdc140 not found in all_genes list
# Gene ccdc151 not found in all_genes list
# Gene ccdc155 not found in all_genes list
# Gene ccdc36 not found in all_genes list
# Gene ccdc39 not found in all_genes list
# Gene ccdc84 not found in all_genes list
# Gene cd3eap not found in all_genes list
# Gene cenpbd1 not found in all_genes list
# Gene cllu1os not found in all_genes list
# Gene cntd2 not found in all_genes list
# Gene ct62 not found in all_genes list
# Gene cxorf21 not found in all_genes list
# Gene cxorf40a not found in all_genes list
# Gene cxorf56 not found in all_genes list
# Gene cyb561d2 not found in all_genes list
# Gene dars not found in all_genes list
# Gene dec1 not found in all_genes list
# Gene defb133 not found in all_genes list
# Gene dirc1 not found in all_genes list
# Gene dock8-as1 not found in all_genes list
# Gene dupd1 not found in all_genes list
# Gene dusp27 not found in all_genes list
# Gene elfn2 not found in all_genes list
# Gene elmsan1 not found in all_genes list
# Gene eloa3 not found in all_genes list
# Gene eprs not found in all_genes list
# Gene fam122a not found in all_genes list
# Gene fam122b not found in all_genes list
# Gene fam122c not found in all_genes list
# Gene fam169b not found in all_genes list
# Gene fam192a not found in all_genes list
# Gene fam218a not found in all_genes list
# Gene fam30a not found in all_genes list
# Gene fam49b not found in all_genes list
# Gene fam92b not found in all_genes list
# Gene fgfr1op not found in all_genes list
# Gene fopnl not found in all_genes list
# Gene fp565260.1 not found in all_genes list
# Gene g6pc not found in all_genes list
# Gene gars not found in all_genes list
# Gene gcsaml-as1 not found in all_genes list
# Gene gdf5os not found in all_genes list
# Gene glra4 not found in all_genes list
# Gene golga8m not found in all_genes list
# Gene grasp not found in all_genes list
# Gene h1f0 not found in all_genes list
# Gene h1fnt not found in all_genes list
# Gene h1foo not found in all_genes list
# Gene h1fx not found in all_genes list
# Gene h2afj not found in all_genes list
# Gene h2afx not found in all_genes list
# Gene h2afy not found in all_genes list
# Gene h2afy2 not found in all_genes list
# Gene h2afz not found in all_genes list
# Gene h2bfm not found in all_genes list
# Gene h2bfwt not found in all_genes list
# Gene h3.y not found in all_genes list
# Gene h3f3a not found in all_genes list
# Gene h3f3b not found in all_genes list
# Gene h3f3c not found in all_genes list
# Gene hars not found in all_genes list
# Gene hhla3 not found in all_genes list
# Gene hist1h1a not found in all_genes list
# Gene hist1h1b not found in all_genes list
# Gene hist1h1c not found in all_genes list
# Gene hist1h1d not found in all_genes list
# Gene hist1h1e not found in all_genes list
# Gene hist1h2aa not found in all_genes list
# Gene hist1h2ac not found in all_genes list
# Gene hist1h2ae not found in all_genes list
# Gene hist1h2ag not found in all_genes list
# Gene hist1h2ai not found in all_genes list
# Gene hist1h2ak not found in all_genes list
# Gene hist1h2ba not found in all_genes list
# Gene hist1h2bb not found in all_genes list
# Gene hist1h2bg not found in all_genes list
# Gene hist1h2bh not found in all_genes list
# Gene hist1h2bn not found in all_genes list
# Gene hist1h3e not found in all_genes list
# Gene hist1h3g not found in all_genes list
# Gene hist1h3h not found in all_genes list
# Gene hist1h4b not found in all_genes list
# Gene hist1h4c not found in all_genes list
# Gene hist1h4e not found in all_genes list
# Gene hist1h4g not found in all_genes list
# Gene hist1h4i not found in all_genes list
# Gene hist1h4j not found in all_genes list
# Gene hist2h2be not found in all_genes list
# Gene hist3h2a not found in all_genes list
# Gene hist3h2bb not found in all_genes list
# Gene hist3h3 not found in all_genes list
# Gene hist4h4 not found in all_genes list
# Gene hypm not found in all_genes list
# Gene iars not found in all_genes list
# Gene ick not found in all_genes list
# Gene igha1 not found in all_genes list
# Gene igha2 not found in all_genes list
# Gene ighd not found in all_genes list
# Gene ighe not found in all_genes list
# Gene ighg1 not found in all_genes list
# Gene ighg3 not found in all_genes list
# Gene ighm not found in all_genes list
# Gene igkc not found in all_genes list
# Gene iglc1 not found in all_genes list
# Gene iglc7 not found in all_genes list
# Gene impad1 not found in all_genes list
# Gene kiaa0355 not found in all_genes list
# Gene kiaa0556 not found in all_genes list
# Gene kiaa1211 not found in all_genes list
# Gene kiaa1211l not found in all_genes list
# Gene kiaa1257 not found in all_genes list
# Gene kiaa1324 not found in all_genes list
# Gene kiaa1324l not found in all_genes list
# Gene kif1bp not found in all_genes list
# Gene linc02693 not found in all_genes list
# Gene linc02694 not found in all_genes list
# Gene lor not found in all_genes list
# Gene lrmp not found in all_genes list
# Gene lrp5l not found in all_genes list
# Gene lrrc29 not found in all_genes list
# Gene maats1 not found in all_genes list
# Gene marc1 not found in all_genes list
# Gene marc2 not found in all_genes list
# Gene march1 not found in all_genes list
# Gene march10 not found in all_genes list
# Gene march11 not found in all_genes list
# Gene march2 not found in all_genes list
# Gene march3 not found in all_genes list
# Gene march4 not found in all_genes list
# Gene march5 not found in all_genes list
# Gene march6 not found in all_genes list
# Gene march7 not found in all_genes list
# Gene march8 not found in all_genes list
# Gene march9 not found in all_genes list
# Gene mars not found in all_genes list
# Gene mir1915hg not found in all_genes list
# Gene mrvi1 not found in all_genes list
# Gene mycnos not found in all_genes list
# Gene nxf5 not found in all_genes list
# Gene or5r1 not found in all_genes list
# Gene palm2-akap2 not found in all_genes list
# Gene pano1 not found in all_genes list
# Gene pde11a not found in all_genes list
# Gene pih1d3 not found in all_genes list
# Gene pinx1 not found in all_genes list
# Gene ppp5d1 not found in all_genes list
# Gene prky not found in all_genes list
# Gene rars not found in all_genes list
# Gene rgs5 not found in all_genes list
# Gene sars not found in all_genes list
# Gene sfta3 not found in all_genes list
# Gene siglec5 not found in all_genes list
# Gene slc26a10 not found in all_genes list
# Gene slc66a1l not found in all_genes list
# Gene slfn12l not found in all_genes list
# Gene snhg32 not found in all_genes list
# Gene spata13 not found in all_genes list
# Gene spata8 not found in all_genes list
# Gene spert not found in all_genes list
# Gene sspo not found in all_genes list
# Gene st5 not found in all_genes list
# Gene tars not found in all_genes list
# Gene tarsl2 not found in all_genes list
# Gene tbce not found in all_genes list
# Gene tcte3 not found in all_genes list
# Gene tctex1d1 not found in all_genes list
# Gene tctex1d2 not found in all_genes list
# Gene tctex1d4 not found in all_genes list
# Gene terc not found in all_genes list
# Gene tmem155 not found in all_genes list
# Gene tmem173 not found in all_genes list
# Gene tmem189 not found in all_genes list
# Gene tmem246 not found in all_genes list
# Gene tmem8a not found in all_genes list
# Gene tmem99 not found in all_genes list
# Gene tmsb15b not found in all_genes list
# Gene trbc1 not found in all_genes list
# Gene trbc2 not found in all_genes list
# Gene trdc not found in all_genes list
# Gene trgc1 not found in all_genes list
# Gene trgc2 not found in all_genes list
# Gene trgjp1 not found in all_genes list
# Gene trgjp2 not found in all_genes list
# Gene trim16l not found in all_genes list
# Gene tsta3 not found in all_genes list
# Gene ttc25 not found in all_genes list
# Gene twistnb not found in all_genes list
# Gene vars not found in all_genes list
# Gene wdr34 not found in all_genes list
# Gene wdr60 not found in all_genes list
# Gene wdr63 not found in all_genes list
# Gene wdr66 not found in all_genes list
# Gene wdr78 not found in all_genes list
# Gene wdyhv1 not found in all_genes list
# Gene yars not found in all_genes list
# Gene z82206.1 not found in all_genes list
# Gene znf883 not found in all_genes list
# Gene znrd1 not found in all_genes list

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

estim.model.eval()
with torch.no_grad():
    X_train_tensor = torch.tensor(X_train).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    train_embeddings = estim.model.encoder(X_train_tensor).detach().cpu().numpy()
    test_embeddings = estim.model.encoder(X_test_tensor).detach().cpu().numpy()
# Out:
# cuda

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.7902809234314777
# Weighted F1 Score: 0.7820104567996425
# Macro F1 Score: 0.6217529561958304
# Random Guess Accuracy: 0.1320247177116093
#                          precision    recall  f1-score   support
#
#                 B_Cells       0.74      0.82      0.78       772
#            CD4+_T_Cells       0.67      0.71      0.69      1286
#            CD8+_T_Cells       0.66      0.67      0.66      1026
#                  DCIS_1       0.62      0.79      0.69      1937
#                  DCIS_2       0.65      0.42      0.51      1746
#             Endothelial       0.88      0.93      0.90      1348
#               IRF7+_DCs       0.58      0.64      0.61        74
#          Invasive_Tumor       0.85      0.91      0.88      5230
#              LAMP3+_DCs       0.68      0.31      0.42        49
#           Macrophages_1       0.79      0.86      0.82      1692
#           Macrophages_2       0.55      0.44      0.49       223
#              Mast_Cells       0.60      0.21      0.32        28
#           Myoepi_ACTA2+       0.81      0.81      0.81      1043
#           Myoepi_KRT15+       0.83      0.84      0.83       426
#       Perivascular-Like       0.61      0.42      0.50       125
#   Prolif_Invasive_Tumor       0.63      0.33      0.43       533
#                 Stromal       0.90      0.91      0.91      6184
# Stromal_&_T_Cell_Hybrid       0.16      0.03      0.05        93
#   T_Cell_&_Tumor_Hybrid       0.49      0.61      0.54        87
#               Unlabeled       0.70      0.50      0.58      1265
#
#                accuracy                           0.79     25167
#               macro avg       0.67      0.61      0.62     25167
#            weighted avg       0.78      0.79      0.78     25167

# %%
with torch.no_grad():
    new_data_tensor = torch.tensor(new_data).float().to(device)
    SSL_embeddings = estim.model.encoder(new_data_tensor).detach().cpu().numpy()
new_adata = sc.read_h5ad(data_dir)
new_adata.obsm[f'SSL_RM_ZS_{random_seed}'] = SSL_embeddings
new_adata.uns[f'RM_ZS_y_test_{random_seed}'] = y_test
new_adata.uns[f'RM_ZS_predictions_{random_seed}'] = predictions
new_adata.uns[f'RM_ZS_target_names_{random_seed}'] = label_encoder.classes_
new_adata.write_h5ad(data_dir)

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "SpaGE_imputed_Xenium_breast_cancer_sample1_replicate1_random_mask_zero_shot_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicro_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicro_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['SpaGE_imputed_xenium_breast_cancer_sample1_replicate1'],
    'method': [re.search(r'replicate1_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micro_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# macro_f1	weighted_f1	micro_f1
# 0.622	0.782	0.790
