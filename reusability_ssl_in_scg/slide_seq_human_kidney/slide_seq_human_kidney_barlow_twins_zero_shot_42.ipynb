# %%
import scanpy as sc
data_dir = '../../dataset/Marshall2022High_human_sampled.h5ad'
adata = sc.read_h5ad(data_dir)
adata.X = adata.raw.X

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
adata.var['gene_id'] = adata.var.index
adata.var.index = adata.var['gene_name']

# %%
# %load_ext autoreload
# %autoreload 2
import scanpy as sc
import torch
import lightning.pytorch as pl
from self_supervision.models.lightning_modules.cellnet_autoencoder import MLPBarlowTwins
from self_supervision.estimator.cellnet import EstimatorAutoEncoder

# 设置你的 .ckpt 文件路径
ckpt_path = "../../sc_pretrained/Pretrained Models/BarlowTwins.ckpt"

# 模型参数
units_encoder = [512, 512, 256, 256, 64]

# 初始化 EstimatorAutoEncoder 实例
estim = EstimatorAutoEncoder(data_path=None)  # 如果没有实际数据路径，可以设置为None

# 加载预训练模型
estim.model = MLPBarlowTwins(
        gene_dim=19331,  # 根据你的数据调整
        batch_size=2048,  # 根据你的需要调整
        units_encoder=units_encoder,
        CHECKPOINT_PATH=ckpt_path
    )


estim.trainer = pl.Trainer(accelerator="gpu", devices=1 if torch.cuda.is_available() else None)
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/tf.py:52: UserWarning: Tensorflow dtype mappings did not load successfully due to an error: No module named 'tensorflow'
#   warn(f"Tensorflow dtype mappings did not load successfully due to an error: {exc.msg}")
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
# 加载 checkpoint
checkpoint = torch.load(ckpt_path)
estim.model.inner_model.load_state_dict({k.replace('backbone.', ''): v for k, v in checkpoint.items() if 'backbone' in k})

# 设定模型为评估模式
estim.model.eval()
# Out:
# MLPBarlowTwins(
#   (train_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=train_
#   )
#   (val_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=val_
#   )
#   (test_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=test_
#   )
#   (inner_model): MLP(
#     (0): Linear(in_features=19331, out_features=512, bias=True)
#     (1): SELU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SELU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SELU()
#     (8): Dropout(p=0.0, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): SELU()
#     (11): Dropout(p=0.0, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=True)
#   )
#   (barlow_twins): BarlowTwins(
#     (backbone): MLP(
#       (0): Linear(in_features=19331, out_features=512, bias=True)
#       (1): SELU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): SELU()
#       (5): Dropout(p=0.0, inplace=False)
#       (6): Linear(in_features=512, out_features=256, bias=True)
#       (7): SELU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): Linear(in_features=256, out_features=256, bias=True)
#       (10): SELU()
#       (11): Dropout(p=0.0, inplace=False)
#       (12): Linear(in_features=256, out_features=64, bias=True)
#     )
#     (projector): Sequential(
#       (0): Linear(in_features=64, out_features=256, bias=False)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Linear(in_features=256, out_features=256, bias=False)
#       (4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Linear(in_features=256, out_features=512, bias=False)
#       (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): Linear(in_features=512, out_features=512, bias=False)
#     )
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   )
# )

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# gene_name
# A1BG                                              A1BG
# A1BG-AS1                                      A1BG-AS1
# A1CF                                              A1CF
# A2M                                                A2M
# A2M-AS1                                        A2M-AS1
#                                        ...
# ZZZ3                                              ZZZ3
# MISP3                                            MISP3
# ENSG00000234352.9                    ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3    ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                    SBNO1-AS1
# Name: gene_name, Length: 20299, dtype: category
# Categories (25391, object): ['7SK_ENSG00000202198', 'A1BG', 'A1BG-AS1', 'A1CF', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# gene_name
# A1BG                                              A1BG
# A1BG-AS1                                      A1BG-AS1
# A1CF                                              A1CF
# A2M                                                A2M
# A2M-AS1                                        A2M-AS1
#                                        ...
# ZZZ3                                              ZZZ3
# MISP3                                            MISP3
# ENSG00000234352.9                    ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3    ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                    SBNO1-AS1
# Name: gene_name, Length: 20299, dtype: category
# Categories (25391, object): ['7SK_ENSG00000202198', 'A1BG', 'A1BG-AS1', 'A1CF', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 15360
# 匹配的基因列表: {'mpp3', 'llgl1', 'dipk1b', 'grk6', 'irak4', 'spef1', 'il23a', 'sh2d4b', 'plg', 'stox1', 'capn5', 'slc38a11', 'det1', 'hnrnph2', 'drich1', 'pitrm1', 'gucy2c', 'rps15', 'nudt21', 'telo2', 'aco2', 'c1qa', 'strc', 'gm2a', 'grin3a', 'acbd3', 'dock3', 'dchs2', 'hus1', 'hpd', 'stmn1', 'stra6', 'pcnx3', 'cep152', 'plac8', 'cradd', 'kmo', 'smco3', 'frmpd2', 'mapk10', 'cast', 'bak1', 'josd1', 'ndufa5', 'otub1', 'gpr173', 'ifrd1', 'aurkaip1', 'prr11', 'tmem230', 'spry1', 'trim4', 'snapc2', 'usp47', 'hspg2', 'rnmt', 'slc28a1', 'ankrd13b', 'sh3bgrl', 'sfrp4', 'traf6', 'dnajb6', 'nup160', 'luc7l2', 'cabp1', 'acap2', 'ptprd', 'gab3', 'btn2a2', 'atp6v0e1', 'raf1', 'znf326', 'fam83f', 'uba1', 'akap10', 'clk4', 'crppa', 'gmip', 'maf1', 'ankrd36', 'cntnap2', 'fech', 'ttc16', 'ppp1r3f', 'znf600', 'mrpl10', 'susd1', 'akt2', 'wbp2', 'zc4h2', 'anos1', 'gdf6', 'fth1', 'nfix', 'stk26', 'mtmr11', 'cryz', 'hyal4', 'fosl1', 'myo15a', 'ctnnbl1', 'coq10a', 'ptgs2', 'proser3', 'znf480', 'mgat5', 'phex', 'fhad1', 'arhgef26', 'cd14', 'mogs', 'ccdc65', 'slc22a17', 'b9d2', 'lin52', 'cybc1', 'usp21', 'fbxl14', 'endou', 'myl12a', 'rfc1', 'stk17a', 'cd80', 'mrm3', 'taf3', 'usp9x', 'pum1', 'akna', 'pls3', 'emb', 'fank1', 'cacna1e', 'c18orf32', 'styk1', 'pdp2', 'pcdhga12', 'senp6', 'setd5', 'fam81b', 'arrdc1', 'gprc5c', 'lrp10', 'prelid3a', 'nim1k', 'irag1', 'suclg2', 'mob1b', 'xaf1', 'prmt7', 'pfdn2', 'atp2c1', 'tcf25', 'sms', 'kat14', 'vgll4', 'ptger1', 'dedd2', 'lsm10', 'gatb', 'prkn', 'cyp3a43', 'usf3', 'coro2a', 'dnajc12', 'pnpla4', 'kcnmb4', 'acat1', 'pigs', 'ndufa9', 'snx10', 'atcay', 'ppp6c', 'cfap52', 'sat2', 'znf596', 'smim36', 'psmb7', 'rap2b', 'saal1', 'rbm18', 'cox5b', 'rag1', 'ppp4r3a', 'dhdh', 'oxt', 'fgl2', 'fancg', 'clcn4', 'gsn', 'znf275', 'rbm25', 'camk1g', 'mgst3', 'erich1', 'calml6', 'vkorc1', 'nol6', 'psma3', 'vars2', 'rpl28', 'enox2', 'rock2', 'fbxo2', 'cxxc4', 'iqcd', 'lhb', 'mt-nd4l', 'kiaa2026', 'hoxc8', 'ythdf2', 'clstn3', 'foxj3', 'c3orf20', 'cyp27b1', 'ncoa5', 'optn', 'pwp2', 'lmod1', 'tro', 'st6gal1', 'sec14l1', 'ptprt', 'micos13', 'coq3', 'clpb', 'paqr4', 'trim54', 'dnajb4', 'tmcc1', 'katna1', 'lrrc4b', 'dnajc1', 'senp5', 'znf226', 'pak3', 'ccdc24', 'faah', 'igfbp1', 'kif12', 'pnrc1', 'ethe1', 'mchr1', 'cap2', 'pigx', 'aldh3b1', 'tmed9', 'arhgap40', 'znf571', 'cd48', 'cnp', 'lrrc8d', 'evi5', 'fbxl13', 'sh3gl3', 'taf9b', 'ccar2', 'ift43', 'igsf1', 'vps35l', 'cd84', 'c1orf116', 'myo16', 'kat5', 'mzb1', 'gpbp1l1', 'atp6v1d', 'zcchc7', 'acsm6', 'rnf126', 'zfpm1', 'bnip2', 'tom1l1', 'xpnpep3', 'pard6g', 'apoe', 'fam227a', 'eno4', 'poln', 'slco3a1', 'degs2', 'naf1', 'sypl1', 'hla-drb1', 'ppp1r26', 'kbtbd11', 'nrcam', 'sstr5', 'pax2', 'ap2s1', 'agpat1', 'apoo', 'znf138', 'eme2', 'xkr8', 'camkk2', 'sbds', 'kpna2', 'pygb', 'zbbx', 'gpr107', 'eif2s1', 'mesp2', 'eif3a', 'pgap6', 'orc1', 'znf683', 'shisa3', 'esyt2', 'svep1', 'znf550', 'znf438', 'rhpn2', 'cfap73', 'epm2aip1', 'irf2bp1', 'rragc', 'ttc8', 'shisal2a', 'ntn4', 'borcs6', 'arhgef18', 'ogfod2', 'abl1', 'atp6v0a4', 'smu1', 'tmprss11e', 'slc7a14', 'c8orf82', 'bicdl1', 'timp3', 'pigl', 'tslp', 'znf121', 'osgepl1', 'hoxa5', 'cltrn', 'gpsm3', 'tox3', 'mrnip', 'wdr33', 'eea1', 'peak1', 'fcgr2a', 'pigu', 'tmem50b', 'ascc1', 'rab42', 'znf248', 'catspere', 'ap2m1', 'kcnk17', 'rsph4a', 'anapc16', 'slc25a16', 'rad23b', 'zhx1-c8orf76', 'adal', 'hla-dqa1', 'slc35b3', 'snrk', 'timm23b', 'nkrf', 'tenm1', 'fam169a', 'dph2', 'fam135b', 'ttll11', 'iqgap3', 'vip', 'aplp2', 'snx19', 'pfas', 'ccdc43', 'ppp1r9b', 'stam2', 'tent4b', 'bid', 'dhx35', 'abcc5', 'lancl2', 'anp32a', 'ube2d2', 'ccl22', 'inmt', 'mrtfb', 'cd81', 'fscn2', 'gjd3', 'hmga1', 'lipj', 'flrt1', 'id3', 'hadh', 'pkp3', 'alyref', 'prss45p', 'mesd', 'myl5', 'kif2c', 'chchd2', 'c5orf15', 'kcng3', 'prim2', 'aspdh', 'rab3b', 'c11orf24', 'gria4', 'cdh11', 'znf280c', 'stx1a', 'vrk1', 'znf462', 'slc24a1', 'zcchc17', 'rgl2', 'gid8', 'klhdc7b', 'plcxd3', 'acp3', 'arcn1', 'znf711', 'ostn', 'smn1', 'lrrc27', 'dync1li2', 'atrn', 'cd99l2', 'cxcl9',  ...
# {'ensg00000227681.5',
#  'tesc-as1',
#  'nepro-as1',
#  'syt15-as1',
#  'dhrsx_ensg00000169084',
#  'gata3-as1',
#  'tns2-as1',
#  'ensg00000257286.1',
#  'ensg00000228150.1',
#  'pvt1',
#  'ensg00000272221.1',
#  'hdac4-as1',
#  'ensg00000261386.2',
#  'tprg1-as1',
#  'ensg00000227388.3',
#  'linc02018',
#  'ensg00000270956.1',
#  'gata2-as1',
#  'ensg00000224738.2',
#  'nup107-dt',
#  'ensg00000263257.3',
#  'ensg00000224356.5',
#  'ensg00000271978.2',
#  'ensg00000269621.1',
#  'rnu6-1327p',
#  'fhad1-as1',
#  'ccr5as',
#  'ensg00000241345.1',
#  'linc02398',
#  'ensg00000268083.5',
#  'ensg00000224985.1',
#  'ensg00000248101.2',
#  'ensg00000266397.1',
#  'dennd6a-as1',
#  'ensg00000243004.7',
#  'ensg00000248491.6',
#  'ensg00000259891.1',
#  'linc-pint',
#  'ensg00000238280.2',
#  'catip-as1',
#  'xpc-as1',
#  'rsl1d1-dt',
#  'ensg00000243389.1',
#  'ensg00000265393.1',
#  'linc02778',
#  'adam20p1_ensg00000259158',
#  'ensg00000260661.1',
#  'ensg00000270871.1',
#  'atxn7l3-as1',
#  'ensg00000273456.2',
#  'namptp1',
#  'dlgap1-as3',
#  'cbr3-as1',
#  'ensg00000260710.3',
#  'slc16a4-as1',
#  'c7_ensg00000112936',
#  'hsd11b1-as1',
#  'jazf1-as1',
#  'prkx-as1',
#  'ensg00000259353.1',
#  'atp2b1-as1',
#  'linc02268',
#  'ensg00000269535.1',
#  'linc02019',
#  'linc02343',
#  'ccdc26',
#  'linc02147',
#  'dpy19l3-dt',
#  'ensg00000260914.3',
#  'ensg00000259359.2',
#  'adamts9-as1',
#  'ensg00000229151.3',
#  'suclg2-dt',
#  'ensg00000267827.5',
#  'gna15-dt',
#  'ensg00000251652.1',
#  'rnu2-68p',
#  'ensg00000227598.1',
#  'hexa-as1',
#  'ensg00000258365.1',
#  'ankrd17-dt',
#  'ier3-as1',
#  'slc14a2-as1',
#  'rbm26-as1',
#  'ensg00000270147.1',
#  'ensg00000253693.1',
#  'pgm5-as1',
#  'ensg00000258603.5',
#  'ensg00000272341.1',
#  'ensg00000232110.9',
#  'dleu1',
#  'ensg00000224746.2',
#  'ensg00000260392.6',
#  'ensg00000270638.1',
#  'ensg00000227075.1',
#  'wapl-dt',
#  'stim1-as1',
#  'ensg00000260647.1',
#  'linc01547',
#  'ensg00000259704.3',
#  'ensg00000255462.1',
#  'ensg00000265749.6',
#  'pus1-as1',
#  'ensg00000270240.2',
#  'ensg00000228648.1',
#  'ensg00000260017.1',
#  'linc01765',
#  'ensg00000273209.1',
#  'linc01535',
#  'ensg00000259644.1',
#  'st7-ot4',
#  'ensg00000267504.1',
#  'ensg00000235271.6',
#  'ensg00000222017.1',
#  'ensg00000260342.2',
#  'ensg00000238282.1',
#  'ensg00000229227.8',
#  'cd109-as1',
#  'linc01410',
#  'ensg00000248656.3',
#  'ptprn2-as1',
#  'ensg00000272969.1',
#  'snord13',
#  'tm9sf5p',
#  'crim1-dt',
#  'c1qtnf7-as1',
#  'ensg00000263917.1',
#  'ensg00000243081.2',
#  'ensg00000231970.1',
#  'mrgprf-as1',
#  'smad9-it1',
#  'piwil4-as1',
#  'traf3ip2-as1',
#  'ensg00000267193.7',
#  'ensg00000247903.1',
#  'ensg00000253238.3',
#  'linc00671',
#  'zdhhc12-dt',
#  'vash1-dt',
#  'csrp3-as1',
#  'ensg00000257767.3',
#  'linc00635',
#  'ensg00000223786.1',
#  'ensg00000269680.1',
#  'ensg00000262681.2',
#  'ensg00000225721.5',
#  'patl1-dt',
#  'tle1-dt',
#  'ensg00000253627.1',
#  'ensg00000267748.4',
#  'znf667-as1',
#  'ensg00000261101.2',
#  'linc02926',
#  'ank3-dt',
#  'linc02346',
#  'c5orf64',
#  'ensg00000267780.2',
#  'dusp5-dt',
#  'linc00907',
#  'ensg00000259985.1',
#  'fam169a-as1',
#  'ensg00000226149.6',
#  'ensg00000266953.6',
#  'ensg00000257894.2',
#  'ensg00000265542.5',
#  'ensg00000272953.2',
#  'ensg00000223838.2',
#  'ensg00000269481.1',
#  'ensg00000272692.2',
#  'ensg00000272871.1',
#  'nherf1',
#  'linc02202',
#  'ensg00000259138.1',
#  'linc02028',
#  'linc01994',
#  'ensg00000234185.2',
#  'ensg00000251615.3',
#  'coq7-dt',
#  'ensg00000228061.7',
#  'linc01882',
#  'mt-tr',
#  'nudt19-dt',
#  'abca15p',
#  'atp1a1-as1',
#  'linc00887',
#  'ensg00000234405.2',
#  'hsd17b2-as1',
#  'ensg00000259366.3',
#  'ensg00000260917.1',
#  'clrn1-as1',
#  'ensg00000273328.5',
#  'ap4b1-as1',
#  'ensg00000215304.3',
#  'ensg00000225718.2',
#  'ensg00000273118.1',
#  'ensg00000273026.1',
#  'ensg00000267175.5',
#  'cops8-dt',
#  'epb41l4a-as1',
#  'ensg00000272156.1',
#  'frg1-dt',
#  'ensg00000262769.1',
#  'ensg00000271754.1',
#  'tirap-as1',
#  'linc01436',
#  'ensg00000256571.1',
#  'ensg00000265967.1',
#  'ensg00000271993.1',
#  'ensg00000269246.2',
#  'ensg00000269292.1',
#  'gask1b-as1',
#  'ensg00000254035.1',
#  'grm7-as3',
#  'ensg00000271780.2',
#  'tex56p',
#  'linc02696',
#  'ensg00000233967.7',
#  'linc02277',
#  'cenpn-as1',
#  'ensg00000228107.1',
#  'ensg00000225339.4',
#  'cep250-as1',
#  'ensg00000272768.1',
#  'ensg00000269237.1',
#  'linc01980',
#  'ppp4r1-as1',
#  'jdp2-as1',
#  'paqr5-dt',
#  'hoxb-as3',
#  'dlgap1-as1',
#  'linc01951',
#  'ensg00000259675.4',
#  'ensg00000234626.2',
#  'ensg00000253125.1',
#  'ensg00000262160.1',
#  'ensg00000272733.1',
#  'mphosph6-dt',
#  'ensg00000272079.2',
#  'linc03033',
#  'linc01554',
#  'ensg00000271833.1',
#  'cpb2-as1',
#  'anxa2r-as1',
#  'linc02397',
#  'ensg00000267039.1',
#  'ensg00000262089.1',
#  'ensg00000260401.1',
#  'magi2-as3',
#  'ttc23-as1',
#  'ensg00000267458.1',
#  'ensg00000229294.1',
#  'lmntd2-as1',
#  'ensg00000249319.2',
#  'ensg00000244063.1',
#  'linc00923',
#  'ensg00000176593.8',
#  'synpo2l-as1',
#  'ensg00000273179.1',
#  'ensg00000244459.4',
#  'malinc1',
#  'ensg00000255130.1',
#  'ensg00000260368.1',
#  'linc02614',
#  'mir503hg',
#  'hoxa-as3',
#  'ensg00000267011.5',
#  'ensg00000261098.1',
#  'ensg00000269243.1',
#  'itfg2-as1_ensg00000258325',
#  'ensg00000223462.2',
#  'ensg00000259543.1',
#  'ensg00000234553.1',
#  'h1-10-as1',
#  'linc01409',
#  'ensg00000273017.1',
#  'linc02693',
#  'cerox1',
#  'ensg00000259124.1',
#  'mmp25-as1',
#  'c2orf74-dt',
#  'ensg00000226578.1',
#  'ensg00000230107.1',
#  'ensg00000272416.1',
#  'ensg00000226526.1',
#  'eola2-dt',
#  'ensg00000220256.4',
#  'ensg00000272502.1',
#  'ensg00000249675.1',
#  'ensg00000253500.6',
#  'mirlet7bhg',
#  'linc01285',
#  'ensg00000240401.9',
#  'pinx1_ensg00000254093',
#  'ensg00000262810.1',
#  'ensg00000272024.1',
#  'ensg00000253557.6',
#  'vim-as1',
#  'rfx3-dt',
#  'linc01571',
#  'ensg00000259616.2',
#  'ensg00000259316.12',
#  'znf778-dt',
#  'rn7sl308p',
#  'ensg00000272444.1',
#  'ensg00000266578.2',
#  'linc01344',
#  'ensg00000256407.2',
#  'card16',
#  'fam3d-as1',
#  'ensg00000257194.2',
#  'ensg00000250167.2',
#  'xiap-as1',
#  'oser1-dt',
#  'linc01643',
#  'srp54-as1',
#  'gau1',
#  'ensg00000273156.2',
#  'ensg00000246331.2',
#  'chct1',
#  'linc02897',
#  'ensg00000244137.1',
#  'linc01990',
#  'ensg00000234396.3',
#  'ensg00000273335.1',
#  'ensg00000257831.1',
#  'linc01847',
#  'ensg00000228835.1',
#  'linc00106_ensg00000236871',
#  'gpr199p',
#  'ensg00000213121.2',
#  'linc02777',
#  'ensg00000268093.1',
#  'ensg00000240571.1',
#  'linc02593',
#  'ensg00000271011.1',
#  'ensg00000271344.1',
#  'ensg00000258558.1',
#  'ensg00000253372.5',
#  'emc1-as1',
#  'linc01564',
#  'usp3-as1',
#  'pelo-as1',
#  'ensg00000248799.1',
#  'rny1',
#  'ensg00000265750.1',
#  'linc01019',
#  'ensg00000275119.1',
#  'ensg00000259053.1',
#  'ensg00000233251.8',
#  'pdgfa-dt',
#  'ensg00000226566.2',
#  'cibar1-dt',
#  'aprg1',
#  'ensg00000231698.3',
#  'lucat1',
#  'ensg00000272971.1',
#  'ensg00000253163.1',
#  'ensg00000256481.1',
#  'ensg00000235726.7',
#  'ensg00000261732.1',
#  'linc01931',
#  'nfib-as1',
#  'ftx',
#  'rabgap1l-dt',
#  'linc02408',
#  'linc02387',
#  'ensg00000263826.1',
#  'linc02741',
#  'tenm2-as1',
#  'linc00502',
#  'ensg00000267283.1',
#  'linc01123',
#  'rn7sl608p',
#  'h2ac25',
#  'ensg00000124593.16',
#  'flg-as1',
#  'ensg00000225032.5',
#  'ensg00000231856.4',
#  'ensg00000255031.5',
#  'ensg00000229066.2',
#  'ensg00000228084.3',
#  'rfpl3s',
#  'linc01431',
#  'scoc-as1',
#  'ensg00000272970.5',
#  'linc02217',
#  'ensg00000258317.1',
#  'ensg00000266002.1',
#  'linc03070',
#  'ensg00000232811.1',
#  'linc02802',
#  'ensg00000224077.1',
#  'ensg00000270008.1',
#  'ensg00000272973.2',
#  'adamts16-dt',
#  'ensg00000226647.2',
#  'sanbr',
#  'ensg00000259678.1',
#  'ensg00000261502.4',
#  'rn7sl521p',
#  'ensg00000260381.2',
#  'rnu6-272p',
#  'ensg00000263331.1',
#  'cpeb1-as1',
#  'snhg12',
#  'gucy2c-as1',
#  'ensg00000253496.3',
#  'ensg00000243944.5',
#  'ensg00000231724.1',
#  'ensg00000268981.5',
#  'linc01787',
#  'ensg00000272442.2',
#  'ensg00000231557.1',
#  'ensg00000273186.1',
#  'linc03042',
#  'linc01605_ensg00000253161',
#  'haglr',
#  'prr7-as1',
#  'linc00698',
#  'cyp4a22-as1',
#  'linc01584',
#  'rxylt1-as1',
#  'ensg00000270605.1',
#  'znf747-dt',
#  'ensg00000241168.1',
#  'ensg00000253675.1',
#  'ensg00000254951.7',
#  'ensg00000213204.8',
#  'ensg00000230612.3',
#  'linc00954',
#  'ensg00000260948.1',
#  'ensg00000268744.1',
#  'lgalsl-dt',
#  'ensg00000265204.1',
#  'ensg00000262714.1',
#  'ensg00000272667.1',
#  'map3k4-as1',
#  'terlr1',
#  'znf337-as1',
#  'ensg00000259250.1',
#  'ensg00000255038.1',
#  'dph6-dt',
#  'ensg00000271755.1',
#  'linc02901',
#  'ensg00000204584.1',
#  'patj-dt',
#  'ensg00000248515.2',
#  'clxn',
#  'ensg00000251555.1',
#  'linc02175',
#  'madcam1-as1',
#  'ensg00000272482.2',
#  'kcnip2-as1',
#  'linc00324',
#  'linc00513',
#  'linc01416',
#  'bnc2-as1',
#  'linc01102',
#  'slc41a3-as1',
#  'linc02165',
#  'ensg00000257746.2',
#  'ensg00000255467.1',
#  'linc00922',
#  'linc01166',
#  'ensg00000260269.5',
#  'rassf10-dt',
#  'agap1-it1',
#  'ensg00000259363.6',
#  'ensg00000259995.1',
#  'ensg00000257407.1',
#  'diaph2-as1',
#  'ensg00000214559.3',
#  'ociad1-as1',
#  'ensg00000258466.5',
#  'tenm3-as1',
#  'ensg00000263280.4',
#  'ensg00000267249.1',
#  'ensg00000258084.6',
#  'ensg00000260371.1',
#  'ensg00000244151.1',
#  'rabgef1p1',
#  'linc01679',
#  'linc00645',
#  'linc01322',
#  'apcdd1l-dt',
#  'ensg00000230333.6',
#  'ensg00000255306.1',
#  'ensg00000272508.1',
#  'linc01117',
#  'ensg00000250945.1',
#  'znf497-as1',
#  'ensg00000271763.1',
#  'linc01606',
#  'pdk1-as1',
#  'ensg00000272896.1',
#  'prr34',
#  'ilrun-as1',
#  'ensg00000260510.1',
#  'ensg00000259627.1',
#  'idh2-dt',
#  'linc01909',
#  'rbms3-as2',
#  'ensg00000227240.2',
#  'ensg00000239791.2',
#  'linc02542',
#  'linc02223',
#  'ensg00000272647.3',
#  'ensg00000267509.5',
#  'raet1e-as1_ensg00000268592',
#  'a2m-as1',
#  'ensg00000260296.1',
#  'linc02925',
#  'cdc42ep3-as1',
#  'linc02728',
#  'aqp4-as1',
#  'rn7sl230p',
#  'nova1-dt',
#  'ensg00000258666.1',
#  'nr2f1-as1',
#  'ensg00000231683.6',
#  'ensg00000271746.1',
#  'arnt2-dt',
#  'bhlhe40-as1',
#  'linc01428',
#  'znf407-as1',
#  'dync1li2-dt',
#  'ensg00000227678.8',
#  'ensg00000254973.2',
#  'map7-as1',
#  'ankrd42-dt',
#  'eif2b5-dt',
#  'ensg00000272054.1',
#  'ensg00000241520.1',
#  'rb1-dt',
#  'linc01091',
#  'linc02369',
#  'znrf3-it1',
#  'zranb2-as1',
#  'glcci1-dt',
#  'milip',
#  'znf503-as2',
#  'ensg00000233290.4',
#  'linc00879',
#  'edrf1-dt',
#  'fam200c',
#  'linc02937',
#  'mef2c-as1',
#  'ensg00000260306.1',
#  'ensg00000239498.1',
#  'znf236-dt',
#  'linc00892',
#  'dgcr11',
#  'linc02994',
#  'ensg00000229261.1',
#  'ensg00000266538.1',
#  'ensg00000261669.1',
#  'ensg00000269711.1',
#  'ensg00000260361.1',
#  'ensg00000236501.6',
#  'fam83c-as1',
#  'ensg00000269971.1',
#  'linc02853',
#  'ensg00000229727.7',
#  'linc02067',
#  'ensg00000267070.1',
#  'ensg00000269604.1',
#  'linc00944',
#  'hnrnpd-dt',
#  'zbtb47-as1',
#  'ensg00000267260.4',
#  'linc02848',
#  'usp46-dt',
#  'ercc6l2-as1',
#  'ensg00000267109.1',
#  'hhla3',
#  'linc01558',
#  'ensg00000259684.1',
#  'ensg00000266667.1',
#  'ensg00000256325.1',
#  'vash1-as1',
#  'dap-dt',
#  'ensg00000253730.1',
#  'ensg00000226471.7',
#  'lrrc8c-dt',
#  'linc01524',
#  'linc02154',
#  'ensg00000260996.1',
#  'ensg00000244055.2',
#  'linc00862',
#  'linc01829',
#  'ensg00000229855.9',
#  'linc01719',
#  'myo1b-as1',
#  'linc02642',
#  'znf529-as1',
#  'ensg00000263731.1',
#  'idi2-as1',
#  'linc00393',
#  'linc03056',
#  'ints6-as1',
#  'ensg00000227479.1',
#  'ensg00000228113.7',
#  'ensg00000247934.4',
#  'ensg00000272754.1',
#  'ensg00000270933.2',
#  'ensg00000258902.2',
#  'ensg00000248176.2',
#  'ensg00000267627.5',
#  'ensg00000259437.1',
#  'gtf2ip20',
#  'cryzl2p-sec16b',
#  'ensg00000268015.1',
#  'ensg00000223969.7',
#  'st3gal1-dt',
#  'rab33b-as1',
#  'ewsat1',
#  'ubox5-as1',
#  'ensg00000226571.2',
#  'ensg00000253553.9',
#  'mecom-as1',
#  'ensg00000237461.3',
#  'linc01982',
#  'galnt7-dt',
#  'zbtb11-as1',
#  'ensg00000269886.1',
#  'ceacam16-as1',
#  'matr3_ensg00000015479',
#  'ensg00000272510.1',
#  'linc01169',
#  'kctd21-as1',
#  'ensg00000260170.1',
#  'adamts9-as2',
#  'mir200chg',
#  'clecl1p',
#  'znrd2-dt',
#  'brwd1-as1',
#  'adam7-as1',
#  'linc02084',
#  'linc01936',
#  'linc02284',
#  'ensg00000187951.11',
#  'ensg00000234597.2',
#  'ensg00000273141.1',
#  'lhfpl7',
#  'esam-as1',
#  'pla2g4e-as1',
#  'linc02596',
#  'ensg00000250781.2',
#  'sox2-ot',
#  'psma3-as1',
#  'ensg00000259283.2',
#  'linc02980',
#  'ensg00000213994.3',
#  'tarid',
#  'ensg00000260751.2',
#  'id2-as1',
#  'ensg00000273088.2',
#  'linc02273',
#  'rufy1-as1',
#  'ensg00000265401.1',
#  'ensg00000258272.1',
#  'ythdf3-dt',
#  'ensg00000258891.1',
#  'spata41',
#  'dio3os',
#  'cpne8-as1',
#  'serpinb9p1',
#  'ensg00000206567.10',
#  'linc02306',
#  'dmtf1-as1',
#  'ensg00000260279.4',
#  'ensg00000254024.1',
#  'ensg00000272297.2',
#  'ensg00000261338.2',
#  'adissp',
#  'ensg00000259076.1',
#  'ensg00000267058.1',
#  'linc01354',
#  'ate1osp',
#  'ensg00000230532.1',
#  'ensg00000269172.1',
#  'ensg00000270076.1',
#  'akap13-as1',
#  'mir3648-2',
#  'ensg00000268027.5',
#  'ensg00000240710.1',
#  'or2a1-as1',
#  'itga9-as1',
#  'lncrna-iur',
#  'ensg00000233760.3',
#  'ensg00000271717.1',
#  'ensg00000260658.7',
#  'ripk2-dt',
#  'hcg25',
#  'ensg00000259126.1',
#  'msra-dt',
#  'ensg00000232377.1',
#  'ensg00000225676.2',
#  'ensg00000268573.1',
#  'ensg00000273080.2',
#  'ensg00000259713.1',
#  'ensg00000272512.1',
#  'ensg00000227227.1',
#  'ensg00000273064.1',
#  'fam66a',
#  'wfdc21p',
#  'ensg00000251314.2',
#  'cop1-dt',
#  'fam153cp',
#  'ensg00000241409.1',
#  'ensg00000272335.1',
#  'linc00899',
#  'ensg00000273139.2',
#  'ensg00000253636.1',
#  'linc02384',
#  'linc00992',
#  'ensg00000242009.2',
#  'ensg00000267698.2',
#  'ppp1cb-dt',
#  'ensg00000245008.4',
#  'pitrm1-as1',
#  'linc02742',
#  'ensg00000273188.1',
#  'ensg00000261136.1',
#  'ensg00000269986.1',
#  'rnu6-817p',
#  'hpn-as1',
#  'ensg00000268533.1',
#  'ensg00000265254.1',
#  'ensg00000253988.1',
#  'ensg00000251170.6',
#  'ensg00000262920.5',
#  'far1-it1',
#  'fhip1a',
#  'ensg00000223716.2',
#  'ensg00000280351.2',
#  'tdrkh-as1',
#  'arhgap26-as1',
#  'ensg00000258378.1',
#  'linc00461',
#  'dtx2p1-upk3bp1-pms2p11',
#  'linc00857',
#  'klc4-as1',
#  'linc01702',
#  'plcg1-as1',
#  'ash1l-as1',
#  'epic1',
#  'linc01426',
#  'asmtl_ensg00000169093',
#  'rigi',
#  'ensg00000273258.1',
#  'linc00972',
#  'pals1',
#  'linc02112',
#  'ensg00000261845.2',
#  'ensg00000259049.1',
#  'linc03064',
#  'ensg00000268945.1',
#  'linc01503',
#  'rnf157-as1',
#  'ensg00000251537.4',
#  'ensg00000265055.2',
#  'lama4-as1',
#  'linc02550',
#  'linc01376',
#  'ensg00000197813.6',
#  'ptpn23-dt',
#  'linc01948',
#  'ensg00000225610.1',
#  'anxa2r-ot1',
#  'ino80d-as1',
#  'ensg00000233393.2',
#  'dant2',
#  'ensg00000265359.1',
#  'ensg00000273275.1',
#  'linc01533',
#  'ensg00000240963.1',
#  'ensg00000240240.10',
#  'eif2ak3-dt',
#  'ensg00000255422.4',
#  'ensg00000275431.1',
#  'ensg00000215014.5',
#  'lamtor5-as1',
#  'rpl34-dt',
#  'linc03072',
#  'ensg00000223542.1',
#  'ensg00000236154.3',
#  'adgrl3-as1',
#  'ensg00000226640.2',
#  'ensg00000261889.1',
#  'dirc3-as1',
#  'ensg00000268204.1',
#  'leng8-as1',
#  'linc01876',
#  'pantr1',
#  'gcc2-as1',
#  'linc02492',
#  'bbln',
#  'ensg00000258757.1',
#  'pou6f2-as1',
#  'ensg00000203279.6',
#  'tars1-dt',
#  'ensg00000260796.1',
#  'ensg00000262412.1',
#  'ensg00000251417.2',
#  'ensg00000239415.1',
#  'ensg00000267564.1',
#  'nqo1-dt',
#  'ensg00000272149.1',
#  'loxl1-as1',
#  'ensg00000224675.1',
#  'ensg00000223774.5',
#  'ensg00000232063.2',
#  'mapkapk5-as1',
#  'ensg00000236206.2',
#  'ensg00000273381.1',
#  'linc02916',
#  'ace2-dt',
#  'ppp1r3b-dt',
#  'linc01011',
#  'afdn-dt',
#  'fam85b',
#  'magi1-as1',
#  'efcab10-as1',
#  'ensg00000231496.2',
#  'ensg00000272465.1',
#  'ensg00000273449.1',
#  'ensg00000228033.6',
#  'ensg00000250025.2',
#  'linc02893',
#  'pard6g-as1',
#  'linc01919',
#  'ensg00000253666.4',
#  'ensg00000124835.2',
#  'ensg00000267801.1',
#  'mad2l1-dt',
#  'ensg00000259376.1',
#  'ensg00000257524.6',
#  'ensg00000145075.13',
#  'linc01983',
#  'ensg00000264421.1',
#  'rnu4-62p',
#  'cfap210',
#  'myh9-dt',
#  'ensg00000249236.2',
#  'linc01435',
#  'lmf1-as1',
#  'trgc2',
#  'linc00301',
#  'ensg00000258744.3',
#  'ensg00000230387.5',
#  'znf582-dt',
#  'spcs3-as1',
#  'mir3671',
#  'ensg00000228222.1',
#  'ensg00000263923.1',
#  'dym-as1',
#  'ensg00000227355.5',
#  'idh1-as1',
#  'rhpn1-as1',
#  'atosb',
#  'celf2-as2',
#  'rere-as1',
#  'ensg00000225313.5',
#  'prkacb-dt',
#  'ensg00000272735.2',
#  'ensg00000251257.3',
#  'ensg00000230534.6',
#  'kcnq1-as1',
#  'ensg00000258677.2',
#  'ensg00000225233.2',
#  'ensg00000260257.2',
#  'dlx6-as1',
#  'ensg00000239462.2',
#  'linc02021',
#  'ensg00000204971.3',
#  'ensg00000259605.3',
#  'ensg00000264324.1',
#  'ensg00000261760.9',
#  'ensg00000259754.2',
#  'ensg00000230975.1',
#  'girgl',
#  'ensg00000272588.1',
#  'ensg00000271009.3',
#  'ensg00000236924.3',
#  'smc5-dt',
#  'ensg00000269976.1',
#  'ensg00000243155.1',
#  'ensg00000259976.3',
#  'afap1-as1',
#  'ensg00000266313.2',
#  'ensg00000259522.3',
#  'ensg00000258302.2',
#  'tprxl',
#  'ensg00000224216.1',
#  'lyrm4-as1',
#  'rn7sl329p',
#  'ensg00000260111.1',
#  'ensg00000228944.1',
#  'akt3-it1',
#  'filnc1',
#  'rtca-as1',
#  'ensg00000258168.6',
#  'smim11',
#  'asic4-as1',
#  'ensg00000131152.4',
#  'tmem30a-dt',
#  'g2e3-as1',
#  'ensg00000254303.1',
#  'ensg00000250999.2',
#  'linc02389',
#  'linc01411',
#  'fignl2-dt',
#  'ensg00000227885.4',
#  'ensg00000264635.1',
#  'ensg00000272420.1',
#  'hcg21',
#  'ensg00000277589.1',
#  'ensg00000259827.1',
#  'pierce1',
#  'ensg00000257378.1',
#  'arrdc1-as1',
#  'ensg00000261596.2',
#  'ensg00000241962.9',
#  'linc02512',
#  'ensg00000249684.6',
#  'rn7sl449p',
#  'ensg00000242282.6',
#  'fam13a-as1',
#  'znf652-as1',
#  'ensg00000235495.1',
#  'linc02332',
#  'mir302chg',
#  'ensg00000259244.1',
#  'ensg00000264112.1',
#  'linc02803',
#  'ensg00000231119.2',
#  'dnmt3l-as1',
#  'lhfpl3-as1',
#  'ensg00000261242.1',
#  'ensg00000269179.1',
#  'pcbp1-as1',
#  'abhd15-as1',
#  'spacdr',
#  'linc00900',
#  'zftraf1',
#  'ensg00000273243.1',
#  'prkar1b-as2',
#  'rrs1-dt',
#  'ensg00000267114.1',
#  'prkg2-as1',
#  'ensg00000259327.1',
#  'ensg00000235939.1',
#  'ctdp1-dt',
#  'zfhx2-as1',
#  'ensg00000255054.3',
#  'ensg00000176320.2',
#  'mrps30-dt',
#  'ensg00000259659.1',
#  'cyp4f33p',
#  'ensg00000258881.6',
#  'ensg00000268458.1',
#  'prss42p',
#  'ensg00000268112.1',
#  'ensg00000206549.13',
#  'ep300-as1',
#  'tox-dt',
#  'ensg00000249806.1',
#  'ensg00000231104.8',
#  'cfap68',
#  'ensg00000268163.1',
#  'cbarp-dt',
#  'ensg00000270165.1',
#  'f3_ensg00000117525',
#  'linc02296',
#  'ensg00000258162.4',
#  'grhl3-as1',
#  'linc02256_ensg00000261064',
#  'lbx2-as1',
#  'linc00847',
#  'eps15-as1',
#  'mios-dt',
#  'ensg00000229308.1',
#  'ensg00000236356.1',
#  'linc02714',
#  'linc01480',
#  'ptov1-as1',
#  'mir4733hg',
#  'rnu4-2',
#  'ensg00000270894.1',
#  'ensg00000257178.5',
#  'fam157c',
#  'ensg00000272347.1',
#  'ensg00000260196.1',
#  'ensg00000259504.2',
#  'linc02986',
#  'ccdc144nl_ensg00000205212',
#  'ensg00000265334.1',
#  'linc02613',
#  'linc01844',
#  ...}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 3971
# 仅在 all_genes 中存在的基因: {'foxd4l6', 'tmem275', 'rfx6', 'ceacam8', 'cxorf65', 'plscr5', 'or51e2', 'zbed2', 'h2ac16', 'tas2r8', 'tmem239', 'rpel1', 'tas2r20', 'or4k13', 'mafa', 'shox2', 'golga8n', 'or5h14', 'prag1', 'dmrtc2', 'nxpe2', 'ct83', 'spdye5', 'cdy1b', 'poted', 'bpifb2', 'tiaf1', 'nyap1', 'tchh', 'nt5c1a', 'ct55', 'c17orf50', 'cgb5', 'linc02210-crhr1', 'or5d16', 'trim75p', 'dipk1c', 'h3c10', 'or2i1p', 'cbsl', 'znf560', 'myocos', 'rnase13', 'cdh19', 'prr18', 'usp29', 'or4c16', 'tgfbr3l', 'spanxd', 'dnajc25-gng10', 'rnase2', 'ftmt', 'usp17l26', 'taz', 'defb103b', 'or5ar1', 'ppp4r3c', 'gage12j', 'cnmd', 'psma1', 'spata31a1', 'tex13a', 'foxh1', 'cby2', 'akr1b10', 'or4a15', 'kbtbd4', 'or56a1', 'klrc4', 'cd8b2', 'phox2b', 'cylc1', 'krt26', 'ace', 'fam90a18p', 'h2aw', 'btnl3', 'h4c2', 'csf2ra', 'cfhr5', 'catsperz', 'h1-6', 'ctage6', 'gpr179', 'or2t1', 'klhl34', 'higd2b', 'defb136', 'foxl2nb', 'accsl', 'or5d13', 'or5ap2', 'igfals', 'magec1', 'tectb', 'c22orf15', 'h3c8', 'or6n2', 'gpr78', 'atoh1', 'or5c1', 'nlrp10', 'trim51', 'rhex', 'qrfp', 'or2t35', 'ankrd34a', 'lce2a', 'trim63', 'wfdc5', 'or5h6', 'actl10', 'gmcl2', 'defb123', 'rpe65', 'rgpd5', 'h2ac11', 'krt38', 'hcar3', 'tfap2d', 'slc34a1', 'cntn2', 'ccl25', 'brs3', 'rbp3', 'guca1a', 'gpr26', 'dazl', 'pi4k2a', 'elspbp1', 'lgals16', 'ssu72p3', 'alpi', 'arg1', 'pramef9', 'pydc2', 'ssx5', 'zan', 'lefty2', 'lce2d', 'or51l1', 'otog', 'tmem151b', 'f11r', 'h3-4', 'tlr8', 'trim51gp', 'tcn1', 'ct47a4', 'lce1f', 'fam102b', 'barhl1', 'uqcr11', 'ccl1', 'hdgfl1', 'nkpd1', 'ct47a2', 'tas2r7', 'tmed7-ticam2', 'kcns2', 'edn3', 'adgrg7', 'awat2', 'gfra4', 'polr2j2', 'trpc5os', 'h3y1', 'krtap21-2', 'or52n2', 'ocstamp', 'krt14', 'amelx', 'pom121l12', 'cdrt15', 'or2m2', 'gpr151', 'c8orf74', 'agtr2', 'ggtlc1', 'znf280a', 'f9', 'nutm2f', 'vcx', 'ccdc168', 'c3', 'ntf4', 'hnrnpa1p48', 'ccdc188', 'magea10', 'opn1sw', 'gpr31', 'pate4', 'or2g2', 'tbx22', 'taf11l9', 'or4c46', 'adora2a', 'or5m1', 'ticrr', 'fam236c', 'cpa2', 'pcdhga1', 'ppp1r3a', 'or10ad1', 'cenps-cort', 'prr33', 'rnasek-c17orf49', 'gpr45', 'ccl15', 'mrgprx1', 'or5f1', 'th', 'or52b4', 'krt24', 'etdc', 'lims3', 'mrap', 'hes7', 'fam189b', 'hhla2', 'zscan5c', 'taf11l4', 'or10h4', 'nr5a1', 'nlrp9', 'fam166b', 'or10k1', 'scgb1a1', 'rag2', 'lhx1', 'ascl4', 'mettl11b', 'or8j3', 'cyp11b1', 'mageb4', 'sp7', 'flg', 'c1orf232', 'iqcj-schip1', 'mmp10', 'nlrp5', 'prr27', 'smim2', 'il24', 'otud7b', 'krtap7-1', 'fam72c', 'gtf2i', 'rfpl4b', 'npas4', 'rgpd6', 'or51d1', 'il27', 'nutm1', 'gbx2', 'ankrd20a1', 'ifnl1', 'b3gnt6', 'usp17l10', 'il21', 'or2h1', 'zar1l', 'rax', 'cyp7a1', 'fam71b', 'tekt4', 'ube2l5', 'krtap12-3', 'tmem215', 'usp17l1', 'gpihbp1', 'fam90a8p', 'duxa', 'hsd3b1', 'clec4m', 'prm3', 'krtap4-5', 'ccl3l1', 'h4-16', 'spatc1l', 'mc3r', 'astl', 'kcna7', 'asb12', 'or10a5', 'fancd2os', 'cxcr5', 'reg1b', 'sbk3', 'apoc3', 'lacrt', 'krt85', 'gjb5', 'or52k2', 'or4s1', 'acaca', 'fndc7', 'slc22a7', 'lgi1', 'c11orf97', 'or1a2', 'fam237b', 'tmem31', 'krtap29-1', 'kcnt1', 'grp', 'plk5', 'muc17', 'krtap20-1', 'apcs', 'tmem269', 'cldn22', 'nr0b1', 'chia', 'or5k3', 'mcidas', 'nhlh2', 'or8h1', 'krtap26-1', 'septin14', 'or14a16', 'tspyl6', 'gp5', 'dcd', 'clec2l', 'plcz1', 'ppan-p2ry11', 'magel2', 'golga8g', 'f3', 'rgs8', 'c1qtnf9b', 'asb11', 'prr23c', 'or8b8', 'asic4', 'mb', 'atp1b4', 'c16orf71', 'or6f1', 'serpinb13', 'cryaa', 'rtel1', 'daw1', 'znf705g', 'spdye9', 'or5d3p', 'ubqln3', 'serpinb3', 'tmed6', 'krtap2-2', 'samd7', 'ankrd63', 'defb110', 'cyfip1', 'h2ac14', 'rps27ap5', 'smim43', 'pla2g2e', 'tubgcp5', 'cphxl', 'rnase3', 'or2a5', 'or10r2', 'cyp26c1', 'trpm5', 'c11orf86', 'kir2dl3', 'st20-mthfs', 'fam236a', 'ahsp', 'tpsg1', 'h3c2', 'or10a6', 'anxa8', 'mageb17', 'spty2d1os', 'tff1', 'pglyrp1', 'pld5p1', 'pramef15', 'sp9', 'potej', 'slc16a8', 'egr4', 'krt33a', 'spaca1', 'tmem225', 'fndc8', 'or2w1', 'tex44', 'cxorf49b', 'ankrd33', 'or4c5', 'plppr4', 'prr20a', 'oosp4a', 'h2bc18', 'chrm1', 'cabp5', 'magea6', 'or4c15', 'soga3', 'ltc4s', 'c16orf70', 'fabp9', 'my ...
# 仅在 adata_genes 中存在的基因数量: 4939
# 仅在 adata_genes 中存在的基因: {'ensg00000227681.5', 'tesc-as1', 'nepro-as1', 'syt15-as1', 'dhrsx_ensg00000169084', 'gata3-as1', 'tns2-as1', 'ensg00000257286.1', 'ensg00000228150.1', 'pvt1', 'ensg00000272221.1', 'hdac4-as1', 'ensg00000261386.2', 'tprg1-as1', 'ensg00000227388.3', 'linc02018', 'ensg00000270956.1', 'gata2-as1', 'ensg00000224738.2', 'nup107-dt', 'ensg00000263257.3', 'ensg00000224356.5', 'ensg00000271978.2', 'ensg00000269621.1', 'rnu6-1327p', 'fhad1-as1', 'ccr5as', 'ensg00000241345.1', 'linc02398', 'ensg00000268083.5', 'ensg00000224985.1', 'ensg00000248101.2', 'ensg00000266397.1', 'dennd6a-as1', 'ensg00000243004.7', 'ensg00000248491.6', 'ensg00000259891.1', 'linc-pint', 'ensg00000238280.2', 'catip-as1', 'xpc-as1', 'rsl1d1-dt', 'ensg00000243389.1', 'ensg00000265393.1', 'linc02778', 'adam20p1_ensg00000259158', 'ensg00000260661.1', 'ensg00000270871.1', 'atxn7l3-as1', 'ensg00000273456.2', 'namptp1', 'dlgap1-as3', 'cbr3-as1', 'ensg00000260710.3', 'slc16a4-as1', 'c7_ensg00000112936', 'hsd11b1-as1', 'jazf1-as1', 'prkx-as1', 'ensg00000259353.1', 'atp2b1-as1', 'linc02268', 'ensg00000269535.1', 'linc02019', 'linc02343', 'ccdc26', 'linc02147', 'dpy19l3-dt', 'ensg00000260914.3', 'ensg00000259359.2', 'adamts9-as1', 'ensg00000229151.3', 'suclg2-dt', 'ensg00000267827.5', 'gna15-dt', 'ensg00000251652.1', 'rnu2-68p', 'ensg00000227598.1', 'hexa-as1', 'ensg00000258365.1', 'ankrd17-dt', 'ier3-as1', 'slc14a2-as1', 'rbm26-as1', 'ensg00000270147.1', 'ensg00000253693.1', 'pgm5-as1', 'ensg00000258603.5', 'ensg00000272341.1', 'ensg00000232110.9', 'dleu1', 'ensg00000224746.2', 'ensg00000260392.6', 'ensg00000270638.1', 'ensg00000227075.1', 'wapl-dt', 'stim1-as1', 'ensg00000260647.1', 'linc01547', 'ensg00000259704.3', 'ensg00000255462.1', 'ensg00000265749.6', 'pus1-as1', 'ensg00000270240.2', 'ensg00000228648.1', 'ensg00000260017.1', 'linc01765', 'ensg00000273209.1', 'linc01535', 'ensg00000259644.1', 'st7-ot4', 'ensg00000267504.1', 'ensg00000235271.6', 'ensg00000222017.1', 'ensg00000260342.2', 'ensg00000238282.1', 'ensg00000229227.8', 'cd109-as1', 'linc01410', 'ensg00000248656.3', 'ptprn2-as1', 'ensg00000272969.1', 'snord13', 'tm9sf5p', 'crim1-dt', 'c1qtnf7-as1', 'ensg00000263917.1', 'ensg00000243081.2', 'ensg00000231970.1', 'mrgprf-as1', 'smad9-it1', 'piwil4-as1', 'traf3ip2-as1', 'ensg00000267193.7', 'ensg00000247903.1', 'ensg00000253238.3', 'linc00671', 'zdhhc12-dt', 'vash1-dt', 'csrp3-as1', 'ensg00000257767.3', 'linc00635', 'ensg00000223786.1', 'ensg00000269680.1', 'ensg00000262681.2', 'ensg00000225721.5', 'patl1-dt', 'tle1-dt', 'ensg00000253627.1', 'ensg00000267748.4', 'znf667-as1', 'ensg00000261101.2', 'linc02926', 'ank3-dt', 'linc02346', 'c5orf64', 'ensg00000267780.2', 'dusp5-dt', 'linc00907', 'ensg00000259985.1', 'fam169a-as1', 'ensg00000226149.6', 'ensg00000266953.6', 'ensg00000257894.2', 'ensg00000265542.5', 'ensg00000272953.2', 'ensg00000223838.2', 'ensg00000269481.1', 'ensg00000272692.2', 'ensg00000272871.1', 'nherf1', 'linc02202', 'ensg00000259138.1', 'linc02028', 'linc01994', 'ensg00000234185.2', 'ensg00000251615.3', 'coq7-dt', 'ensg00000228061.7', 'linc01882', 'mt-tr', 'nudt19-dt', 'abca15p', 'atp1a1-as1', 'linc00887', 'ensg00000234405.2', 'hsd17b2-as1', 'ensg00000259366.3', 'ensg00000260917.1', 'clrn1-as1', 'ensg00000273328.5', 'ap4b1-as1', 'ensg00000215304.3', 'ensg00000225718.2', 'ensg00000273118.1', 'ensg00000273026.1', 'ensg00000267175.5', 'cops8-dt', 'epb41l4a-as1', 'ensg00000272156.1', 'frg1-dt', 'ensg00000262769.1', 'ensg00000271754.1', 'tirap-as1', 'linc01436', 'ensg00000256571.1', 'ensg00000265967.1', 'ensg00000271993.1', 'ensg00000269246.2', 'ensg00000269292.1', 'gask1b-as1', 'ensg00000254035.1', 'grm7-as3', 'ensg00000271780.2', 'tex56p', 'linc02696', 'ensg00000233967.7', 'linc02277', 'cenpn-as1', 'ensg00000228107.1', 'ensg00000225339.4', 'cep250-as1', 'ensg00000272768.1', 'ensg00000269237.1', 'linc01980', 'ppp4r1-as1', 'jdp2-as1', 'paqr5-dt', 'hoxb-as3', 'dlgap1-as1', 'linc01951', 'ensg00000259675.4', 'ensg00000234626.2', 'ens ...

# %%
import numpy as np
from scipy.sparse import csr_matrix

# Initialize a mapping from gene names in adata to their column indices
adata_gene_to_index = {gene: idx for idx, gene in enumerate(adata_genes_lower)}

# Create an array to map adata.X column indices to new_data column indices
adata_to_new_data_indices = -1 * np.ones(adata.X.shape[1], dtype=int)
for idx, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        adata_to_new_data_indices[idx] = gene_to_index[gene]



# Extract data from adata.X without converting it to a dense array
data = adata.X.data
indices = adata.X.indices
indptr = adata.X.indptr

# Map the column indices to the new indices in new_data
mapped_indices = adata_to_new_data_indices[indices]

# Filter out entries where the mapping is invalid (-1)
valid_entries = mapped_indices != -1
new_data_values = data[valid_entries]
new_data_indices = mapped_indices[valid_entries]

# Build the new indptr array for the new_data matrix
new_indptr = np.zeros(adata.X.shape[0] + 1, dtype=int)


for i in range(adata.X.shape[0]):
    row_start = indptr[i]
    row_end = indptr[i + 1]
    valid_count = np.sum(valid_entries[row_start:row_end])
    new_indptr[i + 1] = new_indptr[i] + valid_count


# Construct the new_data sparse matrix
new_data = csr_matrix(
    (new_data_values, new_data_indices, new_indptr),
    shape=(adata.X.shape[0], len(all_genes)),
    dtype=np.float32
)
new_data = new_data.toarray()

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
estim.model.to(device)
estim.model.eval()
with torch.no_grad():
    X_train_tensor = torch.tensor(X_train).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    train_embeddings = estim.model.inner_model(X_train_tensor).detach().cpu().numpy()
    test_embeddings = estim.model.inner_model(X_test_tensor).detach().cpu().numpy()
# Out:
# cuda

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.595791270783848
# Weighted F1 Score: 0.5636010112940153
# Macro F1 Score: 0.27089193307730425
# Random Guess Accuracy: 0.2927884776016484
#                                                            precision    recall  f1-score   support
#
#                           blood vessel smooth muscle cell       0.26      0.14      0.19       852
#                                          endothelial cell       0.64      0.83      0.72     13511
#                  kidney collecting duct intercalated cell       0.23      0.16      0.19      1032
#                     kidney collecting duct principal cell       0.51      0.53      0.52      2040
#           kidney distal convoluted tubule epithelial cell       0.37      0.22      0.28       618
#                                      kidney granular cell       0.00      0.00      0.00       105
#                            kidney interstitial fibroblast       0.30      0.06      0.10       781
# kidney loop of Henle thick ascending limb epithelial cell       0.57      0.50      0.53      1410
#         kidney proximal convoluted tubule epithelial cell       0.61      0.52      0.56      4160
#                                                 leukocyte       0.50      0.21      0.30      1905
#                                                macrophage       0.31      0.06      0.10       295
#                              macula densa epithelial cell       0.00      0.00      0.00        10
#                                            mesangial cell       0.00      0.00      0.00        11
#                                                  podocyte       0.56      0.21      0.30       214
#
#                                                  accuracy                           0.60     26944
#                                                 macro avg       0.35      0.25      0.27     26944
#                                              weighted avg       0.56      0.60      0.56     26944
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
with torch.no_grad():
    new_data_tensor = torch.tensor(new_data).float().to(device)
    SSL_embeddings = estim.model.inner_model(new_data_tensor).detach().cpu().numpy()
new_adata = sc.read_h5ad(data_dir)
new_adata.obsm[f'SSL_BT_ZS_{random_seed}'] = SSL_embeddings
new_adata.uns[f'BT_ZS_y_test_{random_seed}'] = y_test
new_adata.uns[f'BT_ZS_predictions_{random_seed}'] = predictions
new_adata.uns[f'BT_ZS_target_names_{random_seed}'] = label_encoder.classes_
new_adata.write_h5ad(data_dir)

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "slide_seq_human_kidney_barlow_twins_zero_shot_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicor_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicor_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['slide_seq_human_kidney'],
    'method': [re.search(r'kidney_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micor_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# macro_f1	weighted_f1	micor_f1
# 0.271	0.564	0.596
