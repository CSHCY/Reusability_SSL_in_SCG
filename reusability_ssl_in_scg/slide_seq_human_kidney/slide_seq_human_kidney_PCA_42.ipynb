# %%
import scanpy as sc
data_dir = '../../dataset/Marshall2022High_human_sampled.h5ad'
adata = sc.read_h5ad(data_dir)
adata.X = adata.raw.X

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
adata.var['gene_id'] = adata.var.index
adata.var.index = adata.var['gene_name']

# 输出 adata.var
adata.var
# Out:
#                           feature_reference feature_biotype  \
# gene_name
# A1BG                         NCBITaxon:9606            gene
# A1BG-AS1                     NCBITaxon:9606            gene
# A1CF                         NCBITaxon:9606            gene
# A2M                          NCBITaxon:9606            gene
# A2M-AS1                      NCBITaxon:9606            gene
# ...                                     ...             ...
# ZZZ3                         NCBITaxon:9606            gene
# MISP3                        NCBITaxon:9606            gene
# ENSG00000234352.9            NCBITaxon:9606            gene
# ARHGAP27P1-BPTFP1-KPNA2P3    NCBITaxon:9606            gene
# SBNO1-AS1                    NCBITaxon:9606            gene
#
#                            feature_is_filtered-0             feature_name-0  \
# gene_name
# A1BG                                        True                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-0  feature_type-0  \
# gene_name
# A1BG                                  2134  protein_coding
# A1BG-AS1                              1667          lncRNA
# A1CF                                  2211  protein_coding
# A2M                                    590  protein_coding
# A2M-AS1                               2551          lncRNA
# ...                                    ...             ...
# ZZZ3                                   686  protein_coding
# MISP3                                 1473  protein_coding
# ENSG00000234352.9                      728          lncRNA
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA
# SBNO1-AS1                              625          lncRNA
#
#                            feature_is_filtered-1             feature_name-1  \
# gene_name
# A1BG                                       False                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-1  feature_type-1  ...  \
# gene_name                                                   ...
# A1BG                                  2134  protein_coding  ...
# A1BG-AS1                              1667          lncRNA  ...
# A1CF                                  2211  protein_coding  ...
# A2M                                    590  protein_coding  ...
# A2M-AS1                               2551          lncRNA  ...
# ...                                    ...             ...  ...
# ZZZ3                                   686  protein_coding  ...
# MISP3                                 1473  protein_coding  ...
# ENSG00000234352.9                      728          lncRNA  ...
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA  ...
# SBNO1-AS1                              625          lncRNA  ...
#
#                            feature_is_filtered-6             feature_name-6  \
# gene_name
# A1BG                                        True                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-6  feature_type-6  \
# gene_name
# A1BG                                  2134  protein_coding
# A1BG-AS1                              1667          lncRNA
# A1CF                                  2211  protein_coding
# A2M                                    590  protein_coding
# A2M-AS1                               2551          lncRNA
# ...                                    ...             ...
# ZZZ3                                   686  protein_coding
# MISP3                                 1473  protein_coding
# ENSG00000234352.9                      728          lncRNA
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA
# SBNO1-AS1                              625          lncRNA
#
#                            feature_is_filtered-7             feature_name-7  \
# gene_name
# A1BG                                        True                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-7  feature_type-7  \
# gene_name
# A1BG                                  2134  protein_coding
# A1BG-AS1                              1667          lncRNA
# A1CF                                  2211  protein_coding
# A2M                                    590  protein_coding
# A2M-AS1                               2551          lncRNA
# ...                                    ...             ...
# ZZZ3                                   686  protein_coding
# MISP3                                 1473  protein_coding
# ENSG00000234352.9                      728          lncRNA
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA
# SBNO1-AS1                              625          lncRNA
#
#                                            gene_name          gene_id
# gene_name
# A1BG                                            A1BG  ENSG00000121410
# A1BG-AS1                                    A1BG-AS1  ENSG00000268895
# A1CF                                            A1CF  ENSG00000148584
# A2M                                              A2M  ENSG00000175899
# A2M-AS1                                      A2M-AS1  ENSG00000245105
# ...                                              ...              ...
# ZZZ3                                            ZZZ3  ENSG00000036549
# MISP3                                          MISP3  ENSG00000141854
# ENSG00000234352.9                  ENSG00000234352.9  ENSG00000234352
# ARHGAP27P1-BPTFP1-KPNA2P3  ARHGAP27P1-BPTFP1-KPNA2P3  ENSG00000215769
# SBNO1-AS1                                  SBNO1-AS1  ENSG00000256092
#
# [20299 rows x 36 columns]

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# gene_name
# A1BG                                              A1BG
# A1BG-AS1                                      A1BG-AS1
# A1CF                                              A1CF
# A2M                                                A2M
# A2M-AS1                                        A2M-AS1
#                                        ...
# ZZZ3                                              ZZZ3
# MISP3                                            MISP3
# ENSG00000234352.9                    ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3    ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                    SBNO1-AS1
# Name: gene_name, Length: 20299, dtype: category
# Categories (25391, object): ['7SK_ENSG00000202198', 'A1BG', 'A1BG-AS1', 'A1CF', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# gene_name
# A1BG                                              A1BG
# A1BG-AS1                                      A1BG-AS1
# A1CF                                              A1CF
# A2M                                                A2M
# A2M-AS1                                        A2M-AS1
#                                        ...
# ZZZ3                                              ZZZ3
# MISP3                                            MISP3
# ENSG00000234352.9                    ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3    ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                    SBNO1-AS1
# Name: gene_name, Length: 20299, dtype: category
# Categories (25391, object): ['7SK_ENSG00000202198', 'A1BG', 'A1BG-AS1', 'A1CF', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 15360
# 匹配的基因列表: {'pcmtd1', 'sowahb', 'trim29', 'cds1', 'znf641', 'pkia', 'reep3', 'kiaa0040', 'hes6', 'epm2aip1', 'fcgr1a', 'ap1s2', 'rabgef1', 'osbpl5', 'tspan13', 'kif5b', 'esrra', 'adap1', 'c8orf33', 'tulp4', 'napepld', 'ralgapa1', 'arl17a', 'mdh1', 'rassf6', 'smim19', 'rab40c', 'diaph1', 'sclt1', 'map2k6', 'oard1', 'ttc21a', 'gak', 'ctso', 'odam', 'vps18', 'olr1', 'st3gal5', 'rnpepl1', 'mrtfb', 'mymx', 'fbxw10', 'scnn1b', 'klf8', 'szrd1', 'plcg2', 'palld', 'shoc2', 'ctage9', 'cdca7l', 'leprotl1', 'mars1', 'ddrgk1', 'cuta', 'desi1', 'asphd1', 'pros1', 'agpat2', 'sostdc1', 'abhd17a', 'acp5', 'slc39a3', 'igsf11', 'pcdh18', 'iqsec2', 'cdkn1c', 'ccdc40', 'znf586', 'znfx1', 'ndufab1', 'rab11a', 'med12l', 'rac3', 'plagl2', 'prr29', 'irf1', 'vps8', 'ttc29', 'gulp1', 'rassf3', 'spg11', 'rufy1', 'sdad1', 'prr16', 'mt1e', 'sprtn', 'tmem131', 'hspa1a', 'sctr', 'brpf1', 'lcp1', 'creld1', 'slc25a40', 'tmem132a', 'hirip3', 'rcn1', 'st7', 'cdk15', 'lyar', 'met', 'ice1', 'cbx8', 'nbl1', 'ece2', 'bcl7b', 'tex45', 'tnfrsf12a', 'pde4d', 'trim4', 'crh', 'adal', 'pnma6a', 'pxdc1', 'dio2', 'sacm1l', 'ankrd1', 'zbtb48', 'mrfap1l1', 'ndc80', 'prr35', 'mcoln1', 'mpv17l2', 'glul', 'st8sia5', 'p2rx7', 'tpm4', 'ppp1r3c', 'abhd5', 'slc29a1', 'tprkb', 'clba1', 'phactr2', 'slc25a13', 'h3-3b', 'poln', 'pin4', 'parg', 'sit1', 'nphp1', 'smim8', 'pdgfc', 'arpin', 'sowahc', 'lpo', 'hacl1', 'cmya5', 'bzw2', 'hoxd11', 'gtf2e1', 'nudcd2', 'kdm8', 'coq8b', 'fzd2', 'marchf2', 'castor1', 'ces3', 'smim13', 'ppa1', 'tbxa2r', 'tpmt', 'utp6', 'map7d2', 'havcr1', 'rhob', 'cyp2s1', 'nlrp12', 'prelp', 'cd55', 'rgs9bp', 'idua', 'stx4', 'kcnh1', 'spcs1', 'ppp2r5d', 'epha7', 'blk', 'soga1', 'cadps', 'serpinb7', 'p2ry14', 'chrm2', 'pdlim1', 'lrrc8b', 'gapdh', 'slc41a1', 'ppm1n', 'rlim', 'ano8', 'msl2', 'ptger3', 'dact2', 'rac1', 'kdm4d', 'mctp1', 'vav2', 'snca', 'ivns1abp', 'supt4h1', 'fnbp1', 'ago2', 'colec12', 'dazap1', 'slc9c1', 'rnf186', 'ppm1b', 'fmnl2', 'stat2', 'gas1', 'gadd45gip1', 'tarbp1', 'tnpo3', 'tex33', 'clstn2', 'vtcn1', 'nt5m', 'pgap4', 'znf236', 'hoxa11', 'lrrc56', 'cfap53', 'htt', 'ube2l3', 'tbc1d10c', 'ifrd2', 'ndufb1', 'arhgap11a', 'vdac2', 'ebf2', 'ms4a7', 'rmdn3', 'ier5', 'srrm2', 'znf765', 'znf550', 'syde1', 'srrd', 'gabrb3', 'lysmd2', 'ing4', 'cux1', 'smad7', 'trim5', 'tada3', 'znf439', 'il15', 'slc2a4rg', 'usp12', 'dlg3', 'prdm8', 'gzmb', 'tbc1d12', 'josd2', 'agr3', 'sema3c', 'pcnx1', 'fam76a', 'scn2b', 'laptm4b', 'usp2', 'zfhx4', 'saa2-saa4', 'xrcc4', 'dcaf16', 'nkain1', 'nop14', 'ppp1r3g', 'msantd2', 'cdk2ap1', 'arhgef9', 'safb2', 'yif1a', 'axdnd1', 'myh10', 'pebp1', 'pprc1', 'rps2', 'nasp', 'stat6', 'htr2a', 'fxyd5', 'pnpla4', 'gle1', 'thumpd3', 'saxo2', 'tmem63a', 'znf490', 'afap1', 'npc2', 'clcn5', 'irf8', 'nqo2', 'nrsn2', 'tigit', 'slc16a13', 'bckdha', 'celsr3', 'ppp1r9b', 'sox5', 'mesp2', 'gpr149', 'atcay', 'pyhin1', 'ckmt2', 'asxl2', 'dbp', 'col28a1', 'gpr3', 'rpl28', 'hectd3', 'znf554', 'cltb', 'kdm3a', 'fkbp1a', 'lin7a', 'mapre1', 'hs1bp3', 'chrnb4', 'tnfaip8l1', 'babam1', 'spata6', 'fam229b', 'iqcn', 'gadl1', 'angptl2', 'eif2a', 'csnk2b', 'deup1', 'kdm4a', 'kcnmb4', 'kcnt2', 'edaradd', 'scarb2', 'naaladl1', 'slc2a10', 'ncstn', 'qsox1', 'sphk1', 'hmgcs1', 'ccdc157', 'cmtm8', 'kank1', 'ccdc134', 'mapk1ip1l', 'nsmce4a', 'spock1', 'zgrf1', 'arrdc5', 'foxk1', 'cpox', 'sntg1', 'sdr39u1', 'nfxl1', 'cast', 'ctdspl2', 'sec24d', 'ppp1r12a', 'tmx1', 'rnf138', 'chsy1', 'prkag1', 'ncaph', 'epb41l2', 'tank', 'mtcl1', 'ehhadh', 'zbtb2', 'sox9', 'rpusd1', 'naaa', 'abcg4', 'dnah3', 'rai1', 'rasal2', 'ccdc12', 'abcc3', 'il6st', 'renbp', 'mfap3l', 'hnrnpc', 'nr1d1', 'znf219', 'znf506', 'lpcat4', 'hps1', 'tbcd', 'tmem63b', 'gsta4', 'ube2d4', 'zbtb7b', 'fgfr2', 'rdh10', 'fnip1', 'rbm12b', 'c11orf65', 'alkbh2', 'mef2c', 'grb14', 'hmgxb4', 'atp6v1e2', 'cpa6', 'vsig10', 'gusb', 'umod', 'lysmd3', 'cfap61', 'mapk14', 'hspa12b', 'efhc2', 'matn4', 'rnf220', 'macf1', 'mcoln3', 'pip4p2', 'luzp1', 'golga3', 'akt1', 'arhgef11', 'rpl36a', 'itga4', 'adamtsl1', 'arfip1', 'sfrp4', ' ...
# {'thorlnc',
#  'ensg00000254777.5',
#  'ensg00000249593.6',
#  'linc00963',
#  'iqsec3-as1',
#  'hotair',
#  'ensg00000261766.1',
#  'ensg00000272369.1',
#  'linc00922',
#  'ensg00000265334.1',
#  'ensg00000227227.1',
#  'ensg00000263244.2',
#  'rpl37a-dt',
#  'linc01702',
#  'ensg00000244151.1',
#  'ube2h-dt',
#  'b4gat1-dt',
#  'zfx-as1',
#  '7sk_ensg00000202198',
#  'ensg00000230286.1',
#  'rnf139-dt',
#  'ensg00000264015.2',
#  'ensg00000256571.1',
#  'ensg00000238039.1',
#  'ensg00000225811.1',
#  'linc01812',
#  'ensg00000255108.1',
#  'usp3-as1',
#  'ensg00000253284.2',
#  'ensg00000229044.1',
#  'ensg00000228629.2',
#  'linc01547',
#  'ensg00000259250.1',
#  'irag1-as1',
#  'ensg00000272854.1',
#  'znf584-dt',
#  'ensg00000257060.8',
#  'pgls-dt',
#  'garin2',
#  'oser1-dt',
#  'ensg00000236469.1',
#  'ensg00000229896.2',
#  'ensg00000229642.1',
#  'pcolce-as1',
#  'misfa',
#  'linc01830',
#  'snhg17',
#  'ensg00000269887.1',
#  'ensg00000254973.2',
#  'marchf6-dt',
#  'ensg00000223390.1',
#  'linc00629',
#  'ensg00000232638.1',
#  'loxl1-as1',
#  'linc03069',
#  'linc03007',
#  'linc02328',
#  'ensg00000273328.5',
#  'linc00574',
#  'rnu4atac',
#  'mcph1-dt',
#  'ensg00000266805.1',
#  'ensg00000262410.1',
#  'cfap20dc-dt',
#  'linc00598',
#  'ensg00000257390.5',
#  'ensg00000272108.1',
#  'slc25a30-as1',
#  'eeig1',
#  'ensg00000265303.1',
#  'ensg00000265625.1',
#  'ensg00000141979.4',
#  'ensg00000259994.1',
#  'ensg00000250906.1',
#  'ensg00000272054.1',
#  'kdsr-dt',
#  'linc02550',
#  'itga2-as1',
#  'linc01588',
#  'ensg00000236528.3',
#  'linc01088',
#  'ensg00000253392.4',
#  'septin4-as1',
#  'casc17',
#  'snx10-as1',
#  'ensg00000258875.6',
#  'ensg00000249738.10',
#  'ensg00000227338.2',
#  'ensg00000271382.1',
#  'ensg00000270265.1',
#  'ensg00000257022.1',
#  'ensg00000272917.1',
#  'wfdc21p',
#  'bbox1-as1',
#  'fam200c',
#  'ensg00000269535.1',
#  'ensg00000257458.1',
#  'satb2-as1',
#  'map3k2-dt',
#  'ensg00000269802.1',
#  'fam13b-as1',
#  'dleu1',
#  'ensg00000262211.1',
#  'ensg00000253988.1',
#  'bach1-it2',
#  'ensg00000224950.2',
#  'nexn-as1',
#  'ensg00000203472.3',
#  'ensg00000231557.1',
#  'ensg00000234998.1',
#  'linc02481',
#  'ensg00000240240.10',
#  'ensg00000225963.8',
#  'ensg00000234810.4',
#  'dmxl1-dt',
#  'gabpb1-as1',
#  'sntg2-as1',
#  'tmco1-as1',
#  'fam106a',
#  'graslnd',
#  'malat1',
#  'linc02492',
#  'ensg00000273149.1',
#  'bcl2l1-as1',
#  'rnu2-68p',
#  'ensg00000236449.2',
#  'linc01331',
#  'ensg00000238273.3',
#  'ensg00000272609.1',
#  'ensg00000257955.1',
#  'prkcq-as1',
#  'ensg00000237422.3',
#  'linc02231',
#  'mir4435-2hg',
#  'ensg00000255968.1',
#  'mir210hg',
#  'ensg00000229227.8',
#  'mrps9-as2',
#  'atp5f1ep2',
#  'capn1-as1',
#  'lifr-as1',
#  'ensg00000268603.2',
#  'ensg00000248664.3',
#  'linc03057',
#  'ensg00000237498.3',
#  'ensg00000260196.1',
#  'hormad2-as1',
#  'piwil2-dt',
#  'linc02596',
#  'ensg00000273113.1',
#  'ensg00000254485.5',
#  'ensg00000255094.1',
#  'b3galt1-as1',
#  'snhg11',
#  'ensg00000267070.1',
#  'ensg00000265091.5',
#  'ensg00000224848.4',
#  'snhg10',
#  'ensg00000256443.1',
#  'alg1l9p_ensg00000248671',
#  'ensg00000224789.1',
#  'ensg00000272463.2',
#  'ensg00000273449.1',
#  'ensg00000268027.5',
#  'ensg00000259316.12',
#  'xpc-as1',
#  'ensg00000257524.6',
#  'ensg00000225806.8',
#  'draic',
#  'snrpf-dt',
#  'ensg00000272787.1',
#  'linc01933',
#  'ensg00000260686.1',
#  'aldh1a3-as1',
#  'nova1-dt',
#  'msantd2-as1',
#  'ensg00000267939.1',
#  'ensg00000259523.1',
#  'ensg00000273076.1',
#  'ensg00000269243.1',
#  'entrep2',
#  'linc01266',
#  'tprx2',
#  'ensg00000263212.2',
#  'fam153cp',
#  'ensg00000273112.1',
#  'map3k4-as1',
#  'ensg00000265100.2',
#  'ensg00000260851.7',
#  'serhl',
#  'snrpa1-dt',
#  'ensg00000262020.1',
#  'setbp1-dt',
#  'gcc2-as1',
#  'hcg17',
#  'ensg00000257759.2',
#  'hotairm1',
#  'msc-as1',
#  'cpeb1-as1',
#  'mt-tr',
#  'flj20021',
#  'ensg00000233928.7',
#  'linc02067',
#  'ensg00000259097.3',
#  'linc00885',
#  'ensg00000269711.1',
#  'ensg00000250954.6',
#  'slc12a9-as1',
#  'linc00323',
#  'ensg00000259321.1',
#  'snhg16',
#  'ensg00000254129.1',
#  'ensg00000245748.1',
#  'linc02237',
#  'chl1-as2',
#  'ensg00000225885.7',
#  'ensg00000250243.3',
#  'igf2bp2-as1',
#  'fam218a',
#  'ensg00000269463.1',
#  'piwil4-as1',
#  'mios-dt',
#  'ensg00000264187.1',
#  'linc01521',
#  'linc02088',
#  'ensg00000223598.1',
#  'ensg00000229839.6',
#  'mir142hg',
#  'ddx59-as1',
#  'ensg00000267248.5',
#  'ensg00000272156.1',
#  'tmem147-as1',
#  'papln-as1',
#  'ensg00000272541.1',
#  'linc00543',
#  'ensg00000265987.1',
#  'linc01473',
#  'gdnf-as1',
#  'ensg00000226862.1',
#  'ensg00000234936.1',
#  'slc30a6-dt',
#  'ensg00000268112.1',
#  'ensg00000267653.1',
#  'c3_ensg00000125730',
#  'ensg00000254192.1',
#  'zftraf1',
#  'yae1-dt',
#  'ensg00000237927.1',
#  'pcat7',
#  'rap2c-as1',
#  'linc02913',
#  'ensg00000258337.1',
#  'dut-as1',
#  'usp34-dt',
#  'mif-as1',
#  'ensg00000257883.1',
#  'l3mbtl2-as1',
#  'fam167a-as1',
#  'ensg00000257355.1',
#  'ensg00000269318.1',
#  'fzd10-as1',
#  'trbc2',
#  'cradd-as1',
#  'ensg00000226816.3',
#  'ighg1',
#  'itga9-as1',
#  'gprc5d-as1',
#  'linc00839',
#  'linc03064',
#  'skic3',
#  'ensg00000234255.9',
#  'ensg00000264666.3',
#  'ensg00000229021.2',
#  'col4a2-as1',
#  'hipk1-as1',
#  'loh12cr2',
#  'ensg00000236948.2',
#  'linc02141',
#  'linc01900',
#  'ensg00000270066.3',
#  'ensg00000262681.2',
#  'ensg00000224643.5',
#  'fam86c1p',
#  'sencr',
#  'rnu6-513p',
#  'linc01270',
#  'ensg00000230648.1',
#  'ensg00000254907.1',
#  'ensg00000232413.1',
#  'ensg00000273066.5',
#  'glis2-as1',
#  'linc00501',
#  'pitpna-as1',
#  'usp2-as1',
#  'st7-ot4',
#  'ensg00000259605.3',
#  'ensg00000258504.2',
#  'stag3l5p-pvrig2p-pilrb',
#  'ngf-as1',
#  'dlgap1-as2',
#  'dm1-as',
#  'ensg00000267249.1',
#  'kdm5c-it1',
#  'ensg00000253197.5',
#  'ensg00000259915.2',
#  'ensg00000253116.1',
#  'epb41l4a-as1',
#  'kpnb1-dt',
#  'slc20a1-dt',
#  'linc01340',
#  'msrb3-as1',
#  'ensg00000232995.7',
#  'zc3h12a-dt',
#  'ensg00000241168.1',
#  'ensg00000230676.1',
#  'fbxo34-as1',
#  'fmo6p',
#  'mt-tp',
#  'ensg00000224746.2',
#  'mrps30-dt',
#  'ensg00000267904.1',
#  'linc00620',
#  'ensg00000233223.5',
#  'smim2-as1',
#  'ilrun-as1',
#  'stpg2-as1',
#  'linc02762',
#  'st7-as2',
#  'ensg00000260185.1',
#  'clec4op_ensg00000267453',
#  'snap25-as1',
#  'ccdc183-as1',
#  'hsd17b2-as1',
#  'ttc36-as1',
#  'ensg00000225012.5',
#  'ensg00000229728.1',
#  'linc01307',
#  'mad2l1-dt',
#  'clasp1-as1',
#  'linc01359',
#  'ensg00000254577.1',
#  'spata13_ensg00000182957',
#  'ehhadh-as1',
#  'uvrag-dt',
#  'akap13-as1',
#  'ensg00000226471.7',
#  'entpd3-as1',
#  'thsd4-as1',
#  'ensg00000267174.7',
#  'ensg00000258181.1',
#  'ensg00000270972.1',
#  'ensg00000263745.7',
#  'ensg00000254676.1',
#  'linc01684',
#  'ctnna1-as1',
#  'tns2-as1',
#  'ensg00000237773.8',
#  'ensg00000273248.2',
#  'ensg00000262979.1',
#  'atp6v0e2-as1',
#  'ensg00000248285.1',
#  'linc00863',
#  'ensg00000261804.3',
#  'ensg00000255621.1',
#  'rny1',
#  'ensg00000260796.1',
#  'afap1-as1',
#  'zng1b',
#  'mlf1-dt',
#  'ensg00000230751.1',
#  'ensg00000254604.1',
#  'ensg00000258904.1',
#  'linc00571',
#  'slc12a2-dt',
#  'linc02035',
#  'ensg00000267783.3',
#  'ep400p1',
#  'linc02896',
#  'fam66b',
#  'ensg00000242628.6',
#  'ensg00000258824.2',
#  'atosa',
#  'ipo9-as1',
#  'icam4-as1',
#  'ensg00000259539.1',
#  'ensg00000261071.2',
#  'ensg00000257681.1',
#  'cox10-dt',
#  'mir222hg',
#  'tmlhe-as1',
#  'smc5-dt',
#  'cfap418-as1',
#  'ensg00000233539.5',
#  'linc02963',
#  'ensg00000273284.1',
#  'ensg00000188223.9',
#  'slc16a12-as1',
#  'linc02864',
#  'ensg00000227218.7',
#  'ensg00000267412.1',
#  'tacr3-as1',
#  'slc14a2-as1',
#  'linc01498',
#  'ensg00000273381.1',
#  'abtb3',
#  'ints15',
#  'ccdc144nl_ensg00000205212',
#  'letr1',
#  'eogt-dt',
#  'linc01780',
#  'ensg00000253256.1',
#  'ensg00000271320.1',
#  'ensg00000237705.1',
#  'eloa-as1',
#  'ensg00000273272.2',
#  'linc01476',
#  'ensg00000269082.1',
#  'fhip2b',
#  'ensg00000273320.2',
#  'ensg00000267058.1',
#  'ensg00000267260.4',
#  'scmh1-dt',
#  'ensg00000254690.1',
#  'ensg00000249319.2',
#  'st8sia6-as1',
#  'ensg00000259342.1',
#  'ensg00000271882.1',
#  'comett',
#  'idi2-as1',
#  'linc00536',
#  'ensg00000222031.1',
#  'linc01814',
#  'ct69',
#  'carhsp1-dt',
#  'ensg00000272622.2',
#  'nr4a1as',
#  'ensg00000272969.1',
#  'ensg00000251448.2',
#  'st3gal6-as1',
#  'hhip-as1',
#  'sugt1p4-stra6lp',
#  'ensg00000271743.1',
#  'grm5-as1',
#  'ensg00000273203.1',
#  'ensg00000231724.1',
#  'ensg00000261553.5',
#  'grpel2-as1',
#  'clecl1p',
#  'rrs1-dt',
#  'bms1p4-agap5',
#  'mcm3ap-as1',
#  'mt-ty',
#  'atp8b1-as1',
#  'ensg00000272831.2',
#  'ensg00000253844.2',
#  'ensg00000230975.1',
#  'linc01503',
#  'ensg00000272732.1',
#  'ensg00000260927.2',
#  'ensg00000268458.1',
#  'ensg00000228421.2',
#  'ensg00000250945.1',
#  'linc01122',
#  'linc02532',
#  'ensg00000184441.4',
#  'ensg00000272442.2',
#  'hey2-as1',
#  'atp11aun',
#  'ensg00000223838.2',
#  'ensg00000255580.1',
#  'linc02217',
#  'ensg00000232451.2',
#  'spag5-as1',
#  'linc01387',
#  'ighg4',
#  'ensg00000261386.2',
#  'ensg00000257764.2',
#  'igfbp7-as1',
#  'ensg00000236154.3',
#  'tirap-as1',
#  'mir3681hg',
#  'linc02519',
#  'ensg00000256538.2',
#  'linc01031',
#  'ensg00000271793.2',
#  'ajuba-dt',
#  'dlgap4-as1',
#  'ensg00000259639.6',
#  'golph3-dt',
#  'fgf7p3',
#  'linc03059',
#  'mincr',
#  'ly86-as1',
#  'ensg00000258365.1',
#  'skic8',
#  'lrp5l',
#  'ca3-as1',
#  'linc02798',
#  'ensg00000267082.1',
#  'ensg00000272277.1',
#  'ensg00000231769.4',
#  'ensg00000254135.3',
#  'ensg00000260955.2',
#  'ensg00000227741.1',
#  'ensg00000273183.1',
#  'tmsb15b',
#  'ensg00000277501.1',
#  'ensg00000260430.2',
#  'ensg00000233760.3',
#  'ensg00000249602.1',
#  'kif23-as1',
#  'ttll13',
#  'ensg00000229587.2',
#  'ensg00000260095.1',
#  'linc02320',
#  'ensg00000223727.6',
#  'ensg00000250167.2',
#  'rnu6-1111p',
#  'rmel3',
#  'sgsm3-as1',
#  'rn7skp16',
#  'ensg00000225096.3',
#  'ensg00000259675.4',
#  'linc01739',
#  'frg1bp',
#  'cecr7',
#  'ensg00000251567.5',
#  'ensg00000272789.1',
#  'ensg00000263624.1',
#  'ensg00000228222.1',
#  'znf691-dt',
#  'arhgef26-as1',
#  'haglr',
#  'linc02185',
#  'ddx39b-as1',
#  'ensg00000271763.1',
#  'ensg00000258168.6',
#  'slc38a4-as1',
#  'ensg00000261543.1',
#  'linc00871',
#  'kbtbd11-ot1_ensg00000253696',
#  'ttc14-dt',
#  'ensg00000270039.1',
#  'ensg00000253671.3',
#  'fsip2-as1',
#  'ensg00000239482.6',
#  'llph-dt',
#  'gpat4-as1',
#  'tbc1d8-as1',
#  'ensg00000249492.3',
#  'ensg00000256100.1',
#  'ensg00000251171.1',
#  'ensg00000272936.1',
#  'mt-tg',
#  'pik3ip1-dt',
#  'ensg00000260983.2',
#  'ensg00000260647.1',
#  'ensg00000226640.2',
#  'ensg00000259118.5',
#  'ensg00000272558.1',
#  'lcmt1-as1',
#  'lncoc1',
#  'ensg00000258077.2',
#  'f10_ensg00000126218',
#  'ensg00000222017.1',
#  'rasa2-it1',
#  'ensg00000272077.1',
#  'syt9-as1',
#  'ensg00000244459.4',
#  'linc02016',
#  'linc01624',
#  'lactb2-as1',
#  'ensg00000259684.1',
#  'linc01711',
#  'fhad1-as1',
#  'carnmt1-as1',
#  'fam135a-as1',
#  'ensg00000261775.1',
#  'ensg00000251023.1',
#  'ensg00000269986.1',
#  'ensg00000273174.1',
#  'ensg00000227374.1',
#  'linc01982',
#  'ensg00000263011.3',
#  'stard13-as',
#  'ensg00000259784.1',
#  'ensg00000272760.1',
#  'linc00626',
#  'ensg00000272918.1',
#  'ensg00000269976.1',
#  'bltp3b',
#  'ensg00000263620.1',
#  'mef2c-as1',
#  'rn7skp30',
#  'csrp1-as1',
#  'heatr5a-dt',
#  'cyp2u1-as1',
#  'ensg00000250764.1',
#  'ensg00000269189.1',
#  'linc00939',
#  'linc02625',
#  'ensg00000240571.1',
#  'ensg00000232555.2',
#  'ensg00000267879.2',
#  'linc02316',
#  'ensg00000260729.1',
#  'itgb5-as1',
#  'ensg00000258964.1',
#  'rnu1-134p',
#  'linc01798',
#  'ensg00000251613.4',
#  'zfpm1-as1',
#  'ensg00000239791.2',
#  'ensg00000255182.2',
#  'dock8-as2',
#  'znf22-as1',
#  'ensg00000259713.1',
#  'ensg00000228107.1',
#  'arhgap29-as1',
#  'ensg00000247970.3',
#  'linc02774',
#  'spcs3-as1',
#  'mirlet7a1hg',
#  'linc02840',
#  'fhip1b',
#  'ensg00000235023.1',
#  'znf503-as2',
#  'ensg00000268240.1',
#  'linc00958',
#  'ensg00000225457.1',
#  'linc01271',
#  'linc02605',
#  'fam88b',
#  'linc02343',
#  'ensg00000267026.5',
#  'ensg00000263120.1',
#  'ensg00000272991.1',
#  'vamp7_ensg00000124333',
#  'slc8a1-as1',
#  'kc6',
#  'ensg00000272112.1',
#  'cmklr2',
#  'pcdh9-as2',
#  'ensg00000260167.1',
#  'nck1-dt',
#  'ensg00000250049.7',
#  'ensg00000268536.2',
#  'septin7-dt',
#  'agk-dt',
#  'ensg00000273391.1',
#  'ensg00000250969.1',
#  'iqch-as1',
#  'asic4-as1',
#  'ensg00000273464.1',
#  'ensg00000229160.1',
#  'ensg00000261113.1',
#  'ensg00000256469.1',
#  'ensg00000267283.1',
#  'ensg00000256591.5',
#  'linc01482',
#  'hccs-dt',
#  'linc00964',
#  'ensg00000248161.5',
#  'bcyrn1',
#  'ensg00000188897.10',
#  'linc01550',
#  'ensg00000236283.5',
#  'linc02818',
#  'aptr',
#  'rhpn1-as1',
#  'ensg00000260392.6',
#  'rnf32-dt',
#  'ensg00000271533.1',
#  'pus1-as1',
#  'linc02945',
#  'ensg00000254024.1',
#  'map2k5-dt',
#  'ensg00000259410.5',
#  'ensg00000214770.3',
#  'ensg00000271926.1',
#  'znf436-as1',
#  'ensg00000225258.1',
#  'ensg00000241770.1',
#  'spen-as1',
#  'linc01315',
#  'ensg00000273363.1',
#  'linc01414',
#  'rhoxf1-as1',
#  'ensg00000267168.1',
#  'ensg00000249635.1',
#  'epha2-as1',
#  'ensg00000262050.2',
#  'rn7sl521p',
#  'dcst1-as1',
#  'ace2-dt',
#  'znf582-dt',
#  'ensg00000250777.2',
#  'ensg00000237280.1',
#  'ensg00000256706.2',
#  'ensg00000260331.1',
#  'casc15',
#  'ensg00000280351.2',
#  'ensg00000232377.1',
#  'ensg00000248636.7',
#  'ensg00000260917.1',
#  'linc00929',
#  'ensg00000271862.1',
#  'nfib-as1',
#  'ensg00000243944.5',
#  'ensg00000249631.7',
#  'ensg00000253347.1',
#  'ensg00000226622.7',
#  'ensg00000230051.3',
#  'tram2-as1',
#  'ensg00000225489.8',
#  'ensg00000264548.1',
#  'krt10-as1',
#  'linc01505',
#  'ensg00000249870.1',
#  'linc02268',
#  'rhoq-as1',
#  'pierce2',
#  'snhg28',
#  'prkag2-as2',
#  'nup153-as1',
#  'zng1c',
#  'gata3-as1',
#  'uqcrfs1-dt',
#  'ensg00000270871.1',
#  'ensg00000253184.1',
#  'linc01094',
#  'tmem11-dt',
#  'ensg00000257746.2',
#  'pxn-as1',
#  'arhgef35-as1',
#  'hsd17b1-as1',
#  'lyset',
#  'ensg00000273077.1',
#  'ensg00000250057.1',
#  'ensg00000261669.1',
#  'sgms1-as1',
#  'ensg00000260418.1',
#  'smim34',
#  'ensg00000266950.1',
#  'ensg00000258773.2',
#  'rundc3a-as1',
#  'rn7skp38',
#  'cyp4a22-as1',
#  'vdac1p8',
#  'map9-as1',
#  'foxp4-as1',
#  'ensg00000265749.6',
#  'ensg00000266268.5',
#  'tm4sf1-as1',
#  'tafazzin',
#  'znf295-as1',
#  'tbx2-as1',
#  'ensg00000255028.5',
#  'ensg00000254303.1',
#  'ensg00000249684.6',
#  'rsf1-it1',
#  'ensg00000203546.7',
#  'linc01725',
#  'ensg00000233393.2',
#  'ensg00000250237.3',
#  'ensg00000223725.6',
#  'ensg00000273192.1',
#  'linc01800',
#  'gs1-24f4.2',
#  'dennd2b-as1',
#  'hif1a-as1',
#  'ensg00000267048.1',
#  'ensg00000268205.1',
#  'linc01098',
#  'ilf3-dt',
#  'ensg00000255644.1',
#  'linc00630',
#  'epha1-as1',
#  'pkd1p6-npipp1',
#  'tmem123-dt',
#  'linc01611',
#  'ensg00000273258.1',
#  'ensg00000259081.1',
#  'ensg00000270482.1',
#  'ensg00000270277.1',
#  'brpf3-as1',
#  'ensg00000243620.2',
#  'cnn3-dt',
#  'ensg00000271554.1',
#  'entrep3',
#  'ktn1-as1',
#  'ensg00000260593.1',
#  'hspa2-as1',
#  'lyplal1-dt',
#  'ensg00000271843.1',
#  'ensg00000229233.1',
#  'zfta',
#  'ensg00000268119.8',
#  'maftrr',
#  'pcdh10-dt',
#  'bmal2',
#  'ensg00000262877.5',
#  'pdgfa-dt',
#  'ensg00000273471.1',
#  'calcrl-as1',
#  'grik1-as1',
#  'mrpl20-dt',
#  'fbxl19-as1',
#  'ensg00000272689.1',
#  'ensg00000253154.4',
#  'exo5-dt',
#  'ensg00000269125.1',
#  'mgc27382',
#  'kif9-as1',
#  'ensg00000247372.2',
#  'ensg00000257925.1',
#  'wwtr1-it1',
#  'cenpbd1p',
#  'linc02936',
#  'linc02226',
#  'rpl26l1-as1',
#  'pdk4-as1',
#  'ensg00000273451.1',
#  'tmem254-as1',
#  'ensg00000228274.5',
#  'snhg32',
#  'tmem202-as1',
#  'ensg00000232633.4',
#  'ensg00000232220.2',
#  'ensg00000257058.1',
#  'ensg00000259407.1',
#  'ensg00000265408.1',
#  'linc02082',
#  'linc01806',
#  'ensg00000250354.1',
#  'ensg00000270165.1',
#  'ppm1b-dt',
#  'ensg00000262160.1',
#  'dnaaf11',
#  'aga-dt',
#  'ensg00000226349.1',
#  'wt1-as',
#  'linc01584',
#  'ensg00000266728.5',
#  'ensg00000196566.2',
#  'linc01389',
#  'rfpl1s',
#  'ensg00000225610.1',
#  'ensg00000260816.2',
#  'muc12-as1',
#  'ensg00000262633.2',
#  'ensg00000261889.1',
#  'ensg00000237813.4',
#  'ensg00000223774.5',
#  'rn7sl388p',
#  'ensg00000257176.3',
#  'ensg00000251488.1',
#  'ensg00000242798.1',
#  'casc2',
#  'tbc1d22a-dt',
#  'ensg00000261799.1',
#  'ensg00000262801.6',
#  'duxap9',
#  'ensg00000267523.1',
#  'ensg00000267360.6',
#  'ensg00000254951.7',
#  'ppp3cb-as1',
#  'ensg00000249849.1',
#  'gosr2-dt',
#  'ensg00000269427.1',
#  'ensg00000273096.1',
#  'hdac4-as1',
#  'ensg00000225643.1',
#  'nr2f2-as1',
#  'ensg00000226149.6',
#  'slc41a3-as1',
#  'rmst',
#  'mal2-as1',
#  'ensg00000249574.1',
#  'linc01033',
#  'ensg00000261526.3',
#  'rn7sl737p',
#  'ece1-as1',
#  'linc02307',
#  'ensg00000234210.1',
#  'linc03070',
#  'ensg00000266783.1',
#  'ensg00000273319.1',
#  'ensg00000230647.3',
#  'linc03018',
#  'ppm1k-dt',
#  'zim2-as1',
#  'ensg00000260669.2',
#  'linc00648',
#  'basp1-as1',
#  'ensg00000269918.1',
#  'ensg00000253361.3',
#  'ensg00000263731.1',
#  'slco5a1-as1',
#  'linc00276',
#  'mrpl20-as1',
#  'mir181a1hg',
#  'bmal1',
#  'plbd1-as1',
#  'chct1',
#  'mir3936',
#  'nap1l6p',
#  'linc02604',
#  'lrfn5-dt',
#  'ensg00000269919.1',
#  'malinc1',
#  'adamts9-as2',
#  'map4k3-dt',
#  'gasal1',
#  'ensg00000270681.1',
#  'ensg00000261659.2',
#  'ensg00000258631.3',
#  'add3-as1',
#  'ensg00000255224.2',
#  'ensg00000260534.1',
#  'ensg00000268643.2',
#  'ensg00000232034.1',
#  'ensg00000271758.2',
#  'ensg00000259628.1',
#  'ensg00000236194.3',
#  'ensg00000227355.5',
#  'ensg00000261916.1',
#  'ensg00000226530.4',
#  'arhgap5-as1',
#  'slc26a10p',
#  'ensg00000272927.1',
#  'rhoa-it1',
#  'linc01501',
#  'slc5a4-as1',
#  'cfap276',
#  'foxo6-as1',
#  'ensg00000270996.1',
#  'linc02981',
#  'ensg00000271427.1',
#  'ensg00000261369.1',
#  'ensg00000237525.7',
#  'ensg00000228434.1',
#  'ensg00000260272.1',
#  'linc03060',
#  'ensg00000268713.1',
#  'ensg00000264635.1',
#  'ensg00000268472.2',
#  'ensg00000235939.1',
#  'agap2-as1',
#  'bsg-as1',
#  'ensg00000226699.1',
#  'tmem26-as1',
#  'ensg00000241860.7',
#  'steap2-as1',
#  'ctdp1-dt',
#  'ensg00000270137.1',
#  'linc02196',
#  'ensg00000267049.1',
#  'ensg00000271893.1',
#  'linc02362',
#  'ensg00000267109.1',
#  'nbeap2',
#  'ensg00000228044.3',
#  'ensg00000249753.2',
#  'ensg00000227857.2',
#  'ensg00000265737.1',
#  'synm-as1',
#  'ensg00000257411.2',
#  'crppa-as1',
#  'linc00707',
#  'linc02417',
#  'arrdc1-as1',
#  'linc02250',
#  'ensg00000259644.1',
#  'linc01320',
#  'mt-ts2',
#  'linc01970',
#  'ensg00000267062.1',
#  'ensg00000267784.1',
#  'arhgap26-as1',
#  'rnaseh1-dt',
#  'ensg00000269906.1',
#  'linc00390',
#  'linc01215',
#  'ensg00000258902.2',
#  'rnu4-62p',
#  'linc00106_ensg00000236871',
#  'linc00887',
#  'ensg00000272678.1',
#  'akap17a_ensg00000197976',
#  'adam7-as1',
#  'ensg00000253706.5',
#  'pelo-as1',
#  'ensg00000259584.1',
#  'ensg00000228423.2',
#  'septin7p13',
#  'ensg00000268230.5',
#  'ensg00000234477.1',
#  'exosc10-as1',
#  'ensg00000237031.7',
#  ...}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 3971
# 仅在 all_genes 中存在的基因: {'rtp2', 'spata48', 'fer1l5', 'hes5', 'gtf2i', 'krt20', 'defb123', 'gjd4', 'lbx1', 'lgals12', 'or2f2', 'krt84', 'anxa8', 'fam237b', 'c13orf46', 'krtap10-11', 'defb125', 'krt78', 'arr3', 'fcn2', 'lgals14', 'ms4a13', 'spty2d1os', 'rab41', 'prorp', 'nlrp9', 'snurf', 'slc10a1', 'trhr', 'galnt4', 'hoxd12', 'f8a1', 'gpr26', 'wfdc6', 'ccdc116', 'h3c3', 'or6c4', 'or6f1', 'mymk', 'h2ab1', 'mylk2', 'fev', 'gk3p', 'klk13', 'fam90a26', 'mageb18', 'ezhip', 'krtap19-1', 'upk3a', 'shpk', 'trim40', 'srgap2b', 'adgrf2', 'hcar3', 'defa6', 'prr20c', 'foxl3', 'aipl1', 'fmc1-luc7l2', 'or7g1', 'slc22a25', 'cacng1', 'c7', 'foxb2', 'smim28', 'krtap4-4', 'dmrtc2', 'cd1e', 'or2ap1', 'ascl1', 'drd3', 'spink13', 'bglap', 'h2ap', 'or52e6', 'hhla2', 'gpr75', 'vn1r4', 'fgf16', 'defb124', 'zacn', 'psg6', 'or4k14', 'tsga13', 'zfp91-cntf', 'frg2b', 'dbndd2', 'or8k3', 'cxcr5', 'saa4', 'raet1g', 'dclk3', 'npipb9', 'or4a16', 'tshb', 'nmur2', 'ugt1a4', 'resp18', 'hcrt', 'or51b6', 'adora2a', 'plscr5', 'prlhr', 'tex13a', 'frg2c', 'tubal3', 'serpina3', 'pglyrp3', 'cisd3', 'ifna17', 'c22orf15', 'amer3', 'nbpf6', 'lrrc52', 'or2t2', 'cabp2', 'tspy10', 'krtap12-1', 'or4d9', 'dus4l-bcap29', 'teddm1', 'pcdha8', 'bmp10', 'hnrnpcl2', 'epha8', 'gpr37l1', 'elspbp1', 'lcn6', 'pla2g2f', 'cetn1', 'p3r3urf', 'prr20g', 'slitrk3', 'or51a7', 'nkx2-6', 'mmp10', 'tsbp1', 'pecam1', 'nox3', 'krtap27-1', 'cst9', 'ecel1', 'lair2', 'scgb2a2', 'smr3b', 'slc6a2', 'mmp20', 'or5h2', 'magec1', 'adam21', 'nudt4b', 'pramef17', 'cdx4', 'znf177', 'mtrnr2l13', 'or4d2', 'c16orf72', 'krt33b', 'rax2', 'rps17', 'trim63', 'usp17l2', 'ly6g5b', 'znf286a', 'c3orf56', 'ms4a1', 'rnf133', 'mansc4', 'krtap13-3', 'f11r', 'znf648', 'or56a3', 'foxr1', 'guca1a', 'pom121c', 'ankle1', 'il12b', 'klk5', 'psg2', 'serf1a', 'pcsk1', 'ceacam8', 'c5orf58', 'sdhd', 'or52j3', 'kcna2', 'flt3lg', 'znf709', 'pkp1', 'usp17l3', 'mucl1', 'padi3', 'lhx8', 'psg7', 'r3hdml', 'pga3', 'gng13', 'npbwr2', 'adra1d', 'rlbp1', 'or10g9', 'serpinb5', 'fsd1', 'usp17l19', 'amely', 'trim39-rpp21', 'lta', 'fgf22', 'or8d1', 'mmp27', 'cd300ld', 'rtl3', 'smim38', 'neurod6', 'riiad1', 'or10h4', 'h2ac1', 'siglec8', 'magea9b', 'ibsp', 'defa3', 'sftpc', 'upk3bl2', 'tectb', 'prdm14', 'tmem151b', 'pcdhga2', 'defb129', 'baat', 'slc36a3', 'c7orf33', 'or14k1', 'znf705g', 'znf469', 'sprr1a', 'neurog1', 'ier3ip1', 'tas1r2', 'tspy3', 'tmod4', 'ifnl1', 'panx3', 'trim51gp', 'dmrtc1', 'or13c9', 'slurp2', 'krt3', 'ccl18', 'sap25', 'dhrs11', 'tspy2', 'pcdha11', 'ct47a2', 'defb105b', 'slc24a5', 'bcan', 'actrt1', 'spata31e1', 'foxd4', 'or7d2', 'atp1a4', 'gpr50', 'p2rx2', 'vsx1', 'dio3', 'potei', 'krtap19-3', 'or6c65', 'pvalef', 'krtap19-2', 'spdef', 'defb104a', 'vamp7', 'c6orf15', 'dppa5', 'pianp', 'usp17l27', 'or4f15', 'daz1', 'or1d5', 'gab4', 'lce1a', 'klk12', 'or52w1', 'rbp3', 'arl14epl', 'defb134', 'fzd10', 'f3', 'h1-7', 'trim64', 'tle7', 'magea2b', 'or7e24', 'scp2d1', 'serpinb3', 'otos', 'ina', 'treml4', 'mia', 'serpina7', 'or5au1', 'znf479', 'h3c13', 'higd2b', 'taf11l6', 'gpr151', 'nppa', 'dhrsx', 'or11a1', 'tmem270', 'smim21', 'or52n5', 'tmem89', 'ttyh1', 'or4k1', 'c4b', 'tmbim4', 'pi16', 'aldh3b2', 'tpd52l3', 'fam86b2', 'ct55', 'fzd9', 'gage12j', 'capns2', 'ly6h', 'fdx2', 'f2', 'krtap10-7', 'or1e2', 'fam90a8p', 'slc10a4', 'ceacam18', 'fam189a2', 'or4f29', 'tas2r40', 'krtap24-1', 'zscan5c', 'gpr141', 'sftpa1', 'tmem210', 'fmr1nb', 'tpbgl', 'tpte', 'tex101', 'rfpl3', 'prh2', 'hjurp', 'gpr15', 'slc35g6', 'f8', 'rnase2', 'or56a4', 'ube2l5', 'krtap25-1', 'casp14', 'dqx1', 'krtap10-8', 'rnase8', 'nox5', 'cxorf51b', 'atoh1', 'hnf1b', 'spata31a1', 'cfb', 'cckbr', 'rxrg', 'krtap9-4', 'h3c11', 'oosp4a', 'rbmy1e', 'c9orf72', 'dpf1', 'tmprss11f', 'adgrd2', 'tmprss6', 'spdye21', 'tgif2lx', 'ct45a2', 'il36rn', 'ccdc169-sohlh2', 'golga8o', 'fezf2', 'armh2', 'tspy9p', 'il13ra2', 'kmt2b', 'pglyrp1', 'ssu72p8', 'kbtbd4', 'tubb3', 'fgf20', 'ssx1', 'timm10b', 'reg3g', 'pmf1-bglap', 'duxa', 'six6', 'c19orf84', 'gabra1', 'c2orf78', 'krt83', 'nxpe2', 'clca2', 'spa ...
# 仅在 adata_genes 中存在的基因数量: 4939
# 仅在 adata_genes 中存在的基因: {'thorlnc', 'ensg00000254777.5', 'ensg00000249593.6', 'linc00963', 'iqsec3-as1', 'hotair', 'ensg00000261766.1', 'ensg00000272369.1', 'linc00922', 'ensg00000265334.1', 'ensg00000227227.1', 'ensg00000263244.2', 'rpl37a-dt', 'linc01702', 'ensg00000244151.1', 'ube2h-dt', 'b4gat1-dt', 'zfx-as1', '7sk_ensg00000202198', 'ensg00000230286.1', 'rnf139-dt', 'ensg00000264015.2', 'ensg00000256571.1', 'ensg00000238039.1', 'ensg00000225811.1', 'linc01812', 'ensg00000255108.1', 'usp3-as1', 'ensg00000253284.2', 'ensg00000229044.1', 'ensg00000228629.2', 'linc01547', 'ensg00000259250.1', 'irag1-as1', 'ensg00000272854.1', 'znf584-dt', 'ensg00000257060.8', 'pgls-dt', 'garin2', 'oser1-dt', 'ensg00000236469.1', 'ensg00000229896.2', 'ensg00000229642.1', 'pcolce-as1', 'misfa', 'linc01830', 'snhg17', 'ensg00000269887.1', 'ensg00000254973.2', 'marchf6-dt', 'ensg00000223390.1', 'linc00629', 'ensg00000232638.1', 'loxl1-as1', 'linc03069', 'linc03007', 'linc02328', 'ensg00000273328.5', 'linc00574', 'rnu4atac', 'mcph1-dt', 'ensg00000266805.1', 'ensg00000262410.1', 'cfap20dc-dt', 'linc00598', 'ensg00000257390.5', 'ensg00000272108.1', 'slc25a30-as1', 'eeig1', 'ensg00000265303.1', 'ensg00000265625.1', 'ensg00000141979.4', 'ensg00000259994.1', 'ensg00000250906.1', 'ensg00000272054.1', 'kdsr-dt', 'linc02550', 'itga2-as1', 'linc01588', 'ensg00000236528.3', 'linc01088', 'ensg00000253392.4', 'septin4-as1', 'casc17', 'snx10-as1', 'ensg00000258875.6', 'ensg00000249738.10', 'ensg00000227338.2', 'ensg00000271382.1', 'ensg00000270265.1', 'ensg00000257022.1', 'ensg00000272917.1', 'wfdc21p', 'bbox1-as1', 'fam200c', 'ensg00000269535.1', 'ensg00000257458.1', 'satb2-as1', 'map3k2-dt', 'ensg00000269802.1', 'fam13b-as1', 'dleu1', 'ensg00000262211.1', 'ensg00000253988.1', 'bach1-it2', 'ensg00000224950.2', 'nexn-as1', 'ensg00000203472.3', 'ensg00000231557.1', 'ensg00000234998.1', 'linc02481', 'ensg00000240240.10', 'ensg00000225963.8', 'ensg00000234810.4', 'dmxl1-dt', 'gabpb1-as1', 'sntg2-as1', 'tmco1-as1', 'fam106a', 'graslnd', 'malat1', 'linc02492', 'ensg00000273149.1', 'bcl2l1-as1', 'rnu2-68p', 'ensg00000236449.2', 'linc01331', 'ensg00000238273.3', 'ensg00000272609.1', 'ensg00000257955.1', 'prkcq-as1', 'ensg00000237422.3', 'linc02231', 'mir4435-2hg', 'ensg00000255968.1', 'mir210hg', 'ensg00000229227.8', 'mrps9-as2', 'atp5f1ep2', 'capn1-as1', 'lifr-as1', 'ensg00000268603.2', 'ensg00000248664.3', 'linc03057', 'ensg00000237498.3', 'ensg00000260196.1', 'hormad2-as1', 'piwil2-dt', 'linc02596', 'ensg00000273113.1', 'ensg00000254485.5', 'ensg00000255094.1', 'b3galt1-as1', 'snhg11', 'ensg00000267070.1', 'ensg00000265091.5', 'ensg00000224848.4', 'snhg10', 'ensg00000256443.1', 'alg1l9p_ensg00000248671', 'ensg00000224789.1', 'ensg00000272463.2', 'ensg00000273449.1', 'ensg00000268027.5', 'ensg00000259316.12', 'xpc-as1', 'ensg00000257524.6', 'ensg00000225806.8', 'draic', 'snrpf-dt', 'ensg00000272787.1', 'linc01933', 'ensg00000260686.1', 'aldh1a3-as1', 'nova1-dt', 'msantd2-as1', 'ensg00000267939.1', 'ensg00000259523.1', 'ensg00000273076.1', 'ensg00000269243.1', 'entrep2', 'linc01266', 'tprx2', 'ensg00000263212.2', 'fam153cp', 'ensg00000273112.1', 'map3k4-as1', 'ensg00000265100.2', 'ensg00000260851.7', 'serhl', 'snrpa1-dt', 'ensg00000262020.1', 'setbp1-dt', 'gcc2-as1', 'hcg17', 'ensg00000257759.2', 'hotairm1', 'msc-as1', 'cpeb1-as1', 'mt-tr', 'flj20021', 'ensg00000233928.7', 'linc02067', 'ensg00000259097.3', 'linc00885', 'ensg00000269711.1', 'ensg00000250954.6', 'slc12a9-as1', 'linc00323', 'ensg00000259321.1', 'snhg16', 'ensg00000254129.1', 'ensg00000245748.1', 'linc02237', 'chl1-as2', 'ensg00000225885.7', 'ensg00000250243.3', 'igf2bp2-as1', 'fam218a', 'ensg00000269463.1', 'piwil4-as1', 'mios-dt', 'ensg00000264187.1', 'linc01521', 'linc02088', 'ensg00000223598.1', 'ensg00000229839.6', 'mir142hg', 'ddx59-as1', 'ensg00000267248.5', 'ensg00000272156.1', 'tmem147-as1', 'papln-as1', 'ensg00000272541.1', 'linc00543', 'ensg00000265987.1', 'linc01473', 'gdnf-as1', 'ensg00000226 ...

# %%
import numpy as np
from scipy.sparse import csr_matrix

# Initialize a mapping from gene names in adata to their column indices
adata_gene_to_index = {gene: idx for idx, gene in enumerate(adata_genes_lower)}

# Create an array to map adata.X column indices to new_data column indices
adata_to_new_data_indices = -1 * np.ones(adata.X.shape[1], dtype=int)
for idx, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        adata_to_new_data_indices[idx] = gene_to_index[gene]



# Extract data from adata.X without converting it to a dense array
data = adata.X.data
indices = adata.X.indices
indptr = adata.X.indptr

# Map the column indices to the new indices in new_data
mapped_indices = adata_to_new_data_indices[indices]

# Filter out entries where the mapping is invalid (-1)
valid_entries = mapped_indices != -1
new_data_values = data[valid_entries]
new_data_indices = mapped_indices[valid_entries]

# Build the new indptr array for the new_data matrix
new_indptr = np.zeros(adata.X.shape[0] + 1, dtype=int)


for i in range(adata.X.shape[0]):
    row_start = indptr[i]
    row_end = indptr[i + 1]
    valid_count = np.sum(valid_entries[row_start:row_end])
    new_indptr[i + 1] = new_indptr[i] + valid_count


# Construct the new_data sparse matrix
new_data = csr_matrix(
    (new_data_values, new_data_indices, new_indptr),
    shape=(adata.X.shape[0], len(all_genes)),
    dtype=np.float32
)
new_data = new_data.toarray()

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

from sklearn.decomposition import PCA
n_components = 64
pca = PCA(n_components=n_components)
train_embeddings = pca.fit_transform(X_train)
test_embeddings = pca.transform(X_test)

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.5853251187648456
# Weighted F1 Score: 0.5499940090819535
# Macro F1 Score: 0.29085125694636993
# Random Guess Accuracy: 0.2927884776016484
#                                                            precision    recall  f1-score   support
#
#                           blood vessel smooth muscle cell       0.14      0.07      0.09       852
#                                          endothelial cell       0.64      0.80      0.71     13511
#                  kidney collecting duct intercalated cell       0.25      0.26      0.26      1032
#                     kidney collecting duct principal cell       0.59      0.68      0.63      2040
#           kidney distal convoluted tubule epithelial cell       0.50      0.44      0.47       618
#                                      kidney granular cell       0.00      0.00      0.00       105
#                            kidney interstitial fibroblast       0.21      0.03      0.06       781
# kidney loop of Henle thick ascending limb epithelial cell       0.52      0.71      0.60      1410
#         kidney proximal convoluted tubule epithelial cell       0.61      0.42      0.50      4160
#                                                 leukocyte       0.30      0.09      0.14      1905
#                                                macrophage       0.12      0.02      0.03       295
#                              macula densa epithelial cell       0.50      0.10      0.17        10
#                                            mesangial cell       0.00      0.00      0.00        11
#                                                  podocyte       0.49      0.37      0.42       214
#
#                                                  accuracy                           0.59     26944
#                                                 macro avg       0.35      0.29      0.29     26944
#                                              weighted avg       0.54      0.59      0.55     26944
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
PCA_embeddings = pca.transform(new_data)
new_adata = sc.read_h5ad(data_dir)
new_adata.obsm[f'SSL_GP_ZS_{random_seed}'] = PCA_embeddings
new_adata.uns[f'GP_ZS_y_test_{random_seed}'] = y_test
new_adata.uns[f'GP_ZS_predictions_{random_seed}'] = predictions
new_adata.uns[f'GP_ZS_target_names_{random_seed}'] = label_encoder.classes_
new_adata.write_h5ad(data_dir)

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "slide_seq_human_kidney_PCA_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicor_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicor_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['slide_seq_human_kidney'],
    'method': [re.search(r'kidney_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micor_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# macro_f1	weighted_f1	micor_f1
# 0.291	0.550	0.585
