# %%
import scanpy as sc
data_dir = '../../dataset/Marshall2022High_mouse_sampled.h5ad'
adata = sc.read_h5ad(data_dir)

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
adata.var['gene_id'] = adata.var.index
adata.var.index = adata.var['gene_name']

# 输出 adata.var
adata.var
# Out:
#                feature_is_filtered feature_reference feature_biotype  \
# gene_name
# Erg28                        False   NCBITaxon:10090            gene
# 0610009B22Rik                False   NCBITaxon:10090            gene
# 0610009E02Rik                False   NCBITaxon:10090            gene
# 0610009L18Rik                False   NCBITaxon:10090            gene
# Dele1                        False   NCBITaxon:10090            gene
# ...                            ...               ...             ...
# mt-Tm                        False   NCBITaxon:10090            gene
# mt-Tp                        False   NCBITaxon:10090            gene
# mt-Tq                        False   NCBITaxon:10090            gene
# mt-Tt                        False   NCBITaxon:10090            gene
# mt-Tv                        False   NCBITaxon:10090            gene
#
#               feature_name-0 feature_length-0  feature_type-0 feature_name-1  \
# gene_name
# Erg28                  Erg28              696  protein_coding          Erg28
# 0610009B22Rik  0610009B22Rik              852  protein_coding  0610009B22Rik
# 0610009E02Rik  0610009E02Rik              981          lncRNA  0610009E02Rik
# 0610009L18Rik  0610009L18Rik              639          lncRNA  0610009L18Rik
# Dele1                  Dele1             2394  protein_coding          Dele1
# ...                      ...              ...             ...            ...
# mt-Tm                  mt-Tm               69         Mt_tRNA          mt-Tm
# mt-Tp                  mt-Tp               67         Mt_tRNA          mt-Tp
# mt-Tq                  mt-Tq               71         Mt_tRNA          mt-Tq
# mt-Tt                  mt-Tt               67         Mt_tRNA          mt-Tt
# mt-Tv                  mt-Tv               69         Mt_tRNA          mt-Tv
#
#               feature_length-1  feature_type-1 feature_name-2  ...  \
# gene_name                                                      ...
# Erg28                      696  protein_coding          Erg28  ...
# 0610009B22Rik              852  protein_coding  0610009B22Rik  ...
# 0610009E02Rik              981          lncRNA  0610009E02Rik  ...
# 0610009L18Rik              639          lncRNA  0610009L18Rik  ...
# Dele1                     2394  protein_coding          Dele1  ...
# ...                        ...             ...            ...  ...
# mt-Tm                       69         Mt_tRNA          mt-Tm  ...
# mt-Tp                       67         Mt_tRNA          mt-Tp  ...
# mt-Tq                       71         Mt_tRNA          mt-Tq  ...
# mt-Tt                       67         Mt_tRNA          mt-Tt  ...
# mt-Tv                       69         Mt_tRNA          mt-Tv  ...
#
#               feature_length-5  feature_type-5 feature_name-6  \
# gene_name
# Erg28                      696  protein_coding          Erg28
# 0610009B22Rik              852  protein_coding  0610009B22Rik
# 0610009E02Rik              981          lncRNA  0610009E02Rik
# 0610009L18Rik              639          lncRNA  0610009L18Rik
# Dele1                     2394  protein_coding          Dele1
# ...                        ...             ...            ...
# mt-Tm                       69         Mt_tRNA          mt-Tm
# mt-Tp                       67         Mt_tRNA          mt-Tp
# mt-Tq                       71         Mt_tRNA          mt-Tq
# mt-Tt                       67         Mt_tRNA          mt-Tt
# mt-Tv                       69         Mt_tRNA          mt-Tv
#
#               feature_length-6  feature_type-6 feature_name-7  \
# gene_name
# Erg28                      696  protein_coding          Erg28
# 0610009B22Rik              852  protein_coding  0610009B22Rik
# 0610009E02Rik              981          lncRNA  0610009E02Rik
# 0610009L18Rik              639          lncRNA  0610009L18Rik
# Dele1                     2394  protein_coding          Dele1
# ...                        ...             ...            ...
# mt-Tm                       69         Mt_tRNA          mt-Tm
# mt-Tp                       67         Mt_tRNA          mt-Tp
# mt-Tq                       71         Mt_tRNA          mt-Tq
# mt-Tt                       67         Mt_tRNA          mt-Tt
# mt-Tv                       69         Mt_tRNA          mt-Tv
#
#               feature_length-7  feature_type-7      gene_name  \
# gene_name
# Erg28                      696  protein_coding          Erg28
# 0610009B22Rik              852  protein_coding  0610009B22Rik
# 0610009E02Rik              981          lncRNA  0610009E02Rik
# 0610009L18Rik              639          lncRNA  0610009L18Rik
# Dele1                     2394  protein_coding          Dele1
# ...                        ...             ...            ...
# mt-Tm                       69         Mt_tRNA          mt-Tm
# mt-Tp                       67         Mt_tRNA          mt-Tp
# mt-Tq                       71         Mt_tRNA          mt-Tq
# mt-Tt                       67         Mt_tRNA          mt-Tt
# mt-Tv                       69         Mt_tRNA          mt-Tv
#
#                           gene_id
# gene_name
# Erg28          ENSMUSG00000021252
# 0610009B22Rik  ENSMUSG00000007777
# 0610009E02Rik  ENSMUSG00000086714
# 0610009L18Rik  ENSMUSG00000043644
# Dele1          ENSMUSG00000024442
# ...                           ...
# mt-Tm          ENSMUSG00000064344
# mt-Tp          ENSMUSG00000064372
# mt-Tq          ENSMUSG00000064343
# mt-Tt          ENSMUSG00000064371
# mt-Tv          ENSMUSG00000064338
#
# [16661 rows x 29 columns]

# %%
import scanpy as sc
import torch
import lightning.pytorch as pl
from self_supervision.models.lightning_modules.cellnet_autoencoder import MLPAutoEncoder
from self_supervision.estimator.cellnet import EstimatorAutoEncoder

# 设置你的 .ckpt 文件路径
ckpt_path = "../../sc_pretrained/Pretrained Models/GPMask.ckpt"

# 模型参数
units_encoder = [512, 512, 256, 256, 64]
units_decoder = [256, 256, 512, 512]

# 初始化 EstimatorAutoEncoder 实例
estim = EstimatorAutoEncoder(data_path=None)  # 如果没有实际数据路径，可以设置为None

# 加载预训练模型
estim.model = MLPAutoEncoder.load_from_checkpoint(
    ckpt_path,
    gene_dim=19331,  # 根据你的数据调整
    batch_size=128,  # 根据你的需要调整
    units_encoder=units_encoder, 
    units_decoder=units_decoder,
    masking_strategy="random",  # 假设模型使用了随机掩码
    masking_rate=0.5,  # 根据需要调整
)

# 使用 GPU 进行评估（如果可用）
estim.trainer = pl.Trainer(accelerator="gpu", devices=1 if torch.cuda.is_available() else None)
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/tf.py:52: UserWarning: Tensorflow dtype mappings did not load successfully due to an error: No module named 'tensorflow'
#   warn(f"Tensorflow dtype mappings did not load successfully due to an error: {exc.msg}")
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# gene_name
# Erg28                    Erg28
# 0610009B22Rik    0610009B22Rik
# 0610009E02Rik    0610009E02Rik
# 0610009L18Rik    0610009L18Rik
# Dele1                    Dele1
#                      ...
# mt-Tm                    mt-Tm
# mt-Tp                    mt-Tp
# mt-Tq                    mt-Tq
# mt-Tt                    mt-Tt
# mt-Tv                    mt-Tv
# Name: gene_name, Length: 16661, dtype: category
# Categories (20499, object): ['0610009B22Rik', '0610009E02Rik', '0610009L18Rik', '0610010K14Rik', ..., 'mt-Tq', 'mt-Ts2', 'mt-Tt', 'mt-Tv']

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# gene_name
# Erg28                    Erg28
# 0610009B22Rik    0610009B22Rik
# 0610009E02Rik    0610009E02Rik
# 0610009L18Rik    0610009L18Rik
# Dele1                    Dele1
#                      ...
# mt-Tm                    mt-Tm
# mt-Tp                    mt-Tp
# mt-Tq                    mt-Tq
# mt-Tt                    mt-Tt
# mt-Tv                    mt-Tv
# Name: gene_name, Length: 16661, dtype: category
# Categories (20499, object): ['0610009B22Rik', '0610009E02Rik', '0610009L18Rik', '0610010K14Rik', ..., 'mt-Tq', 'mt-Ts2', 'mt-Tt', 'mt-Tv']

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 13074
# 匹配的基因列表: {'pigbos1', 'ccdc9', 'rnf40', 'mospd3', 'heatr5b', 'wdr17', 'tinag', 'cfap54', 'b4galt7', 'inpp5d', 'prox2', 'dcp1a', 'ubb', 'rgs13', 'id1', 'pde4d', 'mllt10', 'alox5ap', 'arpc3', 'dstn', 'ftsj3', 'fcho2', 'pdgfc', 'tubg1', 'sema5b', 'ctns', 'micall1', 'strada', 'adipor2', 'bbs4', 'tmem127', 'atg16l1', 'tor4a', 'vps37c', 'pars2', 'hif3a', 'homer1', 'fam13c', 'lrg1', 'arl14ep', 'pglyrp3', 'sil1', 'kcnma1', 'vwf', 'ggt1', 'tgm1', 'sephs1', 'prrt2', 'ppp1r36', 'fhdc1', 'rpl37a', 'meis2', 'rps6ka3', 'ovol2', 'tex38', 'taf5l', 'pithd1', 'fbxl4', 'ptpn9', 'sphkap', 'alkbh7', 'satb1', 'slc30a7', 'rad51', 'tbc1d31', 'rc3h1', 'acvr2b', 'csde1', 'taf12', 'gabarapl2', 'slc17a8', 'cdh11', 'ermp1', 'abhd17a', 'cep170b', 'cebpz', 'tead3', 'hgf', 'pigf', 'tmem9', 'lpar3', 'ube2m', 'zfand1', 'glod5', 'pcdhb3', 'rcor2', 'slc16a2', 'zdhhc15', 'ebf3', 'mrps31', 'tmem253', 'cib1', 'rnf216', 'emc1', 'rbbp8', 'gpc3', 'gpnmb', 'csnk2a2', 'zdhhc18', 'cd19', 'ermap', 'kmt2c', 'bgn', 'mid1', 'tgfbr1', 'il23r', 'gprin3', 'mybpc1', 'thyn1', 'bank1', 'evl', 'ptch1', 'usp4', 'dnajc5', 'man2b1', 'madd', 'zdhhc1', 'ap4s1', 'dgkz', 'ntm', 'ric3', 'slc7a5', 'stk38', 'tmc4', 'wapl', 'papln', 'nrbp1', 'stk19', 'slc25a35', 'atp2b4', 'spsb3', 'erh', 'cd46', 'abcg8', 'vipas39', 'ncor1', 'pros1', 'cd86', 'wwox', 'tubgcp6', 'por', 'fbln5', 'fyttd1', 'nipsnap3b', 'txndc15', 'zfyve19', 'rrp9', 'zmynd12', 'cryga', 'tarbp1', 'shpk', 'fdps', 'ptpn4', 'slc24a3', 'slc39a5', 'gpr19', 'cby1', 'flrt3', 'pcgf5', 'rfxap', 'ttc21b', 'ak3', 'tnc', 'dner', 'osgin1', 'sdhd', 'trim3', 'pacsin3', 'copg1', 'fgd5', 'oxr1', 'wdr55', 'emc7', 'slc25a4', 'cdh19', 'cnpy3', 'lztr1', 'vps53', 'glipr2', 'klf16', 'arhgap17', 'tagln', 'lgals8', 'bend5', 'prr27', 'pip5k1b', 'tcea1', 'anks4b', 'ccdc28a', 'rbm3', 'prkaca', 'bbof1', 'fam161a', 'hmgn5', 'cckar', 'cep120', 'prkca', 'slc35f1', 'lpar4', 'slc13a4', 'drc1', 'srsf4', 'pde4b', 'entpd7', 'klhl32', 'hmgcr', 'prr15', 'jph2', 'fmr1nb', 'mthfd1', 'smg8', 'srfbp1', 'r3hdm4', 'skp1', 'fancc', 'st6galnac6', 'tm2d3', 'btnl9', 'tafa5', 'fam180a', 'nfatc3', 'anapc11', 'tcaf1', 'zc3h10', 'n4bp2l1', 'usp16', 'yap1', 'lmnb2', 'tmeff1', 'zc2hc1c', 'grb14', 'map3k21', 'mink1', 'tsr3', 'spdl1', 'apaf1', 'cdc5l', 'tmtc1', 'cyfip1', 'treh', 'znfx1', 'plekhn1', 'dgcr6', 'dnajc11', 'tmem139', 'npas3', 'vdac2', 'srsf5', 'vps37a', 'sod3', 'ice1', 'trim45', 'mettl24', 'ctcfl', 'atxn7l3', 'col6a2', 'coq8a', 'cnot3', 'tma16', 'fbxo45', 'trim42', 'misp', 'tmx2', 'lxn', 'slk', 'cep89', 'opcml', 'tox', 'smarcd3', 'smc3', 'dda1', 'ube2r2', 'gramd4', 'septin9', 'daxx', 'pdrg1', 'kri1', 'etfb', 'apobec1', 'scimp', 'lef1', 'slitrk6', 'mbip', 'amt', 'vezt', 'fam72a', 'kif21b', 'ccdc189', 'taf3', 'il17rd', 'ikzf2', 'ak7', 'tor3a', 'tm9sf1', 'artn', 'snai1', 'elf3', 'reep1', 'bbox1', 'dnajb9', 'ahdc1', 'dnajb14', 'cdc42bpa', 'msrb3', 'lrp1b', 'hs1bp3', 'pdia6', 'jarid2', 'ntng2', 'klhl42', 'alpk2', 'zkscan3', 'wfdc2', 'rtn4r', 'ier3ip1', 'fam3a', 'tbx20', 'gal3st2', 'ncf4', 'ikbip', 'ecm1', 'mbd4', 'gabrd', 'cd101', 'rabif', 'ciao2a', 'gabpb1', 'styxl1', 'cux2', 'guf1', 'ccdc12', 'rgs2', 'ifi27', 'ehbp1', 'eda', 'spred3', 'pak5', 'map6', 'veph1', 'ahctf1', 'cnga1', 'arhgap33', 'mettl16', 'tmie', 'phactr1', 'setd1b', 'hagh', 'angptl3', 'bcl2l14', 'cdkl2', 'arhgef5', 'stam', 'alkbh4', 'ccr5', 'kcnj6', 'ddr1', 'eif4a3', 'klhl23', 'ppfia4', 'fam107a', 'cox8a', 'elf2', 'lrrcc1', 'ezr', 'mctp2', 'fzd3', 'uqcr10', 'evc', 'tshz3', 'camta2', 'thoc1', 'celf1', 'calhm2', 'zscan10', 'nhlrc2', 'tfap4', 'hes6', 'tnpo3', 'crtap', 'morc4', 'hdhd2', 'tlk1', 'anapc4', 'pdlim1', 'fmo2', 'sap25', 'kcnj12', 'pcyox1l', 'tor2a', 'cox5a', 'cdk5rap2', 'fam193a', 'nup155', 'trim39', 'gpm6a', 'hoxb7', 'clba1', 'rnf8', 'huwe1', 'cdon', 'fndc1', 'tmem185a', 'chst14', 'fbxl8', 'chd4', 'calhm5', 'mypop', 'fam184a', 'ebpl', 'hirip3', 'nmur2', 'dennd6a', 'zfp3', 'sesn3', 'eva1b', 'fcgrt', 'ankle1', 'brox', 'hes1', 'pdzd8', 'vcam1', 'tg', 'col16a1', 'prmt7', 'kiss1r', 'ntf3', 'galns', 'sdc2', 'mrpl20' ...
# {'gm5577',
#  'zfp472',
#  'peg13',
#  '6030442k20rik',
#  'gm15506',
#  'dbil5',
#  'h3f3aos',
#  'gm13840',
#  'rsl1',
#  '4930509g22rik',
#  'lockd',
#  '2900089d17rik',
#  'gm43482',
#  'gm43573',
#  'gm28641',
#  'gm19705',
#  'gm37090',
#  'gm44503',
#  'cyp2j7',
#  'gm14812',
#  'ppp2r3d',
#  'gm43682',
#  'gm20528',
#  'gm15409',
#  'xlr',
#  '5730405o15rik',
#  'gm26760',
#  'gm2093',
#  'gm13889',
#  '4931429p17rik',
#  'gm6793',
#  '4931422a03rik',
#  'gm10575',
#  'gm9755',
#  '3222401l13rik',
#  '4930481b07rik',
#  'ctla2a',
#  '1700003e16rik',
#  'gm4117',
#  'd3ertd751e',
#  'zfp429',
#  'gm9910',
#  'gm27224',
#  'gm43445',
#  'gm37982',
#  'zfp27',
#  'a930005h10rik',
#  '1700048o20rik',
#  '2900026a02rik',
#  'gm15489',
#  'gm16861',
#  'zfp445',
#  'ab124611',
#  '9130019o22rik',
#  'ces2b',
#  'ugt2b34',
#  '2500004c02rik',
#  'gm12153',
#  'a930006k02rik',
#  'gm7334',
#  'tha1',
#  'gm31243',
#  'mt1',
#  'gm43055',
#  'zfp420',
#  'b630019a10rik',
#  'gm16549',
#  'mir6236',
#  'gm34240',
#  'gm43154',
#  'gm12925',
#  'gm26666',
#  'rdh7',
#  'mapk1ip1',
#  'slc22a26',
#  'gm12798',
#  'zfp784',
#  'gm42962',
#  '4930426d05rik',
#  'gm14169',
#  '4921515e04rik',
#  'gm20431',
#  'neurl1a',
#  'd8ertd738e',
#  'bb365896',
#  'rsph3a',
#  'gm8739',
#  '9130221h12rik',
#  'slfn5os',
#  'gm37516',
#  'phf11d',
#  'gm42772',
#  'gm16136',
#  'zfp235',
#  'zfp341',
#  'mfsd4b4',
#  'f8a',
#  '2310040g07rik',
#  '2810404m03rik',
#  'gm12474',
#  'zfp365',
#  'gm20498',
#  'gm37212',
#  'tmem178',
#  'zfp11',
#  'ftl1',
#  'zfp7',
#  'zfp457',
#  'zfp507',
#  '6720475m21rik',
#  'gm37747',
#  'sult2a5',
#  'gm10644',
#  'zfp763',
#  'zfp964',
#  'gm26629',
#  '9430065f17rik',
#  'gm15441',
#  'dnaaf9',
#  'gm16090',
#  'gm12963',
#  'gm43254',
#  'gm12724',
#  '1700018l02rik',
#  'gm13262',
#  '2300009a05rik',
#  '9130230n09rik',
#  'gm37626',
#  'timd2',
#  'gm43413',
#  'ifit1bl2',
#  'gm37691',
#  'ank',
#  'gm14393',
#  'a130051j06rik',
#  '9530046b11rik',
#  'gm43032',
#  'dleu2',
#  'hycc1',
#  'pnp2',
#  'zfp157',
#  '4930589o11rik',
#  'gstm6',
#  'gm8369',
#  'nrg1_ensmusg00000062991',
#  '6430548m08rik',
#  '2310039l15rik',
#  '6430511e19rik',
#  'gm37902',
#  'cyp2j12',
#  'gm16093',
#  'gm26627',
#  'tnfsf13os',
#  'a330093e20rik',
#  'gm9843',
#  'gm26965',
#  '4930429f24rik',
#  '1110035h17rik',
#  'gm6288',
#  'zim1',
#  'gm29050',
#  'notumos',
#  'mfsd7a',
#  'gm29247',
#  'gm38115',
#  'pcdhb17',
#  'supt6',
#  'gm29123',
#  'gm8066',
#  'zfp324',
#  'gm20644',
#  'gm43328',
#  'nat8f1',
#  'eeig2',
#  'icosl',
#  'gm12381',
#  'gm37202',
#  'c1ra',
#  'a930017k11rik',
#  'car3',
#  'ifi208',
#  'zfp458',
#  'zfp758',
#  '2810002d19rik',
#  'zfp384',
#  'gm9828',
#  '4921524j17rik',
#  'zfp619',
#  'gm4707',
#  'plet1os',
#  'xlr3a',
#  'c630028m04rik',
#  'mfsd4b1',
#  'tmem147os_ensmusg00000097320',
#  'gm43768',
#  '6030443j06rik',
#  'kcne1l',
#  '2810408a11rik',
#  'gm26901',
#  'pea15a',
#  'brd8dc',
#  'st8sia3os',
#  '8430429k09rik',
#  'gm16170',
#  'entrep3',
#  'pcx',
#  '2310008n11rik',
#  'gm11630',
#  '2700049a03rik',
#  'd16ertd472e',
#  'gm14532',
#  'fam220a_ensmusg00000083012',
#  'pate12',
#  'gm12968',
#  '2310044k18rik',
#  'gm45902',
#  'gm38012',
#  '1110020a21rik',
#  'gm38250',
#  'gm26805',
#  'gm12454',
#  'gm15294',
#  'slc22a27',
#  'zfp971',
#  '4930573h18rik',
#  'gm11767',
#  '2610020c07rik',
#  'gm28403',
#  '0610043k17rik',
#  'zfp583',
#  'zfp454',
#  'slfn9',
#  'gm26827',
#  '4930563e22rik',
#  'gm525',
#  'gimap1os',
#  'srp54c',
#  'gm16536',
#  'zfp954',
#  'gm17473',
#  'gm26549',
#  'gm37334',
#  'gm28961',
#  'gm3604',
#  'zfp768',
#  '1700057h15rik',
#  'gm10778',
#  'gm43462',
#  'ttll13',
#  'gm7694',
#  'cyp2j8',
#  '4930562c15rik',
#  'eif1a',
#  '4931406c07rik',
#  'gm23458',
#  '2810428j06rik',
#  'gm12426',
#  '4930444p10rik',
#  'gm37052',
#  'gm10687',
#  'b230208h11rik',
#  '4930539j05rik',
#  'apobec3',
#  'gm8013',
#  'gm10649',
#  'gm10787',
#  'gm17116',
#  '2810408i11rik',
#  'gm12927',
#  'gm19541',
#  'tmem198b',
#  'zfp276',
#  'clec4a2',
#  'cbr2',
#  'zfp882',
#  'dnah7c',
#  'hoxb5os',
#  'gm23455',
#  'halr1',
#  'gm43426',
#  'gm20646',
#  'gm16124',
#  'zfp707',
#  'e130317f20rik',
#  'gm10125',
#  '1810044d09rik',
#  'gm15337',
#  'gm884',
#  'au020206',
#  'trp53inp1',
#  '9330175m20rik',
#  'gm5914',
#  '2410003l11rik',
#  'e130311k13rik',
#  '4933406p04rik',
#  'zmiz1os1',
#  'prox1os',
#  'gm28523',
#  'ms4a4d',
#  'gm38020',
#  'gm37820',
#  'gm567',
#  'gm29012',
#  'gm43190',
#  '8430419k02rik',
#  '4933427d14rik_ensmusg00000020807',
#  'zfp653',
#  'gm15743',
#  'zfp446',
#  'acaa1b',
#  'gm12905',
#  'gm14966',
#  '2310009b15rik',
#  'zfp219',
#  'ai480526',
#  'cdiptos',
#  'gm4258',
#  'nupl2',
#  '0610031o16rik',
#  'gm26861',
#  'gm29282',
#  'zfp87',
#  'gm42477',
#  'zfp260',
#  'snord3b-ps1_ensmusg00000064400',
#  'gm9949',
#  'gm28551',
#  'gm43844',
#  'h2-oa',
#  'g630022f23rik',
#  'a730036i17rik',
#  'zfp692',
#  '4930525g20rik',
#  'gm42906',
#  'ms4a4c',
#  'dnaaf10',
#  'gm43267',
#  'dnase2a',
#  'slc5a4b',
#  'akr1c12',
#  'h2bc27',
#  'gm10785',
#  '4933404o12rik',
#  'gm14022',
#  'zfp532',
#  '9430034n14rik',
#  'gm42572',
#  'zfp658',
#  'gm12709',
#  '9230114k14rik',
#  'gm42992',
#  'a530064n14rik',
#  '9330160f10rik',
#  '1700010k24rik',
#  '2010003k11rik',
#  'gm16096',
#  'zpld2',
#  'gm43628',
#  'gm37988',
#  'c130036l24rik',
#  '4930570g19rik',
#  '4930592c13rik',
#  'gm43697',
#  '1700021n21rik',
#  'c230037l18rik',
#  '6530403h02rik',
#  '0610040j01rik',
#  'gm10373',
#  'bc031181',
#  'e430024p14rik',
#  'gm42692',
#  'gm43568',
#  'gm15404',
#  'gm37466',
#  'tescl',
#  'zfp329',
#  'potegl',
#  'tlr12',
#  '4930447c04rik',
#  'gm17090',
#  'kifc5b',
#  'gm43571',
#  'sox5os4',
#  '1700019n19rik',
#  'arhgap26_ensmusg00000036452',
#  'gm13778',
#  'gm43312',
#  'gm10138',
#  'gm43251',
#  'e230016m11rik',
#  'gm42669',
#  '2900009j06rik',
#  'ugt2b38',
#  'gm12764',
#  'gm28374',
#  'spaca7b',
#  'gm13610',
#  'gm42879',
#  '4930467d21rik',
#  'a530013c23rik',
#  'zfp606',
#  'pierce2',
#  'gm8909',
#  'd630014o11rik',
#  'sult5a1',
#  'gm11423',
#  '4930477o15rik',
#  '2810402e24rik',
#  'gm14295',
#  'a630052c17rik',
#  'pcdhb21',
#  'psma5-ps',
#  '1110046j04rik',
#  'zfp982',
#  'vmn2r60',
#  'b930094e09rik',
#  '1700109g14rik',
#  '4930426i24rik',
#  'gm31121',
#  'gm43372',
#  '1700123o20rik',
#  'gm38057',
#  'gm1604b',
#  'ai467606',
#  'sirpb1a',
#  'e330020d12rik',
#  'gm42544',
#  'h2-q6',
#  'gm43598',
#  'gm16175',
#  'mre11a',
#  'rbm3os',
#  'a930038b10rik',
#  'acaa1a',
#  'gm7628',
#  '9430015g10rik',
#  '4931403e22rik',
#  'gm7030',
#  '4930513d17rik',
#  'spin2c',
#  'c030034l19rik',
#  '0610009l18rik',
#  '1700084e18rik',
#  'gm22107',
#  'gm10053',
#  'gm42109',
#  'ttc39d',
#  'au015336',
#  'gm37255',
#  'gm45837',
#  'b130055m24rik',
#  'fh1',
#  'gm15345',
#  'gm17705',
#  'gm13684',
#  'd330023k18rik',
#  'eprs',
#  'rimoc1',
#  'd630039a03rik',
#  'gm42461',
#  'gcat_ensmusg00000006378',
#  'serf1',
#  'gm11149',
#  'c330013e15rik',
#  'gm38365',
#  'gm37407',
#  'gm10433',
#  'xntrpc',
#  'c130075a20rik',
#  '1500011b03rik',
#  'ccdc142os',
#  '9230116n13rik',
#  'gm12216',
#  'mir181a-1hg',
#  'zfp97',
#  'a930004j17rik',
#  'gm13986',
#  'zfp933',
#  'trf',
#  'nlrp9b',
#  'gm43387',
#  'gm26684',
#  'mt-ti',
#  'ifi203',
#  'gm16251',
#  'iglc3',
#  'zfp65',
#  'ptp4a1_ensmusg00000026064',
#  'zfp512b',
#  'gm43091',
#  'c730034f03rik',
#  'gm37397',
#  'zfp937',
#  'gm43205',
#  'gm42991',
#  'gm28959',
#  'zfp119b',
#  'gm14207',
#  'trim34a',
#  '2610021a01rik',
#  'zfp141',
#  '5530601h04rik',
#  'zfp275',
#  '6720427i07rik',
#  'a430005l14rik',
#  'rab26os',
#  'gm27252',
#  'morc2a',
#  'h2-eb1',
#  'gm10658',
#  '1700010i14rik',
#  'gm10032',
#  'gm10642',
#  'aldoart1',
#  'cetn4',
#  'gm16341',
#  'gm29536',
#  '4930558k02rik',
#  '5830416i19rik',
#  'au040320',
#  'gm15265',
#  'slco1a1',
#  'plekhd1os',
#  'gm42843',
#  'c630004m23rik',
#  'gm4799',
#  'gm17163',
#  'gm38343',
#  '1700084f23rik',
#  'tspyl3',
#  'e030042o20rik',
#  'gm21972',
#  'csf2rb2',
#  'gm14507',
#  'gm12981',
#  'zfp563',
#  'gm16083',
#  'rab10os',
#  'rab39',
#  'a430018g15rik',
#  'pcdhb18',
#  'gbp8',
#  'cyp2a4',
#  'scpep1os',
#  'snhg6',
#  'c87436',
#  'gm49342',
#  'gm13052',
#  'a230107n01rik',
#  'atp5j2',
#  'gm15611',
#  'aw495222',
#  'gm19461',
#  'zfp592',
#  'gm26555',
#  'gm12811',
#  'gm43593',
#  '2010001a14rik',
#  'zfp334',
#  'trp53i13',
#  '4921511c10rik',
#  'gm42748',
#  'gm37403',
#  'trim30a',
#  '4930586n03rik',
#  'gm36447',
#  'neat1',
#  '2810414n06rik',
#  'rigi',
#  'aw146154',
#  'zfp719',
#  '4930430f08rik',
#  'gm17057',
#  '1600012h06rik',
#  'gm13832',
#  'dars',
#  'klk1b5',
#  'gm43545',
#  'zfp646',
#  'zfp281',
#  '1700009j07rik',
#  'lncob1',
#  '0610030e20rik',
#  'gm32391',
#  'gpi-ps',
#  'gm28807',
#  'a430010j10rik',
#  'cenpc1',
#  'h1f0',
#  'cfap68',
#  'zfp628',
#  '1110019d14rik',
#  'mir124-2hg',
#  'gm14379',
#  'gm10767',
#  'iglc1',
#  '1810012k16rik',
#  'atp6ap1l',
#  'gm43823',
#  '2010013b24rik',
#  'gm40332',
#  'zfp976',
#  'c230071h17rik',
#  'gm37954',
#  'serpina3g',
#  'gm15638',
#  'gm28376',
#  'zfp566',
#  'gm19265',
#  'a330048o09rik',
#  'gm10036',
#  'rnu4atac',
#  '2810459m11rik',
#  '4930524o07rik',
#  'zfp142',
#  'mtrfr',
#  '2310043l19rik',
#  'gm15545',
#  'gm42783',
#  '1700023f02rik',
#  'man1a',
#  'zfp609',
#  '4632404h12rik',
#  'gm43668',
#  'gm29865',
#  'gm33050',
#  'acat3',
#  'c9orf72_ensmusg00000028300',
#  'pot1b',
#  '1700024b05rik',
#  'gm16157',
#  'gm9920',
#  'fcnaos',
#  'iqca',
#  'ctcflos',
#  'gm20753',
#  'gm20635',
#  'serpina1e',
#  'arhgap27os2',
#  'trp73',
#  'gm38211',
#  'gm37018',
#  '3110045c21rik',
#  'pard3bos3',
#  'gm11739',
#  '5430427m07rik',
#  'zfp740',
#  'mannr',
#  '9330185c12rik',
#  'kctd12b',
#  '2700029l08rik',
#  'panct2',
#  'gm37776',
#  'gm29666',
#  'b430010i23rik',
#  'ly6a',
#  'gm26912',
#  'cyp2d22',
#  'supt3',
#  'zfp322a',
#  'gm15446',
#  'gm34728',
#  'gm12367',
#  'gm37470',
#  'a230083n12rik',
#  'c130050o18rik',
#  'nxpe5',
#  'gm17344',
#  'gm28982',
#  'gm38319',
#  'gm42690',
#  'skic8',
#  'clca3a1',
#  'gm17058',
#  'ssu2',
#  'gm14023',
#  'e430018j23rik',
#  'd6wsu163e',
#  'gm28635',
#  'atpif1',
#  'atad3aos',
#  'gm5424',
#  'gm15535',
#  'gm16973',
#  'hoxaas2',
#  'abcb1b',
#  'psg16',
#  'gm12184',
#  'trp53i11',
#  'eif2s3y',
#  'gm15640',
#  '2310057m21rik',
#  'gm3086',
#  'zfp518b',
#  'il11ra1',
#  'aw822252_ensmusg00000085998',
#  'gm30003',
#  'gm14582',
#  '4933421o10rik',
#  'gm13936',
#  '1700112j16rik',
#  'gm21992',
#  '1700029n11rik',
#  'gm42595',
#  'pigyl',
#  '4930556j24rik',
#  'gm17399',
#  'zfp623',
#  'h2-t24',
#  '3100003l05rik',
#  'rsf1os2',
#  'h3f3a',
#  'cldn34c1',
#  'tnfsfm13',
#  '6430571l13rik',
#  'klk1b3',
#  'evi2',
#  'gm20743',
#  'zfp866',
#  'gm20342',
#  '4930550c14rik',
#  'gm42986',
#  '1810019d21rik',
#  'zfp451',
#  'g6pdx',
#  'zfp280b',
#  '4932438h23rik',
#  'gm13963',
#  'gm14443',
#  'snhg18',
#  '4833422c13rik',
#  'gm26779',
#  'vars',
#  'gm12121',
#  'zfp868',
#  'gm13375',
#  'gm42829',
#  'cyp4a14',
#  'gm2415',
#  'tmem29',
#  'gm13421',
#  'gm26739',
#  'gm16156',
#  'platr22',
#  '4930590j08rik',
#  '9530077c05rik',
#  'trim30d',
#  'd5ertd579e',
#  'erich2os',
#  'gm37060',
#  'gm19391',
#  '2310022a10rik',
#  '9430038i01rik',
#  'gm26944',
#  'slc35e2',
#  'gm43775',
#  'atosa',
#  'gm38248',
#  'mfap1b',
#  'gm17168',
#  'zfp948',
#  'gm26704',
#  'gm37186',
#  'rps27rt',
#  'pde11a',
#  'gm13205',
#  'gm15155',
#  '4930434b07rik',
#  '2010315b03rik',
#  'zfp800',
#  'b230216n24rik',
#  'zfp641',
#  'man2c1os',
#  'gm43794',
#  'gm15559',
#  'rps4l',
#  'zfp961',
#  'gm29051',
#  '2310015k22rik',
#  '1110002l01rik',
#  'gm16178',
#  'ces1d',
#  'zfp282',
#  'zfp131',
#  'gm15866',
#  'gm55594',
#  'gm26885',
#  'elobl',
#  'rnf113a1',
#  'mir670hg',
#  'gm6410',
#  'gm43062',
#  'emx2os',
#  'serpinb3b',
#  'utp14b',
#  'cd300c2',
#  'gm12354',
#  'gm13479',
#  'trac',
#  '5430402o13rik',
#  'd930015m05rik',
#  'gm29611',
#  'a830018l16rik',
#  '5930430l01rik',
#  'gm11476',
#  'chrna1os',
#  'gm26947',
#  'akr1c14',
#  'h2ac25',
#  'gm14410',
#  'hbb-bt',
#  'mterf1b',
#  '1700055d18rik',
#  'sox2ot',
#  'gm43809',
#  'gm2895',
#  'gm266',
#  'e330011m16rik',
#  'fbxl12os',
#  'gm16091',
#  'gm29107',
#  'gm12915',
#  '1600025m17rik',
#  'gm43275',
#  'zfp423',
#  'd730045b01rik',
#  '1110059e24rik',
#  'gm33206',
#  'gm17021',
#  '9130019p16rik',
#  'amy1',
#  'kics2',
#  'gm13110',
#  '1810017p11rik',
#  'atp5l',
#  'gm15918',
#  'mettl13',
#  'gm29571',
#  'gm3289',
#  '2210406o10rik',
#  'gm42635',
#  'gm20896',
#  'gm3081',
#  '9530052e02rik',
#  'gm13481',
#  'ms4a6b',
#  'gm527',
#  'gm12781',
#  'sgms1os1',
#  'gm37809',
#  'c130083m11rik',
#  'd930030i03rik',
#  'gm12940',
#  'au041133',
#  'gm15834',
#  'gm9958',
#  'gm37474',
#  'tomm6os',
#  'lhx1os',
#  'gm20521',
#  'zfp248',
#  'gm43423',
#  'gm15903',
#  'gm38077',
#  '4930579k19rik',
#  'gm26569',
#  'gm7964',
#  '8430432a02rik',
#  'selenok-ps1',
#  'gm17029',
#  'gm14330',
#  'zfp712',
#  'ly6c1',
#  'pcdhb20',
#  'gm42615',
#  'nlrp4e',
#  'lto1_ensmusg00000031072',
#  '2200002d01rik',
#  '1700012i11rik',
#  'gm49322',
#  '4933406c10rik',
#  'themis3',
#  'tgtp1',
#  'a330035p11rik',
#  'tprgl',
#  'gm14235',
#  'hoxb3os',
#  'gm10244',
#  '4930486i03rik',
#  'bcl2a1d',
#  'atp5g3',
#  '1110065p20rik',
#  'gm38192',
#  'gm8126',
#  'p2ry10b',
#  'gm19557',
#  'zfp688',
#  'bc050972',
#  'klrb1f',
#  'gm16838',
#  'zfp367',
#  'gm26782',
#  'abcb1a',
#  'a330070k13rik',
#  '4930458d05rik',
#  '2610306m01rik',
#  'zfp174',
#  'ndor1_ensmusg00000006471',
#  '9130024f11rik',
#  'sh2d1b1',
#  'oas1g',
#  'gm29103',
#  'runx2os1',
#  '1700119h24rik',
#  'pantr1',
#  'gm3839',
#  'gm27184',
#  'mzt2',
#  'gm42890',
#  'gm37240',
#  'mill2',
#  'siglece',
#  'zfp286',
#  'dnah7b',
#  '9630013d21rik',
#  '9430091e24rik',
#  'snhg20',
#  'cyp2b13',
#  'gm2164',
#  'gm4131',
#  'gm43566',
#  'gm20324',
#  'trp53inp2',
#  'gm37623',
#  'supt20',
#  'gm38376',
#  'zfp81',
#  'gm13427',
#  '1700120c14rik',
#  'hoxaas3',
#  'zfp354b',
#  'c130074g19rik',
#  'samd4',
#  'zfp846',
#  'bc004004',
#  'gm43300',
#  'atp5j',
#  'd130017n08rik',
#  'gm16833',
#  'gm17035',
#  'gm43258',
#  'gm11337',
#  'cyp4a10',
#  'frey1',
#  'b230217o12rik',
#  'a',
#  'ugt1a6a',
#  'gm15651',
#  'zfp459',
#  'gm12744',
#  'gm42436',
#  '5430427n15rik',
#  'gm20939',
#  'gm9968',
#  'zfp101',
#  'b230317f23rik',
#  'zfp677',
#  'igkc',
#  'zfp599',
#  '1700001o22rik',
#  'a330044p14rik',
#  'cryzl2',
#  'gm7467',
#  'gm16740',
#  '2310033p09rik',
#  'celrr',
#  'gm17023',
#  'gm15706',
#  'gm43692',
#  'zfp536',
#  '4921539e11rik',
#  'aox4',
#  'mthfsl',
#  'gm9776',
#  'zfp119a',
#  'gm43439',
#  'yae1d1',
#  '5430420f09rik',
#  'gramd3',
#  '4930579f01rik',
#  '1700022a22rik',
#  'gm15420',
#  'gm42841',
#  'gm28981',
#  'zfp456',
#  'gm20696',
#  'pot1a',
#  'gm28720',
#  '2310015a10rik',
#  '1810055g02rik',
#  ...}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 6257
# 仅在 all_genes 中存在的基因: {'cst11', 'sgcg', 'znf331', 'gcsam', 'defa6', 'magef1', 'coa1', 'dio3', 'lcn1', 'ecel1', 'cdsn', 'plpp4', 'nbpf19', 'mesp1', 'amy2b', 'pnma8c', 'otos', 'rtp2', 'znf853', 'smco2', 'abcb1', 'h3-2', 'fam153a', 'fam9a', 'or51m1', 'dhrs4l2', 'nudt15', 'pgr', 'c1orf94', 'kiaa0040', 'spata32', 'spdye1', 'chst6', 'ankrd20a4p', 'nanos2', 'vsx2', 'slc45a1', 'kiaa1614', 'ndnf', 'znf697', 'znf582', 'rnase7', 'hsh2d', 'itih6', 'itln2', 'mt-atp6', 'or5k3', 'krtap29-1', 'nanos3', 'nlrp13', 'znf432', 'ren', 'nt5c1b', 'oit3', 'prr30', 'znf678', 'onecut3', 'ebln1', 'lman1l', 'tigit', 'dpysl5', 'c1orf52', 'cd58', 'thbs4', 'nxpe4', 'adirf', 'ggtlc2', 'ripply1', 'ccl1', 'h4c12', 'ccn5', 'cacna1s', 'rpl39l', 'zfp92', 'cmtm5', 'krt38', 'mmp10', 'golga8n', 'cyp3a5', 'rtp5', 'ctag2', 'kif25', 'cdr1', 'cdk5r2', 'or6j1', 'mael', 'c3orf62', 'golga8q', 'tuba3d', 'tmco5a', 'eddm13', 'ttll6', 'mageb10', 'ctsv', 'or6c6', 'tas2r42', 'lrrc6', 'nppa', 'map3k19', 'hla-dqb1', 'aars1', 'psca', 'pcdhgc4', 'c2', 'znf689', 'or4s2', 'c16orf82', 'gfi1b', 'mx2', 'foxa1', 'sox21', 'lgals2', 'isl1', 'flg', 'apoc4-apoc2', 'znf619', 'ppbp', 'tas2r38', 'cela3b', 'akr1e2', 'fbxw12', 'or5as1', 'mov10l1', 'ypel4', 'or4c11', 'sult1a4', 'eys', 'argfx', 'pcdha8', 'clul1', 'ct83', 'c20orf202', 'znf787', 'nbpf3', 'h3c12', 'krtap6-3', 'nr5a1', 'pramef26', 'tubb8b', 'znf696', 'h1-7', 'lamb4', 'or4k15', 'gfral', 'cabp2', 'gage12g', 'glyatl3', 'pram1', 'prkacg', 'tptep2-csnk1e', 'defa1', 'dkk4', 'trim40', 'c6orf15', 'cyp3a7', 'c12orf71', 'gjd2', 'csrp3', 'nt5c3a', 'cfhr3', 'serpina12', 'hsd3b1', 'adad2', 'tubal3', 'ugt2b10', 'rem2', 'lrit1', 'il23a', 'msx2', 'gnrh2', 'sarm1', 'dmrt1', 'maneal', 'ctage15', 'tigd1', 'ubtfl1', 'cabp7', 'timm8a', 'ccdc187', 'znf208', 'cyp2b6', 'hyi', 'ptf1a', 'slco5a1', 'retnlb', 'or13c8', 'dyrk4', 'or7g2', 'gage12e', 'pudp', 'cabp4', 'barhl2', 'c1s', 'c12orf75', 'krtap1-4', 'asphd1', 'mnda', 'znf625', 'tcfl5', 'gabrq', 'hsd17b3', 'serpina1', 'c11orf45', 'trim4', 'st20', 'cplx3', 'pth2r', 'pcdh11y', 'krtap22-1', 'vcx2', 'c1orf56', 'mtif3', 'get1-sh3bgr', 'gapdhs', 'or4k13', 'tdrd9', 'znf773', 'tbc1d3b', 'h3c8', 'rps27ap5', 'slc30a3', 'rpl10l', 'or2h1', 'defb107a', 'psmb11', 'or5d16', 'sh2d6', 'lhx9', 'c20orf144', 'bves', 'rpp14', 'togaram2', 'mmp25', 'or6k2', 'csta', 'c1orf167', 'h2ac21', 'irf4', 'znf534', 'anp32d', 'nrip3', 'or5m8', 'slc22a12', 'gpr52', 'rpl24', 'tlr8', 'znf699', 'c1orf43', 'kitlg', 'krt27', 'tbc1d3l', 'or2ag1', 'fgf6', 'phf11', 'cxorf51a', 'h3c14', 'ezhip', 'h2ab1', 'or4f5', 'bean1', 'eya1', 'znf316', 'tbx5', 'ripply2', 'eno4', 'blacat1', 'spata12', 'c1orf232', 'khdc1l', 'or14a16', 'or1a2', 'gtf2ird2b', 'gbp6', 'nars1', 'lrrc30', 'fzd10', 'tmsb15a', 'sirpd', 'dars1', 'ulbp3', 'krtap9-7', 'or8b8', 'cebpe', 'c12orf57', 'rnf224', 'magec1', 'kcnh4', 'pom121c', 'or2f1', 'c1orf185', 'prss21', 'gpr142', 'atp5f1d', 'cemp1', 'ppp3r2', 'c9orf24', 'pramef1', 'krtap5-8', 'znf341', 'h2ab3', 'fetub', 'ervk3-1', 'znf593os', 'sall4', 'tectb', 'usp17l2', 'hspb2-c11orf52', 'tmem181', 'slco1b3', 'eppin-wfdc6', 'klkb1', 'c2orf74', 'c15orf61', 'ldlrad1', 'pitx1', 'c4orf50', 'or2j1', 'pcdhga9', 'or52h1', 'wfdc10b', 'nutm2b', 'klk14', 'kcne1b', 'lgals7', 'plaat4', 'znf865', 'il1f10', 'spanxn2', 'pnliprp3', 'chst5', 'krt16', 'saa2-saa4', 'lrrc37b', 'ppial4d', 'ostn', 'usp17l20', 'cd5l', 'taf11l12', 'ppef1', 'hmsd', 'prr7', 'trim31', 'cd300c', 'cyp8b1', 'adgrb1', 'potej', 'or4a5', 'asb16', 'tex47', 'krtap3-1', 'ropn1', 'prrt4', 'fam220a', 'mt1h', 'gal3st4', 'washc2c', 'ankrd20a1', 'tmem254', 'kcna7', 'plscr5', 'lmln2', 'mtmr8', 'defb113', 'znf24', 'rbp2', 'upk3bl1', 'spdye14', 'trim73', 'trpv1', 'adipoq', 'ibsp', 'g6pc1', 'znf548', 'lrcol1', 'rnf207', 'fgf4', 'dcdc1', 'cpxcr1', 'or10z1', 'muc5ac', 'lims4', 'cr1', 'prr20d', 'slc6a3', 'taf11l9', 'c5orf52', 'il5', 'atp2a1', 'frg2c', 'c19orf71', 'lrrc37a', 'adora3', 'c1orf127', 'znf597', 'krt37', 'rgl4', 'or13c2', 'prcd', 'znf10', 'grk7', 'znf680', 'c3orf85', 'znf613', 'cyp21a2', 'pmis2', 'c1orf1 ...
# 仅在 adata_genes 中存在的基因数量: 3587
# 仅在 adata_genes 中存在的基因: {'gm5577', 'zfp472', 'peg13', '6030442k20rik', 'gm15506', 'dbil5', 'h3f3aos', 'gm13840', 'rsl1', '4930509g22rik', 'lockd', '2900089d17rik', 'gm43482', 'gm43573', 'gm28641', 'gm19705', 'gm37090', 'gm44503', 'cyp2j7', 'gm14812', 'ppp2r3d', 'gm43682', 'gm20528', 'gm15409', 'xlr', '5730405o15rik', 'gm26760', 'gm2093', 'gm13889', '4931429p17rik', 'gm6793', '4931422a03rik', 'gm10575', 'gm9755', '3222401l13rik', '4930481b07rik', 'ctla2a', '1700003e16rik', 'gm4117', 'd3ertd751e', 'zfp429', 'gm9910', 'gm27224', 'gm43445', 'gm37982', 'zfp27', 'a930005h10rik', '1700048o20rik', '2900026a02rik', 'gm15489', 'gm16861', 'zfp445', 'ab124611', '9130019o22rik', 'ces2b', 'ugt2b34', '2500004c02rik', 'gm12153', 'a930006k02rik', 'gm7334', 'tha1', 'gm31243', 'mt1', 'gm43055', 'zfp420', 'b630019a10rik', 'gm16549', 'mir6236', 'gm34240', 'gm43154', 'gm12925', 'gm26666', 'rdh7', 'mapk1ip1', 'slc22a26', 'gm12798', 'zfp784', 'gm42962', '4930426d05rik', 'gm14169', '4921515e04rik', 'gm20431', 'neurl1a', 'd8ertd738e', 'bb365896', 'rsph3a', 'gm8739', '9130221h12rik', 'slfn5os', 'gm37516', 'phf11d', 'gm42772', 'gm16136', 'zfp235', 'zfp341', 'mfsd4b4', 'f8a', '2310040g07rik', '2810404m03rik', 'gm12474', 'zfp365', 'gm20498', 'gm37212', 'tmem178', 'zfp11', 'ftl1', 'zfp7', 'zfp457', 'zfp507', '6720475m21rik', 'gm37747', 'sult2a5', 'gm10644', 'zfp763', 'zfp964', 'gm26629', '9430065f17rik', 'gm15441', 'dnaaf9', 'gm16090', 'gm12963', 'gm43254', 'gm12724', '1700018l02rik', 'gm13262', '2300009a05rik', '9130230n09rik', 'gm37626', 'timd2', 'gm43413', 'ifit1bl2', 'gm37691', 'ank', 'gm14393', 'a130051j06rik', '9530046b11rik', 'gm43032', 'dleu2', 'hycc1', 'pnp2', 'zfp157', '4930589o11rik', 'gstm6', 'gm8369', 'nrg1_ensmusg00000062991', '6430548m08rik', '2310039l15rik', '6430511e19rik', 'gm37902', 'cyp2j12', 'gm16093', 'gm26627', 'tnfsf13os', 'a330093e20rik', 'gm9843', 'gm26965', '4930429f24rik', '1110035h17rik', 'gm6288', 'zim1', 'gm29050', 'notumos', 'mfsd7a', 'gm29247', 'gm38115', 'pcdhb17', 'supt6', 'gm29123', 'gm8066', 'zfp324', 'gm20644', 'gm43328', 'nat8f1', 'eeig2', 'icosl', 'gm12381', 'gm37202', 'c1ra', 'a930017k11rik', 'car3', 'ifi208', 'zfp458', 'zfp758', '2810002d19rik', 'zfp384', 'gm9828', '4921524j17rik', 'zfp619', 'gm4707', 'plet1os', 'xlr3a', 'c630028m04rik', 'mfsd4b1', 'tmem147os_ensmusg00000097320', 'gm43768', '6030443j06rik', 'kcne1l', '2810408a11rik', 'gm26901', 'pea15a', 'brd8dc', 'st8sia3os', '8430429k09rik', 'gm16170', 'entrep3', 'pcx', '2310008n11rik', 'gm11630', '2700049a03rik', 'd16ertd472e', 'gm14532', 'fam220a_ensmusg00000083012', 'pate12', 'gm12968', '2310044k18rik', 'gm45902', 'gm38012', '1110020a21rik', 'gm38250', 'gm26805', 'gm12454', 'gm15294', 'slc22a27', 'zfp971', '4930573h18rik', 'gm11767', '2610020c07rik', 'gm28403', '0610043k17rik', 'zfp583', 'zfp454', 'slfn9', 'gm26827', '4930563e22rik', 'gm525', 'gimap1os', 'srp54c', 'gm16536', 'zfp954', 'gm17473', 'gm26549', 'gm37334', 'gm28961', 'gm3604', 'zfp768', '1700057h15rik', 'gm10778', 'gm43462', 'ttll13', 'gm7694', 'cyp2j8', '4930562c15rik', 'eif1a', '4931406c07rik', 'gm23458', '2810428j06rik', 'gm12426', '4930444p10rik', 'gm37052', 'gm10687', 'b230208h11rik', '4930539j05rik', 'apobec3', 'gm8013', 'gm10649', 'gm10787', 'gm17116', '2810408i11rik', 'gm12927', 'gm19541', 'tmem198b', 'zfp276', 'clec4a2', 'cbr2', 'zfp882', 'dnah7c', 'hoxb5os', 'gm23455', 'halr1', 'gm43426', 'gm20646', 'gm16124', 'zfp707', 'e130317f20rik', 'gm10125', '1810044d09rik', 'gm15337', 'gm884', 'au020206', 'trp53inp1', '9330175m20rik', 'gm5914', '2410003l11rik', 'e130311k13rik', '4933406p04rik', 'zmiz1os1', 'prox1os', 'gm28523', 'ms4a4d', 'gm38020', 'gm37820', 'gm567', 'gm29012', 'gm43190', '8430419k02rik', '4933427d14rik_ensmusg00000020807', 'zfp653', 'gm15743', 'zfp446', 'acaa1b', 'gm12905', 'gm14966', '2310009b15rik', 'zfp219', 'ai480526', 'cdiptos', 'gm4258', 'nupl2', '0610031o16rik', 'gm26861', 'gm29282', 'zfp87', 'gm42477', 'zfp260', 'snord3b-ps1_ensmusg00000064400', 'gm9949', 'gm28551', 'gm43844 ...

# %%
import numpy as np
from scipy.sparse import csr_matrix

# Initialize a mapping from gene names in adata to their column indices
adata_gene_to_index = {gene: idx for idx, gene in enumerate(adata_genes_lower)}

# Create an array to map adata.X column indices to new_data column indices
adata_to_new_data_indices = -1 * np.ones(adata.X.shape[1], dtype=int)
for idx, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        adata_to_new_data_indices[idx] = gene_to_index[gene]



# Extract data from adata.X without converting it to a dense array
data = adata.X.data
indices = adata.X.indices
indptr = adata.X.indptr

# Map the column indices to the new indices in new_data
mapped_indices = adata_to_new_data_indices[indices]

# Filter out entries where the mapping is invalid (-1)
valid_entries = mapped_indices != -1
new_data_values = data[valid_entries]
new_data_indices = mapped_indices[valid_entries]

# Build the new indptr array for the new_data matrix
new_indptr = np.zeros(adata.X.shape[0] + 1, dtype=int)


for i in range(adata.X.shape[0]):
    row_start = indptr[i]
    row_end = indptr[i + 1]
    valid_count = np.sum(valid_entries[row_start:row_end])
    new_indptr[i + 1] = new_indptr[i] + valid_count


# Construct the new_data sparse matrix
new_data = csr_matrix(
    (new_data_values, new_data_indices, new_indptr),
    shape=(adata.X.shape[0], len(all_genes)),
    dtype=np.float32
)
new_data = new_data.toarray()

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

estim.model.eval()
with torch.no_grad():
    X_train_tensor = torch.tensor(X_train).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    train_embeddings = estim.model.encoder(X_train_tensor).detach().cpu().numpy()
    test_embeddings = estim.model.encoder(X_test_tensor).detach().cpu().numpy()
# Out:
# cuda

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.4278759103528749
# Weighted F1 Score: 0.3956782391219308
# Macro F1 Score: 0.14224940274465533
# Random Guess Accuracy: 0.2526864384339867
#                                                            precision    recall  f1-score   support
#
#                           blood vessel smooth muscle cell       0.09      0.07      0.08       483
#                                          endothelial cell       0.38      0.52      0.44      7705
#                  kidney collecting duct intercalated cell       0.12      0.03      0.05        68
#                     kidney collecting duct principal cell       0.04      0.01      0.01       376
#           kidney distal convoluted tubule epithelial cell       0.42      0.16      0.23       509
#                                      kidney granular cell       0.00      0.00      0.00        21
#                            kidney interstitial fibroblast       0.05      0.01      0.01       270
# kidney loop of Henle thick ascending limb epithelial cell       0.54      0.44      0.49      2014
#         kidney proximal convoluted tubule epithelial cell       0.51      0.61      0.55      8716
#                                                 leukocyte       0.21      0.08      0.12      3956
#                                                macrophage       0.04      0.01      0.01       552
#                              macula densa epithelial cell       0.00      0.00      0.00        19
#                                            mesangial cell       0.00      0.00      0.00        31
#                                                  podocyte       0.00      0.00      0.00       133
#
#                                                  accuracy                           0.43     24853
#                                                 macro avg       0.17      0.14      0.14     24853
#                                              weighted avg       0.39      0.43      0.40     24853
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "slide_seq_mouse_kidney_GP_mask_zero_shot_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicor_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicor_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['slide_seq_mouse_kidney'],
    'method': [re.search(r'kidney_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micor_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# macro_f1	weighted_f1	micor_f1
# 0.142	0.396	0.428
