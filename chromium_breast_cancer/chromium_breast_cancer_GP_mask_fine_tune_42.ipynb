# %%
import scanpy as sc
data_dir = '../../dataset/annotated_Chromium_FFPE_Human_Breast_Cancer_Chromium_FFPE_Human_Breast_Cancer_count_sample_filtered_feature_bc_matrix.h5ad'
adata = sc.read_h5ad(data_dir)
print(adata.X)
sc.pp.normalize_total(adata,target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 71173076 stored elements and shape (27460, 18082)>
#   Coords	Values
#   (0, 13)	1.0
#   (0, 40)	1.0
#   (0, 48)	1.0
#   (0, 108)	1.0
#   (0, 114)	1.0
#   (0, 146)	1.0
#   (0, 171)	1.0
#   (0, 225)	1.0
#   (0, 235)	3.0
#   (0, 261)	1.0
#   (0, 262)	3.0
#   (0, 263)	2.0
#   (0, 276)	1.0
#   (0, 280)	5.0
#   (0, 366)	1.0
#   (0, 369)	1.0
#   (0, 378)	2.0
#   (0, 391)	1.0
#   (0, 402)	1.0
#   (0, 438)	1.0
#   (0, 439)	1.0
#   (0, 452)	1.0
#   (0, 471)	1.0
#   (0, 478)	1.0
#   (0, 516)	1.0
#   :	:
#   (27459, 17744)	2.0
#   (27459, 17747)	2.0
#   (27459, 17764)	1.0
#   (27459, 17769)	1.0
#   (27459, 17780)	1.0
#   (27459, 17812)	1.0
#   (27459, 17820)	1.0
#   (27459, 17843)	1.0
#   (27459, 17867)	2.0
#   (27459, 17899)	1.0
#   (27459, 17901)	1.0
#   (27459, 17911)	1.0
#   (27459, 17915)	2.0
#   (27459, 17919)	1.0
#   (27459, 17960)	1.0
#   (27459, 17961)	1.0
#   (27459, 17964)	1.0
#   (27459, 17969)	1.0
#   (27459, 17971)	1.0
#   (27459, 18008)	1.0
#   (27459, 18027)	2.0
#   (27459, 18030)	1.0
#   (27459, 18035)	2.0
#   (27459, 18077)	3.0
#   (27459, 18080)	1.0

# %%
import scanpy as sc
import torch
from torch import nn
import lightning.pytorch as pl
from self_supervision.models.lightning_modules.cellnet_autoencoder import MLPAutoEncoder
from self_supervision.estimator.cellnet import EstimatorAutoEncoder

# 设置你的 .ckpt 文件路径
ckpt_path = "../../sc_pretrained/Pretrained Models/GPMask.ckpt"

# 模型参数
units_encoder = [512, 512, 256, 256, 64]
units_decoder = [256, 256, 512, 512]

# 初始化 EstimatorAutoEncoder 实例
estim = EstimatorAutoEncoder(data_path=None)  # 如果没有实际数据路径，可以设置为None

# 加载预训练模型
estim.model = MLPAutoEncoder.load_from_checkpoint(
    ckpt_path,
    gene_dim=19331,  # 根据你的数据调整
    batch_size=128,  # 根据你的需要调整
    units_encoder=units_encoder, 
    units_decoder=units_decoder,
    masking_strategy="random",  # 假设模型使用了随机掩码
    masking_rate=0.5,  # 根据需要调整
)

# 使用 GPU 进行评估（如果可用）
estim.trainer = pl.Trainer(accelerator="gpu", devices=1 if torch.cuda.is_available() else None)
estim.model
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/tf.py:52: UserWarning: Tensorflow dtype mappings did not load successfully due to an error: No module named 'tensorflow'
#   warn(f"Tensorflow dtype mappings did not load successfully due to an error: {exc.msg}")
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# MLPAutoEncoder(
#   (train_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=train_
#   )
#   (val_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=val_
#   )
#   (test_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=test_
#   )
#   (encoder): MLP(
#     (0): Linear(in_features=19331, out_features=512, bias=True)
#     (1): SELU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SELU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SELU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): SELU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=True)
#   )
#   (decoder): Sequential(
#     (0): MLP(
#       (0): Linear(in_features=64, out_features=256, bias=True)
#       (1): SELU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SELU()
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=256, out_features=512, bias=True)
#       (7): SELU()
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SELU()
#       (11): Dropout(p=0.1, inplace=False)
#       (12): Linear(in_features=512, out_features=19331, bias=True)
#     )
#     (1): Sigmoid()
#   )
# )

# %%
# 添加分类层 (FC)
n_classes = len(adata.obs['cell_type'].unique())
estim.model.fc = nn.Linear(units_encoder[-1], n_classes)
n_classes
# Out:
# 19

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# SAMD11      SAMD11
# NOC2L        NOC2L
# KLHL17      KLHL17
# PLEKHN1    PLEKHN1
# PERM1        PERM1
#             ...
# MT-ND4L    MT-ND4L
# MT-ND4      MT-ND4
# MT-ND5      MT-ND5
# MT-ND6      MT-ND6
# MT-CYB      MT-CYB
# Name: gene_name, Length: 18082, dtype: object

# %%
import numpy as np
# 初始化一个新的数据矩阵，形状为 (adata.X.shape[0], len(all_genes))，填充为零
new_data = np.zeros((adata.X.shape[0], len(all_genes)), dtype=np.float32)

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# SAMD11      SAMD11
# NOC2L        NOC2L
# KLHL17      KLHL17
# PLEKHN1    PLEKHN1
# PERM1        PERM1
#             ...
# MT-ND4L    MT-ND4L
# MT-ND4      MT-ND4
# MT-ND5      MT-ND5
# MT-ND6      MT-ND6
# MT-CYB      MT-CYB
# Name: gene_name, Length: 18082, dtype: object

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 17768
# 匹配的基因列表: {'serpine2', 'rhoxf1', 'slc2a5', 'klf4', 'arhgef10', 'capn12', 'micu2', 'extl3', 'klrd1', 'gypc', 'asic5', 'atp5f1e', 'lurap1', 'lsr', 'mcf2l', 'qsox2', 'igsf9', 'hsdl1', 'brd2', 'adgrf1', 'atp6v1c1', 'stag2', 'lhcgr', 'lrpprc', 'lce1a', 'zfhx2', 'cks1b', 'rtbdn', 'rbbp9', 'prrc1', 'hephl1', 'rcan1', 'obscn', 'adra1b', 'mcat', 'zfyve28', 'actl10', 'zc3h10', 'muc7', 'usp9x', 'traf3ip3', 'diaph1', 'arl2bp', 'fbxo21', 'krba2', 'rasal3', 'rbm5', 'cryl1', 'ldlrad1', 'kctd19', 'atp5f1d', 'snn', 'cyb5r3', 'cmc1', 'plxnc1', 'deup1', 'exosc6', 'cd164l2', 'otud1', 'tgfb3', 'thnsl1', 'pcdh15', 'aqp9', 'adora1', 'alkbh5', 'lrif1', 'tcf25', 'pcdhga9', 'brd3os', 'znf717', 'pappa2', 'folr3', 'gla', 'krtap21-1', 'jun', 'synpr', 'lrch4', 'paep', 'alx1', 'bmerb1', 'rnaseh2a', 'tigd4', 'setmar', 'cidec', 'c4orf33', 'pde4d', 'slc9a3r1', 'cdh18', 'tsc22d2', 'ndc1', 'eif3i', 'or2b2', 'ppp3cc', 'fam180b', 'znf45', 'slc22a13', 'prdm10', 'mc3r', 'zscan9', 'tmem40', 'c2cd5', 'glb1l3', 'gpbp1', 'hoxd1', 'cpne5', 'c6orf118', 'eid2b', 'rd3', 'usp51', 'edn2', 'btbd10', 'b3gnt4', 'mocs3', 'fzd3', 'dhx32', 'fancd2os', 'efr3b', 'plac8', 'ank3', 'lrrc55', 'wiz', 'abhd16b', 'cdh4', 'gk5', 'las1l', 'pomt2', 'linc02218', 'colec11', 'fam124a', 'fbn3', 'mast1', 'calr', 'htra4', 'yif1b', 'fam118a', 'ctnna1', 'hoga1', 'akr1c2', 'ankrd35', 'tex26', 'rab4b', 'c8b', 'il18rap', 'trpv1', 'sccpdh', 'ccdc116', 'ehbp1', 'dchs2', 'mybl1', 'taf1c', 'a2m', 'cdk9', 'znf41', 'sumf2', 'tmem184b', 'or4a5', 'mmp17', 'rcor1', 'spata5l1', 'ctdspl', 'ly6g6f', 'il1r2', 'panx2', 'lrrc66', 'aoah', 'akr1c4', 'usp6nl', 'c1qtnf4', 'gtpbp2', 'emp3', 'stn1', 'heg1', 'tceal6', 'evl', 'fbh1', 'c20orf141', 'lmf2', 'srl', 'cdh3', 'rbfox2', 'ccl3l1', 'syn3', 'usp17l1', 'recql4', 'rhno1', 'ufm1', 'ubl7', 'pramef18', 'fjx1', 'syncrip', 'c6orf226', 'anxa8', 'galntl6', 'sh3bgrl3', 'scygr8', 'spaar', 'rec114', 'rhbdl3', 'fcar', 'nmt2', 'pygm', 'gas2l3', 'mrm3', 'znf772', 'enpp5', 'ccdc190', 'galnt10', 'septin6', 'cacna1g', 'dact3', 'pcdhb16', 'zbbx', 'rnf17', 'hdhd3', 'phyhipl', 'cdx2', 'itgad', 'sox9', 'olfml1', 'ntf3', 'vamp2', 'cd1c', 'hyal3', 'or56a5', 'rbm10', 'gng12', 'tbc1d30', 'trabd2b', 'onecut2', 'rft1', 'pla2g2d', 'tex43', 'fer1l5', 'dusp21', 'dnajc10', 'yes1', 'rdh13', 'tm4sf19', 'lrrc2', 'birc6', 'adam30', 'tsn', 'igfals', 'krt86', 'slc6a7', 'naaladl1', 'mphosph8', 'ypel3', 'mgat4b', 'nthl1', 'cyb5d1', 'klhl25', 'znf606', 'kiaa1671', 'or10g3', 'spata46', 'sh2b2', 'ldhb', 'hyou1', 'larp4', 'znf136', 'timp2', 'samd10', 'atp6v1f', 'hjv', 'gbp1', 'tmem126a', 'elovl7', 'osbpl5', 'znf8', 'znf282', 'fam71f1', 'znf181', 'klc3', 'dkc1', 'tmem252', 'sidt1', 'numa1', 'c11orf1', 'dgat2', 'fam71a', 'c12orf57', 'mageh1', 'spef1', 'znf470', 'spcs3', 'fbll1', 'stk32a', 'ebi3', 'lce1b', 'dhrs1', 'iah1', 'gipc2', 'ttc36', 'igsf11', 'exosc3', 'ttpa', 'epyc', 'czib', 'tasp1', 'tbc1d32', 'cdan1', 'or10h3', 'pak3', 'slc22a3', 'mtap', 'fbxo47', 'zc3h12d', 'or52e5', 'brd4', 'suclg2', 'aaas', 'tmem107', 'grp', 'gzmm', 'mknk1', 'nfkbie', 'tnfsf18', 'c2orf49', 'egfl6', 'rrp9', 'sptan1', 'egln3', 'gnat2', 'ppp2r5a', 'tada3', 'pcbd2', 'kif13b', 'acaa1', 'foxo3', 'hsd11b2', 'tex51', 'npb', 'spsb4', 'arhgef15', 'pot1', 'or4k14', 'plac1', 'hexim1', 'magi1', 'alas2', 'btn2a1', 'clstn3', 'ccnb1ip1', 'pir', 'pds5b', 'parp9', 'mtg1', 'ckm', 'bmi1', 'rab15', 'casq2', 'palmd', 'thoc6', 'mmp28', 'klrf1', 'trpv4', 'pklr', 'cxcl8', 'tmem45b', 'csrp1', 'rhou', 'capzb', 'rpgrip1', 'unc13c', 'palm3', 'ttc32', 'sesn2', 'ly6g6e', 'anxa3', 'nlrp4', 'hs3st6', 'cep72', 'znf143', 'kif18a', 'vsig1', 'xg', 'stxbp5l', 'cenpk', 'asb10', 'chuk', 'cox5b', 'znf319', 'ube2e2', 'znf662', 'gprin1', 'septin2', 'chat', 'ints2', 'znf330', 'pmm1', 'rbm3', 'cabcoco1', 'serpinf1', 'pfkp', 'rc3h1', 'inpp5d', 'dlec1', 'rflnb', 'nfatc2ip', 'dis3', 'yy2', 'csmd1', 'lcn10', 'bicdl1', 'tmem183a', 'tcerg1l', 'kcnk2', 'dph7', 'mt3', 'tigar', 'atp2a2', 'nanos1', 'caps2', 'nup107', 'kntc1', 'foxf1', 'slfnl1', 'ccdc187', 'cdc25b', 'rnd3', 'aldh3b1', 'rcl1', ...
# {'aars',
#  'ac004593.3',
#  'ac005551.1',
#  'ac007244.1',
#  'ac007906.2',
#  'ac008397.1',
#  'ac008687.4',
#  'ac010255.3',
#  'ac010325.1',
#  'ac011005.1',
#  'ac011195.2',
#  'ac013470.2',
#  'ac015871.1',
#  'ac021072.1',
#  'ac021097.2',
#  'ac025283.2',
#  'ac025287.4',
#  'ac067752.1',
#  'ac072022.2',
#  'ac073111.4',
#  'ac087498.1',
#  'ac090360.1',
#  'ac091057.6',
#  'ac092835.1',
#  'ac093323.1',
#  'ac099489.1',
#  'ac104389.5',
#  'ac106774.4',
#  'ac113348.1',
#  'ac115220.1',
#  'ac118549.1',
#  'ac119396.1',
#  'ac132217.2',
#  'ac134684.8',
#  'ac135068.1',
#  'ac138647.1',
#  'ac187653.1',
#  'ac233723.1',
#  'ac236972.4',
#  'acpp',
#  'adprhl2',
#  'adss',
#  'adssl1',
#  'al032819.3',
#  'al109810.2',
#  'al121578.2',
#  'al135905.2',
#  'al160269.1',
#  'al162231.1',
#  'al162596.1',
#  'al353572.3',
#  'al354761.1',
#  'al391650.1',
#  'al445238.1',
#  'al451007.3',
#  'al590560.2',
#  'al603764.2',
#  'al772284.2',
#  'al845331.2',
#  'alg1l',
#  'ap000552.4',
#  'ap002495.1',
#  'arih2os',
#  'armc4',
#  'arse',
#  'atp5md',
#  'atp5mpl',
#  'atp6ap1l',
#  'b3gnt10',
#  'bhmg1',
#  'bx255925.3',
#  'bx276092.9',
#  'c10orf142',
#  'c10orf55',
#  'c11orf40',
#  'c11orf74',
#  'c11orf88',
#  'c12orf10',
#  'c12orf49',
#  'c12orf74',
#  'c12orf81',
#  'c14orf177',
#  'c15orf41',
#  'c16orf58',
#  'c17orf53',
#  'c19orf48',
#  'c19orf57',
#  'c1orf61',
#  'c2orf83',
#  'c2orf91',
#  'c3orf67',
#  'c5orf30',
#  'c5orf60',
#  'c5orf67',
#  'c6orf201',
#  'c6orf223',
#  'c7orf77',
#  'c9orf129',
#  'c9orf92',
#  'card16',
#  'card17',
#  'cars',
#  'casc1',
#  'casc4',
#  'castor3',
#  'ccdc114',
#  'ccdc140',
#  'ccdc151',
#  'ccdc155',
#  'ccdc36',
#  'ccdc39',
#  'ccdc84',
#  'cd3eap',
#  'cenpbd1',
#  'cllu1os',
#  'cntd2',
#  'ct62',
#  'cxorf21',
#  'cxorf40a',
#  'cxorf56',
#  'cyb561d2',
#  'dars',
#  'dec1',
#  'defb133',
#  'dirc1',
#  'dock8-as1',
#  'dupd1',
#  'dusp27',
#  'elfn2',
#  'elmsan1',
#  'eloa3',
#  'eprs',
#  'fam122a',
#  'fam122b',
#  'fam122c',
#  'fam169b',
#  'fam192a',
#  'fam218a',
#  'fam30a',
#  'fam49a',
#  'fam49b',
#  'fam92b',
#  'fgfr1op',
#  'fopnl',
#  'fp565260.1',
#  'g6pc',
#  'gars',
#  'gcsaml-as1',
#  'gdf5os',
#  'glra4',
#  'golga8m',
#  'grasp',
#  'h1f0',
#  'h1fnt',
#  'h1foo',
#  'h1fx',
#  'h2afj',
#  'h2afx',
#  'h2afy',
#  'h2afy2',
#  'h2afz',
#  'h2bfm',
#  'h2bfwt',
#  'h3.y',
#  'h3f3a',
#  'h3f3b',
#  'h3f3c',
#  'hars',
#  'hhla3',
#  'hist1h1a',
#  'hist1h1b',
#  'hist1h1c',
#  'hist1h1d',
#  'hist1h1e',
#  'hist1h2aa',
#  'hist1h2ac',
#  'hist1h2ae',
#  'hist1h2ag',
#  'hist1h2ai',
#  'hist1h2ak',
#  'hist1h2ba',
#  'hist1h2bb',
#  'hist1h2bg',
#  'hist1h2bh',
#  'hist1h2bn',
#  'hist1h3e',
#  'hist1h3g',
#  'hist1h3h',
#  'hist1h4b',
#  'hist1h4c',
#  'hist1h4e',
#  'hist1h4g',
#  'hist1h4i',
#  'hist1h4j',
#  'hist2h2be',
#  'hist3h2a',
#  'hist3h2bb',
#  'hist3h3',
#  'hist4h4',
#  'hypm',
#  'iars',
#  'ick',
#  'igha1',
#  'igha2',
#  'ighd',
#  'ighe',
#  'ighg1',
#  'ighg3',
#  'ighm',
#  'igkc',
#  'iglc1',
#  'iglc7',
#  'impad1',
#  'kars',
#  'kiaa0355',
#  'kiaa0556',
#  'kiaa1211',
#  'kiaa1211l',
#  'kiaa1257',
#  'kiaa1324',
#  'kiaa1324l',
#  'kif1bp',
#  'lars',
#  'linc02693',
#  'linc02694',
#  'lor',
#  'lrmp',
#  'lrp5l',
#  'lrrc29',
#  'maats1',
#  'marc1',
#  'marc2',
#  'march1',
#  'march10',
#  'march11',
#  'march2',
#  'march3',
#  'march4',
#  'march5',
#  'march6',
#  'march7',
#  'march8',
#  'march9',
#  'mars',
#  'mir1915hg',
#  'mrvi1',
#  'mycnos',
#  'nars',
#  'nxf5',
#  'or5r1',
#  'palm2-akap2',
#  'pano1',
#  'pde11a',
#  'pih1d3',
#  'pinx1',
#  'ppp5d1',
#  'prky',
#  'qars',
#  'rars',
#  'rgs5',
#  'sars',
#  'sfta3',
#  'siglec5',
#  'slc26a10',
#  'slc66a1l',
#  'slfn12l',
#  'snhg32',
#  'spata13',
#  'spata8',
#  'spert',
#  'sspo',
#  'st5',
#  'tars',
#  'tarsl2',
#  'tbce',
#  'tcte3',
#  'tctex1d1',
#  'tctex1d2',
#  'tctex1d4',
#  'terc',
#  'tmem155',
#  'tmem173',
#  'tmem189',
#  'tmem246',
#  'tmem8a',
#  'tmem99',
#  'tmsb15b',
#  'trac',
#  'trbc1',
#  'trbc2',
#  'trdc',
#  'trgc1',
#  'trgc2',
#  'trgjp1',
#  'trgjp2',
#  'trim16l',
#  'tsta3',
#  'ttc25',
#  'twistnb',
#  'vars',
#  'wars',
#  'wdr34',
#  'wdr60',
#  'wdr63',
#  'wdr66',
#  'wdr78',
#  'wdyhv1',
#  'yars',
#  'z82206.1',
#  'znf883',
#  'znrd1'}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 1563
# 仅在 all_genes 中存在的基因: {'rpl27', 'mrpl18', 'slco1b3-slco1b7', 'gars1', 'fam236b', 'gage12d', 'or1r1p', 'ssb', 'washc2a', 'gage12g', 'ankrd20a2p', 'fam72b', 'lgals9b', 'gage12c', 'mrpl35', 'supt20hl1', 'il17re', 'mrps18b', 'dynlt5', 'epor', 'pwp2', 'hla-doa', 'serf1a', 'rasa4', 'golga8h', 'usp17l26', 'fam243b', 'h2bc17', 'tbc1d3d', 'wars1', 'bpnt2', 'ctag1b', 'uts2r', 'mag', 'tas2r46', 'rps3a', 'znf814', 'h3-3b', 'eml3', 'nbpf4', 'cyp2c19', 'mzt2a', 'eef1e1-bloc1s5', 'cers1', 'mt-atp8', 'taf11l2', 'pgam4', 'krtap5-11', 'f8a2', 'gal3st2', 'h2bc5', 'mrpl40', 'h2bc18', 'trappc2b', 'spanxc', 'golga8f', 'fam86b2', 'naca', 'ncf1', 'znf670-znf695', 'rps6ka5', 'cfc1', 'cenpvl1', 'or4m2', 'mtrnr2l3', 'defb130b', 'nomo3', 'abcc6', 'ntn5', 'c20orf203', 'hypk', 'cdy1b', 'pabpn1', 'ccdc144a', 'hla-a', 'palm2akap2', 'zfand6', 'mrpl23', 'ssu72p4', 'cngb1', 'upk3bl1', 'odad4', 'mrps18a', 'tbc1d26', 'taf11l7', 'cibar2', 'tpt1', 'bcas1', 'cxorf51b', 'ccdc169-sohlh2', 'krtap10-4', 'eprs1', 'agap6', 'fsbp', 'prr20b', 'ipo7', 'agap4', 'or4f5', 'tspy4', 'eif3cl', 'trim6-trim34', 'ct47a6', 'u2af1l5', 'washc1', 'h2ac4', 'h3-2', 'ppp1r2b', 'zzz3', 'mrpl46', 'h2bc13', 'pramef26', 'usp17l21', 'rpl9', 'hnrnpcl4', 'rps6kl1', 'usp17l24', 'rps24', 'opn1mw', 'eif3k', 'mrps35', 'h4-16', 'gpr75', 'h3c6', 'aknad1', 'gucy2d', 'c5orf63', 'vcy1b', 'trim64', 'dpy19l2', 'h2bc12', 'fut2', 'cenpvl2', 'tuba8', 'golga6l1', 'marchf3', 'prr20a', 'usp17l28', 'h2ac14', 'cnpy1', 'defb103a', 'ston1-gtf2a1l', 'rpl13', 'ptp4a1', 'rps25', 'mrps18c', 'trim49', 'h4c14', 'hes3', 'pkhd1l1', 'rps7', 'npipb8', 'mrpl45', 'tpsab1', 'znf528', 'kir3dl2', 'tamalin', 'smim11b', 'impdh1', 'rps12', 'notch2nla', 'h4c6', 'bola2b', 'h2be1', 'mbd3l3', 'or4f17', 'ifna10', 'h1-7', 'ube2s', 'tmed7-ticam2', 'rpl26', 'znf593os', 'cbwd5', 'h2ac17', 'h2ac18', 'gpr52', 'mrpl49', 'rps23', 'hla-dqa1', 'ppial4e', 'znf749', 'mrpl11', 'hla-dob', 'apoc4-apoc2', 'ifnl3', 'or2t3', 'mrpl36', 'rps27a', 'rpl7a', 'itgae', 'gstm4', 'mbd3l4', 'adss2', 'gtf2a1l', 'c21orf62', 'lpa', 'cryaa2', 'ptprcap', 'notch4', 'h2ax', 'prdm12', 'kifbp', 'znf443', 'mettl2b', 'arl2-snx15', 'tas2r19', 'fam90a16p', 'hspb2-c11orf52', 'nphp3-acad11', 'cxorf51a', 'fam47e-stbd1', 'h4c3', 'cgb2', 'ankrd23', 'atp5mk', 'isy1-rab43', 'aqp12b', 'marchf8', 'fam90a14p', 'ct47a2', 'ankrd20a4p', 'u2af1', 'ggta1', 'amy2b', 'tnfsf12-tnfsf13', 'rpl12', 'or5h1', 'casp1', 'h2ab3', 'h3c13', 'rps16', 'h1-10', 'pde4dip', 'h2ac20', 'nanog', 'marchf1', 'ifna17', 'urgcp-mrps24', 'h2ac19', 'adck1', 'ano7', 'or5p3', 'cct5', 'ssu72p3', 'pcnp', 'rpl27a', 'c16orf82', 'spata31a3', 'macroh2a2', 'cgb7', 'tdgf1', 'ppan-p2ry11', 'trim74', 'rps6kb2', 'scoc', 'bpy2b', 'fam90a8p', 'golga8q', 'ckmt1b', 'krtap9-2', 'usp17l27', 'mrpl32', 'rpl36a', 'smim39', 'sdhd', 'spdye2b', 'unkl', 'or2a42', 'setsip', 'tp53tg3', 'znf468', 'rps6ka3', 'ct47a9', 'fbxl14', 'pramef25', 'trim73', 'rpl10l', 'fpgt-tnni3k', 'mtrnr2l8', 'phf7', 'h1-8', 'rgs9', 'vcx3b', 'mrps34', 'ct47a5', 'h3-3a', 'fam25c', 'nsrp1', 'clp1', 'rpl21', 'mtrnr2l4', 'rps10-nudt3', 'ino80b-wbp1', 'tas2r41', 'krtap2-2', 'rusf1', 'h1-0', 'hoatz', 'ptcd3', 'mrpl16', 'cfap20dc', 'cracd', 'hla-dpa1', 'cyria', 'hmgn2', 'qars1', 'h2bc9', 'specc1l-adora2a', 'cntf', 'ppfia1', 'styxl2', 'h3y2', 'tcaf2c', 'rpl29', 'cdy2b', 'mrps5', 'defb104a', 'dnai3', 'potei', 'or2t29', 'fcn1', 'foxd4l1', 'smim42', 'nbpf14', 'kir2dl3', 'cox5a', 'nme1-nme2', 'ct45a6', 'pcdhgb1', 'iqcf3', 'gpr42', 'plglb1', 'or4f16', 'abcc10', 'iars1', 'cilk1', 'hnrnph1', 'spdye13', 'prr20e', 'usp17l19', 'ankrd36b', 'ssx4', 'ovca2', 'acp3', 'rsc1a1', 'cenatac', 'fkbp4', 'tgif2-rab5if', 'rpl39l', 'ylpm1', 'prss50', 'tp53tg3e', 'rps6kb1', 'znf701', 'rpl8', 'pga4', 'rpl19', 'krt18', 'atp5mj', 'pdxdc1', 'mrpl24', 'h4c2', 'lce1f', 'usp17l11', 'mrpl57', 'saa2-saa4', 'lrtm1', 'abhd17a', 'magea9', 'lypla2', 'foxd4l4', 'rps13', 'mrpl58', 'gpr82', 'spdye16', 'fmc1-luc7l2', 'morn1', 'cd8b', 'trim49d2', 'znf487', 'sftpa2', 'gtf2ird2', 'notch2nlb', 'gage13', 'rhoxf2', 'golga6c', 'h2bc ...
# 仅在 adata_genes 中存在的基因数量: 311
# 仅在 adata_genes 中存在的基因: {'hist1h3e', 'c9orf129', 'h1foo', 'hist1h4e', 'tmsb15b', 'hist1h2ag', 'c17orf53', 'trbc2', 'al772284.2', 'ac233723.1', 'trgjp2', 'kiaa1324l', 'mars', 'ighd', 'sfta3', 'ccdc84', 'h2afy2', 'tars', 'ac091057.6', 'hist1h4b', 'tmem189', 'hhla3', 'ac104389.5', 'ccdc155', 'tcte3', 'h2afy', 'al391650.1', 'castor3', 'cd3eap', 'trgc2', 'ighg3', 'dirc1', 'aars', 'card16', 'hist1h4j', 'c10orf142', 'al353572.3', 'h3f3a', 'h3f3c', 'hist1h2aa', 'acpp', 'qars', 'hist1h2ai', 'lrp5l', 'tctex1d2', 'fp565260.1', 'ac092835.1', 'cxorf21', 'ac011195.2', 'card17', 'hist1h3h', 'ac013470.2', 'palm2-akap2', 'st5', 'ac087498.1', 'slfn12l', 'wdr66', 'tarsl2', 'kiaa0355', 'marc1', 'znrd1', 'c12orf81', 'eloa3', 'hist1h1d', 'ccdc140', 'sspo', 'rars', 'tsta3', 'tctex1d4', 'arse', 'linc02693', 'prky', 'fam169b', 'wars', 'al445238.1', 'ac010255.3', 'pde11a', 'tmem155', 'tmem173', 'znf883', 'march10', 'c11orf74', 'ap002495.1', 'hist3h3', 'ac067752.1', 'rgs5', 'cyb561d2', 'hypm', 'ac007244.1', 'dock8-as1', 'c14orf177', 'h2afz', 'al160269.1', 'bx276092.9', 'hist4h4', 'lrrc29', 'hist1h4g', 'al590560.2', 'al451007.3', 'fam92b', 'hist1h2bn', 'ac025287.4', 'wdr63', 'adprhl2', 'trbc1', 'arih2os', 'eprs', 'armc4', 'hist2h2be', 'fam122a', 'march11', 'nars', 'h1f0', 'al032819.3', 'hist3h2bb', 'hist1h1b', 'ac005551.1', 'march1', 'ct62', 'vars', 'c5orf30', 'al135905.2', 'ac008397.1', 'ac073111.4', 'terc', 'h1fx', 'grasp', 'nxf5', 'ac008687.4', 'bx255925.3', 'hist1h1e', 'defb133', 'ac132217.2', 'cars', 'pih1d3', 'kif1bp', 'fam192a', 'ccdc114', 'mir1915hg', 'c2orf83', 'or5r1', 'ac072022.2', 'c5orf60', 'hist1h3g', 'c16orf58', 'lrmp', 'spata8', 'trgc1', 'alg1l', 'dec1', 'hist1h2ac', 'kars', 'c15orf41', 'wdr60', 'casc1', 'ac134684.8', 'march5', 'ac138647.1', 'dupd1', 'igha2', 'snhg32', 'hist1h2bg', 'fgfr1op', 'tmem99', 'ac010325.1', 'c12orf49', 'elfn2', 'ac021097.2', 'marc2', 'h2bfm', 'al603764.2', 'sars', 'atp6ap1l', 'march2', 'h1fnt', 'yars', 'golga8m', 'h2bfwt', 'cntd2', 'c12orf10', 'h2afx', 'iglc1', 'dars', 'ac187653.1', 'slc26a10', 'hist1h2ae', 'al845331.2', 'c1orf61', 'ac135068.1', 'igha1', 'mycnos', 'al354761.1', 'lars', 'adss', 'ppp5d1', 'fam49a', 'h3f3b', 'atp5mpl', 'hars', 'ac090360.1', 'al162596.1', 'c12orf74', 'hist1h2bb', 'kiaa1211l', 'g6pc', 'c2orf91', 'h3.y', 'ac004593.3', 'gdf5os', 'iglc7', 'fam122b', 'hist1h1c', 'tbce', 'gcsaml-as1', 'ighm', 'c3orf67', 'ap000552.4', 'ac021072.1', 'ccdc151', 'ac115220.1', 'march7', 'c19orf48', 'wdyhv1', 'march4', 'ac236972.4', 'trgjp1', 'c6orf223', 'al162231.1', 'wdr78', 'igkc', 'cllu1os', 'ttc25', 'march8', 'hist3h2a', 'ighe', 'kiaa1257', 'gars', 'ac025283.2', 'c10orf55', 'ac007906.2', 'hist1h1a', 'spata13', 'trim16l', 'adssl1', 'wdr34', 'al121578.2', 'glra4', 'ighg1', 'ac106774.4', 'ac113348.1', 'linc02694', 'c19orf57', 'pano1', 'cenpbd1', 'b3gnt10', 'c11orf40', 'pinx1', 'tctex1d1', 'hist1h2ak', 'ac011005.1', 'kiaa1211', 'impad1', 'hist1h4c', 'c6orf201', 'kiaa1324', 'kiaa0556', 'ac015871.1', 'al109810.2', 'h2afj', 'c11orf88', 'ccdc39', 'fam122c', 'fopnl', 'march3', 'twistnb', 'casc4', 'spert', 'hist1h4i', 'maats1', 'trac', 'fam218a', 'tmem246', 'ick', 'tmem8a', 'march9', 'dusp27', 'trdc', 'march6', 'ac093323.1', 'siglec5', 'hist1h2ba', 'cxorf56', 'atp5md', 'ac118549.1', 'mrvi1', 'c7orf77', 'ac099489.1', 'z82206.1', 'elmsan1', 'fam30a', 'ccdc36', 'fam49b', 'c9orf92', 'c5orf67', 'cxorf40a', 'hist1h2bh', 'bhmg1', 'lor', 'iars', 'ac119396.1', 'slc66a1l'}

# %%
dense_adata_X = adata.X.toarray()
for i, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        new_data[:, gene_to_index[gene]] = dense_adata_X[:, i]
    else:
        print(f'Gene {gene} not found in all_genes list')
# Out:
# Gene al391650.1 not found in all_genes list
# Gene yars not found in all_genes list
# Gene adprhl2 not found in all_genes list
# Gene tctex1d4 not found in all_genes list
# Gene tctex1d1 not found in all_genes list
# Gene wdr78 not found in all_genes list
# Gene hhla3 not found in all_genes list
# Gene ac118549.1 not found in all_genes list
# Gene wdr63 not found in all_genes list
# Gene kiaa1324 not found in all_genes list
# Gene sars not found in all_genes list
# Gene hist2h2be not found in all_genes list
# Gene al162596.1 not found in all_genes list
# Gene lor not found in all_genes list
# Gene c1orf61 not found in all_genes list
# Gene al590560.2 not found in all_genes list
# Gene rgs5 not found in all_genes list
# Gene dusp27 not found in all_genes list
# Gene eprs not found in all_genes list
# Gene marc2 not found in all_genes list
# Gene marc1 not found in all_genes list
# Gene h3f3a not found in all_genes list
# Gene hist3h3 not found in all_genes list
# Gene hist3h2a not found in all_genes list
# Gene hist3h2bb not found in all_genes list
# Gene al109810.2 not found in all_genes list
# Gene tbce not found in all_genes list
# Gene tbce not found in all_genes list
# Gene adss not found in all_genes list
# Gene al451007.3 not found in all_genes list
# Gene gcsaml-as1 not found in all_genes list
# Gene mycnos not found in all_genes list
# Gene fam49a not found in all_genes list
# Gene c2orf91 not found in all_genes list
# Gene igkc not found in all_genes list
# Gene al845331.2 not found in all_genes list
# Gene ac092835.1 not found in all_genes list
# Gene kiaa1211l not found in all_genes list
# Gene dars not found in all_genes list
# Gene march7 not found in all_genes list
# Gene pde11a not found in all_genes list
# Gene dirc1 not found in all_genes list
# Gene march4 not found in all_genes list
# Gene ccdc140 not found in all_genes list
# Gene c2orf83 not found in all_genes list
# Gene arih2os not found in all_genes list
# Gene qars not found in all_genes list
# Gene ccdc36 not found in all_genes list
# Gene cyb561d2 not found in all_genes list
# Gene c3orf67 not found in all_genes list
# Gene maats1 not found in all_genes list
# Gene alg1l not found in all_genes list
# Gene kiaa1257 not found in all_genes list
# Gene h1fx not found in all_genes list
# Gene h1foo not found in all_genes list
# Gene acpp not found in all_genes list
# Gene slc66a1l not found in all_genes list
# Gene terc not found in all_genes list
# Gene ccdc39 not found in all_genes list
# Gene ac072022.2 not found in all_genes list
# Gene tctex1d2 not found in all_genes list
# Gene ac093323.1 not found in all_genes list
# Gene kiaa1211 not found in all_genes list
# Gene h2afz not found in all_genes list
# Gene tmem155 not found in all_genes list
# Gene march1 not found in all_genes list
# Gene fam218a not found in all_genes list
# Gene march6 not found in all_genes list
# Gene march11 not found in all_genes list
# Gene ac106774.4 not found in all_genes list
# Gene h3.y not found in all_genes list
# Gene tars not found in all_genes list
# Gene c5orf67 not found in all_genes list
# Gene atp6ap1l not found in all_genes list
# Gene c5orf30 not found in all_genes list
# Gene ac010255.3 not found in all_genes list
# Gene march3 not found in all_genes list
# Gene h2afy not found in all_genes list
# Gene tmem173 not found in all_genes list
# Gene hars not found in all_genes list
# Gene lars not found in all_genes list
# Gene rars not found in all_genes list
# Gene ac113348.1 not found in all_genes list
# Gene c5orf60 not found in all_genes list
# Gene c6orf201 not found in all_genes list
# Gene hist1h2aa not found in all_genes list
# Gene hist1h2ba not found in all_genes list
# Gene hist1h1a not found in all_genes list
# Gene hist1h4b not found in all_genes list
# Gene hist1h2bb not found in all_genes list
# Gene hist1h1c not found in all_genes list
# Gene hist1h4c not found in all_genes list
# Gene hist1h2ac not found in all_genes list
# Gene hist1h1e not found in all_genes list
# Gene hist1h4e not found in all_genes list
# Gene hist1h2bg not found in all_genes list
# Gene hist1h2ae not found in all_genes list
# Gene hist1h3e not found in all_genes list
# Gene hist1h1d not found in all_genes list
# Gene hist1h4g not found in all_genes list
# Gene hist1h2bh not found in all_genes list
# Gene hist1h3g not found in all_genes list
# Gene hist1h2ag not found in all_genes list
# Gene hist1h4i not found in all_genes list
# Gene hist1h2ai not found in all_genes list
# Gene hist1h3h not found in all_genes list
# Gene hist1h4j not found in all_genes list
# Gene hist1h2bn not found in all_genes list
# Gene hist1h2ak not found in all_genes list
# Gene hist1h1b not found in all_genes list
# Gene znrd1 not found in all_genes list
# Gene vars not found in all_genes list
# Gene snhg32 not found in all_genes list
# Gene c6orf223 not found in all_genes list
# Gene defb133 not found in all_genes list
# Gene ick not found in all_genes list
# Gene al135905.2 not found in all_genes list
# Gene fgfr1op not found in all_genes list
# Gene tcte3 not found in all_genes list
# Gene ac187653.1 not found in all_genes list
# Gene ac013470.2 not found in all_genes list
# Gene twistnb not found in all_genes list
# Gene ac004593.3 not found in all_genes list
# Gene gars not found in all_genes list
# Gene trgc2 not found in all_genes list
# Gene trgjp2 not found in all_genes list
# Gene trgc1 not found in all_genes list
# Gene trgjp1 not found in all_genes list
# Gene ac115220.1 not found in all_genes list
# Gene kiaa1324l not found in all_genes list
# Gene castor3 not found in all_genes list
# Gene c7orf77 not found in all_genes list
# Gene ac011005.1 not found in all_genes list
# Gene trbc1 not found in all_genes list
# Gene trbc2 not found in all_genes list
# Gene sspo not found in all_genes list
# Gene ac073111.4 not found in all_genes list
# Gene ac021097.2 not found in all_genes list
# Gene wdr60 not found in all_genes list
# Gene ac134684.8 not found in all_genes list
# Gene pinx1 not found in all_genes list
# Gene impad1 not found in all_genes list
# Gene wdyhv1 not found in all_genes list
# Gene fam49b not found in all_genes list
# Gene ac138647.1 not found in all_genes list
# Gene tsta3 not found in all_genes list
# Gene dock8-as1 not found in all_genes list
# Gene c9orf92 not found in all_genes list
# Gene al162231.1 not found in all_genes list
# Gene fam122a not found in all_genes list
# Gene al353572.3 not found in all_genes list
# Gene iars not found in all_genes list
# Gene c9orf129 not found in all_genes list
# Gene al160269.1 not found in all_genes list
# Gene tmem246 not found in all_genes list
# Gene palm2-akap2 not found in all_genes list
# Gene znf883 not found in all_genes list
# Gene dec1 not found in all_genes list
# Gene b3gnt10 not found in all_genes list
# Gene wdr34 not found in all_genes list
# Gene al354761.1 not found in all_genes list
# Gene bx255925.3 not found in all_genes list
# Gene mir1915hg not found in all_genes list
# Gene armc4 not found in all_genes list
# Gene c10orf142 not found in all_genes list
# Gene march8 not found in all_genes list
# Gene ac067752.1 not found in all_genes list
# Gene kif1bp not found in all_genes list
# Gene h2afy2 not found in all_genes list
# Gene c10orf55 not found in all_genes list
# Gene dupd1 not found in all_genes list
# Gene march5 not found in all_genes list
# Gene atp5md not found in all_genes list
# Gene al603764.2 not found in all_genes list
# Gene pano1 not found in all_genes list
# Gene ac132217.2 not found in all_genes list
# Gene cars not found in all_genes list
# Gene c11orf40 not found in all_genes list
# Gene ac104389.5 not found in all_genes list
# Gene st5 not found in all_genes list
# Gene mrvi1 not found in all_genes list
# Gene c11orf74 not found in all_genes list
# Gene or5r1 not found in all_genes list
# Gene ap002495.1 not found in all_genes list
# Gene card16 not found in all_genes list
# Gene card17 not found in all_genes list
# Gene c11orf88 not found in all_genes list
# Gene ccdc84 not found in all_genes list
# Gene h2afx not found in all_genes list
# Gene hist4h4 not found in all_genes list
# Gene h2afj not found in all_genes list
# Gene lrmp not found in all_genes list
# Gene casc1 not found in all_genes list
# Gene h3f3c not found in all_genes list
# Gene h1fnt not found in all_genes list
# Gene c12orf81 not found in all_genes list
# Gene grasp not found in all_genes list
# Gene ac021072.1 not found in all_genes list
# Gene c12orf10 not found in all_genes list
# Gene mars not found in all_genes list
# Gene slc26a10 not found in all_genes list
# Gene march9 not found in all_genes list
# Gene cllu1os not found in all_genes list
# Gene c12orf74 not found in all_genes list
# Gene c12orf49 not found in all_genes list
# Gene wdr66 not found in all_genes list
# Gene spata13 not found in all_genes list
# Gene spert not found in all_genes list
# Gene al445238.1 not found in all_genes list
# Gene trdc not found in all_genes list
# Gene trac not found in all_genes list
# Gene sfta3 not found in all_genes list
# Gene elmsan1 not found in all_genes list
# Gene c14orf177 not found in all_genes list
# Gene wars not found in all_genes list
# Gene atp5mpl not found in all_genes list
# Gene adssl1 not found in all_genes list
# Gene igha2 not found in all_genes list
# Gene ighe not found in all_genes list
# Gene igha1 not found in all_genes list
# Gene ighg1 not found in all_genes list
# Gene ighg3 not found in all_genes list
# Gene ighd not found in all_genes list
# Gene ighm not found in all_genes list
# Gene fam30a not found in all_genes list
# Gene ac135068.1 not found in all_genes list
# Gene golga8m not found in all_genes list
# Gene ac091057.6 not found in all_genes list
# Gene c15orf41 not found in all_genes list
# Gene linc02694 not found in all_genes list
# Gene casc4 not found in all_genes list
# Gene ct62 not found in all_genes list
# Gene ac015871.1 not found in all_genes list
# Gene spata8 not found in all_genes list
# Gene fam169b not found in all_genes list
# Gene tarsl2 not found in all_genes list
# Gene tmem8a not found in all_genes list
# Gene al032819.3 not found in all_genes list
# Gene ac025283.2 not found in all_genes list
# Gene ac099489.1 not found in all_genes list
# Gene fopnl not found in all_genes list
# Gene kiaa0556 not found in all_genes list
# Gene c16orf58 not found in all_genes list
# Gene ac007906.2 not found in all_genes list
# Gene fam192a not found in all_genes list
# Gene lrrc29 not found in all_genes list
# Gene aars not found in all_genes list
# Gene kars not found in all_genes list
# Gene ac025287.4 not found in all_genes list
# Gene fam92b not found in all_genes list
# Gene cenpbd1 not found in all_genes list
# Gene ac087498.1 not found in all_genes list
# Gene ac233723.1 not found in all_genes list
# Gene trim16l not found in all_genes list
# Gene linc02693 not found in all_genes list
# Gene slfn12l not found in all_genes list
# Gene tmem99 not found in all_genes list
# Gene ttc25 not found in all_genes list
# Gene g6pc not found in all_genes list
# Gene c17orf53 not found in all_genes list
# Gene ac011195.2 not found in all_genes list
# Gene march10 not found in all_genes list
# Gene h3f3b not found in all_genes list
# Gene eloa3 not found in all_genes list
# Gene nars not found in all_genes list
# Gene ac090360.1 not found in all_genes list
# Gene ac005551.1 not found in all_genes list
# Gene ac119396.1 not found in all_genes list
# Gene march2 not found in all_genes list
# Gene ccdc151 not found in all_genes list
# Gene c19orf57 not found in all_genes list
# Gene ac008397.1 not found in all_genes list
# Gene kiaa0355 not found in all_genes list
# Gene cntd2 not found in all_genes list
# Gene cd3eap not found in all_genes list
# Gene bhmg1 not found in all_genes list
# Gene ppp5d1 not found in all_genes list
# Gene ccdc114 not found in all_genes list
# Gene ac008687.4 not found in all_genes list
# Gene ccdc155 not found in all_genes list
# Gene ac010325.1 not found in all_genes list
# Gene c19orf48 not found in all_genes list
# Gene siglec5 not found in all_genes list
# Gene gdf5os not found in all_genes list
# Gene tmem189 not found in all_genes list
# Gene fp565260.1 not found in all_genes list
# Gene ap000552.4 not found in all_genes list
# Gene iglc1 not found in all_genes list
# Gene iglc7 not found in all_genes list
# Gene lrp5l not found in all_genes list
# Gene elfn2 not found in all_genes list
# Gene h1f0 not found in all_genes list
# Gene z82206.1 not found in all_genes list
# Gene arse not found in all_genes list
# Gene cxorf21 not found in all_genes list
# Gene hypm not found in all_genes list
# Gene al121578.2 not found in all_genes list
# Gene bx276092.9 not found in all_genes list
# Gene nxf5 not found in all_genes list
# Gene glra4 not found in all_genes list
# Gene tmsb15b not found in all_genes list
# Gene h2bfwt not found in all_genes list
# Gene h2bfm not found in all_genes list
# Gene tmsb15b not found in all_genes list
# Gene pih1d3 not found in all_genes list
# Gene al772284.2 not found in all_genes list
# Gene cxorf56 not found in all_genes list
# Gene fam122b not found in all_genes list
# Gene fam122c not found in all_genes list
# Gene cxorf40a not found in all_genes list
# Gene ac236972.4 not found in all_genes list
# Gene prky not found in all_genes list
# Gene ac007244.1 not found in all_genes list

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)



# 将训练数据转换为张量
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train_tensor = torch.tensor(X_train).float().to(device)
y_train_tensor = torch.tensor(y_train).long().to(device)
X_val_tensor = torch.tensor(X_val).float().to(device)
y_val_tensor = torch.tensor(y_val).long().to(device)
estim.model.to(device)
# Out:
# cuda
# MLPAutoEncoder(
#   (train_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=train_
#   )
#   (val_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=val_
#   )
#   (test_metrics): MetricCollection(
#     (explained_var_uniform): ExplainedVariance()
#     (explained_var_weighted): ExplainedVariance()
#     (mse): MeanSquaredError(),
#     prefix=test_
#   )
#   (encoder): MLP(
#     (0): Linear(in_features=19331, out_features=512, bias=True)
#     (1): SELU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SELU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SELU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): SELU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=True)
#   )
#   (decoder): Sequential(
#     (0): MLP(
#       (0): Linear(in_features=64, out_features=256, bias=True)
#       (1): SELU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=256, out_features=256, bias=True)
#       (4): SELU()
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=256, out_features=512, bias=True)
#       (7): SELU()
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SELU()
#       (11): Dropout(p=0.1, inplace=False)
#       (12): Linear(in_features=512, out_features=19331, bias=True)
#     )
#     (1): Sigmoid()
#   )
#   (fc): Linear(in_features=64, out_features=19, bias=True)
# )

# %%
# 6. 微调模型，仅微调 encoder 的最后两层，其他层参数冻结
for param in estim.model.encoder.parameters():
    param.requires_grad = False  # 冻结所有层

# 解冻最后两层
for param in list(estim.model.encoder.parameters())[-5:]:
    param.requires_grad = True

# %%
from torch.optim import AdamW
# 定义损失函数和优化器
loss_fn = nn.CrossEntropyLoss()
optimizer = AdamW(filter(lambda p: p.requires_grad, estim.model.parameters()), lr=9e-4, weight_decay=0.05)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.9)

# %%
from torch.utils.data import DataLoader, TensorDataset

# 设置 batch size
batch_size = 128  # 根据实际需求调整 batch size

# 使用 TensorDataset 将训练数据和标签打包
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

# 使用 DataLoader 来创建批次
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 7. 微调模型
def train_epoch(model, optimizer, loss_fn, train_loader, val_loader):
    model.train()
    total_train_loss = 0
    
    # 训练集批次训练
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        
        # 前向传播
        outputs = model.encoder(X_batch)
        logits = model.fc(outputs)
        
        # 计算损失
        loss = loss_fn(logits, y_batch)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
    
    # 验证集
    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            val_outputs = model.encoder(X_val_batch)
            val_logits = model.fc(val_outputs)
            val_loss = loss_fn(val_logits, y_val_batch)
            total_val_loss += val_loss.item()

    # 返回平均损失
    return total_train_loss / len(train_loader), total_val_loss / len(val_loader)

# %%
import copy  # 用于保存模型的最佳状态

# Early Stopping 参数
patience = 20  # 如果验证损失在 10 个 epoch 中没有改善，停止训练
min_delta = 1e-4  # 最小改善幅度
patience_counter = 0
best_val_loss = float('inf')  # 初始设置为正无穷大
best_model_weights = copy.deepcopy(estim.model.state_dict())  # 保存最佳模型权重
train_losses = []
val_losses = []

# 训练 500 个 epoch
for epoch in range(500):
    train_loss, val_loss = train_epoch(estim.model, optimizer, loss_fn, train_loader, val_loader)
    print(f'Epoch {epoch+1}, Train Loss: {train_loss}, Validation Loss: {val_loss}')
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    # Early Stopping 检查
    if val_loss < best_val_loss - min_delta:
        best_val_loss = val_loss  # 更新最佳验证损失
        patience_counter = 0  # 重置 patience 计数器
        best_model_weights = copy.deepcopy(estim.model.state_dict())  # 保存当前最佳模型
        print(f"Validation loss improved to {best_val_loss}, resetting patience.")
    else:
        patience_counter += 1
        print(f"No improvement in validation loss. Patience counter: {patience_counter}/{patience}")
    
    # 如果 patience_counter 超过设置的 patience，停止训练
    if patience_counter >= patience:
        print(f"Early stopping triggered. Stopping training at epoch {epoch+1}.")
        break

# 恢复到训练中性能最好的模型权重
estim.model.load_state_dict(best_model_weights)
print("Loaded best model weights based on validation loss.")
# Out:
# Epoch 1, Train Loss: 1.5213677310785712, Validation Loss: 0.7534392801198092
# Validation loss improved to 0.7534392801198092, resetting patience.
# Epoch 2, Train Loss: 0.8638546849718157, Validation Loss: 0.7004216909408569
# Validation loss improved to 0.7004216909408569, resetting patience.
# Epoch 3, Train Loss: 0.8105383124572552, Validation Loss: 0.6645408498518395
# Validation loss improved to 0.6645408498518395, resetting patience.
# Epoch 4, Train Loss: 0.7763308886660646, Validation Loss: 0.6391171262119756
# Validation loss improved to 0.6391171262119756, resetting patience.
# Epoch 5, Train Loss: 0.7645111411612555, Validation Loss: 0.6291722438552163
# Validation loss improved to 0.6291722438552163, resetting patience.
# Epoch 6, Train Loss: 0.7471664034767657, Validation Loss: 0.6280045834454623
# Validation loss improved to 0.6280045834454623, resetting patience.
# Epoch 7, Train Loss: 0.7369760444622167, Validation Loss: 0.6261625894994447
# Validation loss improved to 0.6261625894994447, resetting patience.
# Epoch 8, Train Loss: 0.7265934284949145, Validation Loss: 0.6240099469820658
# Validation loss improved to 0.6240099469820658, resetting patience.
# Epoch 9, Train Loss: 0.7170535045743778, Validation Loss: 0.63111407196883
# No improvement in validation loss. Patience counter: 1/20
# Epoch 10, Train Loss: 0.7206200073096926, Validation Loss: 0.5958648053082553
# Validation loss improved to 0.5958648053082553, resetting patience.
# Epoch 11, Train Loss: 0.6982589200237729, Validation Loss: 0.6142086558269731
# No improvement in validation loss. Patience counter: 1/20
# Epoch 12, Train Loss: 0.7105046664642183, Validation Loss: 0.6181665541547717
# No improvement in validation loss. Patience counter: 2/20
# Epoch 13, Train Loss: 0.6998656482886005, Validation Loss: 0.6158122384186947
# No improvement in validation loss. Patience counter: 3/20
# Epoch 14, Train Loss: 0.6867823701425894, Validation Loss: 0.5980575500112592
# No improvement in validation loss. Patience counter: 4/20
# Epoch 15, Train Loss: 0.6918565984198589, Validation Loss: 0.618174408421372
# No improvement in validation loss. Patience counter: 5/20
# Epoch 16, Train Loss: 0.6799611253848928, Validation Loss: 0.6204582353432974
# No improvement in validation loss. Patience counter: 6/20
# Epoch 17, Train Loss: 0.681075230339505, Validation Loss: 0.5842657929117029
# Validation loss improved to 0.5842657929117029, resetting patience.
# Epoch 18, Train Loss: 0.6760699411496421, Validation Loss: 0.6096344517939019
# No improvement in validation loss. Patience counter: 1/20
# Epoch 19, Train Loss: 0.6714169803439387, Validation Loss: 0.6070994391585841
# No improvement in validation loss. Patience counter: 2/20
# Epoch 20, Train Loss: 0.6785096437331067, Validation Loss: 0.6169524915290602
# No improvement in validation loss. Patience counter: 3/20
# Epoch 21, Train Loss: 0.6719032999695531, Validation Loss: 0.5865720718195944
# No improvement in validation loss. Patience counter: 4/20
# Epoch 22, Train Loss: 0.6610000151277378, Validation Loss: 0.6002658858443751
# No improvement in validation loss. Patience counter: 5/20
# Epoch 23, Train Loss: 0.6653891014342277, Validation Loss: 0.5869999825954437
# No improvement in validation loss. Patience counter: 6/20
# Epoch 24, Train Loss: 0.6646204381589068, Validation Loss: 0.5779570304986202
# Validation loss improved to 0.5779570304986202, resetting patience.
# Epoch 25, Train Loss: 0.655726815493691, Validation Loss: 0.5856156854918508
# No improvement in validation loss. Patience counter: 1/20
# Epoch 26, Train Loss: 0.6599544209755019, Validation Loss: 0.5911362405979272
# No improvement in validation loss. Patience counter: 2/20
# Epoch 27, Train Loss: 0.6532520426819656, Validation Loss: 0.5820210169662129
# No improvement in validation loss. Patience counter: 3/20
# Epoch 28, Train Loss: 0.6579873005285958, Validation Loss: 0.5703109593102427
# Validation loss improved to 0.5703109593102427, resetting patience.
# Epoch 29, Train Loss: 0.6543268442943396, Validation Loss: 0.5828400407776688
# No improvement in validation loss. Patience counter: 1/20
# Epoch 30, Train Loss: 0.6603563149638524, Validation Loss: 0.5930342078208923
# No improvement in validation loss. Patience counter: 2/20
# Epoch 31, Train Loss: 0.6440031354790492, Validation Loss: 0.5727051839683995
# No improvement in validation loss. Patience counter: 3/20
# Epoch 32, Train Loss: 0.6558687653367883, Validation Loss: 0.5654643132831111
# Validation loss improved to 0.5654643132831111, resetting patience.
# Epoch 33, Train Loss: 0.6371988669925968, Validation Loss: 0.5784295941844131
# No improvement in validation loss. Patience counter: 1/20
# Epoch 34, Train Loss: 0.653065073371723, Validation Loss: 0.5823747624050487
# No improvement in validation loss. Patience counter: 2/20
# Epoch 35, Train Loss: 0.6411372908693276, Validation Loss: 0.5665817305897222
# No improvement in validation loss. Patience counter: 3/20
# Epoch 36, Train Loss: 0.6394831996090364, Validation Loss: 0.5999096099174384
# No improvement in validation loss. Patience counter: 4/20
# Epoch 37, Train Loss: 0.6524053300848071, Validation Loss: 0.6052340205871698
# No improvement in validation loss. Patience counter: 5/20
# Epoch 38, Train Loss: 0.6423451620221927, Validation Loss: 0.5612807300957766
# Validation loss improved to 0.5612807300957766, resetting patience.
# Epoch 39, Train Loss: 0.6310033750849844, Validation Loss: 0.5755468823693015
# No improvement in validation loss. Patience counter: 1/20
# Epoch 40, Train Loss: 0.635672717102316, Validation Loss: 0.5768389223199902
# No improvement in validation loss. Patience counter: 2/20
# Epoch 41, Train Loss: 0.6432710388638326, Validation Loss: 0.5829173570329492
# No improvement in validation loss. Patience counter: 3/20
# Epoch 42, Train Loss: 0.6391821223378971, Validation Loss: 0.5672784113522732
# No improvement in validation loss. Patience counter: 4/20
# Epoch 43, Train Loss: 0.6335820577397252, Validation Loss: 0.6096015111966566
# No improvement in validation loss. Patience counter: 5/20
# Epoch 44, Train Loss: 0.6372926987164858, Validation Loss: 0.5708548300194017
# No improvement in validation loss. Patience counter: 6/20
# Epoch 45, Train Loss: 0.6279744347989165, Validation Loss: 0.5811375668554595
# No improvement in validation loss. Patience counter: 7/20
# Epoch 46, Train Loss: 0.6321307479940503, Validation Loss: 0.580189641677972
# No improvement in validation loss. Patience counter: 8/20
# Epoch 47, Train Loss: 0.6282478004496619, Validation Loss: 0.5624628554690968
# No improvement in validation loss. Patience counter: 9/20
# Epoch 48, Train Loss: 0.6227003430688618, Validation Loss: 0.5856333456256173
# No improvement in validation loss. Patience counter: 10/20
# Epoch 49, Train Loss: 0.6294536207685407, Validation Loss: 0.5781508593848257
# No improvement in validation loss. Patience counter: 11/20
# Epoch 50, Train Loss: 0.6307607385891163, Validation Loss: 0.601609676173239
# No improvement in validation loss. Patience counter: 12/20
# Epoch 51, Train Loss: 0.6218407081057694, Validation Loss: 0.5992238602854989
# No improvement in validation loss. Patience counter: 13/20
# Epoch 52, Train Loss: 0.6256242733917489, Validation Loss: 0.5947077463973652
# No improvement in validation loss. Patience counter: 14/20
# Epoch 53, Train Loss: 0.6191528131630247, Validation Loss: 0.5754749070514332
# No improvement in validation loss. Patience counter: 15/20
# Epoch 54, Train Loss: 0.6256670892633349, Validation Loss: 0.5773982893336903
# No improvement in validation loss. Patience counter: 16/20
# Epoch 55, Train Loss: 0.6199904595384534, Validation Loss: 0.5758911317045038
# No improvement in validation loss. Patience counter: 17/20
# Epoch 56, Train Loss: 0.6280471299657758, Validation Loss: 0.5931849560954354
# No improvement in validation loss. Patience counter: 18/20
# Epoch 57, Train Loss: 0.6224168422601081, Validation Loss: 0.5859565265250929
# No improvement in validation loss. Patience counter: 19/20
# Epoch 58, Train Loss: 0.6176467695773042, Validation Loss: 0.5850970609621569
# No improvement in validation loss. Patience counter: 20/20
# Early stopping triggered. Stopping training at epoch 58.
# Loaded best model weights based on validation loss.

# %%
import matplotlib.pyplot as plt  # 导入 matplotlib.pyplot，而不是 matplotlib

plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.savefig('../loss_curve_fig/merfish_human_neocortex_gp_mask_finetune_full_loss_curve.png', dpi=400)  # 保存图像为png格式，400 dpi
plt.savefig('../loss_curve_fig/merfish_human_neocortex_gp_mask_finetune_full_loss_curve.eps', format='eps', dpi=400)  # 保存图像为png格式，400 dpi

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# 8. 使用 KNN 替代测试阶段的 FC 分类层
# 使用 encoder 提取训练集和测试集的 embedding
estim.model.eval()
with torch.no_grad():
    train_embeddings = estim.model.encoder(torch.tensor(X_train).float().to(device)).cpu().numpy()
    test_embeddings = estim.model.encoder(torch.tensor(X_test).float().to(device)).cpu().numpy()

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.8145180869142996
# Weighted F1 Score: 0.8130340537606421
# Macro F1 Score: 0.8087324162316953
# Random Guess Accuracy: 0.08554398369790313
#                          precision    recall  f1-score   support
#
#                 B Cells       0.88      0.85      0.86       219
#            CD4+ T Cells       0.85      0.91      0.88       392
#            CD8+ T Cells       0.86      0.89      0.88       281
#                  DCIS 1       0.67      0.67      0.67       293
#                  DCIS 2       0.70      0.70      0.70       326
#             Endothelial       0.94      0.88      0.91       154
#               IRF7+ DCs       0.97      0.85      0.90        33
#          Invasive Tumor       0.78      0.88      0.83       701
#              LAMP3+ DCs       0.90      1.00      0.95        19
#           Macrophages 1       0.87      0.80      0.84       425
#           Macrophages 2       0.82      0.86      0.84       106
#              Mast Cells       0.87      1.00      0.93        13
#           Myoepi ACTA2+       0.82      0.77      0.79       219
#           Myoepi KRT15+       0.90      0.67      0.77       112
#       Perivascular-Like       0.87      0.72      0.79        36
#   Prolif Invasive Tumor       0.79      0.81      0.80       212
#                 Stromal       0.92      0.91      0.91       372
# Stromal & T Cell Hybrid       0.61      0.42      0.50        60
#   T Cell & Tumor Hybrid       0.65      0.59      0.62       146
#
#                accuracy                           0.81      4119
#               macro avg       0.82      0.80      0.81      4119
#            weighted avg       0.82      0.81      0.81      4119

# %%
with torch.no_grad():
    new_data_tensor = torch.tensor(new_data).float().to(device)
    SSL_embeddings = estim.model.encoder(new_data_tensor).detach().cpu().numpy()
new_adata = sc.read_h5ad(data_dir)
new_adata.obsm[f'SSL_GP_FT_{random_seed}'] = SSL_embeddings
new_adata.uns[f'GP_FT_y_test_{random_seed}'] = y_test
new_adata.uns[f'GP_FT_predictions_{random_seed}'] = predictions
new_adata.uns[f'GP_FT_target_names_{random_seed}'] = label_encoder.classes_
new_adata.uns[f'GP_FT_train_loss_{random_seed}'] = train_losses
new_adata.uns[f'GP_FT_val_loss_{random_seed}'] = val_losses
new_adata.write_h5ad(data_dir)
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "chromium_breast_cancer_GP_mask_fine_tune_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicro_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicor_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['chromium_breast_cancer'],
    'method': [re.search(r'breast_cancer_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micor_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# init_train_loss	init_val_loss	converged_epoch	converged_val_loss	macro_f1	weighted_f1	micro_f1
# 1.521	0.753	38	0.561	0.809	0.813	0.815
