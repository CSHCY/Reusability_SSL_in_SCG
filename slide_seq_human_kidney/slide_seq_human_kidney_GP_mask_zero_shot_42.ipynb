# %%
import scanpy as sc
data_dir = '../../dataset/Marshall2022High_human_sampled.h5ad'
adata = sc.read_h5ad(data_dir)
adata.X = adata.raw.X

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
adata.var['gene_id'] = adata.var.index
adata.var.index = adata.var['gene_name']

# 输出 adata.var
adata.var
# Out:
#                           feature_reference feature_biotype  \
# gene_name
# A1BG                         NCBITaxon:9606            gene
# A1BG-AS1                     NCBITaxon:9606            gene
# A1CF                         NCBITaxon:9606            gene
# A2M                          NCBITaxon:9606            gene
# A2M-AS1                      NCBITaxon:9606            gene
# ...                                     ...             ...
# ZZZ3                         NCBITaxon:9606            gene
# MISP3                        NCBITaxon:9606            gene
# ENSG00000234352.9            NCBITaxon:9606            gene
# ARHGAP27P1-BPTFP1-KPNA2P3    NCBITaxon:9606            gene
# SBNO1-AS1                    NCBITaxon:9606            gene
#
#                            feature_is_filtered-0             feature_name-0  \
# gene_name
# A1BG                                        True                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-0  feature_type-0  \
# gene_name
# A1BG                                  2134  protein_coding
# A1BG-AS1                              1667          lncRNA
# A1CF                                  2211  protein_coding
# A2M                                    590  protein_coding
# A2M-AS1                               2551          lncRNA
# ...                                    ...             ...
# ZZZ3                                   686  protein_coding
# MISP3                                 1473  protein_coding
# ENSG00000234352.9                      728          lncRNA
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA
# SBNO1-AS1                              625          lncRNA
#
#                            feature_is_filtered-1             feature_name-1  \
# gene_name
# A1BG                                       False                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-1  feature_type-1  ...  \
# gene_name                                                   ...
# A1BG                                  2134  protein_coding  ...
# A1BG-AS1                              1667          lncRNA  ...
# A1CF                                  2211  protein_coding  ...
# A2M                                    590  protein_coding  ...
# A2M-AS1                               2551          lncRNA  ...
# ...                                    ...             ...  ...
# ZZZ3                                   686  protein_coding  ...
# MISP3                                 1473  protein_coding  ...
# ENSG00000234352.9                      728          lncRNA  ...
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA  ...
# SBNO1-AS1                              625          lncRNA  ...
#
#                            feature_is_filtered-6             feature_name-6  \
# gene_name
# A1BG                                        True                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-6  feature_type-6  \
# gene_name
# A1BG                                  2134  protein_coding
# A1BG-AS1                              1667          lncRNA
# A1CF                                  2211  protein_coding
# A2M                                    590  protein_coding
# A2M-AS1                               2551          lncRNA
# ...                                    ...             ...
# ZZZ3                                   686  protein_coding
# MISP3                                 1473  protein_coding
# ENSG00000234352.9                      728          lncRNA
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA
# SBNO1-AS1                              625          lncRNA
#
#                            feature_is_filtered-7             feature_name-7  \
# gene_name
# A1BG                                        True                       A1BG
# A1BG-AS1                                   False                   A1BG-AS1
# A1CF                                       False                       A1CF
# A2M                                        False                        A2M
# A2M-AS1                                    False                    A2M-AS1
# ...                                          ...                        ...
# ZZZ3                                       False                       ZZZ3
# MISP3                                      False                      MISP3
# ENSG00000234352.9                          False          ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3                  False  ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                  False                  SBNO1-AS1
#
#                           feature_length-7  feature_type-7  \
# gene_name
# A1BG                                  2134  protein_coding
# A1BG-AS1                              1667          lncRNA
# A1CF                                  2211  protein_coding
# A2M                                    590  protein_coding
# A2M-AS1                               2551          lncRNA
# ...                                    ...             ...
# ZZZ3                                   686  protein_coding
# MISP3                                 1473  protein_coding
# ENSG00000234352.9                      728          lncRNA
# ARHGAP27P1-BPTFP1-KPNA2P3             2025          lncRNA
# SBNO1-AS1                              625          lncRNA
#
#                                            gene_name          gene_id
# gene_name
# A1BG                                            A1BG  ENSG00000121410
# A1BG-AS1                                    A1BG-AS1  ENSG00000268895
# A1CF                                            A1CF  ENSG00000148584
# A2M                                              A2M  ENSG00000175899
# A2M-AS1                                      A2M-AS1  ENSG00000245105
# ...                                              ...              ...
# ZZZ3                                            ZZZ3  ENSG00000036549
# MISP3                                          MISP3  ENSG00000141854
# ENSG00000234352.9                  ENSG00000234352.9  ENSG00000234352
# ARHGAP27P1-BPTFP1-KPNA2P3  ARHGAP27P1-BPTFP1-KPNA2P3  ENSG00000215769
# SBNO1-AS1                                  SBNO1-AS1  ENSG00000256092
#
# [20299 rows x 36 columns]

# %%
import scanpy as sc
import torch
import lightning.pytorch as pl
from self_supervision.models.lightning_modules.cellnet_autoencoder import MLPAutoEncoder
from self_supervision.estimator.cellnet import EstimatorAutoEncoder

# 设置你的 .ckpt 文件路径
ckpt_path = "../../sc_pretrained/Pretrained Models/GPMask.ckpt"

# 模型参数
units_encoder = [512, 512, 256, 256, 64]
units_decoder = [256, 256, 512, 512]

# 初始化 EstimatorAutoEncoder 实例
estim = EstimatorAutoEncoder(data_path=None)  # 如果没有实际数据路径，可以设置为None

# 加载预训练模型
estim.model = MLPAutoEncoder.load_from_checkpoint(
    ckpt_path,
    gene_dim=19331,  # 根据你的数据调整
    batch_size=128,  # 根据你的需要调整
    units_encoder=units_encoder, 
    units_decoder=units_decoder,
    masking_strategy="random",  # 假设模型使用了随机掩码
    masking_rate=0.5,  # 根据需要调整
)

# 使用 GPU 进行评估（如果可用）
estim.trainer = pl.Trainer(accelerator="gpu", devices=1 if torch.cuda.is_available() else None)
# Out:
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/tf.py:52: UserWarning: Tensorflow dtype mappings did not load successfully due to an error: No module named 'tensorflow'
#   warn(f"Tensorflow dtype mappings did not load successfully due to an error: {exc.msg}")
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
import pandas as pd
var_df = pd.read_parquet('../../sc_pretrained/var.parquet')
var_df
# Out:
#             feature_id feature_name
# 0      ENSG00000186092        OR4F5
# 1      ENSG00000284733       OR4F29
# 2      ENSG00000284662       OR4F16
# 3      ENSG00000187634       SAMD11
# 4      ENSG00000188976        NOC2L
# ...                ...          ...
# 19326  ENSG00000288702       UGT1A3
# 19327  ENSG00000288705       UGT1A5
# 19328  ENSG00000182484       WASH6P
# 19329  ENSG00000288622   PDCD6-AHRR
# 19330  ENSG00000285815  GET1-SH3BGR
#
# [19331 rows x 2 columns]

# %%
all_genes = var_df['feature_name'].tolist()
all_genes
# Out:
# ['OR4F5',
#  'OR4F29',
#  'OR4F16',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
#  'PERM1',
#  'HES4',
#  'ISG15',
#  'AGRN',
#  'RNF223',
#  'C1orf159',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'AURKAIP1',
#  'CCNL2',
#  'MRPL20',
#  'ANKRD65',
#  'TMEM88B',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3B',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'FNDC10',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'NADK',
#  'GNB1',
#  'CALML6',
#  'TMEM52',
#  'CFAP74',
#  'GABRD',
#  'PRKCZ',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14',
#  'PRXL2B',
#  'MMEL1',
#  'TTC34',
#  'ACTRT2',
#  'PRDM16',
#  'ARHGEF16',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'TP73',
#  'CCDC27',
#  'SMIM1',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RPL22',
#  'RNF207',
#  'ICMT',
#  'HES3',
#  'GPR153',
#  'ACOT7',
#  'HES2',
#  'ESPN',
#  'TNFRSF25',
#  'PLEKHG5',
#  'NOL9',
#  'TAS1R1',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'DNAJC11',
#  'CAMTA1',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'PARK7',
#  'ERRFI1',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'CA6',
#  'SLC2A7',
#  'SLC2A5',
#  'GPR157',
#  'H6PD',
#  'SPSB1',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD',
#  'CLSTN1',
#  'CTNNBIP1',
#  'LZIC',
#  'NMNAT1',
#  'RBP7',
#  'UBE4B',
#  'KIF1B',
#  'PGD',
#  'CENPS',
#  'CORT',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'C1orf127',
#  'TARDBP',
#  'MASP2',
#  'SRM',
#  'EXOSC10',
#  'MTOR',
#  'ANGPTL7',
#  'UBIAD1',
#  'DISP3',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'PRAMEF12',
#  'PRAMEF1',
#  'PRAMEF11',
#  'HNRNPCL1',
#  'PRAMEF2',
#  'PRAMEF4',
#  'PRAMEF10',
#  'PRAMEF7',
#  'PRAMEF6',
#  'PRAMEF27',
#  'HNRNPCL3',
#  'PRAMEF25',
#  'HNRNPCL2',
#  'PRAMEF26',
#  'HNRNPCL4',
#  'PRAMEF9',
#  'PRAMEF13',
#  'PRAMEF18',
#  'PRAMEF5',
#  'PRAMEF8',
#  'PRAMEF33',
#  'PRAMEF15',
#  'PRAMEF14',
#  'PRAMEF19',
#  'PRAMEF17',
#  'PRAMEF20',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'EFHD2',
#  'CTRC',
#  'CELA2A',
#  'CELA2B',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'RSC1A1',
#  'PLEKHM2',
#  'SLC25A34',
#  'TMEM82',
#  'FBLIM1',
#  'UQCRHL',
#  'SPEN',
#  'ZBTB17',
#  'SRARP',
#  'HSPB7',
#  'CLCNKA',
#  'CLCNKB',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'NBPF1',
#  'CROCC',
#  'MFAP2',
#  'ATP13A2',
#  'SDHB',
#  'PADI2',
#  'PADI1',
#  'PADI3',
#  'PADI4',
#  'PADI6',
#  'RCC2',
#  'ARHGEF10L',
#  'ACTL8',
#  'IGSF21',
#  'KLHDC7A',
#  'PAX7',
#  'TAS1R2',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'SLC66A1',
#  'CAPZB',
#  'MICOS10',
#  'NBL1',
#  'HTR6',
#  'TMCO4',
#  'RNF186',
#  'OTUD3',
#  'PLA2G2E',
#  'PLA2G2A',
#  'PLA2G5',
#  'PLA2G2D',
#  'PLA2G2F',
#  'PLA2G2C',
#  'UBXN10',
#  'VWA5B1',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'CDA',
#  'PINK1',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'NBPF3',
#  'ALPL',
#  'RAP1GAP',
#  'USP48',
#  'LDLRAD2',
#  'HSPG2',
#  'CELA3B',
#  'CELA3A',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHA8',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'EPHB2',
#  'LACTBL1',
#  'TEX46',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'HNRNPR',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'E2F2',
#  'ID3',
#  'RPL11',
#  'ELOA',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'MYOM3',
#  'IL22RA1',
#  'IFNLR1',
#  'GRHL3',
#  'STPG1',
#  'NIPAL3',
#  'RCAN3',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'SYF2',
#  'RSRP1',
#  'RHD',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'SELENON',
#  'MTFR1L',
#  'AUNIP',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'TRIM63',
#  'PDIK1L',
#  'FAM110D',
#  'C1orf232',
#  'ZNF593OS',
#  'ZNF593',
#  'CNKSR1',
#  'CATSPER4',
#  'CEP85',
#  'SH3BGRL3',
#  'UBXN11',
#  'CD52',
#  'CRYBG2',
#  'ZNF683',
#  'LIN28A',
#  'DHDDS',
#  'HMGN2',
#  'RPS6KA1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'NR0B2',
#  'KDF1',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'IFI6',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'THEMIS2',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'PTAFR',
#  'DNAJC8',
#  'ATP5IF1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'OPRD1',
#  'EPB41',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'LAPTM5',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'FABP3',
#  'SERINC2',
#  'TINAGL1',
#  'HCRTR1',
#  'PEF1',
#  'COL16A1',
#  'ADGRB2',
#  'SPOCD1',
#  'PTP4A2',
#  'KHDRBS1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'ZBTB8OS',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS1',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'RNF19B',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'ZNF362',
#  'A3GALT2',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'HMGB4',
#  'C1orf94',
#  'SMIM12',
#  'GJB5',
#  'GJB4',
#  'GJB3',
#  'GJA4',
#  'DLGAP3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO4',
#  'AGO1',
#  'AGO3',
#  'TEKT2',
#  'ADPRS',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'SH3D21',
#  'EVA1B',
#  'STK40',
#  'LSM10',
#  'OSCP1',
#  'MRPS15',
#  'CSF3R',
#  'GRIK3',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'EPHA10',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'MYCBP',
#  'GJA9',
#  'RHBDL2',
#  'AKIRIN1',
#  'NDUFS5',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'NT5C1A',
#  'HPCAL4',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'MYCL',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'TMCO2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'RIMS3',
#  'NFYC',
#  'KCNQ4',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1',
#  'SCMH1',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'GUCA2B',
#  'GUCA2A',
#  'FOXJ3',
#  'RIMKLA',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'PPIH',
#  'YBX1',
#  'CLDN19',
#  'P3H1',
#  'C1orf50',
#  'TMEM269',
#  'SVBP',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'FAM183A',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'MPL',
#  'CDC20',
#  'ELOVL1',
#  'MED8',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'ST3GAL3',
#  'ARTN',
#  'IPO13',
#  'DPH2',
#  'ATP6V0B',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'KLF17',
#  'KLF18',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'ARMH1',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'DYNLT4',
#  'BTBD19',
#  'PTCH2',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'TSPAN1',
#  'P3R3URF',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'UQCRH',
#  'NSUN4',
#  'FAAH',
#  'DMBX1',
#  'TMEM275',
#  'KNCN',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'TEX38',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4A11',
#  'CYP4X1',
#  'CYP4Z1',
#  'CYP4A22',
#  'PDZK1IP1',
#  'TAL1',
#  'STIL',
#  'CMPK1',
#  'FOXE3',
#  'FOXD2',
#  'TRABD2B',
#  'SLC5A9',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'ELAVL4',
#  'DMRTA2',
#  'FAF1',
#  'CDKN2C',
#  'C1orf185',
#  'RNF11',
#  'TTC39A',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'ORC1',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'SCP2',
#  'PODN',
#  'SLC1A7',
#  'CPT2',
#  'CZIB',
#  'MAGOH',
#  'LRP8',
#  'DMRTB1',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'DIO1',
#  'HSPB11',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'CDCP2',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'FAM151A',
#  'MROH7',
#  'TTC4',
#  'PARS2',
#  'TTC22',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'BSND',
#  'PCSK9',
#  'USP24',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8A',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'C1orf87',
#  'NFIA',
#  'TM2D1',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'ANGPTL3',
#  'ATG4C',
#  'FOXD3',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'UBE2U',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'DYNLT5',
#  'INSL5',
#  'DNAI4',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'DIRAS3',
#  'WLS',
#  'RPE65',
#  'DEPDC1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'CTH',
#  'PTGER3',
#  'ZRANB2',
#  'NEGR1',
#  'LRRIQ3',
#  'FPGT',
#  'TNNI3K',
#  'LRRC53',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'LHX8',
#  'SLC44A5',
#  'ACADM',
#  'RABGGTB',
#  'MSH4',
#  'ASB17',
#  'ST6GALNAC3',
#  'ST6GALNAC5',
#  'PIGK',
#  'AK5',
#  'ZZZ3',
#  'USP33',
#  'MIGA1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'ADGRL2',
#  'TTLL7',
#  'PRKACB',
#  'SAMD13',
#  'DNASE2B',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'LPAR3',
#  'MCOLN2',
#  'DNAI3',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'DDAH1',
#  'CCN1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'CLCA2',
#  'CLCA1',
#  'CLCA4',
#  'SH3GLB1',
#  'SELENOF',
#  'HS2ST1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'GBP5',
#  'GBP6',
#  'LRRC8B',
#  'LRRC8C',
#  'LRRC8D',
#  'ZNF326',
#  'BARHL2',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'SETSIP',
#  'BTBD8',
#  'C1orf146',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'RPL5',
#  'DIPK1A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'ALG14',
#  'TLCD4',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR5',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'LRRC39',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'GPR88',
#  'VCAM1',
#  'EXTL2',
#  'SLC30A7',
#  'DPH5',
#  'S1PR1',
#  'OLFM3',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AMY2A',
#  'AMY1A',
#  'AMY1B',
#  'AMY1C',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'NBPF4',
#  'NBPF6',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'FNDC7',
#  'STXBP3',
#  'AKNAD1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'TMEM167B',
#  'C1orf194',
#  'ELAPOR1',
#  'SARS1',
#  'CELSR2',
#  'PSRC1',
#  'MYBPHL',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GPR61',
#  'GNAI3',
#  'GNAT2',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM1',
#  'GSTM5',
#  'GSTM3',
#  'EPS8L3',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'ALX3',
#  'UBL4B',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'LAMTOR5',
#  'PROK1',
#  'KCNA10',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'LRIF1',
#  'DRAM2',
#  'CEPT1',
#  'DENND2D',
#  'CHI3L2',
#  'CHIA',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'C1orf162',
#  'TMIGD3',
#  'ADORA3',
#  'RAP1A',
#  'INKA2',
#  'DDX20',
#  'KCND3',
#  'CTTNBP2NL',
#  'WNT2B',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'RHOC',
#  'PPM1J',
#  'TAFA3',
#  'SLC16A1',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1',
#  'OLFML3',
#  'SYT6',
#  'TRIM33',
#  ...]

# %%
adata.var['gene_name']=adata.var.index
adata.var['gene_name']
# Out:
# gene_name
# A1BG                                              A1BG
# A1BG-AS1                                      A1BG-AS1
# A1CF                                              A1CF
# A2M                                                A2M
# A2M-AS1                                        A2M-AS1
#                                        ...
# ZZZ3                                              ZZZ3
# MISP3                                            MISP3
# ENSG00000234352.9                    ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3    ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                    SBNO1-AS1
# Name: gene_name, Length: 20299, dtype: category
# Categories (25391, object): ['7SK_ENSG00000202198', 'A1BG', 'A1BG-AS1', 'A1CF', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
existing_genes = adata.var['gene_name']
existing_genes
# Out:
# gene_name
# A1BG                                              A1BG
# A1BG-AS1                                      A1BG-AS1
# A1CF                                              A1CF
# A2M                                                A2M
# A2M-AS1                                        A2M-AS1
#                                        ...
# ZZZ3                                              ZZZ3
# MISP3                                            MISP3
# ENSG00000234352.9                    ENSG00000234352.9
# ARHGAP27P1-BPTFP1-KPNA2P3    ARHGAP27P1-BPTFP1-KPNA2P3
# SBNO1-AS1                                    SBNO1-AS1
# Name: gene_name, Length: 20299, dtype: category
# Categories (25391, object): ['7SK_ENSG00000202198', 'A1BG', 'A1BG-AS1', 'A1CF', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
# 将所有基因名称转换为小写
all_genes_lower = [gene.lower() for gene in all_genes]
adata_genes_lower = [gene.lower() for gene in existing_genes]

# 将两个列表转换为集合
all_genes_set = set(all_genes_lower)
adata_genes_set = set(adata_genes_lower)

# 计算交集
matching_genes = all_genes_set.intersection(adata_genes_set)
matching_count = len(matching_genes)
# 计算不匹配的基因
non_matching_genes = adata_genes_set - matching_genes
non_matching_count = len(non_matching_genes)


# 输出结果
print(f"匹配的基因数量: {matching_count}")
print(f"匹配的基因列表: {matching_genes}")
non_matching_genes
# Out:
# 匹配的基因数量: 15360
# 匹配的基因列表: {'rap1gap', 'psme1', 'mettl22', 'ccdc15', 'znf776', 'tnik', 'gnai2', 'c1s', 'kiaa1191', 'dus1l', 'slc37a1', 'mfsd14a', 'pkib', 'rad54l2', 'spr', 'limd2', 'chst14', 'tollip', 'ikzf5', 'slc48a1', 'cfap54', 'caskin2', 'slf1', 'ap3m2', 'pilrb', 'zzz3', 'boc', 'anapc4', 'elf1', 'igll1', 'rnpep', 'c4orf46', 'sgcg', 'znf195', 'rpl37', 'mrps33', 'pard6b', 'sh3rf2', 'pafah1b2', 'zcchc18', 'nfkb2', 'sobp', 'hbp1', 'cd151', 'stx19', 'fat3', 'cd22', 'lsm11', 'mrpl34', 'slc27a1', 'piwil1', 'sgip1', 'rpusd3', 'gem', 'kctd19', 'psmf1', 'rfx4', 'c18orf54', 'fem1c', 'eda2r', 'fkbp11', 'vil1', 'hspa13', 'cskmt', 'zfand3', 'elovl7', 'lpgat1', 'ccr4', 'b3glct', 'p2ry11', 'chl1', 'park7', 'trpc7', 'susd3', 'tango6', 'magoh', 'nanp', 'csmd2', 'syne4', 'efcab6', 'znf385c', 'eaf1', 'ppp2r2a', 'kiaa1549l', 'znf132', 'h1-3', 'znf644', 'cdca7l', 'wasl', 'rsf1', 'vta1', 'bsg', 'hesx1', 'tnfrsf11a', 'iqub', 'rassf7', 'mgst1', 'gpatch8', 'mrpl51', 'enpp5', 'paxip1', 'isca1', 'hoxb6', 'acvr2a', 'lzts2', 'adm2', 'sars1', 'mastl', 'rgpd1', 'vkorc1', 'hm13', 'cd46', 'rapgef4', 'copg1', 'fastkd5', 'tpst2', 'kcnmb2', 'padi1', 'slco4c1', 'c11orf21', 'prpf40b', 'ccr7', 'tnfrsf8', 'hoxc11', 'galnt16', 'mt-nd4', 's100a4', 'phrf1', 'znf557', 'mfsd3', 'znhit3', 'gmfb', 'nt5dc4', 'slc22a12', 'spag4', 'cd300e', 'znf197', 'tspan14', 'cpsf4', 'adarb2', 'tspan33', 'spopl', 'abca12', 'rnf13', 'rad54b', 'matn4', 'pdk3', 'pum3', 'prpsap1', 'trex1', 'hspb1', 'calca', 'bcam', 'nedd8-mdp1', 'gyg1', 'camkmt', 'rpa1', 'adamtsl5', 'brd4', 'hexa', 'traf3', 'sltm', 'gzmk', 'thrsp', 'glra3', 'gabrr1', 'mfsd10', 'cgn', 'rab30', 'gga3', 'cdh7', 'dis3l2', 'eif2ak4', 'incenp', 'nasp', 'adcy2', 'il18bp', 'tmem140', 'st3gal1', 'klc1', 'usp10', 'hla-doa', 'irx2', 'epha7', 'lhfpl3', 'pde12', 'uchl3', 'cars2', 'znf462', 'snx32', 'emc9', 'atp5mc1', 'rac2', 'hsd17b12', 'tbc1d16', 'ghrhr', 'srbd1', 'lima1', 'zranb3', 'hla-dqb1', 'erich5', 'ifit3', 'ca4', 'znf623', 'crlf1', 'ralgds', 'acot2', 'fkbp8', 'mycl', 'unk', 'ptdss2', 'itih3', 'lrig3', 'msh3', 'snrpe', 'ppie', 'hyal4', 'znf641', 'flt1', 'kif7', 'drg2', 'cd81', 'glra1', 'maml1', 'plekhg3', 'creb3l2', 'ahsa1', 'kdm4b', 'zbtb9', 'znf274', 'nt5dc2', 'slc30a5', 'rad51c', 'c21orf58', 'sdf2l1', 'laptm5', 'lgals8', 'mex3b', 'nab1', 'preb', 'aqr', 'hoxa1', 'cep152', 'hmox1', 'igsf1', 'itga10', 'kif13a', 'vwa2', 'wrap53', 'serinc5', 'cmtm4', 'rap2c', 'nme5', 'myom1', 'mrnip', 'ing2', 'plau', 'cops2', 'atp2a2', 'cfap97', 'ccl21', 'ofd1', 'pcnx2', 'gng12', 'cnot10', 'tmem132c', 'snn', 'znf717', 'amer1', 'nup88', 'tspan9', 'znf311', 'nprl3', 'lcp2', 'ifi27', 'fmo4', 'fstl4', 'pcdhb3', 'henmt1', 'dtnb', 'tmed8', 'atp9b', 'cnih1', 'alkbh5', 'kmt5c', 'pomk', 'znf75a', 'aldh4a1', 'dcun1d5', 'abi3bp', 'lypd5', 'c18orf21', 'nipbl', 'safb2', 'fbxo36', 'tmem126b', 'smad1', 'rpl19', 'rbak', 'elp4', 'hspe1', 'rnf112', 'fam220a', 'inhbb', 'erv3-1', 'sirt3', 'slc6a4', 'lsm6', 'ubtd1', 'zscan21', 'rragc', 'cadm4', 'tmem17', 'exosc5', 'fbxo42', 'slbp', 'srprb', 'wdr27', 'usp14', 'adcy6', 'pou6f2', 'rap2b', 'prss12', 'invs', 'ffar4', 'scin', 'folh1', 'il23a', 'cnnm1', 'tnni2', 'batf', 'cd55', 'disc1', 'snrpa1', 'chst7', 'nudc', 'trmt6', 'st14', 'tyrobp', 'acsbg1', 'mrpl32', 'leap2', 'sema5a', 'cercam', 'rad9a', 'ssbp4', 'pabpc4', 'tmod3', 'casp9', 'atad3b', 'dnmt1', 'anxa13', 'ywhah', 'cdc42ep5', 'fgf2', 'znf562', 'fadd', 'dtx3l', 'dtwd2', 'saa1', 'gca', 'synpo2', 'cenpv', 'trim47', 'nuak2', 'ppid', 'aprt', 'nckap1', 'nlgn2', 'siglec7', 'aida', 'sass6', 'ppp1r18', 'lrrc32', 'znf71', 'itga1', 'ebf3', 'ino80e', 'srpx2', 'gsta1', 'pccb', 'triobp', 'casp6', 'vwc2l', 'rhoa', 'tradd', 'macrod2', 'zhx3', 'atg12', 'vcan', 'ubxn2a', 'spp2', 'bmp1', 'fchsd2', 'ugcg', 'pbld', 'nek11', 'trim39', 'nxph2', 'agpat5', 'tubgcp4', 'selenoo', 'bmi1', 'rab29', 'serpinb6', 'bok', 'qrsl1', 'clasp1', 'tomm5', 'gucy2c', 'cd300lg', 'ddx11', 'mks1', 'eif2s3', 'calm3', 'cldn19', 'pdcd2', 'klhl23', 'znf227', 'cftr', 'mtln', 'slc25a11', 'ly75', 'mpp3', 'sf3a1', 'hba1', 'znf577', 'melk', ...
# {'rab11b-as1',
#  'eeig1',
#  'cldn10-as1',
#  'ensg00000272953.2',
#  'efcab13-dt',
#  'ensg00000271011.1',
#  'hormad2-as1',
#  'zranb2-dt',
#  'psors1c3',
#  'tpm1-as',
#  'c21orf91-ot1',
#  'lpp-as2',
#  'ensg00000272861.1',
#  'ensg00000224376.3',
#  'ensg00000270099.1',
#  'mir1915hg',
#  'ensg00000250397.2',
#  'frmd6-as2',
#  'linc01503',
#  'sp2-as1',
#  'ensg00000272256.1',
#  'linc02104',
#  'ensg00000255310.2',
#  'plcg1-as1',
#  'plcxd1_ensg00000182378',
#  'or2a1-as1',
#  'znf473cr',
#  'linc00839',
#  'ensg00000230782.1',
#  'baz1a-as1',
#  'myo1b-as1',
#  'linc02015',
#  'msra-dt',
#  'cfap119',
#  'lciiar',
#  'arhgap26-as1',
#  'linc02365',
#  'linc01213',
#  'cyp51a1-as1',
#  'dlg5-as1',
#  'linc01494',
#  'linc01508',
#  'mast3-as1',
#  'glis2-as1',
#  'linc02596',
#  'ensg00000248927.1',
#  'exoc3-as1',
#  'rph3al-as2',
#  'dnmbp-as1',
#  'dpy19l3-dt',
#  'septin7-dt',
#  'map3k20-as1',
#  'msrb3-as1',
#  'actmap',
#  'ensg00000269973.1',
#  'ajuba-dt',
#  'linc01643',
#  'zbtb20-as1',
#  'h2az1-dt',
#  'pcdh10-dt',
#  'itpr2-as1',
#  'linc01429',
#  'fgf10-as1',
#  'ensg00000224239.1',
#  'cacna1c-as2',
#  'linc01116',
#  'wac-as1',
#  'ensg00000223732.2',
#  'linc00896',
#  'kcnip2-as1',
#  'linc02987',
#  'ensg00000203472.3',
#  'ensg00000227496.3',
#  'ensg00000255158.1',
#  'znf350-as1',
#  'cyyr1-as1',
#  'map3k4-as1',
#  'ensg00000244055.2',
#  'ensg00000262560.1',
#  'znf470-dt',
#  'ensg00000249476.2',
#  'ensg00000255839.1',
#  'nudt19-dt',
#  'linc02610',
#  'ensg00000260342.2',
#  'ensg00000269971.1',
#  'ensg00000256571.1',
#  'ensg00000256538.2',
#  'itgb5-as1',
#  'ensg00000230387.5',
#  'lyrm4-as1',
#  'pdcd4-as1',
#  'ensg00000260368.1',
#  'linc01192',
#  'nutm2b-as1',
#  'linc00609',
#  'ensg00000260796.1',
#  'ensg00000260495.1',
#  'zng1a',
#  'ensg00000269635.1',
#  'ninj2-as1',
#  'ensg00000273248.2',
#  'ensg00000203392.3',
#  'ensg00000227619.3',
#  'stx5-dt',
#  'ensg00000250696.5',
#  'linc01754',
#  'prkacb-dt',
#  'ensg00000254288.1',
#  'ensg00000263823.2',
#  'faup4',
#  'ensg00000267723.1',
#  'linc01063',
#  'rusc1-as1',
#  'rn7sl834p',
#  'ensg00000226281.6',
#  'ensg00000250186.3',
#  'fzd10-as1',
#  'mir4527hg',
#  'nudt16-dt',
#  'ensg00000267968.1',
#  'bltp3a',
#  'celsr1p1',
#  'mir30c2',
#  'ensg00000272463.2',
#  'ensg00000271926.1',
#  'nxf5',
#  'ensg00000225146.1',
#  'linc02086',
#  'ensg00000254662.1',
#  'cox10-dt',
#  'ensg00000224985.1',
#  'mettl25b',
#  'prkcz-as1',
#  'ensg00000253880.1',
#  'ensg00000258558.1',
#  'lncrna-iur',
#  'ensg00000267868.1',
#  'ensg00000247970.3',
#  'ensg00000249655.1',
#  'ensg00000241409.1',
#  'ensg00000261888.1',
#  'magi2-as3',
#  'ensg00000227857.2',
#  'ensg00000226471.7',
#  'ensg00000272787.1',
#  'ensg00000229178.1',
#  'chrm3-as2',
#  'zfp28-dt',
#  'linc01900',
#  'trabd-as1',
#  'bdnf-as',
#  'ensg00000270277.1',
#  'vps33b-dt',
#  'linc02012',
#  'mir4500hg',
#  'ensg00000275431.1',
#  'linc01951',
#  'linc00484_ensg00000229694',
#  'ensg00000255476.1',
#  'ensg00000257553.1',
#  'linc02762',
#  'linc02067',
#  'ensg00000249319.2',
#  'grpel2-as1',
#  'scube3-as1',
#  'ensg00000260510.1',
#  'mapkapk5-as1',
#  'ensg00000267222.1',
#  'linc01169',
#  'itfg2-as1_ensg00000256150',
#  'linc02102',
#  'ensg00000251409.2',
#  'ensg00000233912.1',
#  'klf3-as1',
#  'garin2',
#  'ensg00000274422.1',
#  'magoh-dt',
#  'ensg00000250069.1',
#  'pank2-as1',
#  'hmga2-as1',
#  'ensg00000267552.6',
#  'ensg00000260878.1',
#  'map7-as1',
#  'ensg00000249240.2',
#  'ensg00000237498.3',
#  'linc00958',
#  'fam182a',
#  'ensg00000246090.9',
#  'gata2-as1',
#  'linc02752',
#  'ensg00000259543.1',
#  'ensg00000230303.6',
#  'linc00970',
#  'linc01841',
#  'heatr5a-dt',
#  'disc1fp1',
#  'ensg00000224746.2',
#  'a2ml1-as1',
#  'ensg00000263300.1',
#  'xpc-as1',
#  'slc35e2a',
#  'ensg00000273448.1',
#  'ensg00000267688.1',
#  'ensg00000232536.1',
#  'ensg00000238272.1',
#  'linc02615',
#  'ensg00000255968.1',
#  'ensg00000258122.1',
#  'ensg00000196566.2',
#  'ensg00000259113.1',
#  'ensg00000260038.1',
#  'mir302chg',
#  'ensg00000245025.3',
#  'ensg00000229591.1',
#  'linc01801',
#  'linc01482',
#  'ensg00000261098.1',
#  'ensg00000260095.1',
#  'gaplinc',
#  'linc02884',
#  'ensg00000232555.2',
#  'linc02696',
#  'linc02226',
#  'ensg00000257894.2',
#  'mt-ti',
#  'ensg00000259682.1',
#  'ensg00000272121.1',
#  'hdac11-as1',
#  'ensg00000267980.1',
#  'ensg00000266490.1',
#  'linc01284',
#  'bfsp2-as1',
#  'ensg00000215304.3',
#  'ensg00000258504.2',
#  'ensg00000271199.1',
#  'hcg25',
#  'ensg00000228648.1',
#  'ensg00000256824.1',
#  'ensg00000285938.1',
#  'ensg00000255320.2',
#  'nrav',
#  'ensg00000246331.2',
#  'ensg00000226644.5',
#  'ensg00000259275.5',
#  'ensg00000231829.4',
#  'b4gat1-dt',
#  'ensg00000273174.1',
#  'rnpc3-dt',
#  'linc01702',
#  'zscan16-as1',
#  'c10orf55',
#  'ppp4r3b-dt',
#  'znf516-as1',
#  'ensg00000261242.1',
#  'ensg00000226829.2',
#  'cop1-dt',
#  'ensg00000268947.1',
#  'ensg00000268575.1',
#  'ensg00000256139.2',
#  'ensg00000243797.6',
#  'slc7a11-as1',
#  'cradd-as1',
#  'ensg00000230325.1',
#  'linc01605_ensg00000253161',
#  'ensg00000258881.6',
#  'hoxa10-as',
#  'cenatac-dt',
#  'ensg00000265254.1',
#  'ensg00000259720.2',
#  'linc01936',
#  'cd2ap-dt',
#  'slc30a6-dt',
#  'ensg00000270659.2',
#  'linc01588',
#  'ensg00000229751.1',
#  'ensg00000253688.2',
#  'ensg00000272906.1',
#  'card8-as1',
#  'fam53b-as1',
#  'card16',
#  'ensg00000262302.1',
#  'lmf1-as1',
#  'linc00996',
#  'deptor-as1',
#  'linc01182',
#  'ensg00000232110.9',
#  'linc01278',
#  'ighg1',
#  'linc01948',
#  'ensg00000226465.5',
#  'tnfrsf10a-dt_ensg00000250714',
#  'ensg00000253475.1',
#  'ensg00000270087.7',
#  'pdxdc2p-npipb14p',
#  'piwil2-dt',
#  'nup107-dt',
#  'znf582-dt',
#  'ensg00000229728.1',
#  'ensg00000264339.1',
#  'ensg00000253307.1',
#  'ensg00000250866.1',
#  'linc01847',
#  'rhoa-it1',
#  'ensg00000256278.1',
#  'ensg00000253361.3',
#  'ensg00000262877.5',
#  'ensg00000290740.1',
#  'snhg14',
#  'ensg00000238280.2',
#  'linc02984',
#  'linc03022',
#  'ensg00000263745.7',
#  'ensg00000273112.1',
#  'linc01170',
#  'linc02154',
#  'linc01592',
#  'linc01914',
#  'ensg00000272667.1',
#  'alox12-as1',
#  'ensg00000226332.2',
#  'ensg00000259345.7',
#  'linc02316',
#  'ensg00000271993.1',
#  'ensg00000253256.1',
#  'linc01611',
#  'ensg00000224818.1',
#  'purpl',
#  'linc01550',
#  'ensg00000228423.2',
#  'ifnar2-il10rb',
#  'glcci1-dt',
#  'ensg00000261487.1',
#  'ensg00000272622.2',
#  'linc01684',
#  'ensg00000270108.1',
#  'arhgef2-as2',
#  'ensg00000272449.3',
#  'ensg00000273212.1',
#  'mgc16275',
#  'mt-rnr2',
#  'add3-as1',
#  'slco5a1-as1',
#  'linc02640',
#  'ensg00000262837.1',
#  'ensg00000267838.2',
#  'ankrd17-dt',
#  'gtpbp6_ensg00000178605',
#  'ensg00000270720.1',
#  'ensg00000250699.1',
#  'mapk6-dt',
#  'ensg00000131152.4',
#  'ensg00000260244.1',
#  'mir3667hg',
#  'ensg00000254533.1',
#  'rhoxf1-as1',
#  'ensg00000261135.1',
#  'ensg00000259767.1',
#  'cttn-dt',
#  'linc01671',
#  'irx2-dt',
#  'dnaaf11',
#  'mir17hg',
#  'ensg00000259168.1',
#  'ensg00000266877.1',
#  'ensg00000250243.3',
#  'fam174a-dt',
#  'matn1-as1',
#  'uqcc6',
#  'ensg00000272221.1',
#  'ensg00000259287.2',
#  'linc01436',
#  'linc00159',
#  'ensg00000266371.1',
#  'ptprn2-as1',
#  'linc03015',
#  'foxn3-as1',
#  'ensg00000273186.1',
#  'ensg00000214719.13',
#  'gorab-as1',
#  'tmem9b-as1',
#  'ensg00000269242.1',
#  'crtc3-as1',
#  'hdac4-as1',
#  'hnrnpd-dt',
#  'cpne8-as1',
#  'linc01311',
#  'dlg1-as1',
#  'ensg00000255447.1',
#  'ensg00000258394.1',
#  'nup50-dt',
#  'gata6-as1',
#  'bves-as1',
#  'fam135a-as1',
#  'tspoap1-as1',
#  'csrp1-as1',
#  'znf295-as1',
#  'ensg00000253939.1',
#  'ensg00000267783.3',
#  'linc01591',
#  'ensg00000266049.1',
#  'linc01089',
#  'linc01194',
#  'linc01271',
#  'sftpd-as1',
#  'ensg00000260177.1',
#  'rgs5',
#  'linc01983',
#  'ensg00000203279.6',
#  'znf790-as1',
#  'linc02913',
#  'ensg00000254757.1',
#  'lmntd2-as1',
#  'smg1-dt',
#  'tmem147-as1',
#  'rn7sl526p',
#  'wakmar2',
#  'aprg1',
#  'uchl1-dt',
#  'linc00877',
#  'linc02506',
#  'linc01117',
#  'znf213-as1',
#  'ensg00000273076.1',
#  'ensg00000260983.2',
#  'ensg00000259366.3',
#  'h2bc20p',
#  'mir200chg',
#  'ensg00000259992.1',
#  'ensg00000249328.3',
#  'ensg00000288670.1',
#  'ensg00000267049.1',
#  'cerox1',
#  'ensg00000272384.2',
#  'ensg00000271780.2',
#  'snhg12',
#  'ensg00000231873.2',
#  'linc01535',
#  'kiz-as1',
#  'ensg00000237899.1',
#  'fsip2-as1',
#  'ensg00000260593.1',
#  'ensg00000268584.1',
#  'ensg00000227678.8',
#  'slc25a21-as1',
#  'ace2-dt',
#  'ensg00000259846.1',
#  'cd99_ensg00000002586',
#  'linc01987',
#  'ensg00000225313.5',
#  'ensg00000263063.1',
#  'ensg00000229896.2',
#  'ensg00000262979.1',
#  'igf2bp2-as1',
#  'h2ac25',
#  'linc02177',
#  'nrsn2-as1',
#  'kcnq1ot1',
#  'tmem11-dt',
#  'ensg00000270100.1',
#  'tnfrsf10a-dt_ensg00000246582',
#  'ensg00000225761.1',
#  'linc03033',
#  'ensg00000272108.1',
#  'ensg00000230551.4',
#  'ensg00000257228.5',
#  'ensg00000253286.6',
#  'linc02520',
#  'ensg00000254787.1',
#  'ensg00000231985.1',
#  'ensg00000249426.1',
#  'ensg00000246308.4',
#  'snrpa1-dt',
#  'ensg00000251652.1',
#  'ensg00000223838.2',
#  'ensg00000231772.5',
#  'eml2-as1',
#  'ensg00000267481.1',
#  'rgs5-as1',
#  'epcam-dt',
#  'ensg00000269949.1',
#  'carmal',
#  'linc00857',
#  'ensg00000267504.1',
#  'ensg00000245768.7',
#  'sspop',
#  'ensg00000238039.1',
#  'linc00870',
#  'rn7sl559p',
#  'ensg00000271155.1',
#  'linc01789',
#  'ensg00000267039.1',
#  'ensg00000253200.1',
#  'neat1',
#  'lipt2-as1',
#  'ensg00000254084.1',
#  'acta2-as1',
#  'rn7sl378p',
#  'ensg00000272243.6',
#  'meg3',
#  'dock9-dt',
#  'ensg00000231769.4',
#  'ensg00000260273.2',
#  'linc00115',
#  'ensg00000272316.1',
#  'scoc-as1',
#  'foxp1-it1',
#  'ensg00000271380.1',
#  'ensg00000272558.1',
#  'znf691-dt',
#  'slc39a13-as1',
#  'rhoq-as1',
#  'rad51-as1',
#  'mirlet7ihg',
#  'ensg00000256185.1',
#  'ensg00000260816.2',
#  'ensg00000255557.1',
#  'ensg00000232628.7',
#  'linc01428',
#  'ensg00000267016.1',
#  'ensg00000267360.6',
#  'ensg00000273258.1',
#  'gtf2i-as1',
#  'satb1-as1',
#  'aftph-dt',
#  'ensg00000228944.1',
#  'linc00393',
#  'ensg00000273058.2',
#  'ate1osp',
#  'ensg00000259647.1',
#  'eif3j-dt',
#  'linc00924',
#  'appbp2-dt',
#  'ensg00000225610.1',
#  'ensg00000272969.1',
#  'rn7sl230p',
#  'rnu2-68p',
#  'linc01220',
#  'comett',
#  'nqo2-as1',
#  'linc01787',
#  'linc01768',
#  'ensg00000229337.2',
#  'linc00457',
#  'ensg00000268744.1',
#  'ensg00000243415.2',
#  'ensg00000267077.1',
#  'mt-tv',
#  'st7-ot4',
#  'hotair',
#  'ensg00000265496.5',
#  'ensg00000269919.1',
#  'ensg00000258784.1',
#  'ensg00000258760.1',
#  'snhg9',
#  'ensg00000243081.2',
#  'suclg2-dt',
#  'rnf217-as1',
#  'mta1-dt',
#  'ensg00000272247.1',
#  'ensg00000230490.4',
#  'ensg00000225311.1',
#  'cdk13-dt',
#  'ensg00000255835.1',
#  'psmb8-as1',
#  'ensg00000224342.1',
#  'ensg00000241770.1',
#  'ensg00000235271.6',
#  'linc01569',
#  'ensg00000261717.5',
#  'ensg00000267448.6',
#  'kdsr-dt',
#  'ensg00000236540.7',
#  'linc01695',
#  'ensg00000273387.1',
#  'chmp3-as1',
#  'ensg00000223804.6',
#  'ddx39b-as1',
#  'ensg00000251194.2',
#  'sap30-dt',
#  'ensg00000259972.3',
#  'dcun1d2-as',
#  'tex56p',
#  'atosb',
#  'tmc3-as1',
#  'ensg00000237844.2',
#  'lnc-lbcs',
#  'dnaaf10',
#  'erve-1',
#  'sap30l-as1',
#  'ensg00000272609.1',
#  'ensg00000257342.1',
#  'ensg00000272541.1',
#  'rusf1-dt',
#  'ensg00000273338.1',
#  'ensg00000230286.1',
#  'ensg00000271949.1',
#  'linc01676',
#  'gacat2',
#  'ensg00000259199.2',
#  'ensg00000267984.1',
#  'linc00574',
#  'rab17-dt',
#  'ensg00000261147.1',
#  'tmco1-as1',
#  'c12orf75-as1',
#  'linc01473',
#  'ovch1-as1',
#  'ensg00000267109.1',
#  'ensg00000261427.6',
#  'ubl7-dt',
#  'hmga1p4',
#  'asic4-as1',
#  'ensg00000260196.1',
#  'adora2a-as1',
#  'rufy1-as1',
#  'ensg00000272510.1',
#  'morf4l2-as1',
#  'linc00882',
#  'ensg00000272647.3',
#  'linc01121',
#  'ensg00000271917.1',
#  'ensg00000261324.2',
#  'ensg00000272689.1',
#  'ensg00000254789.4',
#  'gcnt2p1',
#  'zranb2-as1',
#  'srd5a3-as1',
#  'mrgprf-as1',
#  'sema3f-as1',
#  'mir568',
#  'raet1e-as1_ensg00000268592',
#  'ensg00000259347.9',
#  'ensg00000270871.1',
#  'znf594-dt',
#  'ensg00000253706.5',
#  'ensg00000250195.1',
#  'linc02003',
#  'ensg00000226526.1',
#  'capn1-as1',
#  'ensg00000242861.1',
#  'ensg00000253331.1',
#  'ensg00000269189.1',
#  'linc02165',
#  'ensg00000225335.3',
#  'ensg00000241345.1',
#  'linc00092',
#  'linc02897',
#  'matcap1',
#  'linc02223',
#  'socs2-as1',
#  'ensg00000262920.5',
#  'milip',
#  'linc00543',
#  'linc00487',
#  'pcdh9-as2',
#  'linc02944',
#  'ensg00000262810.1',
#  'vim-as1',
#  'adam7-as1',
#  'cnpy2-as1',
#  'gtscr1',
#  'ensg00000249335.5',
#  'linc01547',
#  'ensg00000259066.5',
#  'linc00702',
#  'ensg00000269124.1',
#  'ttc14-dt',
#  'ensg00000227131.1',
#  'ensg00000222042.2',
#  'linc01996',
#  'rfx5-as1',
#  'girgl',
#  'ensg00000272343.1',
#  'ensg00000238258.1',
#  'ensg00000272275.1',
#  'dlgap1-as3',
#  'ensg00000253634.3',
#  'ensg00000228484.3',
#  'ensg00000273118.1',
#  'hcg11',
#  'dhrsx_ensg00000169084',
#  'smad5-as1',
#  'gprasp3',
#  'ttty4',
#  'usp2-as1',
#  'zkscan7-as1',
#  'ensg00000271755.1',
#  'ensg00000272004.1',
#  'fam66a',
#  'cbr1-as1',
#  'ensg00000261799.1',
#  'anxa2r-as1',
#  'ensg00000266573.6',
#  'ensg00000259283.2',
#  'dubr',
#  'linc01387',
#  'linc01399',
#  'znf346-it1',
#  'meltf-as1',
#  'linc01088',
#  'pierce1',
#  'ensg00000260361.1',
#  'calcrl-as1',
#  'ensg00000267571.1',
#  'tesc-as1',
#  'ensg00000266953.6',
#  'ensg00000261790.2',
#  'ankh-dt',
#  'linc00616',
#  'ap4b1-as1',
#  'linc02325',
#  'ensg00000257298.1',
#  'ensg00000268573.1',
#  'ensg00000262089.1',
#  'ensg00000271893.1',
#  'c7_ensg00000112936',
#  'zfy-as1',
#  'linc02384',
#  'ccdc18-as1',
#  'ensg00000255432.1',
#  'tmem44-as2',
#  'ensg00000258875.6',
#  'ensg00000257703.6',
#  'linc01499',
#  'linc02652',
#  'ensg00000272129.1',
#  'linc00511',
#  'pierce2',
#  'hcg14',
#  'ensg00000272149.1',
#  'ensg00000271795.1',
#  'ensg00000226566.2',
#  'arlnc1',
#  'linc00528',
#  'gatd1-dt',
#  'zeb1-as1',
#  'ensg00000269749.1',
#  'ensg00000225806.8',
#  'ensg00000187186.15',
#  'ensg00000234273.1',
#  'ensg00000269924.1',
#  'ensg00000253553.9',
#  'ensg00000100101.15',
#  'linc02693',
#  'ensg00000271009.3',
#  'ensg00000271882.1',
#  'rnu6-414p',
#  'ensg00000259053.1',
#  'il10rb-dt',
#  'smc2-dt',
#  'ppp1r12a-as1',
#  'ensg00000259515.1',
#  'ensg00000227075.1',
#  'ensg00000232072.1',
#  'cep250-as1',
#  'ensg00000232638.1',
#  'linc02728',
#  'ensg00000250969.1',
#  'nova1-dt',
#  'ptchd1-as',
#  'nckap5-as2',
#  'linc02056',
#  'ensg00000269194.1',
#  'pdgfa-dt',
#  'spopl-dt',
#  'dnah10os',
#  'ensg00000254165.1',
#  'fgf7p3',
#  'ensg00000271833.1',
#  'ensg00000253690.1',
#  'trmt61a-dt',
#  'ensg00000226193.1',
#  'ensg00000268279.4',
#  'slfn12l',
#  'laptm4a-dt',
#  'linc01476',
#  'linc02405',
#  'ensg00000258793.1',
#  'ensg00000258489.4',
#  'ensg00000271793.2',
#  'linc01992',
#  'ensg00000226355.2',
#  'linc01919',
#  'ensg00000272084.1',
#  'ensg00000235127.1',
#  'ensg00000231236.2',
#  'ensg00000267283.1',
#  'khdc1-as1',
#  'ensg00000258921.1',
#  'c8orf44',
#  'ensg00000227769.7',
#  'itga9-as1',
#  'namptp1',
#  'prss42p',
#  'sema6a-as1',
#  'linc02254',
#  'bltp1',
#  'xndc1n',
#  'ensg00000251665.1',
#  'ensg00000266086.3',
#  'linc02484',
#  'part1',
#  'ensg00000229846.2',
#  'ensg00000257058.1',
#  'linc02951',
#  'ensg00000253496.3',
#  'ensg00000248015.7',
#  'ensg00000235609.7',
#  'ttty14',
#  'ensg00000124835.2',
#  'linc01594',
#  'ensg00000272155.1',
#  'linc02088',
#  'mycnut',
#  'znf407-as1',
#  'ensg00000265413.1',
#  'znf460-as1',
#  'linc02332',
#  'ensg00000240086.7',
#  'ensg00000272784.1',
#  'arhgap5-as1',
#  'linc00558',
#  'ensg00000262879.7',
#  'ensg00000270072.1',
#  'ensg00000268416.1',
#  'ccdc54-as1',
#  'ensg00000273183.1',
#  'linc02046',
#  'ensg00000273066.5',
#  'ensg00000273014.1',
#  'ensg00000224077.1',
#  'ensg00000267653.1',
#  'cenpn-as1',
#  'linc02281',
#  'ensg00000269906.1',
#  'rn7sl308p',
#  'ensg00000225233.2',
#  'c9orf72_ensg00000147894',
#  'znf793-as1',
#  'ensg00000253363.7',
#  'ensg00000259327.1',
#  'ensg00000254690.1',
#  'ncoa7-as1',
#  'ensg00000270972.1',
#  'mir2052hg',
#  'rn7sl23p',
#  'ensg00000255224.2',
#  'ensg00000258473.2',
#  'ensg00000269986.1',
#  'gna14-as1',
#  'ensg00000244701.1',
#  'ccnt2-as1',
#  'ensg00000239300.6',
#  'rel-dt',
#  'ensg00000232220.2',
#  'yeats2-as1',
#  'ensg00000263272.1',
#  'nox5_ensg00000255346',
#  'ensg00000259522.3',
#  'ensg00000273139.2',
#  'ensg00000248240.1',
#  'linc02161',
#  'ensg00000240521.1',
#  'linc00621',
#  'ensg00000268129.2',
#  'ensg00000237188.5',
#  'sanbr',
#  'cavin2-as1',
#  'ensg00000268836.1',
#  'ensg00000248161.5',
#  'pcbp1-as1',
#  'h2az2-dt',
#  'gask1b-as1',
#  'ensg00000257322.7',
#  'linc01018',
#  'dph5-dt',
#  'ensg00000268659.2',
#  'ensg00000228886.1',
#  'ppp1r21-dt',
#  'ensg00000272921.1',
#  'linc02742',
#  'ensg00000271880.1',
#  'ensg00000228061.7',
#  'pxn-as1',
#  'ensg00000248242.1',
#  'tex41',
#  'trhde-as1',
#  'ensg00000272892.1',
#  'ensg00000236065.2',
#  'ensg00000261187.1',
#  'zbed5-as1',
#  'pelaton',
#  'ensg00000253888.2',
#  'acvr2b-as1',
#  'proser2-as1',
#  'ensg00000267618.5',
#  'garin1b',
#  'linc01273',
#  'mapt-as1',
#  'ensg00000227240.2',
#  'ensg00000243276.6',
#  'haglr',
#  'gs1-24f4.2',
#  'tm4sf1-as1',
#  'ensg00000267461.1',
#  'ensg00000260971.4',
#  'linc01711',
#  'ensg00000257355.1',
#  'ensg00000253844.2',
#  'ensg00000269469.1',
#  'ensg00000267127.7',
#  'linc02614',
#  'inka2-as1',
#  'ensg00000273188.1',
#  'flvcr1-dt',
#  'tmem220-as1',
#  'efcab15p',
#  'ensg00000229151.3',
#  'linc02777',
#  'ensg00000240963.1',
#  'gar1-dt',
#  'ensg00000237927.1',
#  'gna15-dt',
#  'adgrb3-dt',
#  'ensg00000272416.1',
#  'ccdc26',
#  'dio2-as1',
#  'zng1e',
#  'ensg00000253108.1',
#  'ensg00000245748.1',
#  'linc02082',
#  'erich2-dt',
#  'ensg00000290791.1',
#  'ensg00000268401.2',
#  'ensg00000267026.5',
#  'ensg00000244459.4',
#  'mhencr',
#  'ensg00000227482.1',
#  'ensg00000268536.2',
#  'ensg00000262714.1',
#  'linc00426',
#  'ensg00000235192.1',
#  'ensg00000228142.3',
#  'mir205hg',
#  'stag3l5p-pvrig2p-pilrb',
#  'ensg00000267279.3',
#  'linc00243',
#  'ensg00000255367.4',
#  'mir31hg',
#  'linc01545',
#  'pik3ip1-dt',
#  'ilrun-as1',
#  'snrpf-dt',
#  'ensg00000254129.1',
#  'ensg00000265394.1',
#  'linc01359',
#  'ensg00000259579.1',
#  'cers3-as1',
#  'ensg00000236676.1',
#  'prr34',
#  'ensg00000259986.2',
#  'ensg00000273221.1',
#  'bcdin3d-as1',
#  'krbox5',
#  'ensg00000263708.2',
#  'ensg00000257407.1',
#  'copb2-dt',
#  'ensg00000269489.1',
#  'emx2os',
#  'ensg00000268713.1',
#  'dirc3-as1',
#  'gatd3',
#  'ensg00000233290.4',
#  'oser1-dt',
#  'catip-as2',
#  'ensg00000257681.1',
#  'ensg00000259357.2',
#  'linc02408',
#  'ugdh-as1',
#  'pcat19',
#  'ensg00000269082.1',
#  'sox2-ot',
#  'ensg00000257252.7',
#  'hmgn3-as1',
#  'ensg00000234626.2',
#  'linc01344',
#  'ensg00000268362.6',
#  'arhgap11a-dt',
#  'ensg00000270792.6',
#  'ensg00000236948.2',
#  'patj-dt',
#  'ensg00000266896.1',
#  'ensg00000255663.1',
#  'ensg00000273035.1',
#  'ensg00000228204.2',
#  'asmtl_ensg00000169093',
#  'rn7sl47p',
#  'linc00992',
#  'ensg00000258378.1',
#  ...}

# %%
gene_to_index = {gene: idx for idx, gene in enumerate(all_genes_lower)}
gene_to_index
# Out:
# {'or4f5': 0,
#  'or4f29': 1,
#  'or4f16': 2,
#  'samd11': 3,
#  'noc2l': 4,
#  'klhl17': 5,
#  'plekhn1': 6,
#  'perm1': 7,
#  'hes4': 8,
#  'isg15': 9,
#  'agrn': 10,
#  'rnf223': 11,
#  'c1orf159': 12,
#  'ttll10': 13,
#  'tnfrsf18': 14,
#  'tnfrsf4': 15,
#  'sdf4': 16,
#  'b3galt6': 17,
#  'c1qtnf12': 18,
#  'ube2j2': 19,
#  'scnn1d': 20,
#  'acap3': 21,
#  'pusl1': 22,
#  'ints11': 23,
#  'cptp': 24,
#  'tas1r3': 25,
#  'dvl1': 26,
#  'mxra8': 27,
#  'aurkaip1': 28,
#  'ccnl2': 29,
#  'mrpl20': 30,
#  'ankrd65': 31,
#  'tmem88b': 32,
#  'vwa1': 33,
#  'atad3c': 34,
#  'atad3b': 35,
#  'atad3a': 36,
#  'tmem240': 37,
#  'ssu72': 38,
#  'fndc10': 39,
#  'mib2': 40,
#  'mmp23b': 41,
#  'cdk11b': 42,
#  'slc35e2b': 43,
#  'cdk11a': 44,
#  'nadk': 45,
#  'gnb1': 46,
#  'calml6': 47,
#  'tmem52': 48,
#  'cfap74': 49,
#  'gabrd': 50,
#  'prkcz': 51,
#  'faap20': 52,
#  'ski': 53,
#  'morn1': 54,
#  'rer1': 55,
#  'pex10': 56,
#  'plch2': 57,
#  'pank4': 58,
#  'hes5': 59,
#  'tnfrsf14': 60,
#  'prxl2b': 61,
#  'mmel1': 62,
#  'ttc34': 63,
#  'actrt2': 64,
#  'prdm16': 65,
#  'arhgef16': 66,
#  'megf6': 67,
#  'tprg1l': 68,
#  'wrap73': 69,
#  'tp73': 70,
#  'ccdc27': 71,
#  'smim1': 72,
#  'lrrc47': 73,
#  'cep104': 74,
#  'dffb': 75,
#  'c1orf174': 76,
#  'ajap1': 77,
#  'nphp4': 78,
#  'kcnab2': 79,
#  'chd5': 80,
#  'rpl22': 81,
#  'rnf207': 82,
#  'icmt': 83,
#  'hes3': 84,
#  'gpr153': 85,
#  'acot7': 86,
#  'hes2': 87,
#  'espn': 88,
#  'tnfrsf25': 89,
#  'plekhg5': 90,
#  'nol9': 91,
#  'tas1r1': 92,
#  'zbtb48': 93,
#  'klhl21': 94,
#  'phf13': 95,
#  'thap3': 96,
#  'dnajc11': 97,
#  'camta1': 98,
#  'vamp3': 99,
#  'per3': 100,
#  'uts2': 101,
#  'tnfrsf9': 102,
#  'park7': 103,
#  'errfi1': 104,
#  'slc45a1': 105,
#  'rere': 106,
#  'eno1': 107,
#  'ca6': 108,
#  'slc2a7': 109,
#  'slc2a5': 110,
#  'gpr157': 111,
#  'h6pd': 112,
#  'spsb1': 113,
#  'slc25a33': 114,
#  'tmem201': 115,
#  'pik3cd': 116,
#  'clstn1': 117,
#  'ctnnbip1': 118,
#  'lzic': 119,
#  'nmnat1': 120,
#  'rbp7': 121,
#  'ube4b': 122,
#  'kif1b': 123,
#  'pgd': 124,
#  'cenps': 125,
#  'cort': 126,
#  'dffa': 127,
#  'pex14': 128,
#  'casz1': 129,
#  'c1orf127': 130,
#  'tardbp': 131,
#  'masp2': 132,
#  'srm': 133,
#  'exosc10': 134,
#  'mtor': 135,
#  'angptl7': 136,
#  'ubiad1': 137,
#  'disp3': 138,
#  'fbxo2': 139,
#  'fbxo44': 140,
#  'fbxo6': 141,
#  'mad2l2': 142,
#  'draxin': 143,
#  'agtrap': 144,
#  'c1orf167': 145,
#  'mthfr': 146,
#  'clcn6': 147,
#  'nppa': 148,
#  'nppb': 149,
#  'kiaa2013': 150,
#  'plod1': 151,
#  'mfn2': 152,
#  'miip': 153,
#  'tnfrsf8': 154,
#  'tnfrsf1b': 155,
#  'vps13d': 156,
#  'dhrs3': 157,
#  'aadacl4': 158,
#  'aadacl3': 159,
#  'c1orf158': 160,
#  'pramef12': 161,
#  'pramef1': 162,
#  'pramef11': 163,
#  'hnrnpcl1': 164,
#  'pramef2': 165,
#  'pramef4': 166,
#  'pramef10': 167,
#  'pramef7': 168,
#  'pramef6': 169,
#  'pramef27': 170,
#  'hnrnpcl3': 171,
#  'pramef25': 172,
#  'hnrnpcl2': 173,
#  'pramef26': 174,
#  'hnrnpcl4': 175,
#  'pramef9': 176,
#  'pramef13': 177,
#  'pramef18': 178,
#  'pramef5': 179,
#  'pramef8': 180,
#  'pramef33': 181,
#  'pramef15': 182,
#  'pramef14': 183,
#  'pramef19': 184,
#  'pramef17': 185,
#  'pramef20': 186,
#  'lrrc38': 187,
#  'pdpn': 188,
#  'prdm2': 189,
#  'kazn': 190,
#  'tmem51': 191,
#  'fhad1': 192,
#  'efhd2': 193,
#  'ctrc': 194,
#  'cela2a': 195,
#  'cela2b': 196,
#  'casp9': 197,
#  'dnajc16': 198,
#  'agmat': 199,
#  'ddi2': 200,
#  'rsc1a1': 201,
#  'plekhm2': 202,
#  'slc25a34': 203,
#  'tmem82': 204,
#  'fblim1': 205,
#  'uqcrhl': 206,
#  'spen': 207,
#  'zbtb17': 208,
#  'srarp': 209,
#  'hspb7': 210,
#  'clcnka': 211,
#  'clcnkb': 212,
#  'fam131c': 213,
#  'epha2': 214,
#  'arhgef19': 215,
#  'cplane2': 216,
#  'fbxo42': 217,
#  'szrd1': 218,
#  'spata21': 219,
#  'necap2': 220,
#  'nbpf1': 221,
#  'crocc': 222,
#  'mfap2': 223,
#  'atp13a2': 224,
#  'sdhb': 225,
#  'padi2': 226,
#  'padi1': 227,
#  'padi3': 228,
#  'padi4': 229,
#  'padi6': 230,
#  'rcc2': 231,
#  'arhgef10l': 232,
#  'actl8': 233,
#  'igsf21': 234,
#  'klhdc7a': 235,
#  'pax7': 236,
#  'tas1r2': 237,
#  'aldh4a1': 238,
#  'iffo2': 239,
#  'ubr4': 240,
#  'emc1': 241,
#  'mrto4': 242,
#  'akr7a3': 243,
#  'akr7a2': 244,
#  'slc66a1': 245,
#  'capzb': 246,
#  'micos10': 247,
#  'nbl1': 248,
#  'htr6': 249,
#  'tmco4': 250,
#  'rnf186': 251,
#  'otud3': 252,
#  'pla2g2e': 253,
#  'pla2g2a': 254,
#  'pla2g5': 255,
#  'pla2g2d': 256,
#  'pla2g2f': 257,
#  'pla2g2c': 258,
#  'ubxn10': 259,
#  'vwa5b1': 260,
#  'camk2n1': 261,
#  'mul1': 262,
#  'fam43b': 263,
#  'cda': 264,
#  'pink1': 265,
#  'ddost': 266,
#  'kif17': 267,
#  'sh2d5': 268,
#  'hp1bp3': 269,
#  'eif4g3': 270,
#  'ece1': 271,
#  'nbpf3': 272,
#  'alpl': 273,
#  'rap1gap': 274,
#  'usp48': 275,
#  'ldlrad2': 276,
#  'hspg2': 277,
#  'cela3b': 278,
#  'cela3a': 279,
#  'cdc42': 280,
#  'wnt4': 281,
#  'zbtb40': 282,
#  'epha8': 283,
#  'c1qa': 284,
#  'c1qc': 285,
#  'c1qb': 286,
#  'ephb2': 287,
#  'lactbl1': 288,
#  'tex46': 289,
#  'kdm1a': 290,
#  'luzp1': 291,
#  'htr1d': 292,
#  'hnrnpr': 293,
#  'znf436': 294,
#  'tcea3': 295,
#  'asap3': 296,
#  'e2f2': 297,
#  'id3': 298,
#  'rpl11': 299,
#  'eloa': 300,
#  'pithd1': 301,
#  'lypla2': 302,
#  'gale': 303,
#  'hmgcl': 304,
#  'fuca1': 305,
#  'cnr2': 306,
#  'pnrc2': 307,
#  'srsf10': 308,
#  'myom3': 309,
#  'il22ra1': 310,
#  'ifnlr1': 311,
#  'grhl3': 312,
#  'stpg1': 313,
#  'nipal3': 314,
#  'rcan3': 315,
#  'ncmap': 316,
#  'srrm1': 317,
#  'clic4': 318,
#  'runx3': 319,
#  'syf2': 320,
#  'rsrp1': 321,
#  'rhd': 322,
#  'tmem50a': 323,
#  'rhce': 324,
#  'maco1': 325,
#  'ldlrap1': 326,
#  'man1c1': 327,
#  'selenon': 328,
#  'mtfr1l': 329,
#  'aunip': 330,
#  'paqr7': 331,
#  'stmn1': 332,
#  'pafah2': 333,
#  'extl1': 334,
#  'slc30a2': 335,
#  'trim63': 336,
#  'pdik1l': 337,
#  'fam110d': 338,
#  'c1orf232': 339,
#  'znf593os': 340,
#  'znf593': 341,
#  'cnksr1': 342,
#  'catsper4': 343,
#  'cep85': 344,
#  'sh3bgrl3': 345,
#  'ubxn11': 346,
#  'cd52': 347,
#  'crybg2': 348,
#  'znf683': 349,
#  'lin28a': 350,
#  'dhdds': 351,
#  'hmgn2': 352,
#  'rps6ka1': 353,
#  'arid1a': 354,
#  'pigv': 355,
#  'zdhhc18': 356,
#  'sfn': 357,
#  'gpn2': 358,
#  'gpatch3': 359,
#  'nudc': 360,
#  'nr0b2': 361,
#  'kdf1': 362,
#  'trnp1': 363,
#  'tent5b': 364,
#  'slc9a1': 365,
#  'wdtc1': 366,
#  'tmem222': 367,
#  'sytl1': 368,
#  'map3k6': 369,
#  'fcn3': 370,
#  'cd164l2': 371,
#  'gpr3': 372,
#  'wasf2': 373,
#  'ahdc1': 374,
#  'fgr': 375,
#  'ifi6': 376,
#  'fam76a': 377,
#  'stx12': 378,
#  'ppp1r8': 379,
#  'themis2': 380,
#  'rpa2': 381,
#  'smpdl3b': 382,
#  'xkr8': 383,
#  'eya3': 384,
#  'ptafr': 385,
#  'dnajc8': 386,
#  'atp5if1': 387,
#  'sesn2': 388,
#  'med18': 389,
#  'phactr4': 390,
#  'rcc1': 391,
#  'trnau1ap': 392,
#  'taf12': 393,
#  'rab42': 394,
#  'gmeb1': 395,
#  'ythdf2': 396,
#  'oprd1': 397,
#  'epb41': 398,
#  'tmem200b': 399,
#  'srsf4': 400,
#  'mecr': 401,
#  'ptpru': 402,
#  'matn1': 403,
#  'laptm5': 404,
#  'sdc3': 405,
#  'pum1': 406,
#  'nkain1': 407,
#  'snrnp40': 408,
#  'zcchc17': 409,
#  'fabp3': 410,
#  'serinc2': 411,
#  'tinagl1': 412,
#  'hcrtr1': 413,
#  'pef1': 414,
#  'col16a1': 415,
#  'adgrb2': 416,
#  'spocd1': 417,
#  'ptp4a2': 418,
#  'khdrbs1': 419,
#  'tmem39b': 420,
#  'kpna6': 421,
#  'txlna': 422,
#  'ccdc28b': 423,
#  'iqcc': 424,
#  'dcdc2b': 425,
#  'tmem234': 426,
#  'eif3i': 427,
#  'fam167b': 428,
#  'lck': 429,
#  'hdac1': 430,
#  'marcksl1': 431,
#  'tssk3': 432,
#  'fam229a': 433,
#  'bsdc1': 434,
#  'zbtb8b': 435,
#  'zbtb8a': 436,
#  'zbtb8os': 437,
#  'rbbp4': 438,
#  'sync': 439,
#  'kiaa1522': 440,
#  'yars1': 441,
#  's100pbp': 442,
#  'fndc5': 443,
#  'hpca': 444,
#  'tmem54': 445,
#  'rnf19b': 446,
#  'ak2': 447,
#  'azin2': 448,
#  'trim62': 449,
#  'znf362': 450,
#  'a3galt2': 451,
#  'phc2': 452,
#  'zscan20': 453,
#  'csmd2': 454,
#  'hmgb4': 455,
#  'c1orf94': 456,
#  'smim12': 457,
#  'gjb5': 458,
#  'gjb4': 459,
#  'gjb3': 460,
#  'gja4': 461,
#  'dlgap3': 462,
#  'tmem35b': 463,
#  'zmym6': 464,
#  'zmym1': 465,
#  'sfpq': 466,
#  'zmym4': 467,
#  'kiaa0319l': 468,
#  'ncdn': 469,
#  'tfap2e': 470,
#  'psmb2': 471,
#  'c1orf216': 472,
#  'clspn': 473,
#  'ago4': 474,
#  'ago1': 475,
#  'ago3': 476,
#  'tekt2': 477,
#  'adprs': 478,
#  'col8a2': 479,
#  'trappc3': 480,
#  'map7d1': 481,
#  'thrap3': 482,
#  'sh3d21': 483,
#  'eva1b': 484,
#  'stk40': 485,
#  'lsm10': 486,
#  'oscp1': 487,
#  'mrps15': 488,
#  'csf3r': 489,
#  'grik3': 490,
#  'zc3h12a': 491,
#  'meaf6': 492,
#  'snip1': 493,
#  'dnali1': 494,
#  'gnl2': 495,
#  'rspo1': 496,
#  'c1orf109': 497,
#  'cdca8': 498,
#  'epha10': 499,
#  'maneal': 500,
#  'yrdc': 501,
#  'c1orf122': 502,
#  'mtf1': 503,
#  'inpp5b': 504,
#  'sf3a3': 505,
#  'fhl3': 506,
#  'utp11': 507,
#  'pou3f1': 508,
#  'rragc': 509,
#  'mycbp': 510,
#  'gja9': 511,
#  'rhbdl2': 512,
#  'akirin1': 513,
#  'ndufs5': 514,
#  'macf1': 515,
#  'bmp8a': 516,
#  'pabpc4': 517,
#  'heyl': 518,
#  'nt5c1a': 519,
#  'hpcal4': 520,
#  'ppie': 521,
#  'bmp8b': 522,
#  'oxct2': 523,
#  'trit1': 524,
#  'mycl': 525,
#  'mfsd2a': 526,
#  'cap1': 527,
#  'ppt1': 528,
#  'rlf': 529,
#  'tmco2': 530,
#  'zmpste24': 531,
#  'col9a2': 532,
#  'smap2': 533,
#  'zfp69b': 534,
#  'zfp69': 535,
#  'exo5': 536,
#  'znf684': 537,
#  'rims3': 538,
#  'nfyc': 539,
#  'kcnq4': 540,
#  'cited4': 541,
#  'ctps1': 542,
#  'slfnl1': 543,
#  'scmh1': 544,
#  'foxo6': 545,
#  'edn2': 546,
#  'hivep3': 547,
#  'guca2b': 548,
#  'guca2a': 549,
#  'foxj3': 550,
#  'rimkla': 551,
#  'zmynd12': 552,
#  'ppcs': 553,
#  'ccdc30': 554,
#  'ppih': 555,
#  'ybx1': 556,
#  'cldn19': 557,
#  'p3h1': 558,
#  'c1orf50': 559,
#  'tmem269': 560,
#  'svbp': 561,
#  'ermap': 562,
#  'znf691': 563,
#  'slc2a1': 564,
#  'fam183a': 565,
#  'ebna1bp2': 566,
#  'cfap57': 567,
#  'tmem125': 568,
#  'c1orf210': 569,
#  'tie1': 570,
#  'mpl': 571,
#  'cdc20': 572,
#  'elovl1': 573,
#  'med8': 574,
#  'szt2': 575,
#  'hyi': 576,
#  'ptprf': 577,
#  'kdm4a': 578,
#  'st3gal3': 579,
#  'artn': 580,
#  'ipo13': 581,
#  'dph2': 582,
#  'atp6v0b': 583,
#  'b4galt2': 584,
#  'ccdc24': 585,
#  'slc6a9': 586,
#  'klf17': 587,
#  'klf18': 588,
#  'dmap1': 589,
#  'eri3': 590,
#  'rnf220': 591,
#  'tmem53': 592,
#  'armh1': 593,
#  'kif2c': 594,
#  'rps8': 595,
#  'best4': 596,
#  'plk3': 597,
#  'dynlt4': 598,
#  'btbd19': 599,
#  'ptch2': 600,
#  'eif2b3': 601,
#  'hectd3': 602,
#  'urod': 603,
#  'zswim5': 604,
#  'hpdl': 605,
#  'mutyh': 606,
#  'toe1': 607,
#  'tesk2': 608,
#  'ccdc163': 609,
#  'mmachc': 610,
#  'prdx1': 611,
#  'akr1a1': 612,
#  'nasp': 613,
#  'ccdc17': 614,
#  'gpbp1l1': 615,
#  'tmem69': 616,
#  'ipp': 617,
#  'mast2': 618,
#  'pik3r3': 619,
#  'tspan1': 620,
#  'p3r3urf': 621,
#  'pomgnt1': 622,
#  'lurap1': 623,
#  'rad54l': 624,
#  'lrrc41': 625,
#  'uqcrh': 626,
#  'nsun4': 627,
#  'faah': 628,
#  'dmbx1': 629,
#  'tmem275': 630,
#  'kncn': 631,
#  'mknk1': 632,
#  'mob3c': 633,
#  'atpaf1': 634,
#  'tex38': 635,
#  'efcab14': 636,
#  'cyp4b1': 637,
#  'cyp4a11': 638,
#  'cyp4x1': 639,
#  'cyp4z1': 640,
#  'cyp4a22': 641,
#  'pdzk1ip1': 642,
#  'tal1': 643,
#  'stil': 644,
#  'cmpk1': 645,
#  'foxe3': 646,
#  'foxd2': 647,
#  'trabd2b': 648,
#  'slc5a9': 649,
#  'spata6': 650,
#  'agbl4': 651,
#  'bend5': 652,
#  'elavl4': 653,
#  'dmrta2': 654,
#  'faf1': 655,
#  'cdkn2c': 656,
#  'c1orf185': 657,
#  'rnf11': 658,
#  'ttc39a': 659,
#  'eps15': 660,
#  'osbpl9': 661,
#  'nrdc': 662,
#  'rab3b': 663,
#  'txndc12': 664,
#  'kti12': 665,
#  'btf3l4': 666,
#  'zfyve9': 667,
#  'cc2d1b': 668,
#  'orc1': 669,
#  'prpf38a': 670,
#  'tut4': 671,
#  'gpx7': 672,
#  'shisal2a': 673,
#  'coa7': 674,
#  'zyg11b': 675,
#  'zyg11a': 676,
#  'echdc2': 677,
#  'scp2': 678,
#  'podn': 679,
#  'slc1a7': 680,
#  'cpt2': 681,
#  'czib': 682,
#  'magoh': 683,
#  'lrp8': 684,
#  'dmrtb1': 685,
#  'glis1': 686,
#  'ndc1': 687,
#  'yipf1': 688,
#  'dio1': 689,
#  'hspb11': 690,
#  'lrrc42': 691,
#  'ldlrad1': 692,
#  'tmem59': 693,
#  'tceanc2': 694,
#  'cdcp2': 695,
#  'cyb5rl': 696,
#  'mrpl37': 697,
#  'ssbp3': 698,
#  'acot11': 699,
#  'fam151a': 700,
#  'mroh7': 701,
#  'ttc4': 702,
#  'pars2': 703,
#  'ttc22': 704,
#  'lexm': 705,
#  'dhcr24': 706,
#  'tmem61': 707,
#  'bsnd': 708,
#  'pcsk9': 709,
#  'usp24': 710,
#  'plpp3': 711,
#  'prkaa2': 712,
#  'fyb2': 713,
#  'c8a': 714,
#  'c8b': 715,
#  'dab1': 716,
#  'oma1': 717,
#  'tacstd2': 718,
#  'mysm1': 719,
#  'jun': 720,
#  'fggy': 721,
#  'hook1': 722,
#  'cyp2j2': 723,
#  'c1orf87': 724,
#  'nfia': 725,
#  'tm2d1': 726,
#  'patj': 727,
#  'l1td1': 728,
#  'kank4': 729,
#  'usp1': 730,
#  'dock7': 731,
#  'angptl3': 732,
#  'atg4c': 733,
#  'foxd3': 734,
#  'alg6': 735,
#  'itgb3bp': 736,
#  'efcab7': 737,
#  'pgm1': 738,
#  'ror1': 739,
#  'ube2u': 740,
#  'cachd1': 741,
#  'raver2': 742,
#  'jak1': 743,
#  'ak4': 744,
#  'dnajc6': 745,
#  'leprot': 746,
#  'lepr': 747,
#  'pde4b': 748,
#  'sgip1': 749,
#  'dynlt5': 750,
#  'insl5': 751,
#  'dnai4': 752,
#  'mier1': 753,
#  'slc35d1': 754,
#  'c1orf141': 755,
#  'il23r': 756,
#  'il12rb2': 757,
#  'serbp1': 758,
#  'gadd45a': 759,
#  'gng12': 760,
#  'diras3': 761,
#  'wls': 762,
#  'rpe65': 763,
#  'depdc1': 764,
#  'lrrc7': 765,
#  'lrrc40': 766,
#  'srsf11': 767,
#  'ankrd13c': 768,
#  'cth': 769,
#  'ptger3': 770,
#  'zranb2': 771,
#  'negr1': 772,
#  'lrriq3': 773,
#  'fpgt': 774,
#  'tnni3k': 775,
#  'lrrc53': 776,
#  'erich3': 777,
#  'cryz': 778,
#  'tyw3': 779,
#  'lhx8': 780,
#  'slc44a5': 781,
#  'acadm': 782,
#  'rabggtb': 783,
#  'msh4': 784,
#  'asb17': 785,
#  'st6galnac3': 786,
#  'st6galnac5': 787,
#  'pigk': 788,
#  'ak5': 789,
#  'zzz3': 790,
#  'usp33': 791,
#  'miga1': 792,
#  'nexn': 793,
#  'fubp1': 794,
#  'dnajb4': 795,
#  'gipc2': 796,
#  'ptgfr': 797,
#  'ifi44l': 798,
#  'ifi44': 799,
#  'adgrl4': 800,
#  'adgrl2': 801,
#  'ttll7': 802,
#  'prkacb': 803,
#  'samd13': 804,
#  'dnase2b': 805,
#  'rpf1': 806,
#  'gng5': 807,
#  'spata1': 808,
#  'ctbs': 809,
#  'ssx2ip': 810,
#  'lpar3': 811,
#  'mcoln2': 812,
#  'dnai3': 813,
#  'mcoln3': 814,
#  'syde2': 815,
#  'c1orf52': 816,
#  'bcl10': 817,
#  'ddah1': 818,
#  'ccn1': 819,
#  'znhit6': 820,
#  'col24a1': 821,
#  'odf2l': 822,
#  'clca2': 823,
#  'clca1': 824,
#  'clca4': 825,
#  'sh3glb1': 826,
#  'selenof': 827,
#  'hs2st1': 828,
#  'lmo4': 829,
#  'pkn2': 830,
#  'gtf2b': 831,
#  'kyat3': 832,
#  'rbmxl1': 833,
#  'gbp3': 834,
#  'gbp1': 835,
#  'gbp2': 836,
#  'gbp7': 837,
#  'gbp4': 838,
#  'gbp5': 839,
#  'gbp6': 840,
#  'lrrc8b': 841,
#  'lrrc8c': 842,
#  'lrrc8d': 843,
#  'znf326': 844,
#  'barhl2': 845,
#  'znf644': 846,
#  'hfm1': 847,
#  'cdc7': 848,
#  'tgfbr3': 849,
#  'brdt': 850,
#  'ephx4': 851,
#  'setsip': 852,
#  'btbd8': 853,
#  'c1orf146': 854,
#  'glmn': 855,
#  'rpap2': 856,
#  'gfi1': 857,
#  'evi5': 858,
#  'rpl5': 859,
#  'dipk1a': 860,
#  'mtf2': 861,
#  'tmed5': 862,
#  'ccdc18': 863,
#  'dr1': 864,
#  'fnbp1l': 865,
#  'bcar3': 866,
#  'dnttip2': 867,
#  'gclm': 868,
#  'abca4': 869,
#  'arhgap29': 870,
#  'abcd3': 871,
#  'f3': 872,
#  'slc44a3': 873,
#  'cnn3': 874,
#  'alg14': 875,
#  'tlcd4': 876,
#  'rwdd3': 877,
#  'ptbp2': 878,
#  'dpyd': 879,
#  'snx7': 880,
#  'plppr5': 881,
#  'plppr4': 882,
#  'palmd': 883,
#  'frrs1': 884,
#  'agl': 885,
#  'slc35a3': 886,
#  'mfsd14a': 887,
#  'sass6': 888,
#  'trmt13': 889,
#  'lrrc39': 890,
#  'dbt': 891,
#  'rtca': 892,
#  'cdc14a': 893,
#  'gpr88': 894,
#  'vcam1': 895,
#  'extl2': 896,
#  'slc30a7': 897,
#  'dph5': 898,
#  's1pr1': 899,
#  'olfm3': 900,
#  'col11a1': 901,
#  'rnpc3': 902,
#  'amy2b': 903,
#  'amy2a': 904,
#  'amy1a': 905,
#  'amy1b': 906,
#  'amy1c': 907,
#  'prmt6': 908,
#  'ntng1': 909,
#  'vav3': 910,
#  'slc25a24': 911,
#  'nbpf4': 912,
#  'nbpf6': 913,
#  'fam102b': 914,
#  'henmt1': 915,
#  'prpf38b': 916,
#  'fndc7': 917,
#  'stxbp3': 918,
#  'aknad1': 919,
#  'gpsm2': 920,
#  'clcc1': 921,
#  'wdr47': 922,
#  'taf13': 923,
#  'tmem167b': 924,
#  'c1orf194': 925,
#  'elapor1': 926,
#  'sars1': 927,
#  'celsr2': 928,
#  'psrc1': 929,
#  'mybphl': 930,
#  'sort1': 931,
#  'psma5': 932,
#  'sypl2': 933,
#  'atxn7l2': 934,
#  'cyb561d1': 935,
#  'amigo1': 936,
#  'gpr61': 937,
#  'gnai3': 938,
#  'gnat2': 939,
#  'ampd2': 940,
#  'gstm4': 941,
#  'gstm2': 942,
#  'gstm1': 943,
#  'gstm5': 944,
#  'gstm3': 945,
#  'eps8l3': 946,
#  'csf1': 947,
#  'ahcyl1': 948,
#  'strip1': 949,
#  'alx3': 950,
#  'ubl4b': 951,
#  'slc6a17': 952,
#  'kcnc4': 953,
#  'rbm15': 954,
#  'slc16a4': 955,
#  'lamtor5': 956,
#  'prok1': 957,
#  'kcna10': 958,
#  'kcna2': 959,
#  'kcna3': 960,
#  'cd53': 961,
#  'lrif1': 962,
#  'dram2': 963,
#  'cept1': 964,
#  'dennd2d': 965,
#  'chi3l2': 966,
#  'chia': 967,
#  'pifo': 968,
#  'ovgp1': 969,
#  'wdr77': 970,
#  'atp5pb': 971,
#  'c1orf162': 972,
#  'tmigd3': 973,
#  'adora3': 974,
#  'rap1a': 975,
#  'inka2': 976,
#  'ddx20': 977,
#  'kcnd3': 978,
#  'cttnbp2nl': 979,
#  'wnt2b': 980,
#  'st7l': 981,
#  'capza1': 982,
#  'mov10': 983,
#  'rhoc': 984,
#  'ppm1j': 985,
#  'tafa3': 986,
#  'slc16a1': 987,
#  'lrig2': 988,
#  'magi3': 989,
#  'phtf1': 990,
#  'rsbn1': 991,
#  'ptpn22': 992,
#  'bcl2l15': 993,
#  'ap4b1': 994,
#  'dclre1b': 995,
#  'hipk1': 996,
#  'olfml3': 997,
#  'syt6': 998,
#  'trim33': 999,
#  ...}

# %%
only_in_all_genes = all_genes_set - adata_genes_set

only_in_adata_genes = adata_genes_set - all_genes_set

# 输出结果
print(f"仅在 all_genes 中存在的基因数量: {len(only_in_all_genes)}")
print(f"仅在 all_genes 中存在的基因: {only_in_all_genes}")

print(f"仅在 adata_genes 中存在的基因数量: {len(only_in_adata_genes)}")
print(f"仅在 adata_genes 中存在的基因: {only_in_adata_genes}")
# Out:
# 仅在 all_genes 中存在的基因数量: 3971
# 仅在 all_genes 中存在的基因: {'nmur2', 'pate3', 'krtap9-3', 'khdc3l', 'golga6a', 'gage12b', 'or52l1', 'fam126a', 'h4c13', 'usp29', 'rbm46', 'aicda', 'spata46', 'riox1', 'sprr2d', 'krtap4-9', 'becn2', 'krtap16-1', 'fgg', 'or4d9', 'scgb1d1', 'magea10', 'or52n2', 'gh2', 'dppa3', 'magea8', 'lgals7', 'serpinb12', 'krtap20-2', 'ssx4b', 'hgh1', 'gpr174', 'gage12e', 'kir2dl4', 'kcnj18', 'ggtlc1', 'fam25c', 'spdye2b', 'pramef12', 'nudt11', 'defb104a', 'golga6l10', 'zscan10', 'casq1', 'fam246b', 'lce2b', 'c17orf64', 'borcs8-mef2b', 'fkbp6', 'sbk2', 'triml1', 'wfdc12', 'cort', 'ifna4', 'tert', 'rbmxl3', 'defb116', 'sftpa2', 'sp7', 'znf763', 'spata31a1', 'trim48', 'c11orf91', 'or8k3', 'slc35g5', 'serpind1', 'tlr8', 'nlrp4', 'or7g1', 'xirp1', 'rimbp3b', 'ccdc116', 'alox15', 'gltpd2', 'fgl1', 'pdc', 'bop1', 'chst5', 'qrfp', 'nbpf4', 'prr20c', 'h2bc8', 'guca1a', 'arhgap11b', 'lcn8', 'c8orf89', 'rps17', 'rnf225', 'spata31d1', 'or52w1', 'pld4', 'dlx6', 'ids', 'ly6l', 'usp17l24', 'pdcd6-ahrr', 'ticam2', 'otos', 'or4d1', 'gdpd2', 'edn3', 'or4x2', 'kiaa0100', 'il17a', 'rbm8a', 'lce2d', 'psma1', 'smim42', 'tm9sf1', 'ccdc166', 'jmjd7', 'slco1b1', 'dgat2l6', 'potee', 'spata31e1', 'or52k1', 'tssk4', 'cidec', 'cdc14c', 'scgb1d4', 'c12orf65', 'pigy', 'specc1l-adora2a', 'b3galt9', 'capns2', 'b3gnt6', 'golga8g', 'ifit1b', 'foxr1', 'or52i2', 'tpsab1', 'krtap5-6', 'mdp1', 'prm1', 'slc35d3', 'tlx3', 'hhatl', 'slc2a2', 'dlx3', 'daz1', 'exoc1l', 'or10d3', 'castor2', 'tril', 'ct47a6', 'spanxn1', 'dnase2b', 'alox12b', 'vsx2', 'nbpf14', 'pramef4', 'slc10a4', 'hnrnpcl3', 'mucl3', 'pcdha10', 'tmem89', 'muc17', 'pcdha6', 'cela2b', 'ten1-cdk3', 'npvf', 'or2a14', 'tbr1', 'lcnl1', 'kdm4f', 'pramef25', 'mt1hl1', 'hbz', 'krt78', 'cfhr5', 'percc1', 'mael', 'or11h1', 'tubb8', 'krtap3-3', 'or10ad1', 'c5orf58', 'c5orf47', 'fgf22', 'fndc11', 'golga8q', 'foxh1', 'chia', 'mageb18', 'nodal', 'rtl4', 'or2h1', 'ssx2b', 'or1g1', 'or2l3', 'vcx', 'foxd4', 'or8h3', 'bahcc1', 'asb12', 'prm2', 'palm2akap2', 'prdm12', 'slc25a53', 'krt84', 'slc35g4', 'lin28a', 'poteb3', 'ascl4', 'mmp13', 'plscr5', 'znf560', 'grxcr2', 'tbc1d3i', 'c10orf105', 'brsk2', 'or4x1', 'catsperz', 'fam71a', 'cacng1', 'or10z1', 'cylc2', 'pom121c', 'ubtfl1', 'pnrc2', 'nphp3-acad11', 'mtrnr2l10', 'cst9l', 'or5k4', 'gng13', 'or1d5', 'soga3', 'frg2c', 'or5w2', 'gjb3', 'pcdhb16', 'spata31a7', 'slc36a3', 'akap4', 'got1l1', 'gdf3', 'actn3', 'dlx1', 'tmem265', 'gkn2', 'ccdc42', 'c12orf66', 'nbpf6', 'mc5r', 'or2i1p', 'tcf24', 'rpe65', 'lhx3', 'or4c16', 'h2ac18', 'mllt6', 'hoxc4', 'rps27ap5', 'cyp1a2', 'sertm2', 'pate1', 'lrrc18', 'fignl2', 'treml2', 'fam160a1', 'ggnbp2', 'cd1e', 'lrtomt', 'ceacam20', 'pydc1', 'mmp23b', 'pip', 'f8a3', 'atf7-npff', 'fam156a', 'mmp8', 'mboat4', 'foxc2', 'tex50', 'galnt4', 'gpr179', 'rbl1', 'nutm2f', 'cdy1b', 'slco1b3', 'spata31a6', 'myod1', 'pcsk1', 'ervv-1', 'pramef33', 'znf750', 'krtap6-2', 'mrgprx1', 'gpr62', 'or13j1', 'ocm2', 'or51g1', 'dlk2', 'cfhr4', 'nt5c1b-rdh14', 'prr33', 'phb', 'adgrd2', 'cdk5r2', 'cbln1', 'c7', 'znf479', 'adh1c', 'or4m1', 'adipoq', 'rgs20', 'lman1l', 'krt33b', 'ctage1', 'ifnw1', 'nxpe4', 'tbc1d3e', 'nutm2a', 'znf670', 'slco6a1', 'lce2a', 'rfpl3', 's100g', 'zic2', 'cgb2', 'c20orf141', 'ltc4s', 'taz', 'nkx3-2', 'h3-2', 'pitx3', 'prr23b', 'pramef11', 'oc90', 'cfap298-tcp10l', 'fam47c', 'usp17l13', 'e2f8', 'h2bc14', 'kif19', 'gage12j', 'slfn14', 'ct45a6', 'cyp2a6', 'smim9', 'ct47a5', 'grp', 'or11g2', 'dcaf8', 'npipa2', 'foxd4l5', 'inhbc', 'vstm2a', 'chkb-cpt1b', 'slc22a13', 'defb110', 'ct45a5', 'c1qtnf9', 'acp4', 'ropn1', 'ces5a', 'slc25a47', 'scrt2', 'kif20a', 'spink8', 'tbc1d26', 'or56b4', 'gdf1', 'nbpf20', 'odaph', 'popdc3', 'or2t5', 'mia-rab4b', 'slc6a14', 'apobec3h', 'rnase13', 'vn1r4', 'krt32', 'adgrf2', 'smco1', 'alox12', 'hcar2', 'cemp1', 'c1ql1', 'prss21', 'adrb3', 'ascl1', 'taf11l4', 'lce5a', 'phgr1', 'igfl3', 'or11h2', 'usp17l10', 'lrrc53', 'foxg1', 'tmem236', 'ppial4g', 'c3orf56', 'tex28', 'pax1', 'or2b3', 'cby3', 'c11orf45', 'hsfy2', 'krt9', 'spata32', 'taf15', 'vcy ...
# 仅在 adata_genes 中存在的基因数量: 4939
# 仅在 adata_genes 中存在的基因: {'rab11b-as1', 'eeig1', 'cldn10-as1', 'ensg00000272953.2', 'efcab13-dt', 'ensg00000271011.1', 'hormad2-as1', 'zranb2-dt', 'psors1c3', 'tpm1-as', 'c21orf91-ot1', 'lpp-as2', 'ensg00000272861.1', 'ensg00000224376.3', 'ensg00000270099.1', 'mir1915hg', 'ensg00000250397.2', 'frmd6-as2', 'linc01503', 'sp2-as1', 'ensg00000272256.1', 'linc02104', 'ensg00000255310.2', 'plcg1-as1', 'plcxd1_ensg00000182378', 'or2a1-as1', 'znf473cr', 'linc00839', 'ensg00000230782.1', 'baz1a-as1', 'myo1b-as1', 'linc02015', 'msra-dt', 'cfap119', 'lciiar', 'arhgap26-as1', 'linc02365', 'linc01213', 'cyp51a1-as1', 'dlg5-as1', 'linc01494', 'linc01508', 'mast3-as1', 'glis2-as1', 'linc02596', 'ensg00000248927.1', 'exoc3-as1', 'rph3al-as2', 'dnmbp-as1', 'dpy19l3-dt', 'septin7-dt', 'map3k20-as1', 'msrb3-as1', 'actmap', 'ensg00000269973.1', 'ajuba-dt', 'linc01643', 'zbtb20-as1', 'h2az1-dt', 'pcdh10-dt', 'itpr2-as1', 'linc01429', 'fgf10-as1', 'ensg00000224239.1', 'cacna1c-as2', 'linc01116', 'wac-as1', 'ensg00000223732.2', 'linc00896', 'kcnip2-as1', 'linc02987', 'ensg00000203472.3', 'ensg00000227496.3', 'ensg00000255158.1', 'znf350-as1', 'cyyr1-as1', 'map3k4-as1', 'ensg00000244055.2', 'ensg00000262560.1', 'znf470-dt', 'ensg00000249476.2', 'ensg00000255839.1', 'nudt19-dt', 'linc02610', 'ensg00000260342.2', 'ensg00000269971.1', 'ensg00000256571.1', 'ensg00000256538.2', 'itgb5-as1', 'ensg00000230387.5', 'lyrm4-as1', 'pdcd4-as1', 'ensg00000260368.1', 'linc01192', 'nutm2b-as1', 'linc00609', 'ensg00000260796.1', 'ensg00000260495.1', 'zng1a', 'ensg00000269635.1', 'ninj2-as1', 'ensg00000273248.2', 'ensg00000203392.3', 'ensg00000227619.3', 'stx5-dt', 'ensg00000250696.5', 'linc01754', 'prkacb-dt', 'ensg00000254288.1', 'ensg00000263823.2', 'faup4', 'ensg00000267723.1', 'linc01063', 'rusc1-as1', 'rn7sl834p', 'ensg00000226281.6', 'ensg00000250186.3', 'fzd10-as1', 'mir4527hg', 'nudt16-dt', 'ensg00000267968.1', 'bltp3a', 'celsr1p1', 'mir30c2', 'ensg00000272463.2', 'ensg00000271926.1', 'nxf5', 'ensg00000225146.1', 'linc02086', 'ensg00000254662.1', 'cox10-dt', 'ensg00000224985.1', 'mettl25b', 'prkcz-as1', 'ensg00000253880.1', 'ensg00000258558.1', 'lncrna-iur', 'ensg00000267868.1', 'ensg00000247970.3', 'ensg00000249655.1', 'ensg00000241409.1', 'ensg00000261888.1', 'magi2-as3', 'ensg00000227857.2', 'ensg00000226471.7', 'ensg00000272787.1', 'ensg00000229178.1', 'chrm3-as2', 'zfp28-dt', 'linc01900', 'trabd-as1', 'bdnf-as', 'ensg00000270277.1', 'vps33b-dt', 'linc02012', 'mir4500hg', 'ensg00000275431.1', 'linc01951', 'linc00484_ensg00000229694', 'ensg00000255476.1', 'ensg00000257553.1', 'linc02762', 'linc02067', 'ensg00000249319.2', 'grpel2-as1', 'scube3-as1', 'ensg00000260510.1', 'mapkapk5-as1', 'ensg00000267222.1', 'linc01169', 'itfg2-as1_ensg00000256150', 'linc02102', 'ensg00000251409.2', 'ensg00000233912.1', 'klf3-as1', 'garin2', 'ensg00000274422.1', 'magoh-dt', 'ensg00000250069.1', 'pank2-as1', 'hmga2-as1', 'ensg00000267552.6', 'ensg00000260878.1', 'map7-as1', 'ensg00000249240.2', 'ensg00000237498.3', 'linc00958', 'fam182a', 'ensg00000246090.9', 'gata2-as1', 'linc02752', 'ensg00000259543.1', 'ensg00000230303.6', 'linc00970', 'linc01841', 'heatr5a-dt', 'disc1fp1', 'ensg00000224746.2', 'a2ml1-as1', 'ensg00000263300.1', 'xpc-as1', 'slc35e2a', 'ensg00000273448.1', 'ensg00000267688.1', 'ensg00000232536.1', 'ensg00000238272.1', 'linc02615', 'ensg00000255968.1', 'ensg00000258122.1', 'ensg00000196566.2', 'ensg00000259113.1', 'ensg00000260038.1', 'mir302chg', 'ensg00000245025.3', 'ensg00000229591.1', 'linc01801', 'linc01482', 'ensg00000261098.1', 'ensg00000260095.1', 'gaplinc', 'linc02884', 'ensg00000232555.2', 'linc02696', 'linc02226', 'ensg00000257894.2', 'mt-ti', 'ensg00000259682.1', 'ensg00000272121.1', 'hdac11-as1', 'ensg00000267980.1', 'ensg00000266490.1', 'linc01284', 'bfsp2-as1', 'ensg00000215304.3', 'ensg00000258504.2', 'ensg00000271199.1', 'hcg25', 'ensg00000228648.1', 'ensg00000256824.1', 'ensg00000285938.1', 'ensg00000255320.2', 'nrav', 'ensg00000246331.2', 'en ...

# %%
import numpy as np
from scipy.sparse import csr_matrix

# Initialize a mapping from gene names in adata to their column indices
adata_gene_to_index = {gene: idx for idx, gene in enumerate(adata_genes_lower)}

# Create an array to map adata.X column indices to new_data column indices
adata_to_new_data_indices = -1 * np.ones(adata.X.shape[1], dtype=int)
for idx, gene in enumerate(adata_genes_lower):
    if gene in gene_to_index:
        adata_to_new_data_indices[idx] = gene_to_index[gene]



# Extract data from adata.X without converting it to a dense array
data = adata.X.data
indices = adata.X.indices
indptr = adata.X.indptr

# Map the column indices to the new indices in new_data
mapped_indices = adata_to_new_data_indices[indices]

# Filter out entries where the mapping is invalid (-1)
valid_entries = mapped_indices != -1
new_data_values = data[valid_entries]
new_data_indices = mapped_indices[valid_entries]

# Build the new indptr array for the new_data matrix
new_indptr = np.zeros(adata.X.shape[0] + 1, dtype=int)


for i in range(adata.X.shape[0]):
    row_start = indptr[i]
    row_end = indptr[i + 1]
    valid_count = np.sum(valid_entries[row_start:row_end])
    new_indptr[i + 1] = new_indptr[i] + valid_count


# Construct the new_data sparse matrix
new_data = csr_matrix(
    (new_data_values, new_data_indices, new_indptr),
    shape=(adata.X.shape[0], len(all_genes)),
    dtype=np.float32
)
new_data = new_data.toarray()

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import train_test_split


label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(adata.obs['cell_type'])  # 预先编码标签


random_seed = 42
X_train_val, X_test, y_train_val, y_test = train_test_split(
    new_data, labels_encoded, test_size=0.15, random_state=random_seed)


X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1765, random_state=random_seed)  # 0.1765 是为了让验证集占 15%

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

estim.model.eval()
with torch.no_grad():
    X_train_tensor = torch.tensor(X_train).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    train_embeddings = estim.model.encoder(X_train_tensor).detach().cpu().numpy()
    test_embeddings = estim.model.encoder(X_test_tensor).detach().cpu().numpy()
# Out:
# cuda

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

    

    # 初始化和训练KNN分类器
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_embeddings, y_train)
    
    # 模型预测
predictions = knn.predict(test_embeddings)

    # 计算准确率和 F1 分数
accuracy = accuracy_score(y_test, predictions)
print(f"KNN Accuracy on Test Data: {accuracy}")
f1 = f1_score(y_test, predictions, average='weighted')
print(f"Weighted F1 Score: {f1}")
    
macro_f1 = f1_score(y_test, predictions, average='macro')
print(f'Macro F1 Score: {macro_f1}')

    # 计算随机猜测的准确率
class_probabilities = np.bincount(y_test) / len(y_test)
random_accuracy = np.sum(class_probabilities ** 2)
print(f"Random Guess Accuracy: {random_accuracy}")

    # 生成分类报告
report = classification_report(y_test, predictions, target_names=label_encoder.classes_)
print(report)
# Out:
# KNN Accuracy on Test Data: 0.5617577197149644
# Weighted F1 Score: 0.5301724874185125
# Macro F1 Score: 0.24745223067922048
# Random Guess Accuracy: 0.2927884776016484
#                                                            precision    recall  f1-score   support
#
#                           blood vessel smooth muscle cell       0.17      0.10      0.12       852
#                                          endothelial cell       0.62      0.79      0.69     13511
#                  kidney collecting duct intercalated cell       0.25      0.18      0.21      1032
#                     kidney collecting duct principal cell       0.52      0.55      0.53      2040
#           kidney distal convoluted tubule epithelial cell       0.31      0.17      0.22       618
#                                      kidney granular cell       0.10      0.01      0.02       105
#                            kidney interstitial fibroblast       0.25      0.06      0.10       781
# kidney loop of Henle thick ascending limb epithelial cell       0.52      0.53      0.53      1410
#         kidney proximal convoluted tubule epithelial cell       0.53      0.44      0.48      4160
#                                                 leukocyte       0.41      0.19      0.26      1905
#                                                macrophage       0.23      0.05      0.08       295
#                              macula densa epithelial cell       0.00      0.00      0.00        10
#                                            mesangial cell       0.00      0.00      0.00        11
#                                                  podocyte       0.43      0.16      0.23       214
#
#                                                  accuracy                           0.56     26944
#                                                 macro avg       0.31      0.23      0.25     26944
#                                              weighted avg       0.52      0.56      0.53     26944
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/hanchuangyi/miniconda3/envs/ssl/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
with torch.no_grad():
    new_data_tensor = torch.tensor(new_data).float().to(device)
    SSL_embeddings = estim.model.encoder(new_data_tensor).detach().cpu().numpy()
new_adata = sc.read_h5ad(data_dir)
new_adata.obsm[f'SSL_GP_ZS_{random_seed}'] = SSL_embeddings
new_adata.uns[f'GP_ZS_y_test_{random_seed}'] = y_test
new_adata.uns[f'GP_ZS_predictions_{random_seed}'] = predictions
new_adata.uns[f'GP_ZS_target_names_{random_seed}'] = label_encoder.classes_
new_adata.write_h5ad(data_dir)

# %%
import pandas as pd
import os
import re

# 当前 Notebook 文件名
notebook_name = "slide_seq_human_kidney_GP_mask_zero_shot_42.ipynb"

# 初始化需要打印的值
init_train_loss = train_losses[0] if 'train_losses' in globals() else None
init_val_loss = val_losses[0] if 'val_losses' in globals() else None
converged_epoch = len(train_losses) - patience if 'train_losses' in globals() else None
converged_val_loss = best_val_loss if 'best_val_loss' in globals() else None

# 打印所有所需的指标
print("Metrics Summary:")
if 'train_losses' in globals():
    print(f"init_train_loss\tinit_val_loss\tconverged_epoch\tconverged_val_loss\tmacro_f1\tweighted_f1\tmicor_f1")
    print(f"{init_train_loss:.3f}\t{init_val_loss:.3f}\t{converged_epoch}\t{converged_val_loss:.3f}\t{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")
else:
    print(f"macro_f1\tweighted_f1\tmicor_f1")
    print(f"{macro_f1:.3f}\t{f1:.3f}\t{accuracy:.3f}")

# 保存结果到 CSV 文件
output_data = {
    'dataset_split_random_seed': [int(random_seed)],
    'dataset': ['slide_seq_human_kidney'],
    'method': [re.search(r'kidney_(.*?)_\d+', notebook_name).group(1)],
    'init_train_loss': [init_train_loss if init_train_loss is not None else ''],
    'init_val_loss': [init_val_loss if init_val_loss is not None else ''],
    'converged_epoch': [converged_epoch if converged_epoch is not None else ''],
    'converged_val_loss': [converged_val_loss if converged_val_loss is not None else ''],
    'macro_f1': [macro_f1],
    'weighted_f1': [f1],
    'micor_f1': [accuracy]
}
output_df = pd.DataFrame(output_data)

# 保存到当前目录下名为 results 的文件夹中
if not os.path.exists('results'):
    os.makedirs('results')

csv_filename = f"results/{os.path.splitext(notebook_name)[0]}_results.csv"
output_df.to_csv(csv_filename, index=False)
# Out:
# Metrics Summary:
# macro_f1	weighted_f1	micor_f1
# 0.247	0.530	0.562
